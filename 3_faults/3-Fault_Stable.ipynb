# %% [markdown]
# \***\*============================GRAPH PREPROCESSING============================**

# %%
import networkx as nx
import matplotlib.pyplot as plt
import pickle

# Define the Edge class
class Edge:
    def __init__(self, u, v, weight):
        self.u = u
        self.v = v
        self.weight = weight

# %%
# from random import randint
# G = nx.Graph()

# # Read the file and create edges with random weights
# file_path = 'small_dataset.txt'  # Replace with the actual file path
# # edges = []
# with open(file_path, 'r') as file:
#     file_contents = file.readlines()
#     num_lines = len(file_contents)
#     print(f"Number of lines: {num_lines}")
#     for i, line in enumerate(file_contents):
#         node1, node2 = map(int, line.split())
#         weight = float(randint(1, 99)) + ((i+1) * (1 / (num_lines -1)))
#     # Ensure the weight is displayed with full precision
#         # print(f"Weight: {weight:.50f}")
#         # edges.append(Edge(node1, node2, weight))
#         G.add_edge(node1, node2, weight=weight)
        
        

# # Create a NetworkX graph and add edges
# # for edge in edges:
# #     G.add_edge(edge.u, edge.v, weight=edge.weight)
#     # print(f"Edge: {edge.u} - {edge.v}, Weight: {edge.weight:.1000f}")

# # Preprocess the graph
# D = dict(nx.all_pairs_dijkstra_path_length(G, weight='weight'))
# with open('D.pkl', 'wb') as f:
#     pickle.dump(D, f)

# # # Create a new figure with a larger size
# # plt.figure(figsize=(60, 60))

# # # Draw the graph using the spring_layout
# # pos = nx.spring_layout(G)
# # nx.draw(G, pos, with_labels=True, node_color="yellow", node_size=300, edge_color="gray")

# # # Draw edge labels
# # edge_labels = nx.get_edge_attributes(G, "weight")
# # nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels, font_size=6)

# # plt.show()

# with open('graph.pkl', 'wb') as f:
#     pickle.dump(G, f)

# %%
# Load G and D from the local files
with open('../graph.pkl', 'rb') as f:
    G = pickle.load(f)
    

with open('../D.pkl', 'rb') as f:   
    D = pickle.load(f)
# with open('shortest_paths.pkl', 'rb') as f:
#     shortest_paths = pickle.load(f)

# %%
import networkx as nx
import plotly.graph_objects as go

def create_interactive_graph(G):
    # Create a spring layout for node positions
    pos = nx.spring_layout(G)
    
    # Create edge traces
    edge_x = []
    edge_y = []
    edge_text = []
    edge_weights = []
    
    for edge in G.edges():
        x0, y0 = pos[edge[0]]
        x1, y1 = pos[edge[1]]
        edge_x.extend([x0, x1, None])
        edge_y.extend([y0, y1, None])
        weight = G.edges[edge]['weight']
        edge_weights.append(weight)
        edge_text.append(f"Weight: {int(weight)}")
    
    edge_trace = go.Scatter(
        x=edge_x, y=edge_y,
        line=dict(width=2, color='#888'),
        hoverinfo='text',
        text=edge_text,
        mode='lines+text',
        textposition='middle center',
        textfont=dict(size=10)
    )
    
    # Add edge weight annotations
    annotations = []
    for edge in G.edges():
        x0, y0 = pos[edge[0]]
        x1, y1 = pos[edge[1]]
        weight = G.edges[edge]['weight']
        annotations.append(dict(
            x=(x0 + x1) / 2,
            y=(y0 + y1) / 2,
            xref='x',
            yref='y',
            text=str(int(weight)),
            showarrow=False,
            font=dict(size=10)
        ))
    
    # Create node traces
    node_x = []
    node_y = []
    node_text = []
    
    for node in G.nodes():
        x, y = pos[node]
        node_x.append(x)
        node_y.append(y)
        node_text.append(f"Node: {node}")
    
    node_trace = go.Scatter(
        x=node_x, y=node_y,
        mode='markers+text',
        hoverinfo='text',
        text=[str(node) for node in G.nodes()],
        textposition='middle center',
        marker=dict(
            showscale=False,
            color='yellow',
            size=40,
            line_width=2,
            line=dict(color='black', width=1)
        ),
        textfont=dict(size=12)
    )
    
    # Create the figure with larger size
    fig = go.Figure(
        data=[edge_trace, node_trace],
        layout=go.Layout(
            title='Interactive Graph Visualization',
            showlegend=False,
            hovermode='closest',
            margin=dict(b=20, l=20, r=20, t=40),
            xaxis=dict(showgrid=False, zeroline=False, showticklabels=False),
            yaxis=dict(showgrid=False, zeroline=False, showticklabels=False),
            plot_bgcolor='white',
            width=1200,  # Increased width
            height=800,  # Increased height
            annotations=annotations
        )
    )
    
    return fig

# Create and display the interactive graph
fig = create_interactive_graph(G)
fig.show(figsize=(40, 40))

# %%
# open in browser

fig.show(renderer="browser")

# %% [markdown]
# =================================== Distance Oracle =====================================

# %%
# class DistanceOracle:
#     def __init__(self,distances=None):
#         if distances is None:
#             self.data = {}
#         else:
#             self.data = distances
#     def get_distance(self, u, v):
#         return self.data.get(u, {}).get(v, float("inf"))
#     def __getitem__(self, key):
#         return self.data[key]
#     def add_distance(self, u, v, distance):
#         if u not in self.data:
#             self.data[u] = {}
#         self.data[u][v] = distance

# %%
# distance_oracle = DistanceOracle(D)

# %% [markdown]
# \*\*---------------------------------SHORTEST PATH function and Store-------------------------------

# %%
# import networkx as nx

# def store_shortest_paths(G):
#     # Use NetworkX's built-in function to compute all pairs shortest paths
#     all_pairs_paths = dict(nx.all_pairs_dijkstra_path(G, weight='weight'))
    
#     # Flatten the dictionary to match the desired output format
#     shortest_paths = {}
#     for u, paths in all_pairs_paths.items():
#         for v, path in paths.items():
#             shortest_paths[(u, v)] = path
    
#     return shortest_paths

# # Example usage
# shortest_paths = store_shortest_paths(G)

# %%
# with open('shortest_paths.pkl', 'wb') as f:
#     pickle.dump(shortest_paths, f)

# %%
with open('../shortest_paths.pkl', 'rb') as f:  
    shortest_paths = pickle.load(f)

# %%
with open('../txu_dict.pkl', 'rb') as f:
    txu_dict = pickle.load(f)

# %% [markdown]
# ---------------------------------POWER_OF_2 FUNCTION--------------------------------

# %%
import math

def nearest_power_of_2(x):
    if x <= 0:
        return 0 # Return 1 for non-positive input
    elif math.isinf(x):
        return float("inf")  # Return infinity for infinite input
    else:
        return 2 ** math.floor(math.log2(x))

# %%
# nearest_power_of_2(117)

# %% [markdown]
# --------------------------------FIND_JUMP FUNCTION--------------------------------

# %%
def FINDJUMP(P, F):
    X = []  # Initialie X
    if not P:
        return[]
    x = P[0]
    X.append(x)
    vertices = F
   
    while True:
        u = min(vertices, key=lambda v: nearest_power_of_2(D[x][v]))
        
        distance= max(1, nearest_power_of_2(D[x][u]))

        y = None
        for vertex in P[P.index(x) + 1:]:
            if D[x][vertex] >= distance:
                y = vertex
                break  
        if y is not None:
            X.append(y)
            x = y
        else:
            break
    return X

# %% [markdown]
# **------------------------------MAXIMIZER FUNCTION--------------------------------
# **

# %%
def get_edge_weight(G, u, v):
    if G.has_edge(u, v):
        return G[u][v].get('weight', float('inf'))  # Provide a default value if 'weight' is missing
    else:
        return float('inf')

# %%
def maximizer(G, x, y, d1, d2):
    G = G.copy()
    max_edges = set()
    edges_set = set()
    max_xy_edge = None
    max_xy_path = None
    max_xy_path_new = None

    # Cache distance calculations
    # distance_cache = {}

    # def get_distance_cached(node1, node2):
    #     if (node1, node2) not in distance_cache:
    #         distance_cache[(node1, node2)] = distance_oracle.get_distance(node1, node2)
    #     return distance_cache[(node1, node2)]

    if nx.has_path(G, x, y):
        path = shortest_paths[(x, y)]
        for i in range(len(path) - 1):
            u = path[i]
            v = path[i + 1]
            edges_set.add((u, v))

    for u, v in edges_set:
        # if get_distance_cached(x, u) >= d1 and get_distance_cached(y, v) >= d2:
        #     max_edges.add((u, v))
        if (D[x][u] >= d1 and D[y][v] >= d2) :
        
            max_edges.add((u, v))   

    max_xy_distance = float('-inf')
    for u, v in max_edges:
        edge_data = G.get_edge_data(u, v)
        if G.has_edge(u, v):
            G.remove_edge(u, v)
        # D = preprocess_graph(G)
        # distance_oracle_new = DistanceOracle(D)
        if nx.has_path(G, x, y):
            xy_path = nx.dijkstra_path(G, x, y, weight='weight')
            max_uv_distance = sum(
                get_edge_weight(G, xy_path[i], xy_path[i + 1])
                for i in range(len(xy_path) - 1)
            )
            if max_uv_distance > max_xy_distance:
                max_xy_edge = (u, v)
                max_xy_path = xy_path
                max_xy_distance = max_uv_distance
        G.add_edge(u, v, **edge_data)   

    if max_xy_path is not None:
        s = 0
        max_xy_path_new = []
        f = 1
        i_edge = 0
        i_end = None
        for i in range(len(max_xy_path) - 1):
            u = max_xy_path[s]
            v = max_xy_path[i + 1]
            uv_distance = round(D[u][v] , 7)
            
            
            uv_distance_path = sum(
                get_edge_weight(G, max_xy_path[j], max_xy_path[j + 1])
                for j in range(s, i + 1)
            )
            
            uv_distance_path = round(uv_distance_path, 7)
            if uv_distance < uv_distance_path:
                if i < (len(max_xy_path) - 2):
                    s_to_a_path = [u]
                    intermediate_edge = (v, max_xy_path[i + 2])
                    i_end = max_xy_path[i + 2]
                    s_to_a_path.append(max_xy_path[i])
                    max_xy_path_new.append(s_to_a_path)
                    max_xy_path_new.append(intermediate_edge)
                    s = i + 2
                    i_edge+=1
                    if i_edge == f:
                        break
                    
                    
        max_xy_path_new.append([i_end, max_xy_path[-1]])

        if len(max_xy_path_new) == 1:
            max_xy_path_new = [max_xy_path]

    return max_xy_edge, max_xy_path_new
    # return max_xy_edge, max_xy_path

# %%
maximizer(G , 15 , 2 , 64 , 0)
# Out:
# ((44, 18), [[15, 42, 19, 37, 2]])

# %% [markdown]
# ==============================MAXIMIZER Storage=========================================

# %%
def find_max_distance(G, distance_oracle):
    max_distance = float("-inf")
    for key1, value1 in D.items():
        for key2, value2 in value1.items():
            if value2 > max_distance:
                max_distance = value2
    return max_distance

# %%
max_d_value = int(find_max_distance(G, D))
d1_d2_list = [0]
i = nearest_power_of_2((max_d_value))


while i >= 1:
    d1_d2_list.append(i)
    i //= 2
# print(max_d_value)

# %%
print(d1_d2_list)
# Out:
# [0, 128, 64, 32, 16, 8, 4, 2, 1]

# %%
# import networkx as nx
# import numpy as np
# from concurrent.futures import ProcessPoolExecutor , as_completed
# import tqdm
# import time
# import os


# # Initialize performance tracking
# start_time = time.time()

# # Initialize dictionary to store results
# maximizer_dict = {}

# def process_chunk(chunk_data):
#     """Process a chunk of node pairs using CPU"""
#     chunk_results = {}
#     for x, y, d1, d2 in chunk_data:
#         try:
#             result = maximizer(G, x, y, d1, d2)
#             if result is not None:
#                 chunk_results[(x, y, d1, d2)] = result
#         except Exception as e:
#             continue
#     return chunk_results

# # Generate combinations efficiently
# nodes = list(G.nodes())
# combinations = [
#     (x, y, d1, d2)
#     for x in nodes
#     for y in nodes
#     for d1 in d1_d2_list
#     for d2 in d1_d2_list
#     if x != y
# ]

# # Calculate optimal chunk size based on CPU cores
# n_cores = os.cpu_count()
# chunk_size = max(1, len(combinations) // (n_cores * 4))
# chunks = np.array_split(combinations, len(combinations) // chunk_size)

# # Process chunks using ProcessPoolExecutor for true parallelism
# with ProcessPoolExecutor() as executor:
#     futures = [executor.submit(process_chunk, chunk) for chunk in chunks]
    
#     for future in tqdm.tqdm(
#         as_completed(futures), 
#         total=len(futures),
#         desc="Processing pairs"
#     ):
#         results = future.result()
#         # print(results)
#         maximizer_dict.update(results)

# # Calculate and print performance metrics
# end_time = time.time()
# total_time = end_time - start_time
# pairs_processed = len(combinations)
# pairs_successful = len(maximizer_dict)

# print(f"\nPerformance Summary:")
# print(f"Total time: {total_time:.2f} seconds")
# print(f"Pairs processed: {pairs_processed}")
# print(f"Successful pairs: {pairs_successful}")
# print(f"Success rate: {(pairs_successful/pairs_processed)*100:.2f}%")

# %%
# print(maximizer_dict)

# %%
# import networkx as nx
# from concurrent.futures import ThreadPoolExecutor, as_completed
# import tqdm # Import tqdm to display a progress bar


# # Initialize a dictionary to store the maximizer output
# maximizer_dict = {}

# # Store the maximizer function reference directly
# maximizer_function = maximizer  # Replace 'maximizer' with the actual function name

# # Collect errors to print after the loop
# errors = []

# # Define a function to process a single pair of nodes
# def process_pair(G, x, y, d1, d2):
#     try:
#         result = maximizer_function(G, x, y, d1, d2)
#         if result is not None:
#             max_edge, max_path = result
#             return (x, y, d1, d2), (max_edge, max_path)
#     except nx.NetworkXNoPath:
#         return (x, y, d1, d2), None

# # Use ThreadPoolExecutor to parallelize the computation
# nodes = list(G.nodes)

# with ThreadPoolExecutor() as executor:
#     futures = []
#     for x in nodes:
#         for y in nodes:
#             if x != y:
#                 for d1 in d1_d2_list:
#                     for d2 in d1_d2_list:
#                         futures.append(executor.submit(process_pair, G, x, y, d1, d2))

#     for future in tqdm.tqdm(as_completed(futures), total=len(futures)):
#         key, result = future.result()
#         if result is not None:
#             maximizer_dict[key] = result
#         else:
#             errors.append(f"No path between {key[0]} and {key[1]} for d1: {key[2]}, d2: {key[3]}.")

# # Print all errors after the loop
# for error in errors:
#     print(error)

# # print(maximizer_dict)

# %%
# with open('maximizer_dict.pkl', 'wb') as f:
#     pickle.dump(maximizer_dict, f)

# %%
# load maximizer_dict from the local file   
with open('../maximizer_dict.pkl', 'rb') as f:  
    maximizer_dict = pickle.load(f)

# %% [markdown]
# ===============================MAIN: QUERY FUNCTION====================================

# %%
def is_valid_path(G, path):
    return all(G.has_edge(path[i], path[i + 1]) for i in range(len(path) - 1)) and (
        len(path) < 2 or G.has_edge(path[-2], path[-1])
    )
def remove_duplicates(lst):
    seen = set()
    result = []
    for item in lst:
        if item not in seen:
            seen.add(item)
            result.append(item)
    return result
def QUERY(G, s, t, e):
    if e == []:
        try:
            return shortest_paths[(s, t)]
        except KeyError:
            print(f"Shortest path for ({s}, {t}) not found in shortest_paths.")
            return []
        # return shortest_paths[(s, t)]
    # Check if the edge e is in the graph
    if isinstance(e, list):
        e.u, e.v = e
    if not (G.has_edge(e.u, e.v) or G.has_edge(e.v, e.u)):
        # print("The edge to avoid is not in the graph.")
        return shortest_paths[(s, t)]

    # Check if there is a valid path between s and t
    if shortest_paths[(s, t)] is None and shortest_paths[(t, s)] is None:
        print("There is no valid path between the source and destination vertices.")
        return [], float("inf")
    # print(f"shortest_paths[(s,t)]={shortest_paths[(s, t)]}")
    JUMP_st = FINDJUMP(shortest_paths[(s, t)], [e.u, e.v])
    JUMP_ts = FINDJUMP(shortest_paths[(t, s)], [e.u, e.v])
    # print(f"JUMP_st={JUMP_st}, JUMP_ts={JUMP_ts}")
    final_shortest_path = []
    shortest_path_distance = float("inf")
    for x in JUMP_st:
        for y in JUMP_ts:
            if x == y:
                continue
            # print(f"x={x}, y={y}")
            vertices = [e.u, e.v]

            d1 = min(nearest_power_of_2(D[x][a]) for a in vertices   )

            d2 = min(nearest_power_of_2(D[y][a]) for a in vertices) 
            # print(f"d1={d1}, d2={d2}")
            e_star, xy_e_star = maximizer_dict[(x, y, d1, d2)]
            # e_star, xy_e_star = maximizer(G , x, y, d1, d2)
            

            if xy_e_star is None:
                xy_e_star = []
            elif len(xy_e_star)> 2:
                # Flatten the list of lists
                xy_e_star = shortest_paths[(xy_e_star[0][0], xy_e_star[0][1])] + [xy_e_star[1][0]] + shortest_paths[(
                    # print(f"xy_e_star={xy_e_star}")
                    xy_e_star[2][0], xy_e_star[2][1])]
            else: 
                xy_e_star = xy_e_star[0]
            sx_path = shortest_paths[(s, x)]
            yt_path = shortest_paths[(y, t)]
            # print(f"sx_path={sx_path}, yt_path={yt_path}")
            # if sx_path is None or yt_path is None:
            #     continue  # Skip if there is no valid path from s to x or y to t
            if sx_path is None:
                sx_path = [x]
            if yt_path is None:
                yt_path = [y]
            
            p_distance = float("inf")
            P = sx_path + xy_e_star[1:-1] + yt_path
            # P = remove_duplicates(sx_path + xy_e_star + yt_path)
            
            # if y==s and xy_e_star != []:
            #     P = xy_e_star[::-1] + shortest_paths[(x, t)]
            #     if x==t:
            #         P = xy_e_star[::-1] 
            # elif xy_e_star != [] and D[s][y] < D[x][s]:
            #     P = shortest_paths[(s, y)] + xy_e_star[::-1] + shortest_paths[(x, t)]
            #     if s in xy_e_star and xy_e_star.index(s) > 0:
            #         s_index  = xy_e_star[::-1].index(s) 
            #         p1 = xy_e_star[::-1][s_index:]    
            #         p2 = shortest_paths[(x, t)]
            #         P = p1 + p2
            P = remove_duplicates(P)
            
            # print(f"P={P}")
            if not is_valid_path(G, P):
                continue
            
            if is_valid_path(G, P):
                p_distance = sum(
                    get_edge_weight(G, P[i], P[i + 1]) for i in range(len(P) - 1)
                )

            p_edges = [(P[i], P[i+1]) for i in range(len(P) - 1)]
            if ((e.u , e.v) not in p_edges and (e.v , e.u) not in p_edges ) and (p_distance < shortest_path_distance):
                    final_shortest_path = P
                    # print(f"shortest_path1={final_shortest_path}")
                    shortest_path_distance = p_distance
    return final_shortest_path

# %%
# # G_copy = G.copy()   
def cross_check(G, s, t, e_u, e_v):
    G_copy = G.copy()
    edge_exists = G_copy.has_edge(e_u, e_v)
    if edge_exists:
        edge_data = G_copy.get_edge_data(e_u, e_v)
        G_copy.remove_edge(e_u, e_v)
        # print(f"Removed edge ({e_u}, {e_v}) from the graph.")
        
    if not nx.has_path(G_copy, s, t):
        # print("No path exists between the source and destination vertices.")
        return []

    st_path = nx.dijkstra_path(G_copy, s, t, weight='weight')
    
    
    if edge_exists:
        G_copy.add_edge(e_u, e_v, **edge_data)
        # print(f"Added edge ({e_u}, {e_v}) back to the graph.")



    return st_path

# # cross_check(G, 1, 435, 236, 122)

# %%
import random   
import time
from tqdm import tqdm   

def test_query(G, s, t, e_u, e_v):
    # print(f"shortest st path: {shortest_paths[(s, t)]}")    
    # print(f"Source: {s}, Destination: {t}, Edge to avoid: {e_u}-{e_v}")
    Q_time = time.time()
    P1 = QUERY(G , s, t, Edge(e_u, e_v, get_edge_weight(G, e_u, e_v)))
    wp1 = sum(get_edge_weight(G, P1[i], P1[i + 1]) for i in range(len(P1) - 1))
    Q_time = time.time() - Q_time
    
    C_time = time.time()
    P2 = cross_check(G, s, t, e_u, e_v)
    wp2 = sum(get_edge_weight(G, P2[i], P2[i + 1]) for i in range(len(P2) - 1))
    C_time = time.time() - C_time
    # print(P1 , wp1)
    # print(f"QUERY time: {Q_time:.6f} seconds")
    # print(P2 , wp2)
    # print(f"Cross-check time: {C_time:.6f} seconds")
    
    if P1 != P2:
        print("Paths dont match.")
        print(f"shortest st path: {shortest_paths[(s, t)]}")    
        print(f"Source: {s}, Destination: {t}, Edge to avoid: {e_u}-{e_v}")
        print(P1 , wp1)
        print(f"QUERY time: {Q_time:.6f} seconds")
        print(P2 , wp2)
        print(f"Cross-check time: {C_time:.6f} seconds")
    
    # else:
    #     print(f"shortest st path: {shortest_paths[(s, t)]}")    
    #     print(f"Source: {s}, Destination: {t}, Edge to avoid: {e_u}-{e_v}")
    #     print(P1 , wp1)
    #     print(f"QUERY time: {Q_time:.6f} seconds")
    #     print(P2 , wp2)
    #     print(f"Cross-check time: {C_time:.6f} seconds")
    #     return print("***********************Paths do not match*****************************.\n")
   
   
print("=================Single fault Query test=====================") 
print("=============================================================")
for i in range(10):
    # print(f"Test {i+1}:")
    s = random.randint(0, 49)
    t = random.randint(0, 49)
    if s == t:
        t = (t + 1) % 50
    if (s, t) not in shortest_paths:
        continue
    e_u , e_v = random.sample(shortest_paths[(s, t)], 2)
    test_query(G, s, t, e_u, e_v)
    # print("\n")
    # print("=============================================================\n")
# Out:
# =================Single fault Query test=====================
# =============================================================

# %% [markdown]
# #**-----------------2-fault distance oracle----------------**

# %% [markdown]
# ##Basic Function

# %%
# f = 2

# %%
def edge_in_path(p, F2):
    if len(p) < 2:
        return False
    p_edges = [(p[i], p[i+ 1]) for i in range(len(p) - 1)]
    for edge in F2:
        if (edge.u ,edge.v) in p_edges or (edge.v , edge.u) in p_edges:
            return True
    return False
# def bfs_tree_of_S_rooted_x(graph, s, x):
#     # Generate BFS tree rooted at x
#     bfs_tree_s = nx.bfs_tree(graph, s)
#     # Check if u is in the BFS tree rooted at x
#     if x in bfs_tree_s.nodes:
#         # BFS tree rooted at u from the BFS tree rooted at s
#         bfs_tree_x = nx.bfs_tree(bfs_tree_s, x)
#         bfs_tree_nodes = list(bfs_tree_x.nodes)
#         return bfs_tree_nodes
#     else:
#         # print(f"Node {x} is not in the BFS tree rooted at {s}")
#         return None

def intact_from_failure_path(path, F):
    if path is None:
        return False
    if len(path)==1:
        return False

    path_dist = D[path[0]][path[-1]]

    if len(F) == 0:
        return True


    for edge in F:
        if (D[path[0]][edge.u] + G[edge.u][edge.v]["weight"] + D[path[-1]][edge.v]) == path_dist or (D[path[0]][edge.v] + G[edge.u][edge.v]["weight"] + D[path[-1]][edge.u]) == path_dist:

            return False
        
    return True


    return True
def intact_from_failure_tree(T, F):
    # Check if F is empty
    if T is None:
        # print("bfs_tree_of_S_rooted_x returned None")
        return True
    if not F:
        return True
    
    if isinstance(F, list) and len(F) == 2 and all(isinstance(x, int) for x in F):
        if F[0] in T or F[1] in T:
            return False
        return True

    # Check if any vertex in F is in the tree T
    for edge in F:
        # Unpack edge into u and v
        if isinstance(edge, Edge):
            u, v = edge.u, edge.v
        elif isinstance(edge, tuple) or isinstance(edge, list):
            u, v = edge
        else:
            print(f"Unexpected edge type: {type(edge)}")
            return False

        if u in T or v in T:
            return False

    return True
def single_edge_in_path(p, F2):
    if F2 is None or F2 == []:
        return False
    if p is not None:
        p_edges = [(p[i], p[i + 1]) for i in range(len(p) - 1)]
        
        for edge in F2:
            # unpack edge into u and v
            if isinstance(edge, Edge):
                u, v = edge.u, edge.v
            else:
                u,v = edge
            # check if the edge is in the path
            if (u, v) in p_edges or (v, u) in p_edges:
                return True
            
        return False

# %%
import heapq

def bfs_tree_with_sorting(G, root):
    tree = nx.DiGraph()
    visited = set()
    priority_queue = [(0, root, None)]  # (distance, node, parent)

    while priority_queue:
        distance, node, parent = heapq.heappop(priority_queue)
        if node not in visited:
            visited.add(node)
            if parent is not None:
                tree.add_edge(parent, node)
            for neighbor in G.neighbors(node):
                if neighbor not in visited:
                    edge_weight = G[node][neighbor].get('weight', 1)  # Default weight is 1 if not specified
                    heapq.heappush(priority_queue, (distance + edge_weight, neighbor, node))
    return tree


def bfs_tree_of_S_rooted_x(graph, s, x):
    # Generate BFS tree rooted at x
    bfs_tree_s = bfs_tree_with_sorting(graph, s)
    # Check if u is in the BFS tree rooted at x
    if x in bfs_tree_s.nodes:
        # BFS tree rooted at u from the BFS tree rooted at s
        bfs_tree_x = nx.bfs_tree(bfs_tree_s, x)
        bfs_tree_nodes = list(bfs_tree_x.nodes)
        return bfs_tree_nodes
    else:
        # print(f"Node {x} is not in the BFS tree rooted at {s}")
        return None

# %%
# import heapq

# def build_hierarchical_tree_with_priority(G, root):
#     tree = nx.DiGraph()
#     visited = set()
#     priority_queue = [(0, root, None)]  # (distance, node, parent)

#     while priority_queue:
#         distance, node, parent = heapq.heappop(priority_queue)
#         if node not in visited:
#             visited.add(node)
#             if parent is not None:
#                 tree.add_edge(parent, node)
#             for neighbor in G.neighbors(node):
#                 if neighbor not in visited:
#                     edge_weight = G[node][neighbor].get('weight', 1)  # Default weight is 1 if not specified
#                     heapq.heappush(priority_queue, (distance + edge_weight, neighbor, node))
#     return tree



# def hierarchy_pos(G, root, width=1.0, vert_gap=0.5, vert_loc=0, xcenter=0.5, pos=None, parent=None):
#     """
#     Create a layout dictionary that positions nodes in a hierarchy.
#     """
#     if pos is None:
#         pos = {root: (xcenter, vert_loc)}
#     children = list(G.successors(root))
#     if len(children) != 0:
#         dx = width / len(children)
#         nextx = xcenter - width / 2 - dx / 2
#         for child in children:
#             nextx += dx
#             pos[child] = (nextx, vert_loc - vert_gap)
#             pos = hierarchy_pos(G, child, width=dx, vert_gap=vert_gap,
#                                 vert_loc=vert_loc - vert_gap, xcenter=nextx, pos=pos, parent=root)
#     return pos


# # Build the tree with priority
# tree = build_hierarchical_tree_with_priority(G, 14)
# print(tree)
# pos = hierarchy_pos(tree, 14)

# # Draw the tree
# plt.figure(figsize=(25, 6))
# nx.draw(tree, pos, with_labels=True, node_size=2000, node_color='lightblue', arrows=True)
# plt.title("Hierarchical Tree with Priority (Shortest Distance First)")
# plt.show()

# # // if i have to  explore node that have shortest distance first

# %% [markdown]
# #Maximizer Functions

# %%
# # load all maximizer_dict
# with open('maximizer_dict1.pkl', 'rb') as f:
#     maximizer_dict1 = pickle.load(f)
# with open('maximizer_dict21.pkl', 'rb') as f:
#     maximizer_dict21 = pickle.load(f)
# with open('maximizer_dict2.pkl', 'rb') as f:
#     maximizer_dict2 = pickle.load(f)
# with open('maximizer_dict3.pkl', 'rb') as f:
#     maximizer_dict3 = pickle.load(f)

# %%
from itertools import combinations


def maximizer1(G, x, y, d1, d2):

    max_xy_edge = None
    max_xy_path = None
    max_xy_distance = float("-inf")
    max_xy_path_new = None

    possible_edges = combinations(G.edges, 3)
    
    for F_star in possible_edges:
        # print(F_star)
        eu , ev = F_star[0]
        eu1 , ev1 = F_star[1]
        eu2 , ev2 = F_star[2]
        
        f_vertices = set([eu, ev, eu1, ev1, eu2, ev2])  
        f_vertices = list(f_vertices)   
        
        # print(F_star)
        
        if (
            (D[x][vertex] >= d1 for vertex in f_vertices )
            and (D[y][vertex] >= d2 for vertex in f_vertices )
        ):  
            
            edge1_data = G.get_edge_data(eu , ev)
            edge2_data = G.get_edge_data(eu1, ev1)
            edge3_data = G.get_edge_data(eu2, ev2)
            G.remove_edge(eu, ev)
            G.remove_edge(eu1, ev1)
            G.remove_edge(eu2, ev2)
            if not nx.has_path(G, x, y):
                G.add_edge(eu1, ev1, **edge2_data)
                G.add_edge(eu , ev , **edge1_data)
                G.add_edge(eu2, ev2, **edge3_data)
                continue

            path2 = nx.dijkstra_path(G, x, y, weight="weight")
            path2_distance = sum(
                get_edge_weight(G, path2[i], path2[i + 1]) for i in range(len(path2) - 1)
            )
            if path2_distance > max_xy_distance:
                max_xy_edge = [(eu, ev), (eu1, ev1) , (eu2, ev2)]   
                max_xy_path = path2
                max_xy_distance = path2_distance
            G.add_edge(eu, ev, **edge1_data)
            G.add_edge(eu1, ev1, **edge2_data)
            G.add_edge(eu2, ev2, **edge3_data)  


    if max_xy_path is not None:
        s = 0
        max_xy_path_new = []
        for i in range(len(max_xy_path) - 1):
            u = max_xy_path[s]
            v = max_xy_path[i + 1]
            uv_distance = D[u][v]
            uv_distance_path = sum(
                get_edge_weight(G, max_xy_path[j], max_xy_path[j + 1])
                for j in range(s, i + 1)
            )
            if uv_distance != uv_distance_path:
                if i < (len(max_xy_path) - 2):
                    s_to_a_path = [u]
                    intermediate_edge = (v, max_xy_path[i + 2])
                    s_to_a_path.append(max_xy_path[i])
                    max_xy_path_new.append(s_to_a_path)
                    max_xy_path_new.append(intermediate_edge)
                    s = i + 2
        max_xy_path_new.append([u, max_xy_path[len(max_xy_path) - 1]])
        if len(max_xy_path_new) < 7:
            max_xy_path_new = [max_xy_path]


    return max_xy_edge, max_xy_path_new

# %%
maximizer1(G , 0 , 45 , 0 , 0)
# Out:
# ([(45, 6), (45, 12), (45, 43)], [[0, 45]])

# %%
from concurrent.futures import ProcessPoolExecutor, as_completed
import networkx as nx
import tqdm
import time
import os
import pickle


# Initialize dictionary
maximizer_dict1 = {}


maximizer_function = maximizer1

# Collect errors
errors = []

start_time = time.time()

def process_pair(chunk_data):
    chunk_results = {}
    chunk_errors = []

    for x, y, d1, d2 in chunk_data:
        try:
            result = maximizer_function(G, x, y, d1, d2)
            if result is not None:
                chunk_results[(x, y, d1, d2)] = result
                print(f"Processed ({x}, {y}, {d1}, {d2}): {result}")    
        except Exception as e:
            chunk_errors.append(f"Error processing ({x}, {y}, {d1}, {d2}): {str(e)}")
    return chunk_results, chunk_errors

nodes = list(G.nodes())

# Generate pairs (renamed to avoid collision)
pair_combinations = [
    (x, y, d1, d2)
    for x in nodes
    for y in nodes
    for d1 in d1_d2_list
    for d2 in d1_d2_list
    if x != y
]

print(f"Number of combinations: {len(pair_combinations)}")

# Calculate chunk size and split without NumPy
n_cores = os.cpu_count()
chunk_size = max(1, len(pair_combinations) // (n_cores * 4))
n_chunks = (len(pair_combinations) + chunk_size - 1) // chunk_size  # Ceiling division

# Custom function to split list into chunks
def split_into_chunks(lst, n_chunks):
    chunks = []
    for i in range(n_chunks):
        start = i * chunk_size
        end = min((i + 1) * chunk_size, len(lst))
        if start < len(lst):  # Only add non-empty chunks
            chunks.append(lst[start:end])
    return chunks

chunks = split_into_chunks(pair_combinations, n_chunks)
print(f"Number of chunks: {len(chunks)}")

# Process chunks using ProcessPoolExecutor
with ProcessPoolExecutor() as executor:
    futures = [executor.submit(process_pair, chunk) for chunk in chunks]
    for future in tqdm.tqdm(
        as_completed(futures), 
        total=len(futures),
        desc="Processing pairs"
    ):
        results, chunk_errors = future.result()
        maximizer_dict1.update(results)
        errors.extend(chunk_errors)

# Print errors
for error in errors:
    print(error)

# Performance metrics
end_time = time.time()
total_time = end_time - start_time
pairs_processed = len(pair_combinations)
pairs_successful = len(maximizer_dict1)

print(f"\nMaximizer1 Performance Summary:")
print(f"Total time: {total_time:.2f} seconds")
print(f"Pairs processed: {pairs_processed}")
print(f"Successful pairs: {pairs_successful}")
print(f"Success rate: {(pairs_successful/pairs_processed)*100 if pairs_processed > 0 else 0:.2f}%")

with open('maximizer_dict1.pkl', 'wb') as f:
    pickle.dump(maximizer_dict1, f)
# Out:
# Number of combinations: 175122
# Number of chunks: 49
# ---------------------------------------------------------------------------
# BrokenProcessPool                         Traceback (most recent call last)
# Cell In[44], line 68
#      66 # Process chunks using ProcessPoolExecutor
#      67 with ProcessPoolExecutor() as executor:
# ---> 68     futures = [executor.submit(process_pair, chunk) for chunk in chunks]
#      69     for future in tqdm.tqdm(
#      70         as_completed(futures),
#      71         total=len(futures),
#      72         desc="Processing pairs"
#      73     ):
#      74         results, chunk_errors = future.result()
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2800.0_x64__qbz5n2kfra8p0\Lib\concurrent\futures\process.py:805, in ProcessPoolExecutor.submit(self, fn, *args, **kwargs)
#     803 with self._shutdown_lock:
#     804     if self._broken:
# --> 805         raise BrokenProcessPool(self._broken)
#     806     if self._shutdown_thread:
#     807         raise RuntimeError('cannot schedule new futures after shutdown')
#
# BrokenProcessPool: A child process terminated abruptly, the process pool is not usable anymore

# %%
# # load maximizer_dict from the local file
with open('maximizer_dict1.pkl', 'rb') as f:
    maximizer_dict1 = pickle.load(f)

# %%
from itertools import combinations

def maximizer21(G, x, y, d1, V):
    G = G.copy()
    max_xy_edge = None
    max_xy_path = None
    max_xy_distance = float("-inf")
    max_xy_path_new = None


    possible_edges = combinations(list(G.edges) , 2)
    for F_star in possible_edges:
        eu , ev = F_star[0];
        eu1 , ev1 = F_star[1]
        if (
            nx.has_path(G, x, eu1)
            and nx.has_path(G, y, ev1)
            and (
                D[x][eu1] >= d1  and D[x][eu] >= d1 and D[x][ev1] >= d1 and D[x][ev] >= d1
            )
            and intact_from_failure_path(shortest_paths[(V, y)], F_star)
            and intact_from_failure_tree(txu_dict[(y, V)], F_star)
        ):
            edge1_data = G.get_edge_data(eu, ev)    
            edge2_data = G.get_edge_data(eu1, ev1)
            
            G.remove_edge(eu, ev)
            G.remove_edge(eu1, ev1) 
            if not nx.has_path(G, x, y):
                G.add_edge(eu, ev, **edge1_data)
                G.add_edge(eu1, ev1, **edge2_data)
                continue

            path2 = nx.dijkstra_path(G, x, y, weight="weight")
            path2_distance = sum(
                get_edge_weight(G, path2[i], path2[i + 1])
                for i in range(len(path2) - 1)
            )
            if path2_distance > max_xy_distance:
                max_xy_edge = [(eu, ev), (eu1, ev1)]
                max_xy_path = path2
                max_xy_distance = path2_distance

            G.add_edge(eu1, ev1, **edge2_data)
            G.add_edge(eu, ev, **edge1_data)

    if max_xy_path is not None:
        s = 0
        max_xy_path_new = []
        for i in range(len(max_xy_path) - 1):
            u = max_xy_path[s]
            v = max_xy_path[i + 1]
            uv_distance = D[u][v]
            uv_distance_path = sum(
                get_edge_weight(G, max_xy_path[j], max_xy_path[j + 1])
                for j in range(s, i + 1)
            )
            if uv_distance != uv_distance_path:
                if i < (len(max_xy_path) - 2):
                    s_to_a_path = [u]
                    intermediate_edge = (v, max_xy_path[i + 2])
                    s_to_a_path.append(max_xy_path[i])
                    max_xy_path_new.append(s_to_a_path)
                    max_xy_path_new.append(intermediate_edge)
                    s = i + 2
        max_xy_path_new.append([u, max_xy_path[len(max_xy_path) - 1]])
        if len(max_xy_path_new) == 1:
            max_xy_path_new = [max_xy_path]
        if len(max_xy_path_new) == 3:
            max_xy_path_new = [max_xy_path]

    return max_xy_edge, max_xy_path_new

# %%
# maximizer_dict21[(0, 18, 128, 23)]
# # maximizer21(G, 0, 18, 128, 23)

# %%
# from concurrent.futures import ProcessPoolExecutor, as_completed
# from tqdm import tqdm
# import networkx as nx
# import time
# import pickle
# import os
# import logging

# # Configure logging
# logging.basicConfig(
#     filename='maximizer21.log',  # Log file name
#     filemode='a',               # Append mode
#     level=logging.INFO,         # Logging level
#     format='%(asctime)s - %(message)s'
# )

# # Initialize a dictionary to store the maximizer output
# maximizer_dict21 = {}

# maximizer_function = maximizer21

# # Collect errors to print after the loop
# errors = []

# start_time = time.time()

# # Define a function to process a single pair of nodes
# def process_pair(x, y, d1, v):
#     try:
#         G_copy = G.copy()
#         result = maximizer_function(G_copy, x, y, d1, v)
#         if result is not None:
#             max_edge, max_path = result
#             return (x, y, d1, v), (max_edge, max_path)
#     except nx.NetworkXNoPath:
#         return (x, y, d1, v), None
#     except Exception as e:
#         logging.error(f"Error processing pair ({x}, {y}, {d1}, {v}): {str(e)}")
#         return (x, y, d1, v), None


# nodes = list(G.nodes)

# num_cores = os.cpu_count()
# # Use ProcessPoolExecutor to parallelize the computation
# with ProcessPoolExecutor(max_workers=num_cores) as executor:
#     futures = []
#     for x in nodes:
#         for y in nodes:
#             if x != y:
#                 for d1 in d1_d2_list:
#                     for d2 in d1_d2_list:
#                         F_star, xy_f_star = maximizer_dict1[(x, y, d1, d2)]
#                         F_star_vertex = []

#                         if F_star is not None and F_star != []:
#                             if not isinstance(F_star, list):
#                                 F_star = list(F_star)
#                             if isinstance(F_star[0], int):
#                                 F_star_vertex = [F_star[0], F_star[1]]
#                             else:
#                                 F_star_vertex = [vertex for E in F_star for vertex in E]
#                         for v in F_star_vertex:
#                             futures.append(
#                                 executor.submit(process_pair, x, y, d1, v)
#                             )

#     # Use tqdm to show progress for the futures
#     for future in tqdm(as_completed(futures), total=len(futures), desc="Processing pairs"):
#         key, result = future.result()
#         if result is not None:
#             logging.info(f"Result: {key}: {result}")
#             maximizer_dict21[key] = result
#         else:
#             error_message = f"No path between {key[0]} and {key[1]} for d1: {key[2]}, d2: {key[3]}."
#             logging.error(error_message)
#             errors.append(error_message)

# # Print all errors after the loop
# for error in errors:
#     print(error)

# # Calculate and print performance metrics
# end_time = time.time()
# total_time = end_time - start_time
# pairs_processed = len(futures)
# pairs_successful = len(maximizer_dict21)

# print(f"\nPerformance Summary:")
# print(f"Total time: {total_time:.2f} seconds")
# print(f"Pairs processed: {pairs_processed}")
# print(f"Successful pairs: {pairs_successful}")
# print(f"Success rate: {(pairs_successful/pairs_processed)*100:.2f}%")

# # Save the results to a file
# with open('maximizer_dict21.pkl', 'wb') as f:
#     pickle.dump(maximizer_dict21, f)

# logging.info("Results saved to maximizer_dict21.pkl")

# %%
# import logging
# from concurrent.futures import ProcessPoolExecutor, as_completed
# from tqdm import tqdm
# import networkx as nx
# import time
# import pickle
# import os
# import numpy as np

# # Setup logging
# logging.basicConfig(filename='processing_errors.log', level=logging.ERROR)

# # Initialize a dictionary to store the maximizer output
# maximizer_dict21 = {}

# # Store the maximizer function reference directly
# maximizer_function = maximizer21  # Replace 'maximizer21' with the actual function name

# # Collect errors to print after the loop
# errors = []

# start_time = time.time()

# # Define a function to process a single pair of nodes
# def process_pair(x, y, d1, v):
#     try:
#         if (x, y, d1, v) in maximizer_dict21:
#             return (x, y, d1, v), maximizer_dict21[(x, y, d1, v)]   
#         result = maximizer_function(G, x, y, d1, v)
#         if result is not None:
#             max_edge, max_path = result
#             return (x, y, d1, v), (max_edge, max_path)
#     except nx.NetworkXNoPath:
#         return (x, y, d1, v), None
#     except Exception as e:
#         logging.error(f"Error for ({x}, {y}, {d1}, {v}): {str(e)}")
#         return (x, y, d1, v ), f"Error: {str(e)}"

# def main():
#     start_time = time.time()

#     # Load graph and other data
#     with open('graph.pkl', 'rb') as f:
#         G = pickle.load(f)
#     with open('maximizer_dict1.pkl', 'rb') as f:
#         maximizer_dict1 = pickle.load(f)

#     nodes = list(G.nodes)

#     combinations = [
#         (x, y, d1, v)
#         for x in nodes
#         for y in nodes
#         if x != y
#         for d1 in d1_d2_list
#         for d2 in d1_d2_list
#         for F_star, xy_f_star in [maximizer_dict1[(x, y, d1, d2)]]
#         if F_star is not None and F_star != []
#         for F_star_vertex in [[F_star[0], F_star[1]] if isinstance(F_star[0], int) else [vertex for E in F_star for vertex in E]]
#         for v in F_star_vertex
#     ]

#     # Calculate optimal chunk size based on CPU cores
#     n_cores = os.cpu_count()
#     chunk_size = max(1, len(combinations) // (n_cores * 4))
#     chunks = np.array_split(combinations, len(combinations) // chunk_size)

#     # Process chunks using ProcessPoolExecutor for true parallelism
#     with ProcessPoolExecutor(max_workers=n_cores) as executor:
#         futures = [executor.submit(process_pair, *args) for args in combinations]

#         for future in tqdm(as_completed(futures), total=len(futures), desc="Processing pairs"):
#             key, result = future.result()
#             if result is not None:
#                 maximizer_dict21[key] = result
#             else:
#                 errors.append(f"No path between {key[0]} and {key[1]} for d1: {key[2]}, d2: {key[3]}.")
#                 maximizer_dict21[key] = None , None
#             print(f"Processed: {key} , Result: {result}")
#     # Print all errors after the loop
#     for error in errors:
#         print(error)

#     # Calculate and print performance metrics
#     end_time = time.time()
#     total_time = end_time - start_time
#     pairs_processed = len(combinations)
#     pairs_successful = len(maximizer_dict21)

#     print(f"\nMaximizer21 Performance Summary:")
#     print(f"Total time: {total_time:.2f} seconds")
#     print(f"Pairs processed: {pairs_processed}")
#     print(f"Successful pairs: {pairs_successful}")
#     print(f"Success rate: {(pairs_successful/pairs_processed)*100:.2f}%")

#     # Save the updated dictionary back to the file
#     with open('maximizer_dict21.pkl', 'wb') as f:
#         pickle.dump(maximizer_dict21, f)

# if __name__ == "__main__":
#     main()

# %%
with open('maximizer_dict21.pkl', 'rb') as f:
    maximizer_dict21 = pickle.load(f)

# %%
from itertools import combinations
def maximizer2(G, x, y, V, d2):
    G = G.copy()

    max_xy_edge = None
    max_xy_path = None
    max_xy_distance = float("-inf")
    max_xy_path_new = None


    possible_edges = combinations(list(G.edges) , 2);
    for F_star in possible_edges:
        eu , ev = F_star[0]
        eu1 , ev1 = F_star[1]
 
        Vx_path = shortest_paths[(V, x)]
        txV = txu_dict[(x, V)]  
        if (
            nx.has_path(G, x, eu1)
            and nx.has_path(G, y, ev1)
            and (
                D[y][ev1] >= d2  and D[y][ev] >= d2 and D[y][ev1] >= d2 and D[y][ev] >= d2
            )
            and (intact_from_failure_path(Vx_path, F_star)
            and intact_from_failure_tree(txV, F_star))
        ):  
            edge1_data = G.get_edge_data(eu , ev)
            edge2_data = G.get_edge_data(eu1, ev1)
            G.remove_edge(eu, ev)
            G.remove_edge(eu1, ev1)
            if not nx.has_path(G, x, y):
                G.add_edge(eu1, ev1, **edge2_data)
                G.add_edge(eu, ev, **edge1_data)
                continue

            path2 = nx.dijkstra_path(G, x, y, weight="weight")
            path2_distance = sum(
                get_edge_weight(G, path2[i], path2[i + 1]) for i in range(len(path2) - 1)
            )
            if path2_distance > max_xy_distance:
                max_xy_edge = [(eu, ev), (eu1, ev1)]
                max_xy_path = path2
                max_xy_distance = path2_distance

            G.add_edge(eu1, ev1, **edge2_data)

            G.add_edge(eu, ev, **edge1_data)

    if max_xy_path is not None:
        s = 0
        max_xy_path_new = []
        for i in range(len(max_xy_path) - 1):
            u = max_xy_path[s]
            v = max_xy_path[i + 1]
            uv_distance = D[u][v]
            uv_distance_path = sum(
                get_edge_weight(G, max_xy_path[j], max_xy_path[j + 1])
                for j in range(s, i + 1)
            )
            if uv_distance != uv_distance_path:
                if i < (len(max_xy_path) - 2):
                    s_to_a_path = [u]
                    intermediate_edge = (v, max_xy_path[i + 2])
                    s_to_a_path.append(max_xy_path[i])
                    max_xy_path_new.append(s_to_a_path)
                    max_xy_path_new.append(intermediate_edge)
                    s = i + 2
        max_xy_path_new.append([u, max_xy_path[len(max_xy_path) - 1]])
        if len(max_xy_path_new) == 1:
            max_xy_path_new = [max_xy_path]
        if len(max_xy_path_new) == 3:
            max_xy_path_new = [max_xy_path]

    return max_xy_edge, max_xy_path_new

# %%
with open('maximizer_dict2.pkl', 'rb') as f:
    maximizer_dict2 = pickle.load(f)

# %%
# maximizer_dict2[(23, 1, 21, 0)]

# %%
# keys_list = []

# for x in G.nodes:
#     for y in G.nodes:
#         if x != y:
#             for v in G.nodes:
#                 for d2 in d1_d2_list:
#                     if (x, y, v, d2) not in maximizer_dict2 :
#                         keys_list.append((x, y, v, d2))  
#                     # else :
#                     #     fs , xy_fs = maximizer_dict2[(x, y, v, d2)]
#                     #     print(fs , xy_fs)
#                     #     if fs is None:
#                     #         keys_list.append((x, y, v, d2))

# %%
# from concurrent.futures import ProcessPoolExecutor, as_completed
# from tqdm import tqdm
# import pickle

# # Function to process a single key
# def process_key(x, y, v, d2):
#     try:
        
#         value = maximizer2(G, x, y, v, d2)
#         return (x, y, v, d2), value

#     except Exception as e:
#         print(f"Error processing key ({x}, {y}, {v}, {d2}): {e}")
#     return None


# futures = []
# results = []

# # Use ProcessPoolExecutor for parallel processing
# with ProcessPoolExecutor() as executor:
#     # Submit tasks to the executor

    
#     for x, y, v, d2 in keys_list:
#         futures.append(executor.submit(process_key, x, y, v, d2))
   
#     # Process completed futures
#     for future in tqdm(as_completed(futures), total=len(futures), desc="Processing keys"):
#         result = future.result()
#         if result:
#             results.append(result)

# # Update the dictionary with results
# for key, value in results:
#     maximizer_dict2[key] = value

# # Save the updated dictionary to a file
# with open(maximizer_dict2.pkl, 'wb') as f:
#     pickle.dump(maximizer_dict2, f)

# print(f"Processing complete. Results saved to {maximizer_dict2}.")

# %%
# # dump
# with open('maximizer_dict2.pkl', 'wb') as f:
#     pickle.dump(maximizer_dict2, f)

# %%
with open('maximizer_dict2.pkl', 'rb') as f:
    maximizer_dict2 = pickle.load(f)

# %%
len(maximizer_dict2)
# Out:
# 163327

# %%
# from concurrent.futures import ProcessPoolExecutor, as_completed
# from tqdm import tqdm
# import networkx as nx
# import time
# import pickle
# import os
# import logging

# # Configure logging
# logging.basicConfig(
#     filename='maximizer2.log',  # Log file name
#     filemode='a',              # Append mode
#     level=logging.INFO,        # Logging level
#     format='%(asctime)s - %(levelname)s - %(message)s'
# )

# # Initialize a dictionary to store the maximizer output
# maximizer_dict2 = {}

# maximizer_function = maximizer2

# # Collect errors to print after the loop
# errors = []

# start_time = time.time()

# # Define a function to process a single pair of nodes
# def process_pair(x, y, v, d2):
#     try:
#         G_copy = G.copy()
#         result = maximizer_function(G_copy, x, y, v, d2)
#         if result is not None:
#             max_edge, max_path = result
#             logging.info(f"Processed pair ({x}, {y}, {v}, {d2}): Success")
#             return (x, y, v, d2), (max_edge, max_path)
#     except nx.NetworkXNoPath:
#         logging.warning(f"No path found for pair ({x}, {y}, {v}, {d2})")
#         return (x, y, v, d2), None
#     except Exception as e:
#         logging.error(f"Error processing pair ({x}, {y}, {v}, {d2}): {str(e)}")
#         return (x, y, v, d2), None

# nodes = list(G.nodes)

# num_cores = os.cpu_count()
# logging.info(f"Starting computation with {num_cores} cores and {len(nodes)} nodes.")

# # Use ProcessPoolExecutor to parallelize the computation
# with ProcessPoolExecutor(max_workers=num_cores) as executor:
#     futures = []
#     for x in nodes:
#         for y in nodes:
#             if x != y:
#                 for d1 in d1_d2_list:
#                     for d2 in d1_d2_list:
#                         F_star, xy_f_star = maximizer_dict1[(x, y, d1, d2)]
#                         F_star_vertex = []

#                         if F_star is not None and F_star != []:
#                             if not isinstance(F_star, list):
#                                 F_star = list(F_star)
#                             if isinstance(F_star[0], int):
#                                 F_star_vertex = [F_star[0], F_star[1]]
#                             else:
#                                 F_star_vertex = [vertex for E in F_star for vertex in E]
#                         for v in F_star_vertex:
#                             futures.append(
#                                 executor.submit(process_pair, x, y, v, d2)
#                             )

#     # Use tqdm to show progress for the futures
#     for future in tqdm(as_completed(futures), total=len(futures), desc="Processing pairs"):
#         try:
#             key, result = future.result()
#             if result is not None:
#                 logging.info(f"Result for {key}: {result}")
#                 maximizer_dict2[key] = result
#             else:
#                 error_message = f"No path between {key[0]} and {key[1]} for d1: {key[2]}, d2: {key[3]}."
#                 logging.warning(error_message)
#                 errors.append(error_message)
#         except Exception as e:
#             logging.error(f"Error processing future: {str(e)}")

# # Print all errors after the loop
# for error in errors:
#     logging.warning(error)

# # Calculate and print performance metrics
# end_time = time.time()
# total_time = end_time - start_time
# pairs_processed = len(futures)
# pairs_successful = len(maximizer_dict2)

# logging.info(f"\nPerformance Summary:")
# logging.info(f"Total time: {total_time:.2f} seconds")
# logging.info(f"Pairs processed: {pairs_processed}")
# logging.info(f"Successful pairs: {pairs_successful}")
# logging.info(f"Success rate: {(pairs_successful/pairs_processed)*100:.2f}%")

# # Save the results to a file
# with open('maximizer_dict2.pkl', 'wb') as f:
#     pickle.dump(maximizer_dict2, f)

# logging.info("Results saved to maximizer_dict2.pkl")

# %%
def maximizer3(G, x, y, U, V):
    G = G.copy()    

    max_xy_edge = None
    max_xy_path = None
    max_xy_distance = float("-inf")
    max_xy_path_new = []


    
    # if not ((intact_from_failure_path(shortest_paths[(x, u)], F_star) and intact_from_failure_tree(bfs_tree_of_S_rooted_x(G, x, u), F_star)) 
    #     and (intact_from_failure_path(shortest_paths[(v, y)], F_star) and intact_from_failure_tree(bfs_tree_of_S_rooted_x(G, y, v), F_star))):
    #     return [], []
    

    possible_edges = combinations(list(G.edges) , 2)

    for F_star in possible_edges:
        eu , ev = F_star[0]
        eu1 , ev1 = F_star[1]
        xu_path = shortest_paths[(x, U)]
        vy_path = shortest_paths[(V, y)]
        bfsTree_txu = txu_dict[(x, U)]
        bfsTree_tyv = txu_dict[(y, V)]

        
        if (
            nx.has_path(G, x, eu1)
            and nx.has_path(G, y, ev1)
            and (intact_from_failure_path(xu_path, F_star)
            and intact_from_failure_tree(bfsTree_txu, F_star))
            and ((intact_from_failure_path(vy_path, F_star)
            and intact_from_failure_tree(bfsTree_tyv, F_star)))
        ):  
            
            edge1_data = G.get_edge_data(eu, ev)
            edge2_data = G.get_edge_data(eu1, ev1)
            G.remove_edge(eu, ev)
            G.remove_edge(eu1, ev1)
            if not nx.has_path(G, x, y):
                G.add_edge(eu, ev, **edge1_data)
                G.add_edge(eu1, ev1, **edge2_data)
                continue
            


            path2 = nx.dijkstra_path(G, x, y, weight="weight")
            path2_distance = sum(
                get_edge_weight(G, path2[i], path2[i + 1]) for i in range(len(path2) - 1)
            )
            if path2_distance > max_xy_distance:
                max_xy_edge = [(eu, ev), (eu1, ev1)]
                max_xy_path = path2
                max_xy_distance = path2_distance
            G.add_edge(eu1, ev1, **edge2_data)
            G.add_edge(eu, ev, **edge1_data)

                # print(f"added edge: {eu1, ev1}")

        # G.add_edge(eu, ev, **edge1_data)
        # added_edges.append((eu, ev))
        # print(f"added edge: {eu, ev}")

    if max_xy_path is not None:
        s = 0
        for i in range(len(max_xy_path) - 1):
            u = max_xy_path[s]
            v = max_xy_path[i + 1]
            uv_distance = D[u][v]
            uv_distance_path = sum(
                get_edge_weight(G, max_xy_path[j], max_xy_path[j + 1])
                for j in range(s, i + 1)
            )
            if uv_distance != uv_distance_path:
                if i < (len(max_xy_path) - 2):
                    s_to_a_path = [u]
                    intermediate_edge = (v, max_xy_path[i + 2])
                    s_to_a_path.append(max_xy_path[i])
                    max_xy_path_new.append(s_to_a_path)
                    max_xy_path_new.append(intermediate_edge)
                    s = i + 2
        max_xy_path_new.append([u, max_xy_path[len(max_xy_path) - 1]])
        if len(max_xy_path_new) == 1:
            max_xy_path_new = []
            max_xy_path_new.append(max_xy_path)
        if len(max_xy_path_new) == 3:
            max_xy_path_new = []
            max_xy_path_new.append(max_xy_path)

    # Compare removed and added edges
    # missing_edges = set(removed_edges) - set(added_edges)
    # if missing_edges:
    #     print(f"Missing edges: {missing_edges}")

    return max_xy_edge, max_xy_path_new

# %%
maximizer_dict2[(12, 47, 33, 0)]
# Out:
# ([(0, 45), (39, 47)], [[12, 37, 9, 14, 29, 33, 47]])

# %%
# from concurrent.futures import ProcessPoolExecutor, as_completed
# from tqdm import tqdm
# import networkx as nx
# import time
# import pickle
# import os
# import logging

# # Configure logging
# logging.basicConfig(filename='processing_errors.log', level=logging.INFO, filemode='a',
#                     format='%(asctime)s %(levelname)s:%(message)s')

# maximizer_function = maximizer3

# with open('maximizer_dict3.pkl', 'rb') as f:
#     maximizer_dict3 = pickle.load(f)  
    
# # Load graph and other data
# with open('graph.pkl', 'rb') as f:
#     G = pickle.load(f)  

# # Define a function to process a batch of pairs
# def process_batch(batch):
#     results = []
#     for x, y, u, v in batch:
#         if (x, y, u, v) in maximizer_dict3:
#             continue  # Skip if already processed
#         try:
#             results.append(((x, y, u, v), maximizer_function(G, x, y, u, v)))
#         except nx.NetworkXNoPath as e:
#             results.append(((x, y, u, v), f"NetworkXNoPath: {str(e)}"))
#         except Exception as e:
#             results.append(((x, y, u, v), f"Error: {str(e)}"))
#     return results

# def main():
#     start_time = time.time()


#     with open('maximizer_dict1.pkl', 'rb') as f:
#         maximizer_dict1 = pickle.load(f)
#     with open('maximizer_dict21.pkl', 'rb') as f:
#         maximizer_dict21 = pickle.load(f)
#     with open('maximizer_dict2.pkl', 'rb') as f:
#         maximizer_dict2 = pickle.load(f)
        


#     # Create batches of arguments
#     batch_size = 100  # Reduced batch size for better load balancing
#     batches = []
#     current_batch = []
#     processed_pairs = set()  # Track processed pairs to avoid duplicates

#     nodes = list(G.nodes)

#     for x in nodes:
#         for y in nodes:
#             for d1 in d1_d2_list:
#                 for d2 in d1_d2_list:
#                     if x != y:
#                         F_star1, xy_f_star1 = maximizer_dict1[(x, y, d1, d2)]

#                         F_star_vertex1 = []

#                         if F_star1 is not None and F_star1 != []:
#                             if not isinstance(F_star1, list):
#                                 F_star1 = list(F_star1)
#                             if isinstance(F_star1[0], int):
#                                 F_star_vertex1 = [F_star1[0], F_star1[1]]
#                             else:
#                                 F_star_vertex1 = [vertex for E in F_star1 for vertex in E]
#                         for v in F_star_vertex1:
#                             F_star2, xy_f_star2 = maximizer_dict2[(x, y, v, d2)]
#                             F_star21, xy_f_star21 = maximizer_dict21[(x, y, d1, v)]
#                             F_star_vertex2 = []
#                             F_star_vertex21 = []
#                             if F_star2 is not None and F_star2 != []:
#                                 if not isinstance(F_star2, list):
#                                     F_star2 = list(F_star2)
#                                 if isinstance(F_star2[0], int):
#                                     F_star_vertex2 = [F_star2[0], F_star2[1]]
#                                 else:
#                                     F_star_vertex2 = [vertex for E in F_star2 for vertex in E]

#                             if F_star21 is not None and F_star21 != []:
#                                 if not isinstance(F_star21, list):
#                                     F_star21 = list(F_star21)
#                                 if isinstance(F_star21[0], int):
#                                     F_star_vertex21 = [F_star21[0], F_star21[1]]
#                                 else:
#                                     F_star_vertex21 = [vertex for E in F_star21 for vertex in E]

#                             for u in F_star_vertex21:
#                                 pair = (x, y, u, v)
                              
#                                 current_batch.append(pair)
#                                 if len(current_batch) == batch_size:
#                                     batches.append(current_batch)
#                                     current_batch = []
#                             for u in F_star_vertex2:
#                                 pair = (x, y, u, v)

#                                 current_batch.append(pair)
#                                 if len(current_batch) == batch_size:
#                                     batches.append(current_batch)
#                                     current_batch = []
#     if current_batch:
#         batches.append(current_batch)
    
    
    

#     errors = []

#     # Use ProcessPoolExecutor to parallelize the computation
#     num_processes = os.cpu_count()-1
#     with ProcessPoolExecutor(max_workers=num_processes) as executor:
#         futures = [executor.submit(process_batch, batch) for batch in batches]

#         # Use tqdm to show progress for the futures
#         for future in tqdm(as_completed(futures), total=len(futures), desc="Processing batches"):
#             for key, result in future.result():
#                 if isinstance(result, str):
#                     errors.append(f"Error for {key}: {result}")
#                 else:
#                     logging.info(f"Processed pair {key}: {result}")
#                     maximizer_dict3[key] = result

#     # Log all errors after the loop
#     for error in errors:
#         logging.error(error)

#     # Calculate and print performance metrics
#     end_time = time.time()
#     total_time = end_time - start_time
#     pairs_processed = sum(len(batch) for batch in batches)
#     pairs_successful = len(maximizer_dict3)

#     print(f"\nPerformance Summary:")
#     print(f"Total time: {total_time:.2f} seconds")
#     print(f"Pairs processed: {pairs_processed}")
#     print(f"Successful pairs: {pairs_successful}")
#     print(f"Success rate: {(pairs_successful/pairs_processed)*100:.2f}%")

#     # Save the results to a file
#     with open('maximizer_dict3.pkl', 'wb') as f:
#         pickle.dump(maximizer_dict3, f)


# if __name__ == "__main__":
#     main()

# %%
# # Save the results to a file
# with open('maximizer_dict3.pkl', 'wb') as f:
#     pickle.dump(maximizer_dict3, f)

# %%
# for x in G.nodes:
#     for y in G.nodes:
#         if x != y:
#             for d1 in d1_d2_list:
#                 for d2 in d1_d2_list:
#                     F_star, xy_f_star = maximizer_dict1[(x, y, d1, d2)]
#                     if F_star is not None and F_star != []:
#                         fs_vertices = [vertices for E in F_star for vertices in E]
#                         fs_vertices = list(set(fs_vertices))
#                         F_star2 , xy_f_star2 = maximizer_dict21

# %%
# maximizer3(G, 23 , 5 , 21, 21)
# Out:
# ([(10, 23), (10, 39)], [[23, 36, 27, 32, 10, 5]])

# %%
# load all maximizer_dict
with open('maximizer_dict1.pkl', 'rb') as f:
    maximizer_dict1 = pickle.load(f)
with open('maximizer_dict21.pkl', 'rb') as f:
    maximizer_dict21 = pickle.load(f)
with open('maximizer_dict2.pkl', 'rb') as f:
    maximizer_dict2 = pickle.load(f)
with open('maximizer_dict3.pkl', 'rb') as f:
    maximizer_dict3 = pickle.load(f)

# %% [markdown]
# =====================================Findpath Function=============================

# %%
f=2

# %%
def FINDPATHS(G ,s, t, F2):
    
    
    F_prime = []
    P = []
    
    
    for i in range(1, f + 1):
        if F_prime:
            u, v, weight = F_prime[i - 2].u, F_prime[i - 2].v, F_prime[i - 2].weight
            # print(f"u:{u}, v:{v}, weight:{weight}")
            P_i = QUERY(G,s, t, Edge(u, v, weight))
            # print(f"P_i:{P_i}")
            # print(f"u:{u}, v:{v}, weight:{weight}")
        else:
            P_i = QUERY(G, s, t, F_prime)
            

        P.append(P_i)
        
        if P_i == []:
            continue

        weight_p_i = sum(
            get_edge_weight(G, P_i[i], P_i[i + 1]) for i in range(len(P_i) - 1)
        )
        if F_prime:
            F2.remove(F_prime[i - 2])  
        else:
            F2 = F2
        for e1 in F2:
            if D[s][e1.u] > D[s][e1.v]:
                e1.u, e1.v = e1.v, e1.u
            
            flag = 0
            if F_prime:
                R1 = QUERY(G, s, e1.u, Edge(u, v, weight))
                if(e1.v == t):
                    R2 = QUERY(G, e1.u, t, Edge(u, v, weight))
                else: 
                    R2 = QUERY(G, e1.v, t, Edge(u, v, weight))
            else:
                R1 = QUERY(G, s, e1.u, F_prime)
                # if(e1.v == t):
                #     R2 = QUERY(e1.u, t, F_prime)
                # else: 
                R2 = QUERY(G, e1.v, t, F_prime)
            weight_R1 = sum(
                get_edge_weight(G, R1[i], R1[i + 1]) for i in range(len(R1) - 1)
            )
            weight_R2 = sum(
                get_edge_weight(G, R2[i], R2[i + 1]) for i in range(len(R2) - 1)
            )
            weight_e = get_edge_weight(G, e1.u, e1.v)
            # if rounded(weight_R1 ,) + weight_e + weight_R2 == weight_p_i:
            if round(weight_R1 + weight_e + weight_R2, 7) == round(weight_p_i, 7):
                F_prime.append(e1)
                flag = 1
                # print(f"flag: {flag}")
                break
        if flag == 0:
            return P
    return P

# %% [markdown]
# ========================================FindJump Function===============================================

# %%
# def FINDJUMP2(P, F2):
#     X = []  # Initialie X
#     if not P:
#         return[]
#     x = P[0]
#     X.append(x)
#     vertices = []
#     for edge in F2:
#         vertices += [edge.u, edge.v]
#     # u = min(vertices, key=lambda v: nearest_power_of_2(D[x][v]))
#     u = min(vertices, key=lambda v: D[x][v])
#     for vertex in vertices:
#         if nearest_power_of_2(D[x][vertex]) < nearest_power_of_2(D[x][u]):     
#             u = vertex  
#     # print(u)
#     while True:
#         distance= max(1, nearest_power_of_2(D[x][u]))
#         # print(distance)
#         y = None
#         for vertex in P[P.index(x) + 1:]:
#             if D[x][vertex] >= distance:
#                 y = vertex
#                 break
#         # print(y)   
#         if y is not None:
#             X.append(y)
#             x = y
#         else:
#             # break if no progress can be made (y remains None)
#             break
#         # print(X)
#     return X

# %%
def FINDJUMP2(P, F2):
    """
    Optimized version of FINDJUMP2 to find jump points in a path P based on failure edges F2.
    """
    if not P:
        return []

    X = [P[0]]  # Initialize X with the first vertex in P
    x = P[0]

    # Collect all vertices from edges in F2
    vertices = {edge.u for edge in F2}.union({edge.v for edge in F2})

    # Find the vertex u with the minimum distance from x
    # u = min(vertices, key=lambda v: D[x][v])

    # Iterate to find jump points
    while True:
        u = min(vertices, key=lambda v: nearest_power_of_2(D[x][v]))
        distance = max(1, nearest_power_of_2(D[x][u]))
        y = next((vertex for vertex in P[P.index(x) + 1:] if D[x][vertex] >= distance), None)

        if y is not None:
            X.append(y)
            x = y
        else:
            break  # Exit loop if no further progress can be made

    return X

# %% [markdown]
# ===================================Find Intermediate Functions =================================

# %%
def FIND_INTERMEDIATE3(G , x, y, u, v,  F):
    
    F_star = None
    xy_F_star = None
    

    F_star, xy_F_star = maximizer_dict3[(x, y, u, v)] 
    
    if F_star is None or F_star== []:
        return shortest_paths[(x, y)] , []


    direct_path = []
    direct_path_distance = float("inf")
    
    
    
    for edge in F_star:
        if (edge[0]==x and edge[1]==y) or (edge[0]==y and edge[1]==x):
            direct_path = [x, y]
            direct_path_distance = D[x][y]
            break

    

        
    
    INTERMEDIATE = []
    PATH = []
    
    xy_F_star_path = []
    if xy_F_star is not None and xy_F_star != []:   

        if len(xy_F_star) == 5:
            xy_F_star_path = (
            shortest_paths[(xy_F_star[0][0], xy_F_star[0][1])]
            + [xy_F_star[1][0]]
            + shortest_paths[(xy_F_star[2][0], xy_F_star[2][1])] + [xy_F_star[3][0]] + shortest_paths[(xy_F_star[4][0], xy_F_star[4][1])]
        )
            
        else:
            if xy_F_star:
                xy_F_star_path = xy_F_star[0]
            else:
                xy_F_star_path = []
    
    if not single_edge_in_path(xy_F_star_path, F):
        PATH = xy_F_star_path
        if(PATH):
            path_distance = sum(get_edge_weight(G, PATH[i], PATH[i + 1]) for i in range(len(PATH) - 1))
            if direct_path!= []:
                direct_path_distance = G[x][y]["weight"]
            if path_distance > direct_path_distance and not single_edge_in_path(direct_path, F):    
                PATH = direct_path
                path_distance = direct_path_distance    

        
        

    F_star_vertices = [vetex for tuple in F_star for vetex in tuple]
    for z in F_star_vertices:
        # z satisfiesthe condiions of an intermediate vertex
        xz = shortest_paths[(x, z)]
        zy = shortest_paths[(z, y)]
        if  single_edge_in_path(
            xz, F
        ) and single_edge_in_path(zy, F):
            INTERMEDIATE.append(z)


    INTERMEDIATE=list(set(INTERMEDIATE))
            
    return PATH, INTERMEDIATE

# %%
def FIND_INTERMEDIATE2(G, x, y, u, F):
    vertices = []
    PATH = []
    path_distance = float("inf")
    for edge in F:
        vertices.append(edge.u)
        vertices.append(edge.v)
    # d1 = min(nearest_power_of_2(distance_oracle.get_distance(x, a)) for a in vertices)
    d2 = min(nearest_power_of_2(D[y][b]) for b in vertices)
    
    direct_path = []
    direct_path_distance = float("inf")
    F_star, xy_F_star = maximizer_dict2[(x, y, u, d2)]
    # F_star, xy_F_star = maximizer2(G, x, y, u, d2)
    if F_star is None or xy_F_star == []:   
        return shortest_paths[(x, y)], []
    for edge in F_star:
        if (edge[0]==x and edge[1]==y) or (edge[0]==y and edge[1]==x):
            direct_path = [x, y]
    
    
    
    # F_star, xy_F_star = None, None
    # if (x, y, u, d2) not in maximizer_dict2:
    #     F_star, xy_F_star = maximizer2(G, x, y, u, d2)
    #     print(f"maximizer2: {x, y, u, d2} this is not in maximizer_dict2")
    #     maximizer_dict2[(x, y, u, d2)] = (F_star, xy_F_star)
    # else:
    #     F_star, xy_F_star = maximizer_dict2[(x, y, u, d2)]
    

    
    # print(f"in2 =F_star:{F_star}, xy_F_star:{xy_F_star}")
    xy_F_star_path = []
    if xy_F_star is not None and xy_F_star != []:   

        if len(xy_F_star) == 5:
            xy_F_star_path = (
            shortest_paths[(xy_F_star[0][0], xy_F_star[0][1])]
            + [xy_F_star[1][0]]
            + shortest_paths[(xy_F_star[2][0], xy_F_star[2][1])] + [xy_F_star[3][0]] + shortest_paths[(xy_F_star[4][0], xy_F_star[4][1])]
        )
            
            
        else :
            if xy_F_star:
                xy_F_star_path = xy_F_star[0]
            else :
                xy_F_star_path = [] 
    INTERMEDIATE = []
    if not single_edge_in_path(xy_F_star_path, F):
        PATH = xy_F_star_path
        if(PATH):
            path_distance = sum(get_edge_weight(G, PATH[i], PATH[i + 1]) for i in range(len(PATH) - 1))
            if direct_path!= []:
                direct_path_distance = G[x][y]["weight"]
            if path_distance > direct_path_distance and not single_edge_in_path(direct_path, F):    
                PATH = direct_path
                path_distance = direct_path_distance    
                return PATH, INTERMEDIATE   
       
            
    # print(PATH)
    # print(f"F_star:{F_star}")

    F_star_vertices = [vetex for tuple in F_star for vetex in tuple]
    # F_star_vertices = [vetex for tuple in F_star for vetex in tuple]
    for v in F_star_vertices:
        # u satisfies the condtions of an y-clean vertex
        # print(f"v:{v}")
        
        xv = shortest_paths[(x, v)] 
        yv = shortest_paths[(y, v)]
        
        bfs_tree_of_y_rooted_v = txu_dict[(y, v)]   
        
        
        if intact_from_failure_path(
            yv, F
        ) and intact_from_failure_tree(bfs_tree_of_y_rooted_v, F):
            P, I = FIND_INTERMEDIATE3(G , x, y, u, v, F)
            # print(f"FIND_INTERMEDIATE3: {P}, {I}")
            p_distance = float("inf")
            if P:
                p_distance = sum(
                    get_edge_weight(G, P[i], P[i + 1]) for i in range(len(P) - 1)
            )
            if p_distance < path_distance:  
    
                PATH = P
                path_distance = p_distance
            INTERMEDIATE.extend(I)
        # u satisfies the conditions of an intermediate vertex
        if single_edge_in_path(
            xv, F
        ) and single_edge_in_path(yv, F):
            INTERMEDIATE.append(v)
    INTERMEDIATE = list(set(INTERMEDIATE))
            
    return PATH, INTERMEDIATE

# %%
def FIND_INTERMEDIATE21(G , x, y, v, F):
    vertices = []
    PATH = []
    path_distance = float("inf")
    for edge in F:
        vertices.append(edge.u)
        vertices.append(edge.v)
    d1 = min(nearest_power_of_2(D[x][a]) for a in vertices)
    # d2 = min(nearest_power_of_2(distance_oracle.get_distance(y, b)) for b in vertices)
    
    direct_path = []
    direct_path_distance = float("inf") 
    F_star, xy_F_star = maximizer_dict21[(x, y, d1, v)]
    if F_star is None or F_star==[]:
        return  shortest_paths[(x, y)] , []
    for edge in F_star:
        if (edge[0] == x and edge[1] == y) or (edge[0] == y and edge[1] == x):  
            direct_path = [x , y]
    # F_star, xy_F_star = maximizer21(G, x, y, d1, v)

    # xy_F_star = None
    # F_star = None
    # if (x, y, d1, v) not in maximizer_dict21:
    #     F_star, xy_F_star = maximizer21(G, x, y, d1, v)
    #     print(f"maximizer21: {x, y, d1, v} this is not in maximizer_dict21")
    #     maximizer_dict21[(x, y, d1, v)] = (F_star, xy_F_star)
    # else:
    #     F_star, xy_F_star = maximizer_dict21[(x, y, d1, v)]
    
    # print(f"in2 =F_star:{F_star}, xy_F_star:{xy_F_star}")
    xy_F_star_path = []
    if xy_F_star is not None:
        # if len(xy_F_star)==1:
        #     xy_F_star_path = (
        #         shortest_paths[(xy_F_star[0][0], xy_F_star[0][1])]
        #     )
        # elif len(xy_F_star) ==3:
        #     xy_F_star_path = (
        #         shortest_paths[(xy_F_star[0][0], xy_F_star[0][1])]
        #         + [xy_F_star[1][0]]
        #         + shortest_paths[(xy_F_star[2][0], xy_F_star[2][1])]
        #     )
        if len(xy_F_star) == 5:
            xy_F_star_path = (
            shortest_paths[(xy_F_star[0][0], xy_F_star[0][1])]
            + [xy_F_star[1][0]]
            + shortest_paths[(xy_F_star[2][0], xy_F_star[2][1])] + [xy_F_star[3][0]] + shortest_paths[(xy_F_star[4][0], xy_F_star[4][1])]
        )
            
        else :
            if xy_F_star:
                xy_F_star_path = xy_F_star[0]   
            else:
                xy_F_star_path = []

            
    INTERMEDIATE = []
    
    if not single_edge_in_path(xy_F_star_path, F):
        PATH = xy_F_star_path
        if(PATH):
            path_distance = sum(get_edge_weight(G, PATH[i], PATH[i + 1]) for i in range(len(PATH) - 1))
            if direct_path!= []:
                direct_path_distance = G[x][y]["weight"]
                if path_distance > direct_path_distance and not single_edge_in_path(direct_path, F):    
                    PATH = direct_path
                    path_distance = direct_path_distance    
                    return PATH, INTERMEDIATE   
            
    # print(PATH)

    F_star_vertices = list(set([vetex for tuple in F_star for vetex in tuple]))
    for u in F_star_vertices:
        # u satisfies the condtions of an x-clean vertex
        xu = shortest_paths[(x, u)]
        yu = shortest_paths[(y, u)]
        bfs_tree_of_x_rooted_u = txu_dict[(x, u)]
        
        if intact_from_failure_path(
            xu, F
        ) and intact_from_failure_tree(bfs_tree_of_x_rooted_u, F):
            P, I = FIND_INTERMEDIATE3(G , x, y, u, v,  F)
            p_distance = float("inf")
            if P:
                p_distance = sum(
                    get_edge_weight(G, P[i], P[i + 1]) for i in range(len(P) - 1)
            )
            if p_distance < path_distance:  
    
                PATH = P
                path_distance = p_distance
            INTERMEDIATE.extend(I)
        # u satisfies the conditions of an intermediate vertex
        if single_edge_in_path(
            xu, F
        ) and single_edge_in_path(yu, F):
            INTERMEDIATE.append(u)
    INTERMEDIATE=list(set(INTERMEDIATE))
            
    return PATH, INTERMEDIATE

# %%
# F_star  = [(10 , 5) , (23 , 21)]
# F = [ Edge(23 , 10 , get_edge_weight(G, 23, 10)) , Edge(10 , 5 , get_edge_weight(G, 10, 5))]

# F = [Edge(14, 29, get_edge_weight(G, 14, 29)), Edge(29, 33, get_edge_weight(G, 29, 33))]

# FIND_INTERMEDIATE2(G , 14 , 33, 25 , F)
# FIND_INTERMEDIATE3(G , 14 , 33, 25 , 40 , F)

# %%
# i = 0
# for key , val in maximizer_dict2.items():
#     print(f"{i}: {key}: {val}")
#     i += 1
#     if i == 100000:
#         break

# %%
def FIND_INTERMEDIATE1(G ,x, y, r, F):
    
    # if r == 0:
    #     return [], []
    # Extract vertices from edges in F
    vertices = set()
    for edge in F:
        vertices.add(edge.u)
        vertices.add(edge.v)

    # d1 = min(nearest_power_of_2(distance_oracle.get_distance(x, a)) for a in vertices)
    d1 = min(nearest_power_of_2(D[x][a]) for a in vertices)
    # d2 = min(nearest_power_of_2(distance_oracle.get_distance(a, y)) for a in vertices)
    d2 = min(nearest_power_of_2(D[y][a]) for a in vertices)


    # print(d1, d2)
    # print(maximizer_dict1[(x, y, d1, d2)])
    direct_path = []
    direct_path_distance = float("inf") 
    F_star, xy_F_star = maximizer_dict1[(x, y, d1, d2)]
    if F_star is None or F_star == []:
        return shortest_paths[(x, y)] , []
    for edge in F_star:
        if  (x==edge[0] and y==edge[1]) or (x==edge[1] and y==edge[0]):  
            direct_path = [x , y]
                
            
    
    # F_star, xy_F_star = maximizer1(G, x, y, d1, d2)
    
    # print(f"f_star:{F_star}, xy_F_star:{xy_F_star}")
    xy_F_star_path = []

    if xy_F_star is not None and xy_F_star != []:   

        if len(xy_F_star) == 5:
            xy_F_star_path = (
            shortest_paths[(xy_F_star[0][0], xy_F_star[0][1])]
            + [xy_F_star[1][0]]
            + shortest_paths[(xy_F_star[2][0], xy_F_star[2][1])] + [xy_F_star[3][0]] + shortest_paths[(xy_F_star[4][0], xy_F_star[4][1])]
        )
        
        else:
            # print(xy_F_star)
            
            xy_F_star_path = xy_F_star[0]
    # prin(xy_F_star_path)
    # print(F_star, xy_F_star)
    PATH = []
    path_distance = float("inf")
    INTERMEDIATE = []
    

    if not single_edge_in_path(xy_F_star_path, F):
        PATH = xy_F_star_path
        if direct_path!=[]:        
            direct_path_distance = G[direct_path[0]][direct_path[1]]['weight']
        
        if(PATH):
            path_distance = sum(get_edge_weight(G, PATH[i], PATH[i + 1]) for i in range(len(PATH) - 1))
            if direct_path_distance < path_distance and not single_edge_in_path(direct_path, F):    
                PATH = direct_path
                path_distance = direct_path_distance    
                return PATH, INTERMEDIATE  
            
            

    # print(PATH)
    F_star_vertices = []
    
    F_star_vertices = [vertex for E in F_star for vertex in E]
    F_star_vertices = list(set(F_star_vertices))
    for u in F_star_vertices:
        # u satisfies the condtions of an x-clean vertex
        xu = shortest_paths[(x, u)] 
        bfs_tree_of_s_rooted_x = txu_dict[(x, u)]
        if intact_from_failure_path(
            xu, F
        ) and intact_from_failure_tree(bfs_tree_of_s_rooted_x, F):
            P1, I1 = FIND_INTERMEDIATE2(G , x, y, u, F)
            # print(f"FIND_INTERMEDIATE2: {P1}, {I1}")
            p1_distance = float("inf")
            if P1:
                p1_distance = sum(
                    get_edge_weight(G, P1[i], P1[i + 1]) for i in range(len(P1) - 1)
            )
            if p1_distance < path_distance:  
    
                PATH = P1
                path_distance = p1_distance

            INTERMEDIATE.extend(I1)

        # u satisfies the conditions of a y-clean vertex
        yu = shortest_paths[(y, u)]
        bfs_tree_of_s_rooted_y = txu_dict[(y, u)]   
        if intact_from_failure_path(
            yu, F
        ) and intact_from_failure_tree(bfs_tree_of_s_rooted_y, F):

            P2, I2 = FIND_INTERMEDIATE21(G , x, y, u, F)
            # print(f"FIND_INTERMEDIATE21: {P2}, {I2}")   
            p2_distance = float("inf")
            if P2:
                p2_distance = sum(
                    get_edge_weight(G, P2[i], P2[i + 1]) for i in range(len(P2) - 1)
                )
            
            if p2_distance < path_distance:
                PATH = P2
                path_distance = p2_distance
            INTERMEDIATE.extend(I2)

        # u satisfies the conditions of an intermediate vertex

        if  single_edge_in_path(
            xu, F
        ) and single_edge_in_path(yu, F):
            # print("else")
            INTERMEDIATE.append(u)

    INTERMEDIATE= list(set(INTERMEDIATE))   

    return PATH, INTERMEDIATE

# %% [markdown]
# ===================================== Main Function ==================================================

# %%
from itertools import product


def remove_duplicates(lst):
    seen = set()
    result = []
    for item in lst:
        if item not in seen:
            seen.add(item)
            result.append(item)
    return result
# def QUERY2(s, t,r, F, findpath, findjump, find_intermediate1):
def QUERY2(G ,s, t, r, F):
    # F_copy = F
    if r == 0:
        # return float("inf")
        return []
    # print(FINDPATHS(s, t, F[:]))
    P = FINDPATHS(G ,s, t, F[:])

    # print(P)
    f = len(F)
    
    if len(P)< f:
        return P[0] if P else []    
    jumps = []
    for i in range(f):
        # print(f"ith_paths={P[i]}")
        # for edge in F[:]:
            # print(f"edges:edge.u, edge.v} ")
        # print(f"edges:{F[0].u, F[0].v} ")
        jump_st = FINDJUMP2(P[i], F[:])
        # use slicing to reverse the lis
        jump_ts = FINDJUMP2(P[i][::-1], F)
        # print(f"jump_st={jump_st}, jump_t={jump_ts}")
        jumps.append((jump_st, jump_ts))
    # print(f"jumps={jumps}")
    PATH = []
    
    path_distance = float("inf")
    processed_pairs = set()
    
    # print(f"r={r}")
    for i in range(f):
        for j in range(f):
            INTERMEDIATE = []  
            for x, y in product(jumps[i][0], jumps[j][1]):
                if(x!=y) and (x, y) not in processed_pairs: 
                    # print(f"jumps[i][0]={jumps[i][0]}, jumps[j][1]={jumps[j][1]}")
                    # processed_pairs.add((x, y))
                    sx = shortest_paths[(s, x)]     
                    sy = shortest_paths[(s, y)]
                    xt = shortest_paths[(x, t)]
                    yt = shortest_paths[(y, t)]  

                    # print(f"sx={sx}, sy={sy}, xt{xt}, yt={yt}")
                    if edge_in_path(sx, F[:]) and edge_in_path(xt, F[:]):
                        INTERMEDIATE.append(x)
                    # y satisfies the conditionof an intermediate vertex
                    elif edge_in_path(sy, F[:]) and edge_in_path(yt, F[:]):
                        INTERMEDIATE.append(y)
                    else:
                        P,I = FIND_INTERMEDIATE1(G , x, y, r, F[:])
                        # print(f"P={P}, I={I}")

                        P_prime = []
                        if(not edge_in_path(sx , F[:]) and  not edge_in_path(yt , F[:])):
                            P_prime = sx + P + yt
                        
                        if P_prime == []:
                            continue
                        P_prime = remove_duplicates( P_prime)
                        # print(f"P_prime={P_prime}")
                        if not is_valid_path(G, P_prime):
                            if(I is not None):
                                INTERMEDIATE.extend(I)  
                            continue
                        
                        # P_prime = []

                        # P_prime = sx + P[1:-1] + yt
                        # # P = remove_duplicates(sx_path + xy_e_star + yt_path)
                        
                        # if y==s and P != []:
                        #     P_prime = P[::-1] + xt
                        #     if x==t:
                        #         P_prime = P[::-1] 
                        # elif P != [] and D[s][y] < D[x][s]:
                        #     P_prime = shortest_paths[(s, y)] + P[::-1] + xt
                        #     if s in P and P.index(s) > 0:
                        #         s_index  = P[::-1].index(s) 
                        #         p1 = P[::-1][s_index:]    
                        #         p2 = shortest_paths[(x, t)]
                        #         P_prime = p1 + p2

                        
                        # if P_prime == []:
                        #     continue
                        # P_prime = remove_duplicates( P_prime)
                        



                        # print(f"P_prime={P_prime}")
                        if not is_valid_path(G, P_prime):
                            if(I is not None and I!= []):
                                INTERMEDIATE.extend(I)
                            continue
                        
                        # we can do it by distance oracle but need to check distance oracle to fix
                        P_prime_distance = sum(
                            get_edge_weight(G, P_prime[i], P_prime[i + 1]) for i in range(len(P_prime) - 1)
                            
                        )
                        
                        # new condition
                        if(not edge_in_path(P_prime , F[:]) and (P_prime[0]==s and P_prime[-1]==t)): 
                            if P_prime_distance < path_distance :
                                PATH = P_prime
                                path_distance = P_prime_distance
 
                        if I is not None and I!= []:
                            INTERMEDIATE.extend(I)
                        
                        
                        
                       

    INTERMEDIATE = list(set(INTERMEDIATE))

    for u in INTERMEDIATE:
        query_path = []
        query_path_distance = float("inf")
        
        
        
        
        path1 = QUERY2(G, s, u, r - 1, F[:])
        path2 = QUERY2(G, u, t, r - 1, F[:])

        if path1 == "inf" or path2 == "inf":
            query_path = []
        else:
            query_path = path1 + path2
        
        # query_path = QUERY2(s, u, r - 1, F[:]) + QUERY2(u, t, r - 1, F[:])
        query_path = remove_duplicates(query_path) if query_path!=float("inf") else []

    
        if query_path != []:
            # print(f"query_path={query_path}")
            if(query_path[0]!=s or query_path[-1]!=t):
                continue
            query_path_distance = sum(get_edge_weight(G, query_path[i], query_path[i + 1]) for i in range(len(query_path) - 1) )
            
        if path_distance > query_path_distance and not edge_in_path(query_path, F[:]) :
                
                PATH = query_path
                path_distance = query_path_distance

                
    return PATH

# %% [markdown]
# #Cross Check Function

# %%
import networkx as nx

def cross_check2(G, s, t, e1, e2):
    e1_u, e1_v = e1
    e2_u, e2_v = e2
    
    if not G.has_node(s) or not G.has_node(t):
        print("Source or target node does not exist in the graph.")  
        return []
    
    edge1_exists = False
    edge2_exists = False

    # Check if edges exist before removing them
    if G.has_edge(e1_u, e1_v):
        edge1_exists = True
        edge1_data = G.get_edge_data(e1_u, e1_v)

        G.remove_edge(e1_u, e1_v)
    else:
        print(f"Edge ({e1_u}, {e1_v}) does not exist in the graph.")
    
    if G.has_edge(e2_u, e2_v):
        edge2_exists = True
        edge2_data = G.get_edge_data(e2_u, e2_v)
       # Added debug print
        G.remove_edge(e2_u, e2_v)
    else:
        print(f"Edge ({e2_u}, {e2_v}) does not exist in the graph.")

    # Find the shortest path
    try:
        st_path = nx.dijkstra_path(G, s, t, weight='weight')
      # Added debug print
    except nx.NetworkXNoPath:
        st_path = []
        print(f"No path exists between nodes {s} and {t} after removing edges ({e1_u}, {e1_v}) and ({e2_u}, {e2_v}).")

    # Add the edges back to the graph
    if edge1_exists:
        G.add_edge(e1_u, e1_v, **edge1_data)
     
    if edge2_exists:
        G.add_edge(e2_u, e2_v, **edge2_data)
        

    return st_path

# %%
# [37, 1]
# [32, 10, 25, 12, 45, 43]
# avoiding edges:(25, 12), (32, 10)
# query output:[32, 27, 18, 2, 37, 12, 45, 43] , weight:202.3939393939394
# Query time--- 0.5017330646514893 seconds ---
# cross_check output:[32, 12, 45, 43] , weight:177.8181818181818
# Cross_check time--- 0.00017571449279785156 seconds ---
# !!!!!!!!!!!!----SOMETHING WENT WRONG-----!!!!!!!!!!!!!!!!!!

e = [Edge(25, 12, get_edge_weight(G, 25, 12)), Edge(32, 10, get_edge_weight(G, 32, 10))]
QUERY2(G, 32, 43, 3, e)
# Out:
# [32, 12, 45, 43]

# %%
# case:870 ===>
# [0, 45, 12, 37, 9, 22, 24, 8, 3]
# avoiding edges:(8, 3), (24, 8)
# query output:[0, 45, 12, 25, 17, 3] , weight:174.56565656565658
# Query time--- 0.3410665988922119 seconds ---
# cross_check output:[0, 45, 12, 37, 9, 22, 3] , weight:143.55555555555557
# Cross_check time--- 0.00015926361083984375 seconds ---
# !!!!!!!!!!!!----SOMETHING WENT WRONG-----!!!!!!!!!!!!!!!!!!
e = [Edge(8, 3, get_edge_weight(G, 8, 3)), Edge(24, 8, get_edge_weight(G, 24, 8))]
QUERY2(G, 0, 3, 3, e)
# Out:
# [0, 45, 12, 37, 9, 22, 3]

# %%
# import cProfile
# import pstats

# cProfile.run('QUERY2(G, 0, 3, 3, e)', 'profile_output')
# p = pstats.Stats('profile_output')
# p.strip_dirs().sort_stats('time').print_stats(10)
# Out:
# Wed Apr 30 00:52:06 2025    profile_output
#
#          206 function calls in 0.000 seconds
#
#    Ordered by: internal time
#    List reduced from 20 to 10 due to restriction <10>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#        22    0.000    0.000    0.000    0.000 3754194688.py:1(get_edge_weight)
#         1    0.000    0.000    0.000    0.000 3128880164.py:1(FINDPATHS)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.exec}
#        22    0.000    0.000    0.000    0.000 graph.py:489(__getitem__)
#        22    0.000    0.000    0.000    0.000 coreviews.py:80(__getitem__)
#         5    0.000    0.000    0.000    0.000 1939861067.py:13(QUERY)
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.round}
#        22    0.000    0.000    0.000    0.000 graph.py:1274(has_edge)
#         5    0.000    0.000    0.000    0.000 {built-in method builtins.sum}
#         9    0.000    0.000    0.000    0.000 3128880164.py:24(<genexpr>)

# %%
# !snakeviz profile_output

# %%
# import time

# def FINDPATHS(G ,s, t, F2):
#     start_total = time.time()
#     F_prime = []
#     P = []
    
#     for i in range(1, f + 1):
#         t0 = time.time()
#         if F_prime:
#             u, v, weight = F_prime[i - 2].u, F_prime[i - 2].v, F_prime[i - 2].weight
#             P_i = QUERY(G,s, t, Edge(u, v, weight))
#         else:
#             P_i = QUERY(G, s, t, F_prime)
#         print(f"QUERY for P_i took {time.time() - t0:.6f} sec")
        
#         P.append(P_i)
#         if P_i == []:
#             continue
        
#         t1 = time.time()
#         weight_p_i = sum(
#             get_edge_weight(G, P_i[i], P_i[i + 1]) for i in range(len(P_i) - 1)
#         )
#         print(f"Weight sum for P_i took {time.time() - t1:.6f} sec")

#         if F_prime:
#             F2.remove(F_prime[i - 2])
        
#         for e1 in F2:
#             t2 = time.time()
#             if F_prime:
#                 R1 = QUERY(G, s, e1.u, Edge(u, v, weight))
#                 R2 = QUERY(G, e1.v, t, Edge(u, v, weight))
#             else:
#                 R1 = QUERY(G, s, e1.u, F_prime)
#                 R2 = QUERY(G, e1.v, t, F_prime)
#             print(f"QUERY for R1 and R2 took {time.time() - t2:.6f} sec")
            
#             weight_R1 = sum(
#                 get_edge_weight(G, R1[i], R1[i + 1]) for i in range(len(R1) - 1)
#             )
#             weight_R2 = sum(
#                 get_edge_weight(G, R2[i], R2[i + 1]) for i in range(len(R2) - 1)
#             )
#             weight_e = get_edge_weight(G, e1.u, e1.v)
            
#             if round(weight_R1 + weight_e + weight_R2, 7) == round(weight_p_i, 7):
#                 F_prime.append(e1)
#                 break
#     print(f"Total FINDPATHS time: {time.time() - start_total:.6f} sec")
#     return P

# %%
# import time

# start = time.time()
# s = 0
# t =3 

# P = FINDPATHS(G, s, t,e)
# print(f"FINDPATHS took {time.time() - start:.6f} sec")
# Out:
# QUERY for P_i took 0.000005 sec
# Weight sum for P_i took 0.000042 sec
# QUERY for R1 and R2 took 0.000005 sec
# QUERY for R1 and R2 took 0.000003 sec
# QUERY for P_i took 0.000001 sec
# Weight sum for P_i took 0.000014 sec
# QUERY for R1 and R2 took 0.000001 sec
# QUERY for R1 and R2 took 0.000001 sec
# Total FINDPATHS time: 0.000277 sec
# FINDPATHS took 0.000402 sec

# %%
# case:8149 ===>
# [27, 36, 21, 14, 9, 22, 24, 8, 3]
# avoiding edges:(8, 3), (24, 8)
# query output:[27, 32, 10, 25, 17, 3] , weight:186.26262626262627
# Query time--- 1.6399340629577637 seconds ---
# cross_check output:[27, 36, 21, 14, 9, 22, 3] , weight:146.75757575757575
# Cross_check time--- 0.0004858970642089844 seconds ---
# !!!!!!!!!!!!----SOMETHING WENT WRONG-----!!!!!!!!!!!!!!!!!!
e = [Edge(8, 3, get_edge_weight(G, 8, 3)), Edge(24, 8, get_edge_weight(G, 24, 8))]
QUERY2(G, 27, 3, 3, e)
# Out:
# [27, 36, 21, 14, 9, 22, 3]

# %%
# case:1219 ===>
# [27, 36, 21, 14, 9, 22, 24, 8, 3, 17]
# avoiding edges:(8, 3), (24, 8)
# query output:[27, 32, 10, 25, 17] , weight:168.14141414141415
# Query time--- 1.8661253452301025 seconds ---
# cross_check output:[27, 36, 21, 14, 9, 22, 3, 17] , weight:164.87878787878788
# Cross_check time--- 0.0005004405975341797 seconds ---
# !!!!!!!!!!!!----SOMETHING WENT WRONG-----!!!!!!!!!!!!!!!!!!
e = [Edge(8, 3, get_edge_weight(G, 8, 3)), Edge(24, 8, get_edge_weight(G, 24, 8))]
QUERY2(G, 27, 17, 3, e)
# Out:
# [27, 36, 21, 14, 9, 22, 3, 17]

# %%
# case:1411 ===>
# [12, 37, 2]
# avoiding edges:(12, 37), (37, 2)
# query output:[12, 45, 6, 44, 18, 2] , weight:104.47474747474747
# Query time--- 1.3762853145599365 seconds ---
# cross_check output:[12, 21, 2] , weight:84.51515151515152
# Cross_check time--- 0.0003380775451660156 seconds ---
# !!!!!!!!!!!!----SOMETHING WENT WRONG-----!!!!!!!!!!!!!!!!!!
e = [Edge(12, 37, get_edge_weight(G, 12, 37)), Edge(37, 2, get_edge_weight(G, 37, 2))]  
QUERY2(G, 12, 2, 3, e)
# Out:
# [12, 21, 2]

# %%
# [12, 37, 2, 18]
# avoiding edges:(37, 2), (12, 37)
# query output:[12, 45, 6, 44, 18] , weight:97.41414141414141
# Query time--- 2.2621192932128906 seconds ---
# cross_check output:[12, 21, 2, 18] , weight:91.57575757575758
# Cross_check time--- 0.00038552284240722656 seconds ---
# !!!!!!!!!!!!----SOMETHING WENT WRONG-----!!!!!!!!!!!!!!!!!!
e = [Edge(37, 2, get_edge_weight(G, 37, 2)), Edge(12, 37, get_edge_weight(G, 12, 37))]  
QUERY2(G, 12, 18, 3, e)
# Out:
# [12, 21, 2, 18]

# %%
# case:206 ===>
# [32, 10, 25, 12, 45, 43]
# avoiding edges:(25, 12), (32, 10)
# query output:[32, 27, 18, 2, 37, 12, 45, 43] , weight:202.3939393939394
# Query time--- 0.4797706604003906 seconds ---
# cross_check output:[32, 12, 45, 43] , weight:177.8181818181818
# Cross_check time--- 0.0004916191101074219 seconds ---
# !!!!!!!!!!!!----SOMETHING WENT WRONG-----!!!!!!!!!!!!!!!!!!
e = [Edge(25, 12, get_edge_weight(G, 25, 12)), Edge(32, 10, get_edge_weight(G, 32, 10))]    
QUERY2(G, 32, 43, 3, e)
# Out:
# [32, 12, 45, 43]

# %%
import random
import time

f =2

right = 0
wrong = 0

for case in range(1, 200):
    x = random.randint(0, 50)
    y = random.randint(0, 50)
    if x==y:
        continue
    try:
        print(shortest_paths[(x, y)])
    except KeyError:
        print(f"Shortest path for ({x}, {y}) not found in shortest_paths.")
        continue
            
    # print(shortest_paths[(x, y)])
    path = shortest_paths[(x,y)]
    
    pedges = []
    for i in range(len(path) - 1):
        pedges.append(Edge(path[i], path[i + 1], get_edge_weight(G, path[i], path[i + 1])))
    if len(pedges) < 2:
       continue
    e1 , e2 = random.sample(pedges, 2) 
    
    F3 = [Edge(e1.u, e1.v, get_edge_weight(G, e1.u, e1.v)), Edge(e2.u, e2.v, get_edge_weight(G, e2.u, e2.v))]

    # F3 = [Edge(e1_u, e1_v, get_edge_weight(G, e1_u, e1_v)), Edge(e2_u, e2_v, get_edge_weight(G, e2_u, e2_v))]
    
    
    print(f"avoiding edges:{e1.u, e1.v}, {e2.u, e2.v}")
    start_time = time.time()
    query_output = QUERY2(G , x, y, 3, F3)
    q_weight = sum(get_edge_weight(G, query_output[i], query_output[i + 1]) for i in range(len(query_output) - 1))
    print(f"query output:{query_output} , weight:{q_weight}")
    print("Query time--- %s seconds ---" % (time.time() - start_time))
    start_time = time.time()
    cross_check_output = cross_check2(G, x, y, (e1.u, e1.v), (e2.u, e2.v))
    c_weight = sum(get_edge_weight(G, cross_check_output[i], cross_check_output[i + 1]) for i in range(len(cross_check_output) - 1))
    print(f"cross_check output:{cross_check_output} , weight:{c_weight}")
    print("Cross_check time--- %s seconds ---" % (time.time() - start_time))
    if query_output != cross_check_output:
        wrong += 1
        print("!!!!!!!!!!!!----SOMETHING WENT WRONG-----!!!!!!!!!!!!!!!!!!")
    else :
        right += 1

    print("===================================================")
# Out:
# [0, 45, 12, 37, 28]
# avoiding edges:(0, 45), (45, 12)
# query output:[] , weight:0
# Query time--- 0.014188528060913086 seconds ---
# No path exists between nodes 0 and 28 after removing edges (0, 45) and (45, 12).
# cross_check output:[] , weight:0
# Cross_check time--- 0.00010704994201660156 seconds ---
# ===================================================
# Shortest path for (3, 20) not found in shortest_paths.
# [0, 45, 12, 37, 28, 34]
# avoiding edges:(12, 37), (37, 28)
# query output:[0, 45, 12, 21, 14, 9, 22, 24, 34] , weight:154.40404040404042
# Query time--- 2.2648210525512695 seconds ---
# cross_check output:[0, 45, 12, 21, 14, 9, 22, 24, 34] , weight:154.40404040404042
# Cross_check time--- 0.00034880638122558594 seconds ---
# ===================================================
# [10, 25, 12]
# avoiding edges:(25, 12), (10, 25)
# query output:[10, 32, 12] , weight:111.79797979797979
# Query time--- 0.948967695236206 seconds ---
# cross_check output:[10, 32, 12] , weight:111.79797979797979
# Cross_check time--- 0.00016689300537109375 seconds ---
# ===================================================
# [25, 14, 9, 22, 24]
# avoiding edges:(25, 14), (22, 24)
# query output:[25, 12, 37, 2, 41, 24] , weight:95.8080808080808
# Query time--- 1.4366722106933594 seconds ---
# cross_check output:[25, 12, 37, 2, 41, 24] , weight:95.8080808080808
# Cross_check time--- 0.0002911090850830078 seconds ---
# ===================================================
# Shortest path for (8, 11) not found in shortest_paths.
# Shortest path for (20, 13) not found in shortest_paths.
# [22, 7]
# [21, 14, 9, 22, 7]
# avoiding edges:(9, 22), (22, 7)
# query output:[21, 40, 4, 7] , weight:121.96969696969697
# Query time--- 12.306129217147827 seconds ---
# cross_check output:[21, 40, 4, 7] , weight:121.96969696969697
# Cross_check time--- 0.00034236907958984375 seconds ---
# ===================================================
# [21, 40, 48, 46]
# avoiding edges:(40, 48), (21, 40)
# query output:[21, 14, 9, 48, 46] , weight:109.12121212121211
# Query time--- 0.6137158870697021 seconds ---
# cross_check output:[21, 14, 9, 48, 46] , weight:109.12121212121211
# Cross_check time--- 0.0003783702850341797 seconds ---
# ===================================================
# Shortest path for (50, 40) not found in shortest_paths.
# [28, 37, 19]
# avoiding edges:(28, 37), (37, 19)
# query output:[28, 34, 42, 19] , weight:132.4242424242424
# Query time--- 2.908726930618286 seconds ---
# cross_check output:[28, 34, 42, 19] , weight:132.4242424242424
# Cross_check time--- 0.00028204917907714844 seconds ---
# ===================================================
# Shortest path for (20, 40) not found in shortest_paths.
# Shortest path for (35, 30) not found in shortest_paths.
# [31, 15, 42, 19, 44, 6]
# avoiding edges:(19, 44), (31, 15)
# query output:[31, 3, 8, 24, 41, 13, 6] , weight:165.93939393939397
# Query time--- 1.8491971492767334 seconds ---
# cross_check output:[31, 3, 8, 24, 41, 13, 6] , weight:165.93939393939397
# Cross_check time--- 0.0002613067626953125 seconds ---
# ===================================================
# [24, 41, 2, 18]
# avoiding edges:(2, 18), (24, 41)
# query output:[24, 22, 9, 14, 6, 44, 18] , weight:138.36363636363637
# Query time--- 3.727130651473999 seconds ---
# cross_check output:[24, 22, 9, 14, 6, 44, 18] , weight:138.36363636363637
# Cross_check time--- 0.0003085136413574219 seconds ---
# ===================================================
# Shortest path for (20, 0) not found in shortest_paths.
# Shortest path for (16, 50) not found in shortest_paths.
# [23, 21, 14, 9, 22, 7]
# avoiding edges:(21, 14), (23, 21)
# query output:[23, 36, 12, 37, 9, 22, 7] , weight:159.42424242424244
# Query time--- 0.32093238830566406 seconds ---
# cross_check output:[23, 36, 12, 37, 9, 22, 7] , weight:159.42424242424244
# Cross_check time--- 0.0003101825714111328 seconds ---
# ===================================================
# [27, 18]
# [8, 24, 22, 9, 14, 21, 36, 27]
# avoiding edges:(21, 36), (36, 27)
# query output:[8, 24, 41, 2, 18, 27] , weight:121.76767676767678
# Query time--- 1.1394248008728027 seconds ---
# cross_check output:[8, 24, 41, 2, 18, 27] , weight:121.76767676767678
# Cross_check time--- 0.0002799034118652344 seconds ---
# ===================================================
# [5, 10, 25, 12, 45, 43]
# avoiding edges:(5, 10), (45, 43)
# query output:[] , weight:0
# Query time--- 0.36444711685180664 seconds ---
# No path exists between nodes 5 and 43 after removing edges (5, 10) and (45, 43).
# cross_check output:[] , weight:0
# Cross_check time--- 0.0002982616424560547 seconds ---
# ===================================================
# [42, 19, 37, 12, 36]
# avoiding edges:(19, 37), (42, 19)
# query output:[42, 10, 32, 27, 36] , weight:167.36363636363635
# Query time--- 2.4391870498657227 seconds ---
# cross_check output:[42, 10, 32, 27, 36] , weight:167.36363636363635
# Cross_check time--- 0.00031256675720214844 seconds ---
# ===================================================
# [16, 23]
# [43, 45, 12, 37, 19, 42, 15]
# avoiding edges:(45, 12), (43, 45)
# query output:[] , weight:0
# Query time--- 0.9815666675567627 seconds ---
# No path exists between nodes 43 and 15 after removing edges (45, 12) and (43, 45).
# cross_check output:[] , weight:0
# Cross_check time--- 7.796287536621094e-05 seconds ---
# ===================================================
# [6, 44, 18, 27, 36, 23]
# avoiding edges:(36, 23), (44, 18)
# query output:[6, 14, 21, 23] , weight:123.40404040404042
# Query time--- 3.310483932495117 seconds ---
# cross_check output:[6, 14, 21, 23] , weight:123.40404040404042
# Cross_check time--- 0.00027871131896972656 seconds ---
# ===================================================
# [29, 14, 9, 37, 12, 45]
# avoiding edges:(37, 12), (12, 45)
# query output:[29, 14, 6, 45] , weight:143.91919191919192
# Query time--- 0.09456014633178711 seconds ---
# cross_check output:[29, 14, 6, 45] , weight:143.91919191919192
# Cross_check time--- 0.000270843505859375 seconds ---
# ===================================================
# [0, 45]
# [32, 10, 25, 12, 37, 2, 18]
# avoiding edges:(37, 2), (32, 10)
# query output:[32, 27, 18] , weight:103.43434343434345
# Query time--- 2.794299602508545 seconds ---
# cross_check output:[32, 27, 18] , weight:103.43434343434345
# Cross_check time--- 0.00018215179443359375 seconds ---
# ===================================================
# [19, 42, 34]
# avoiding edges:(19, 42), (42, 34)
# query output:[19, 37, 28, 34] , weight:150.34343434343435
# Query time--- 0.5849382877349854 seconds ---
# cross_check output:[19, 37, 28, 34] , weight:150.34343434343435
# Cross_check time--- 0.000347137451171875 seconds ---
# ===================================================
# [15, 35, 33, 29]
# avoiding edges:(15, 35), (35, 33)
# query output:[15, 22, 9, 14, 29] , weight:136.62626262626262
# Query time--- 0.7586441040039062 seconds ---
# cross_check output:[15, 22, 9, 14, 29] , weight:136.62626262626262
# Cross_check time--- 0.00041222572326660156 seconds ---
# ===================================================
# [17, 3, 8, 24, 22, 9, 14, 21, 36]
# avoiding edges:(3, 8), (17, 3)
# query output:[17, 25, 12, 36] , weight:167.46464646464648
# Query time--- 0.563363790512085 seconds ---
# cross_check output:[17, 25, 12, 36] , weight:167.46464646464648
# Cross_check time--- 0.0002579689025878906 seconds ---
# ===================================================
# Shortest path for (3, 50) not found in shortest_paths.
# [43, 45, 12, 37, 9, 14, 29, 33]
# avoiding edges:(45, 12), (29, 33)
# query output:[43, 45, 6, 44, 40, 48, 33] , weight:247.27272727272728
# Query time--- 2.1830689907073975 seconds ---
# cross_check output:[43, 45, 6, 44, 40, 48, 33] , weight:247.27272727272728
# Cross_check time--- 0.00031256675720214844 seconds ---
# ===================================================
# [16, 46, 7]
# avoiding edges:(46, 7), (16, 46)
# query output:[16, 23, 21, 14, 9, 22, 7] , weight:166.60606060606062
# Query time--- 0.2933003902435303 seconds ---
# cross_check output:[16, 23, 21, 14, 9, 22, 7] , weight:166.60606060606062
# Cross_check time--- 0.00026345252990722656 seconds ---
# ===================================================
# [47, 39, 10, 25, 12, 26]
# avoiding edges:(10, 25), (47, 39)
# query output:[47, 33, 35, 26] , weight:207.63636363636363
# Query time--- 7.295341730117798 seconds ---
# cross_check output:[47, 33, 35, 26] , weight:207.63636363636363
# Cross_check time--- 0.0003120899200439453 seconds ---
# ===================================================
# [15, 31, 3, 8]
# avoiding edges:(31, 3), (3, 8)
# query output:[15, 22, 24, 8] , weight:103.51515151515153
# Query time--- 0.6896212100982666 seconds ---
# cross_check output:[15, 22, 24, 8] , weight:103.51515151515153
# Cross_check time--- 0.00021386146545410156 seconds ---
# ===================================================
# [35, 15, 31]
# avoiding edges:(15, 31), (35, 15)
# query output:[35, 14, 9, 22, 24, 8, 3, 31] , weight:176.31313131313132
# Query time--- 0.9121057987213135 seconds ---
# cross_check output:[35, 14, 9, 22, 24, 8, 3, 31] , weight:176.31313131313132
# Cross_check time--- 0.00036025047302246094 seconds ---
# ===================================================
# [22, 24, 8]
# avoiding edges:(22, 24), (24, 8)
# query output:[22, 3, 8] , weight:72.23232323232322
# Query time--- 0.7592778205871582 seconds ---
# cross_check output:[22, 3, 8] , weight:72.23232323232322
# Cross_check time--- 0.00028252601623535156 seconds ---
# ===================================================
# [34, 24, 22, 9, 14, 25, 10, 39, 47]
# avoiding edges:(25, 10), (9, 14)
# query output:[34, 42, 10, 39, 47] , weight:201.59595959595958
# Query time--- 1.968580961227417 seconds ---
# cross_check output:[34, 42, 10, 39, 47] , weight:201.59595959595958
# Cross_check time--- 0.0003097057342529297 seconds ---
# ===================================================
# [33, 29]
# [19, 37, 12]
# avoiding edges:(19, 37), (37, 12)
# query output:[19, 44, 6, 45, 12] , weight:106.45454545454545
# Query time--- 3.1804587841033936 seconds ---
# cross_check output:[19, 44, 6, 45, 12] , weight:106.45454545454545
# Cross_check time--- 0.0002219676971435547 seconds ---
# ===================================================
# [39, 10, 25, 12]
# avoiding edges:(39, 10), (10, 25)
# query output:[39, 23, 36, 12] , weight:109.8989898989899
# Query time--- 2.0048460960388184 seconds ---
# cross_check output:[39, 23, 36, 12] , weight:109.8989898989899
# Cross_check time--- 0.00018286705017089844 seconds ---
# ===================================================
# [17, 3, 8, 24, 34, 28]
# avoiding edges:(3, 8), (34, 28)
# query output:[17, 25, 12, 37, 28] , weight:160.36363636363637
# Query time--- 1.4470629692077637 seconds ---
# cross_check output:[17, 25, 12, 37, 28] , weight:160.36363636363637
# Cross_check time--- 0.00027680397033691406 seconds ---
# ===================================================
# [46, 48, 40, 4]
# avoiding edges:(46, 48), (48, 40)
# query output:[46, 7, 4] , weight:109.39393939393939
# Query time--- 0.5017068386077881 seconds ---
# cross_check output:[46, 7, 4] , weight:109.39393939393939
# Cross_check time--- 0.0001423358917236328 seconds ---
# ===================================================
# [38, 22, 15, 42]
# avoiding edges:(22, 15), (15, 42)
# query output:[38, 22, 24, 34, 42] , weight:159.15151515151516
# Query time--- 3.1552364826202393 seconds ---
# cross_check output:[38, 22, 24, 34, 42] , weight:159.15151515151516
# Cross_check time--- 0.0002846717834472656 seconds ---
# ===================================================
# [2, 18, 44, 19, 42]
# avoiding edges:(19, 42), (18, 44)
# query output:[2, 37, 1, 40, 48, 46, 42] , weight:127.08080808080808
# Query time--- 2.370427131652832 seconds ---
# cross_check output:[2, 37, 1, 40, 48, 46, 42] , weight:127.08080808080808
# Cross_check time--- 0.0003528594970703125 seconds ---
# ===================================================
# [19, 42, 15, 35, 33]
# avoiding edges:(19, 42), (42, 15)
# query output:[19, 49, 33] , weight:141.54545454545453
# Query time--- 0.3110787868499756 seconds ---
# cross_check output:[19, 49, 33] , weight:141.54545454545453
# Cross_check time--- 0.00027680397033691406 seconds ---
# ===================================================
# [43, 45, 12, 37, 9, 22, 7]
# avoiding edges:(45, 12), (22, 7)
# query output:[43, 45, 6, 44, 40, 4, 7] , weight:237.69696969696972
# Query time--- 7.080810785293579 seconds ---
# cross_check output:[43, 45, 6, 44, 40, 4, 7] , weight:237.69696969696972
# Cross_check time--- 0.0003361701965332031 seconds ---
# ===================================================
# [21, 14, 9, 22, 24, 8]
# avoiding edges:(14, 9), (21, 14)
# query output:[21, 9, 22, 24, 8] , weight:93.5858585858586
# Query time--- 0.8034946918487549 seconds ---
# cross_check output:[21, 9, 22, 24, 8] , weight:93.5858585858586
# Cross_check time--- 0.00025653839111328125 seconds ---
# ===================================================
# [4, 40, 21]
# avoiding edges:(4, 40), (40, 21)
# query output:[4, 7, 22, 9, 14, 21] , weight:103.48484848484847
# Query time--- 1.7424075603485107 seconds ---
# cross_check output:[4, 7, 22, 9, 14, 21] , weight:103.48484848484847
# Cross_check time--- 0.00014162063598632812 seconds ---
# ===================================================
# [48, 46]
# [39, 23, 36, 27]
# avoiding edges:(39, 23), (23, 36)
# query output:[39, 10, 32, 27] , weight:104.56565656565657
# Query time--- 2.9831271171569824 seconds ---
# cross_check output:[39, 10, 32, 27] , weight:104.56565656565657
# Cross_check time--- 0.0001938343048095703 seconds ---
# ===================================================
# [16, 46, 48, 40, 44]
# avoiding edges:(40, 44), (16, 46)
# query output:[16, 23, 36, 27, 18, 44] , weight:136.3838383838384
# Query time--- 2.2124264240264893 seconds ---
# cross_check output:[16, 23, 36, 27, 18, 44] , weight:136.3838383838384
# Cross_check time--- 0.00024199485778808594 seconds ---
# ===================================================
# [42, 46, 16]
# avoiding edges:(46, 16), (42, 46)
# query output:[42, 10, 23, 16] , weight:197.26262626262627
# Query time--- 0.5576732158660889 seconds ---
# cross_check output:[42, 10, 23, 16] , weight:197.26262626262627
# Cross_check time--- 0.00028705596923828125 seconds ---
# ===================================================
# [5, 48, 46]
# avoiding edges:(5, 48), (48, 46)
# query output:[5, 10, 42, 46] , weight:172.5050505050505
# Query time--- 1.6728448867797852 seconds ---
# cross_check output:[5, 10, 42, 46] , weight:172.5050505050505
# Cross_check time--- 0.000278472900390625 seconds ---
# ===================================================
# [15, 42, 19, 44]
# avoiding edges:(15, 42), (19, 44)
# query output:[15, 22, 24, 41, 2, 18, 44] , weight:162.76767676767676
# Query time--- 0.8015036582946777 seconds ---
# cross_check output:[15, 22, 24, 41, 2, 18, 44] , weight:162.76767676767676
# Cross_check time--- 0.00027251243591308594 seconds ---
# ===================================================
# [5, 10]
# [13, 41, 24, 22, 7]
# avoiding edges:(13, 41), (24, 22)
# query output:[13, 48, 40, 4, 7] , weight:150.72727272727272
# Query time--- 2.376966953277588 seconds ---
# cross_check output:[13, 48, 40, 4, 7] , weight:150.72727272727272
# Cross_check time--- 0.00027942657470703125 seconds ---
# ===================================================
# [9, 37, 2, 41, 13]
# avoiding edges:(9, 37), (2, 41)
# query output:[9, 14, 6, 13] , weight:94.76767676767676
# Query time--- 3.8129847049713135 seconds ---
# cross_check output:[9, 14, 6, 13] , weight:94.76767676767676
# Cross_check time--- 0.00030350685119628906 seconds ---
# ===================================================
# [44, 19, 42, 15, 31]
# avoiding edges:(19, 42), (44, 19)
# query output:[44, 40, 48, 46, 42, 15, 31] , weight:143.04040404040404
# Query time--- 0.6070406436920166 seconds ---
# cross_check output:[44, 40, 48, 46, 42, 15, 31] , weight:143.04040404040404
# Cross_check time--- 0.00030875205993652344 seconds ---
# ===================================================
# [33, 29, 14, 9, 37, 12, 45]
# avoiding edges:(14, 9), (37, 12)
# query output:[33, 29, 14, 21, 12, 45] , weight:114.68686868686868
# Query time--- 2.719399929046631 seconds ---
# cross_check output:[33, 29, 14, 21, 12, 45] , weight:114.68686868686868
# Cross_check time--- 0.00025272369384765625 seconds ---
# ===================================================
# [0, 45, 12, 37, 9, 22, 24]
# avoiding edges:(9, 22), (0, 45)
# query output:[] , weight:0
# Query time--- 0.3157074451446533 seconds ---
# No path exists between nodes 0 and 24 after removing edges (9, 22) and (0, 45).
# cross_check output:[] , weight:0
# Cross_check time--- 9.942054748535156e-05 seconds ---
# ===================================================
# [17, 25, 10]
# avoiding edges:(25, 10), (17, 25)
# query output:[17, 3, 31, 15, 42, 10] , weight:168.66666666666669
# Query time--- 2.8234705924987793 seconds ---
# cross_check output:[17, 3, 31, 15, 42, 10] , weight:168.66666666666669
# Cross_check time--- 0.0002808570861816406 seconds ---
# ===================================================
# [39, 10, 25, 12, 37, 2, 41, 13]
# avoiding edges:(10, 25), (37, 2)
# query output:[39, 23, 36, 27, 18, 2, 41, 13] , weight:178.54545454545456
# Query time--- 5.734232664108276 seconds ---
# cross_check output:[39, 23, 36, 27, 18, 2, 41, 13] , weight:178.54545454545456
# Cross_check time--- 0.00036215782165527344 seconds ---
# ===================================================
# [32, 10, 25]
# avoiding edges:(10, 25), (32, 10)
# query output:[32, 12, 25] , weight:132.88888888888889
# Query time--- 0.11281561851501465 seconds ---
# cross_check output:[32, 12, 25] , weight:132.88888888888889
# Cross_check time--- 0.00018262863159179688 seconds ---
# ===================================================
# [32, 10, 25, 12, 45]
# avoiding edges:(32, 10), (10, 25)
# query output:[32, 12, 45] , weight:110.81818181818181
# Query time--- 0.32015538215637207 seconds ---
# cross_check output:[32, 12, 45] , weight:110.81818181818181
# Cross_check time--- 0.00014138221740722656 seconds ---
# ===================================================
# [25, 12, 37, 2, 18, 44]
# avoiding edges:(37, 2), (25, 12)
# query output:[25, 40, 44] , weight:91.76767676767676
# Query time--- 3.3388452529907227 seconds ---
# cross_check output:[25, 40, 44] , weight:91.76767676767676
# Cross_check time--- 0.0002186298370361328 seconds ---
# ===================================================
# [32, 10, 25, 14, 9, 22, 7]
# avoiding edges:(25, 14), (14, 9)
# query output:[32, 10, 25, 40, 4, 7] , weight:153.8080808080808
# Query time--- 0.3375256061553955 seconds ---
# cross_check output:[32, 10, 25, 40, 4, 7] , weight:153.8080808080808
# Cross_check time--- 0.0002894401550292969 seconds ---
# ===================================================
# Shortest path for (8, 11) not found in shortest_paths.
# [15, 42, 19, 49, 26]
# avoiding edges:(19, 49), (42, 19)
# query output:[15, 35, 26] , weight:154.36363636363637
# Query time--- 0.2510795593261719 seconds ---
# cross_check output:[15, 35, 26] , weight:154.36363636363637
# Cross_check time--- 0.0002834796905517578 seconds ---
# ===================================================
# [38, 22, 24, 41, 13]
# avoiding edges:(24, 41), (41, 13)
# query output:[38, 22, 9, 14, 6, 13] , weight:178.7777777777778
# Query time--- 3.7678427696228027 seconds ---
# cross_check output:[38, 22, 9, 14, 6, 13] , weight:178.7777777777778
# Cross_check time--- 0.0002961158752441406 seconds ---
# ===================================================
# [41, 2, 37, 12, 45, 0]
# avoiding edges:(12, 45), (2, 37)
# query output:[41, 13, 6, 45, 0] , weight:133.91919191919192
# Query time--- 4.466017484664917 seconds ---
# cross_check output:[41, 13, 6, 45, 0] , weight:133.91919191919192
# Cross_check time--- 0.0003376007080078125 seconds ---
# ===================================================
# [10, 25, 17]
# avoiding edges:(25, 17), (10, 25)
# query output:[10, 42, 15, 31, 3, 17] , weight:168.66666666666669
# Query time--- 2.91884708404541 seconds ---
# cross_check output:[10, 42, 15, 31, 3, 17] , weight:168.66666666666669
# Cross_check time--- 0.0003349781036376953 seconds ---
# ===================================================
# [34, 28, 1]
# avoiding edges:(28, 1), (34, 28)
# query output:[34, 24, 22, 9, 37, 1] , weight:119.0909090909091
# Query time--- 1.0011987686157227 seconds ---
# cross_check output:[34, 24, 22, 9, 37, 1] , weight:119.0909090909091
# Cross_check time--- 0.0002465248107910156 seconds ---
# ===================================================
# [16, 23, 36, 12, 37, 2, 41]
# avoiding edges:(23, 36), (36, 12)
# query output:[16, 23, 21, 12, 37, 2, 41] , weight:149.2828282828283
# Query time--- 1.209489107131958 seconds ---
# cross_check output:[16, 23, 21, 12, 37, 2, 41] , weight:149.2828282828283
# Cross_check time--- 0.00026607513427734375 seconds ---
# ===================================================
# [43, 45, 12, 37, 19, 42, 15, 31]
# avoiding edges:(15, 31), (43, 45)
# query output:[] , weight:0
# Query time--- 0.7485926151275635 seconds ---
# No path exists between nodes 43 and 31 after removing edges (15, 31) and (43, 45).
# cross_check output:[] , weight:0
# Cross_check time--- 8.0108642578125e-05 seconds ---
# ===================================================
# [33, 29, 14, 9, 22, 24, 8]
# avoiding edges:(22, 24), (14, 9)
# query output:[33, 29, 8] , weight:116.15151515151514
# Query time--- 6.179961919784546 seconds ---
# cross_check output:[33, 29, 8] , weight:116.15151515151514
# Cross_check time--- 0.00029277801513671875 seconds ---
# ===================================================
# [39, 10, 32]
# avoiding edges:(39, 10), (10, 32)
# query output:[39, 23, 36, 27, 32] , weight:126.15151515151516
# Query time--- 2.535568952560425 seconds ---
# cross_check output:[39, 23, 36, 27, 32] , weight:126.15151515151516
# Cross_check time--- 0.00017833709716796875 seconds ---
# ===================================================
# [34, 28, 1]
# avoiding edges:(28, 1), (34, 28)
# query output:[34, 24, 22, 9, 37, 1] , weight:119.0909090909091
# Query time--- 0.30034852027893066 seconds ---
# cross_check output:[34, 24, 22, 9, 37, 1] , weight:119.0909090909091
# Cross_check time--- 0.00022602081298828125 seconds ---
# ===================================================
# [2, 37, 9, 14]
# avoiding edges:(9, 14), (2, 37)
# query output:[2, 21, 14] , weight:63.5959595959596
# Query time--- 4.964898109436035 seconds ---
# cross_check output:[2, 21, 14] , weight:63.5959595959596
# Cross_check time--- 0.00015282630920410156 seconds ---
# ===================================================
# [47, 39, 23, 36]
# avoiding edges:(39, 23), (23, 36)
# query output:[47, 39, 10, 32, 27, 36] , weight:153.35353535353534
# Query time--- 3.665908098220825 seconds ---
# cross_check output:[47, 39, 10, 32, 27, 36] , weight:153.35353535353534
# Cross_check time--- 0.0002682209014892578 seconds ---
# ===================================================
# [35, 14]
# [0, 45, 12, 37, 9, 22, 24, 8]
# avoiding edges:(37, 9), (0, 45)
# query output:[] , weight:0
# Query time--- 1.706650733947754 seconds ---
# No path exists between nodes 0 and 8 after removing edges (37, 9) and (0, 45).
# cross_check output:[] , weight:0
# Cross_check time--- 8.96453857421875e-05 seconds ---
# ===================================================
# Shortest path for (50, 2) not found in shortest_paths.
# [10, 42]
# [31, 15, 42, 19, 37, 12, 45, 0]
# avoiding edges:(45, 0), (37, 12)
# query output:[] , weight:0
# Query time--- 0.002833843231201172 seconds ---
# No path exists between nodes 31 and 0 after removing edges (45, 0) and (37, 12).
# cross_check output:[] , weight:0
# Cross_check time--- 0.00036263465881347656 seconds ---
# ===================================================
# [43, 45, 6]
# avoiding edges:(43, 45), (45, 6)
# query output:[] , weight:0
# Query time--- 0.0008728504180908203 seconds ---
# No path exists between nodes 43 and 6 after removing edges (43, 45) and (45, 6).
# cross_check output:[] , weight:0
# Cross_check time--- 6.532669067382812e-05 seconds ---
# ===================================================
# [18, 44]
# [47, 39, 10, 25, 12, 45]
# avoiding edges:(39, 10), (25, 12)
# query output:[47, 39, 23, 36, 12, 45] , weight:161.2323232323232
# Query time--- 3.017528533935547 seconds ---
# cross_check output:[47, 39, 23, 36, 12, 45] , weight:161.2323232323232
# Cross_check time--- 0.00018477439880371094 seconds ---
# ===================================================
# [15, 22, 24]
# avoiding edges:(22, 24), (15, 22)
# query output:[15, 31, 3, 8, 24] , weight:96.03030303030303
# Query time--- 4.709856271743774 seconds ---
# cross_check output:[15, 31, 3, 8, 24] , weight:96.03030303030303
# Cross_check time--- 0.00019502639770507812 seconds ---
# ===================================================
# Shortest path for (11, 10) not found in shortest_paths.
# [44, 18, 2, 37, 12, 25, 10, 32]
# avoiding edges:(25, 10), (37, 12)
# query output:[44, 18, 27, 32] , weight:127.05050505050505
# Query time--- 5.224789619445801 seconds ---
# cross_check output:[44, 18, 27, 32] , weight:127.05050505050505
# Cross_check time--- 0.0002841949462890625 seconds ---
# ===================================================
# [49, 40, 21, 14, 9, 22]
# avoiding edges:(14, 9), (21, 14)
# query output:[49, 26, 41, 24, 22] , weight:139.10101010101008
# Query time--- 0.20692706108093262 seconds ---
# cross_check output:[49, 26, 41, 24, 22] , weight:139.10101010101008
# Cross_check time--- 0.00026488304138183594 seconds ---
# ===================================================
# [29, 14, 9, 37, 2, 18, 44]
# avoiding edges:(37, 2), (29, 14)
# query output:[29, 33, 48, 40, 44] , weight:150.73737373737373
# Query time--- 3.8954837322235107 seconds ---
# cross_check output:[29, 33, 48, 40, 44] , weight:150.73737373737373
# Cross_check time--- 0.00025081634521484375 seconds ---
# ===================================================
# [29, 14, 9, 22, 24, 8, 3, 17]
# avoiding edges:(29, 14), (8, 3)
# query output:[29, 8, 24, 22, 3, 17] , weight:180.5050505050505
# Query time--- 0.2938392162322998 seconds ---
# cross_check output:[29, 8, 24, 22, 3, 17] , weight:180.5050505050505
# Cross_check time--- 0.000385284423828125 seconds ---
# ===================================================
# [31, 15]
# [8, 24, 22, 9, 14, 21, 36]
# avoiding edges:(9, 14), (22, 9)
# query output:[8, 24, 41, 2, 37, 12, 36] , weight:133.03030303030303
# Query time--- 0.9764490127563477 seconds ---
# cross_check output:[8, 24, 41, 2, 37, 12, 36] , weight:133.03030303030303
# Cross_check time--- 0.0003094673156738281 seconds ---
# ===================================================
# Shortest path for (45, 20) not found in shortest_paths.
# [27, 36, 21, 14, 29, 33]
# avoiding edges:(29, 33), (14, 29)
# query output:[27, 32, 33] , weight:145.7171717171717
# Query time--- 0.9988400936126709 seconds ---
# cross_check output:[27, 32, 33] , weight:145.7171717171717
# Cross_check time--- 0.0002803802490234375 seconds ---
# ===================================================
# [10, 32, 33, 35]
# avoiding edges:(33, 35), (10, 32)
# query output:[10, 25, 14, 35] , weight:124.39393939393939
# Query time--- 0.7896847724914551 seconds ---
# cross_check output:[10, 25, 14, 35] , weight:124.39393939393939
# Cross_check time--- 0.00029468536376953125 seconds ---
# ===================================================
# [13, 41, 24, 22, 38]
# avoiding edges:(41, 24), (13, 41)
# query output:[13, 6, 14, 9, 22, 38] , weight:178.77777777777777
# Query time--- 3.330164909362793 seconds ---
# cross_check output:[13, 6, 14, 9, 22, 38] , weight:178.77777777777777
# Cross_check time--- 0.00033211708068847656 seconds ---
# ===================================================
# [24, 22, 9, 14, 21, 36]
# avoiding edges:(9, 14), (22, 9)
# query output:[24, 41, 2, 37, 12, 36] , weight:112.76767676767676
# Query time--- 1.5981345176696777 seconds ---
# cross_check output:[24, 41, 2, 37, 12, 36] , weight:112.76767676767676
# Cross_check time--- 0.00031256675720214844 seconds ---
# ===================================================
# [48, 40, 25]
# avoiding edges:(48, 40), (40, 25)
# query output:[48, 5, 10, 25] , weight:103.72727272727272
# Query time--- 0.9774162769317627 seconds ---
# cross_check output:[48, 5, 10, 25] , weight:103.72727272727272
# Cross_check time--- 0.0002663135528564453 seconds ---
# ===================================================
# Shortest path for (20, 17) not found in shortest_paths.
# [5, 48, 40, 49, 26]
# avoiding edges:(48, 40), (5, 48)
# query output:[5, 10, 25, 12, 26] , weight:162.39393939393938
# Query time--- 0.42160630226135254 seconds ---
# cross_check output:[5, 10, 25, 12, 26] , weight:162.39393939393938
# Cross_check time--- 0.00033402442932128906 seconds ---
# ===================================================
# [38, 22, 9, 37, 12, 45, 0]
# avoiding edges:(9, 37), (12, 45)
# query output:[38, 22, 9, 14, 6, 45, 0] , weight:224.75757575757578
# Query time--- 2.5860788822174072 seconds ---
# cross_check output:[38, 22, 9, 14, 6, 45, 0] , weight:224.75757575757578
# Cross_check time--- 0.0002925395965576172 seconds ---
# ===================================================
# [48, 40, 25, 10, 32]
# avoiding edges:(48, 40), (40, 25)
# query output:[48, 5, 10, 32] , weight:101.73737373737373
# Query time--- 2.5347447395324707 seconds ---
# cross_check output:[48, 5, 10, 32] , weight:101.73737373737373
# Cross_check time--- 0.0006444454193115234 seconds ---
# ===================================================
# [13, 41, 24, 22, 7]
# avoiding edges:(22, 7), (41, 24)
# query output:[13, 48, 40, 4, 7] , weight:150.72727272727272
# Query time--- 2.541698455810547 seconds ---
# cross_check output:[13, 48, 40, 4, 7] , weight:150.72727272727272
# Cross_check time--- 0.0002815723419189453 seconds ---
# ===================================================
# [46, 48, 40, 25, 10, 32]
# avoiding edges:(10, 32), (25, 10)
# query output:[46, 48, 40, 1, 37, 12, 32] , weight:166.8989898989899
# Query time--- 1.166736364364624 seconds ---
# cross_check output:[46, 48, 40, 1, 37, 12, 32] , weight:166.8989898989899
# Cross_check time--- 0.0002923011779785156 seconds ---
# ===================================================
# [46, 24, 22]
# avoiding edges:(24, 22), (46, 24)
# query output:[46, 48, 40, 21, 14, 9, 22] , weight:101.73737373737373
# Query time--- 0.4300038814544678 seconds ---
# cross_check output:[46, 48, 40, 21, 14, 9, 22] , weight:101.73737373737373
# Cross_check time--- 0.0002903938293457031 seconds ---
# ===================================================
# [16, 46, 42, 15, 31]
# avoiding edges:(15, 31), (42, 15)
# query output:[16, 23, 21, 14, 9, 22, 24, 8, 3, 31] , weight:202.55555555555557
# Query time--- 4.559110164642334 seconds ---
# cross_check output:[16, 23, 21, 14, 9, 22, 24, 8, 3, 31] , weight:202.55555555555557
# Cross_check time--- 0.0002903938293457031 seconds ---
# ===================================================
# [42, 15, 31, 3]
# avoiding edges:(31, 3), (15, 31)
# query output:[42, 34, 24, 8, 3] , weight:136.07070707070707
# Query time--- 0.42035770416259766 seconds ---
# cross_check output:[42, 34, 24, 8, 3] , weight:136.07070707070707
# Cross_check time--- 0.0003058910369873047 seconds ---
# ===================================================
# [16, 23, 21, 14, 9, 22]
# avoiding edges:(23, 21), (9, 22)
# query output:[16, 46, 24, 22] , weight:164.07070707070704
# Query time--- 3.1233956813812256 seconds ---
# cross_check output:[16, 46, 24, 22] , weight:164.07070707070704
# Cross_check time--- 0.0003025531768798828 seconds ---
# ===================================================
# [42, 10, 39, 47]
# avoiding edges:(10, 39), (39, 47)
# query output:[42, 15, 35, 33, 47] , weight:191.94949494949495
# Query time--- 0.9275233745574951 seconds ---
# cross_check output:[42, 15, 35, 33, 47] , weight:191.94949494949495
# Cross_check time--- 0.0002987384796142578 seconds ---
# ===================================================
# [12, 25, 10, 39, 47]
# avoiding edges:(10, 39), (25, 10)
# query output:[12, 36, 23, 39, 47] , weight:146.84848484848484
# Query time--- 3.4034008979797363 seconds ---
# cross_check output:[12, 36, 23, 39, 47] , weight:146.84848484848484
# Cross_check time--- 0.044400691986083984 seconds ---
# ===================================================
# Shortest path for (50, 33) not found in shortest_paths.
# [16, 46, 42]
# avoiding edges:(16, 46), (46, 42)
# query output:[16, 23, 10, 42] , weight:197.26262626262627
# Query time--- 0.8169615268707275 seconds ---
# cross_check output:[16, 23, 10, 42] , weight:197.26262626262627
# Cross_check time--- 0.0002903938293457031 seconds ---
# ===================================================
# [36, 21, 14, 9, 22, 24, 8]
# avoiding edges:(22, 24), (24, 8)
# query output:[36, 21, 14, 9, 22, 3, 8] , weight:156.02020202020202
# Query time--- 0.9023487567901611 seconds ---
# cross_check output:[36, 21, 14, 9, 22, 3, 8] , weight:156.02020202020202
# Cross_check time--- 0.00042438507080078125 seconds ---
# ===================================================
# Shortest path for (10, 20) not found in shortest_paths.
# [44, 18, 2, 41, 24, 8, 3]
# avoiding edges:(2, 41), (41, 24)
# query output:[44, 18, 2, 37, 9, 22, 24, 8, 3] , weight:132.41414141414143
# Query time--- 3.3650784492492676 seconds ---
# cross_check output:[44, 18, 2, 37, 9, 22, 24, 8, 3] , weight:132.41414141414143
# Cross_check time--- 0.00028896331787109375 seconds ---
# ===================================================
# [46, 48, 40, 21, 14, 29]
# avoiding edges:(14, 29), (40, 21)
# query output:[46, 48, 33, 29] , weight:109.8080808080808
# Query time--- 2.786816358566284 seconds ---
# cross_check output:[46, 48, 33, 29] , weight:109.8080808080808
# Cross_check time--- 0.00026226043701171875 seconds ---
# ===================================================
# [32, 10, 25, 17]
# avoiding edges:(32, 10), (10, 25)
# query output:[32, 12, 25, 17] , weight:210.4848484848485
# Query time--- 0.2026047706604004 seconds ---
# cross_check output:[32, 12, 25, 17] , weight:210.4848484848485
# Cross_check time--- 0.0002803802490234375 seconds ---
# ===================================================
# [39, 10, 25, 12, 37, 19]
# avoiding edges:(39, 10), (10, 25)
# query output:[39, 23, 36, 12, 37, 19] , weight:169.96969696969697
# Query time--- 2.798845052719116 seconds ---
# cross_check output:[39, 23, 36, 12, 37, 19] , weight:169.96969696969697
# Cross_check time--- 0.0002655982971191406 seconds ---
# ===================================================
# [19, 44, 40, 48]
# avoiding edges:(44, 40), (19, 44)
# query output:[19, 42, 46, 48] , weight:91.63636363636363
# Query time--- 2.7605528831481934 seconds ---
# cross_check output:[19, 42, 46, 48] , weight:91.63636363636363
# Cross_check time--- 0.0006666183471679688 seconds ---
# ===================================================
# Shortest path for (30, 33) not found in shortest_paths.
# [15, 42, 19, 44, 18, 27]
# avoiding edges:(18, 27), (19, 44)
# query output:[15, 42, 10, 32, 27] , weight:169.07070707070707
# Query time--- 1.720658779144287 seconds ---
# cross_check output:[15, 42, 10, 32, 27] , weight:169.07070707070707
# Cross_check time--- 0.0002911090850830078 seconds ---
# ===================================================
# [7, 22]
# [29, 14, 9, 37, 2, 41, 13]
# avoiding edges:(2, 41), (41, 13)
# query output:[29, 14, 6, 13] , weight:125.94949494949495
# Query time--- 1.2151591777801514 seconds ---
# cross_check output:[29, 14, 6, 13] , weight:125.94949494949495
# Cross_check time--- 0.0002818107604980469 seconds ---
# ===================================================
# [26, 12, 37, 2, 18, 27]
# avoiding edges:(18, 27), (26, 12)
# query output:[26, 41, 2, 37, 12, 36, 27] , weight:160.66666666666666
# Query time--- 2.586313247680664 seconds ---
# cross_check output:[26, 41, 2, 37, 12, 36, 27] , weight:160.66666666666666
# Cross_check time--- 0.00030112266540527344 seconds ---
# ===================================================
# [38, 22, 9, 14, 21, 40]
# avoiding edges:(22, 9), (38, 22)
# query output:[] , weight:0
# Query time--- 0.5257196426391602 seconds ---
# No path exists between nodes 38 and 40 after removing edges (22, 9) and (38, 22).
# cross_check output:[] , weight:0
# Cross_check time--- 9.036064147949219e-05 seconds ---
# ===================================================
# [15, 42, 19]
# avoiding edges:(42, 19), (15, 42)
# query output:[15, 22, 9, 37, 19] , weight:183.74747474747477
# Query time--- 1.597599744796753 seconds ---
# cross_check output:[15, 22, 9, 37, 19] , weight:183.74747474747477
# Cross_check time--- 0.00029158592224121094 seconds ---
# ===================================================
# [21, 14, 9, 22, 24]
# avoiding edges:(9, 22), (14, 9)
# query output:[21, 12, 37, 2, 41, 24] , weight:88.77777777777777
# Query time--- 1.3933966159820557 seconds ---
# cross_check output:[21, 12, 37, 2, 41, 24] , weight:88.77777777777777
# Cross_check time--- 0.0002741813659667969 seconds ---
# ===================================================
# Shortest path for (27, 50) not found in shortest_paths.
# [13, 41, 2, 18, 27]
# avoiding edges:(18, 27), (41, 2)
# query output:[13, 6, 44, 18, 2, 37, 12, 36, 27] , weight:147.88888888888889
# Query time--- 2.4062204360961914 seconds ---
# cross_check output:[13, 6, 44, 18, 2, 37, 12, 36, 27] , weight:147.88888888888889
# Cross_check time--- 0.0005612373352050781 seconds ---
# ===================================================
# [43, 45, 12, 37, 9, 22, 24, 8]
# avoiding edges:(37, 9), (22, 24)
# query output:[43, 45, 12, 37, 2, 41, 24, 8] , weight:161.0
# Query time--- 7.00708794593811 seconds ---
# cross_check output:[43, 45, 12, 37, 2, 41, 24, 8] , weight:161.0
# Cross_check time--- 0.0003407001495361328 seconds ---
# ===================================================
# [12, 36]
# [21, 40, 48, 46]
# avoiding edges:(48, 46), (40, 48)
# query output:[21, 14, 9, 22, 24, 46] , weight:123.59595959595958
# Query time--- 0.11132073402404785 seconds ---
# cross_check output:[21, 14, 9, 22, 24, 46] , weight:123.59595959595958
# Cross_check time--- 0.010017633438110352 seconds ---
# ===================================================
# Shortest path for (2, 20) not found in shortest_paths.
# [34, 28, 1]
# avoiding edges:(34, 28), (28, 1)
# query output:[34, 24, 22, 9, 37, 1] , weight:119.0909090909091
# Query time--- 0.22991442680358887 seconds ---
# cross_check output:[34, 24, 22, 9, 37, 1] , weight:119.0909090909091
# Cross_check time--- 0.0002415180206298828 seconds ---
# ===================================================
# [40, 1, 37, 2]
# avoiding edges:(1, 37), (37, 2)
# query output:[40, 44, 18, 2] , weight:71.65656565656566
# Query time--- 8.483123779296875 seconds ---
# cross_check output:[40, 44, 18, 2] , weight:71.65656565656566
# Cross_check time--- 0.00019359588623046875 seconds ---
# ===================================================
# [49, 40, 25, 10, 32]
# avoiding edges:(49, 40), (25, 10)
# query output:[49, 19, 42, 10, 32] , weight:176.97979797979798
# Query time--- 2.0724692344665527 seconds ---
# cross_check output:[49, 19, 42, 10, 32] , weight:176.97979797979798
# Cross_check time--- 0.00030922889709472656 seconds ---
# ===================================================
# [45, 12, 25, 10, 39]
# avoiding edges:(12, 25), (25, 10)
# query output:[45, 12, 36, 23, 39] , weight:124.28282828282826
# Query time--- 1.6155519485473633 seconds ---
# cross_check output:[45, 12, 36, 23, 39] , weight:124.28282828282826
# Cross_check time--- 0.0003285408020019531 seconds ---
# ===================================================
# [46, 24, 22, 38]
# avoiding edges:(46, 24), (24, 22)
# query output:[46, 48, 40, 21, 14, 9, 22, 38] , weight:161.46464646464645
# Query time--- 1.8665757179260254 seconds ---
# cross_check output:[46, 48, 40, 21, 14, 9, 22, 38] , weight:161.46464646464645
# Cross_check time--- 0.0004010200500488281 seconds ---
# ===================================================
# [42, 19, 37, 12, 45, 43]
# avoiding edges:(19, 37), (45, 43)
# query output:[] , weight:0
# Query time--- 0.5255646705627441 seconds ---
# No path exists between nodes 42 and 43 after removing edges (19, 37) and (45, 43).
# cross_check output:[] , weight:0
# Cross_check time--- 0.0002999305725097656 seconds ---
# ===================================================
# [49, 40, 21, 14, 9, 22, 24]
# avoiding edges:(49, 40), (22, 24)
# query output:[49, 26, 41, 24] , weight:134.38383838383837
# Query time--- 2.1203832626342773 seconds ---
# cross_check output:[49, 26, 41, 24] , weight:134.38383838383837
# Cross_check time--- 0.00022101402282714844 seconds ---
# ===================================================
# [21, 40, 49]
# avoiding edges:(40, 49), (21, 40)
# query output:[21, 12, 37, 19, 49] , weight:136.14141414141415
# Query time--- 0.6428208351135254 seconds ---
# cross_check output:[21, 12, 37, 19, 49] , weight:136.14141414141415
# Cross_check time--- 0.0002994537353515625 seconds ---
# ===================================================
# [44, 18, 2, 37, 12, 25, 10, 39]
# avoiding edges:(37, 12), (18, 2)
# query output:[44, 18, 27, 36, 23, 39] , weight:137.54545454545453
# Query time--- 5.786653995513916 seconds ---
# cross_check output:[44, 18, 27, 36, 23, 39] , weight:137.54545454545453
# Cross_check time--- 0.0003714561462402344 seconds ---
# ===================================================
# [45, 12, 25, 10, 32]
# avoiding edges:(25, 10), (12, 25)
# query output:[45, 12, 32] , weight:110.81818181818181
# Query time--- 0.34335780143737793 seconds ---
# cross_check output:[45, 12, 32] , weight:110.81818181818181
# Cross_check time--- 0.0002620220184326172 seconds ---
# ===================================================
# [39, 10, 25, 12, 45, 43]
# avoiding edges:(45, 43), (39, 10)
# query output:[] , weight:0
# Query time--- 0.0010457038879394531 seconds ---
# No path exists between nodes 39 and 43 after removing edges (45, 43) and (39, 10).
# cross_check output:[] , weight:0
# Cross_check time--- 0.0002446174621582031 seconds ---
# ===================================================
# [45, 12, 37, 19, 42, 15]
# avoiding edges:(42, 15), (19, 42)
# query output:[45, 12, 37, 9, 22, 15] , weight:142.94949494949498
# Query time--- 2.2685561180114746 seconds ---
# cross_check output:[45, 12, 37, 9, 22, 15] , weight:142.94949494949498
# Cross_check time--- 0.0002841949462890625 seconds ---
# ===================================================
# [13, 42, 15, 31]
# avoiding edges:(15, 31), (13, 42)
# query output:[13, 41, 24, 8, 3, 31] , weight:140.70707070707073
# Query time--- 1.0016274452209473 seconds ---
# cross_check output:[13, 41, 24, 8, 3, 31] , weight:140.70707070707073
# Cross_check time--- 0.09842562675476074 seconds ---
# ===================================================
# Shortest path for (36, 50) not found in shortest_paths.
# Shortest path for (50, 14) not found in shortest_paths.
# [26, 12, 25, 10, 39]
# avoiding edges:(26, 12), (12, 25)
# query output:[26, 49, 40, 25, 10, 39] , weight:180.2929292929293
# Query time--- 1.7988383769989014 seconds ---
# cross_check output:[26, 49, 40, 25, 10, 39] , weight:180.2929292929293
# Cross_check time--- 0.00039887428283691406 seconds ---
# ===================================================
# [29, 14, 9, 37, 2, 41]
# avoiding edges:(29, 14), (2, 41)
# query output:[29, 8, 24, 41] , weight:135.29292929292927
# Query time--- 1.6115972995758057 seconds ---
# cross_check output:[29, 8, 24, 41] , weight:135.29292929292927
# Cross_check time--- 0.00028395652770996094 seconds ---
# ===================================================
# [16, 46, 42, 19]
# avoiding edges:(16, 46), (42, 19)
# query output:[16, 23, 36, 12, 37, 19] , weight:168.8080808080808
# Query time--- 0.2968113422393799 seconds ---
# cross_check output:[16, 23, 36, 12, 37, 19] , weight:168.8080808080808
# Cross_check time--- 0.0002465248107910156 seconds ---
# ===================================================
# [49, 40, 4, 7]
# avoiding edges:(49, 40), (4, 7)
# query output:[49, 26, 41, 24, 22, 7] , weight:182.34343434343432
# Query time--- 1.4564180374145508 seconds ---
# cross_check output:[49, 26, 41, 24, 22, 7] , weight:182.34343434343432
# Cross_check time--- 0.0002884864807128906 seconds ---
# ===================================================
# Shortest path for (8, 30) not found in shortest_paths.
# [37, 2, 18, 44, 6]
# avoiding edges:(44, 6), (37, 2)
# query output:[37, 12, 45, 6] , weight:60.03030303030303
# Query time--- 0.9520468711853027 seconds ---
# cross_check output:[37, 12, 45, 6] , weight:60.03030303030303
# Cross_check time--- 0.00019478797912597656 seconds ---
# ===================================================
# [0, 45, 12, 37, 9, 22, 38]
# avoiding edges:(12, 37), (37, 9)
# query output:[0, 45, 12, 21, 14, 9, 22, 38] , weight:165.64646464646464
# Query time--- 4.091856956481934 seconds ---
# cross_check output:[0, 45, 12, 21, 14, 9, 22, 38] , weight:165.64646464646464
# Cross_check time--- 0.00032067298889160156 seconds ---
# ===================================================
# [2, 37, 12, 36]
# avoiding edges:(12, 36), (2, 37)
# query output:[2, 18, 27, 36] , weight:64.5050505050505
# Query time--- 1.301438570022583 seconds ---
# cross_check output:[2, 18, 27, 36] , weight:64.5050505050505
# Cross_check time--- 0.0001556873321533203 seconds ---
# ===================================================
# [47, 33]
# [6, 44, 18, 2, 37, 1]
# avoiding edges:(37, 1), (18, 2)
# query output:[6, 44, 40, 1] , weight:86.22222222222223
# Query time--- 3.1700446605682373 seconds ---
# cross_check output:[6, 44, 40, 1] , weight:86.22222222222223
# Cross_check time--- 0.0002505779266357422 seconds ---
# ===================================================
# [25, 10]
# Shortest path for (30, 34) not found in shortest_paths.
# Shortest path for (1, 11) not found in shortest_paths.
# [1, 37, 9, 14, 35]
# avoiding edges:(9, 14), (37, 9)
# query output:[1, 40, 48, 33, 35] , weight:124.83838383838383
# Query time--- 0.9717295169830322 seconds ---
# cross_check output:[1, 40, 48, 33, 35] , weight:124.83838383838383
# Cross_check time--- 0.00029850006103515625 seconds ---
# ===================================================
# [16, 46, 48, 40, 49, 26]
# avoiding edges:(40, 49), (49, 26)
# query output:[16, 23, 36, 12, 26] , weight:178.14141414141415
# Query time--- 0.39988112449645996 seconds ---
# cross_check output:[16, 23, 36, 12, 26] , weight:178.14141414141415
# Cross_check time--- 0.0002932548522949219 seconds ---
# ===================================================
# [0, 45, 12, 25, 17]
# avoiding edges:(45, 12), (0, 45)
# query output:[] , weight:0
# Query time--- 1.3127307891845703 seconds ---
# No path exists between nodes 0 and 17 after removing edges (45, 12) and (0, 45).
# cross_check output:[] , weight:0
# Cross_check time--- 8.630752563476562e-05 seconds ---
# ===================================================
# [17, 3, 8, 24, 41, 13, 6]
# avoiding edges:(13, 6), (17, 3)
# query output:[17, 4, 40, 44, 6] , weight:169.50505050505052
# Query time--- 4.023356199264526 seconds ---
# cross_check output:[17, 4, 40, 44, 6] , weight:169.50505050505052
# Cross_check time--- 0.0002589225769042969 seconds ---
# ===================================================
# Shortest path for (7, 11) not found in shortest_paths.
# [41, 2, 37, 1, 40, 48]
# avoiding edges:(41, 2), (37, 1)
# query output:[41, 13, 48] , weight:109.93939393939394
# Query time--- 5.65258526802063 seconds ---
# cross_check output:[41, 13, 48] , weight:109.93939393939394
# Cross_check time--- 0.00021839141845703125 seconds ---
# ===================================================
# [45, 12, 37, 1, 40, 48, 46]
# avoiding edges:(40, 48), (45, 12)
# query output:[45, 6, 13, 48, 46] , weight:148.9090909090909
# Query time--- 2.9373912811279297 seconds ---
# cross_check output:[45, 6, 13, 48, 46] , weight:148.9090909090909
# Cross_check time--- 0.0003304481506347656 seconds ---
# ===================================================
# [15, 42, 34]
# avoiding edges:(42, 34), (15, 42)
# query output:[15, 22, 24, 34] , weight:127.02020202020202
# Query time--- 1.027179479598999 seconds ---
# cross_check output:[15, 22, 24, 34] , weight:127.02020202020202
# Cross_check time--- 0.0002467632293701172 seconds ---
# ===================================================
# [1, 40, 48, 46, 16]
# avoiding edges:(46, 16), (40, 48)
# query output:[1, 37, 12, 36, 23, 16] , weight:134.2020202020202
# Query time--- 1.236492395401001 seconds ---
# cross_check output:[1, 37, 12, 36, 23, 16] , weight:134.2020202020202
# Cross_check time--- 0.00028324127197265625 seconds ---
# ===================================================
# Shortest path for (30, 25) not found in shortest_paths.
# [39, 10, 25, 12, 37, 2, 18, 44]
# avoiding edges:(25, 12), (37, 2)
# query output:[39, 23, 36, 27, 18, 44] , weight:137.54545454545453
# Query time--- 4.470710515975952 seconds ---
# cross_check output:[39, 23, 36, 27, 18, 44] , weight:137.54545454545453
# Cross_check time--- 0.00037479400634765625 seconds ---
# ===================================================
# [23, 36, 12, 45]
# avoiding edges:(23, 36), (12, 45)
# query output:[23, 21, 14, 6, 45] , weight:166.60606060606062
# Query time--- 2.6660969257354736 seconds ---
# cross_check output:[23, 21, 14, 6, 45] , weight:166.60606060606062
# Cross_check time--- 0.0003452301025390625 seconds ---
# ===================================================
# [3, 8, 24, 22, 7]
# avoiding edges:(3, 8), (22, 7)
# query output:[3, 17, 4, 7] , weight:112.41414141414143
# Query time--- 3.098249912261963 seconds ---
# cross_check output:[3, 17, 4, 7] , weight:112.41414141414143
# Cross_check time--- 0.00020432472229003906 seconds ---
# ===================================================
# [29, 14, 9, 37, 2, 41, 13]
# avoiding edges:(41, 13), (37, 2)
# query output:[29, 14, 6, 13] , weight:125.94949494949495
# Query time--- 9.02752685546875 seconds ---
# cross_check output:[29, 14, 6, 13] , weight:125.94949494949495
# Cross_check time--- 0.0003616809844970703 seconds ---
# ===================================================
# [12, 37, 9, 14, 35]
# avoiding edges:(37, 9), (9, 14)
# query output:[12, 21, 14, 35] , weight:109.45454545454545
# Query time--- 2.043923854827881 seconds ---
# cross_check output:[12, 21, 14, 35] , weight:109.45454545454545
# Cross_check time--- 0.0002751350402832031 seconds ---
# ===================================================
# [15, 22, 24, 41]
# avoiding edges:(22, 24), (24, 41)
# query output:[15, 42, 19, 44, 18, 2, 41] , weight:129.59595959595958
# Query time--- 3.425025224685669 seconds ---
# cross_check output:[15, 42, 19, 44, 18, 2, 41] , weight:129.59595959595958
# Cross_check time--- 0.0002899169921875 seconds ---
# ===================================================
# Shortest path for (30, 20) not found in shortest_paths.
# [46, 24, 22]
# avoiding edges:(24, 22), (46, 24)
# query output:[46, 48, 40, 21, 14, 9, 22] , weight:101.73737373737373
# Query time--- 0.8213820457458496 seconds ---
# cross_check output:[46, 48, 40, 21, 14, 9, 22] , weight:101.73737373737373
# Cross_check time--- 0.0003631114959716797 seconds ---
# ===================================================
# [21, 14, 9, 22, 24, 8, 3]
# avoiding edges:(14, 9), (9, 22)
# query output:[21, 12, 37, 2, 41, 24, 8, 3] , weight:130.14141414141415
# Query time--- 0.8601081371307373 seconds ---
# cross_check output:[21, 12, 37, 2, 41, 24, 8, 3] , weight:130.14141414141415
# Cross_check time--- 0.0002884864807128906 seconds ---
# ===================================================
# Shortest path for (20, 10) not found in shortest_paths.
# [12, 37, 19, 42, 15]
# avoiding edges:(19, 42), (37, 19)
# query output:[12, 37, 9, 22, 15] , weight:128.56565656565658
# Query time--- 2.4736130237579346 seconds ---
# cross_check output:[12, 37, 9, 22, 15] , weight:128.56565656565658
# Cross_check time--- 0.00029015541076660156 seconds ---
# ===================================================
# [35, 14]
# [36, 21, 14, 9, 22, 24, 8, 3, 17]
# avoiding edges:(36, 21), (3, 17)
# query output:[36, 12, 25, 17] , weight:167.46464646464648
# Query time--- 4.314841032028198 seconds ---
# cross_check output:[36, 12, 25, 17] , weight:167.46464646464648
# Cross_check time--- 0.0002796649932861328 seconds ---
# ===================================================
# [43, 45, 12, 36]
# avoiding edges:(43, 45), (45, 12)
# query output:[] , weight:0
# Query time--- 0.0010864734649658203 seconds ---
# No path exists between nodes 43 and 36 after removing edges (43, 45) and (45, 12).
# cross_check output:[] , weight:0
# Cross_check time--- 5.2928924560546875e-05 seconds ---
# ===================================================
# [14, 9, 37, 12, 45]
# avoiding edges:(14, 9), (9, 37)
# query output:[14, 21, 12, 45] , weight:52.31313131313131
# Query time--- 2.0473623275756836 seconds ---
# cross_check output:[14, 21, 12, 45] , weight:52.31313131313131
# Cross_check time--- 0.0001595020294189453 seconds ---
# ===================================================
# [7, 22, 9, 14, 25, 10, 39, 47]
# avoiding edges:(9, 14), (22, 9)
# query output:[7, 4, 40, 25, 10, 39, 47] , weight:206.7676767676768
# Query time--- 1.0502433776855469 seconds ---
# cross_check output:[7, 4, 40, 25, 10, 39, 47] , weight:206.7676767676768
# Cross_check time--- 0.0002944469451904297 seconds ---
# ===================================================
# Shortest path for (50, 10) not found in shortest_paths.

# %%
print(f"right:{right}, wrong:{wrong}")
# Out:
# right:149, wrong:0

# %%
import random
import time

f =2

right = 0
wrong = 0

for case in range(1, 3000):
    x = random.randint(0, 50)
    y = random.randint(0, 50)
    print(f"case:{case} ===>")
    if x==y:
        continue
    try:
        print(shortest_paths[(x, y)])
    except KeyError:
        print(f"Shortest path for ({x}, {y}) not found in shortest_paths.")
        continue
            
    # print(shortest_paths[(x, y)])
    path = shortest_paths[(x,y)]
    
    pedges = []
    for i in range(len(path) - 1):
        pedges.append(Edge(path[i], path[i + 1], get_edge_weight(G, path[i], path[i + 1])))
    if len(pedges) < 2:
       continue
    e1 , e2 = random.sample(pedges, 2) 
    
    F3 = [Edge(e1.u, e1.v, get_edge_weight(G, e1.u, e1.v)), Edge(e2.u, e2.v, get_edge_weight(G, e2.u, e2.v))]

    # F3 = [Edge(e1_u, e1_v, get_edge_weight(G, e1_u, e1_v)), Edge(e2_u, e2_v, get_edge_weight(G, e2_u, e2_v))]
    
    
    print(f"avoiding edges:{e1.u, e1.v}, {e2.u, e2.v}")
    start_time = time.time()
    query_output = QUERY2(G , x, y, 3, F3)
    q_weight = sum(get_edge_weight(G, query_output[i], query_output[i + 1]) for i in range(len(query_output) - 1))
    print(f"query output:{query_output} , weight:{q_weight}")
    print("Query time--- %s seconds ---" % (time.time() - start_time))
    start_time = time.time()
    cross_check_output = cross_check2(G, x, y, (e1.u, e1.v), (e2.u, e2.v))
    c_weight = sum(get_edge_weight(G, cross_check_output[i], cross_check_output[i + 1]) for i in range(len(cross_check_output) - 1))
    print(f"cross_check output:{cross_check_output} , weight:{c_weight}")
    print("Cross_check time--- %s seconds ---" % (time.time() - start_time))
    if query_output != cross_check_output:
        wrong += 1
        print("!!!!!!!!!!!!----SOMETHING WENT WRONG-----!!!!!!!!!!!!!!!!!!")
    else :
        right += 1

    print("===================================================")
# Out:
# case:1 ===>
# [49, 40, 1, 37, 12, 45]
# avoiding edges:(49, 40), (1, 37)
# query output:[49, 19, 37, 12, 45] , weight:121.1010101010101
# Query time--- 0.8654661178588867 seconds ---
# cross_check output:[49, 19, 37, 12, 45] , weight:121.1010101010101
# Cross_check time--- 0.0006659030914306641 seconds ---
# ===================================================
# case:2 ===>
# [29, 14, 21, 40, 48]
# avoiding edges:(14, 21), (40, 48)
# query output:[29, 33, 48] , weight:101.79797979797979
# Query time--- 1.8285374641418457 seconds ---
# cross_check output:[29, 33, 48] , weight:101.79797979797979
# Cross_check time--- 0.0007557868957519531 seconds ---
# ===================================================
# case:3 ===>
# [15, 42, 19, 44, 18, 27]
# avoiding edges:(19, 44), (15, 42)
# query output:[15, 22, 9, 14, 21, 36, 27] , weight:174.16161616161614
# Query time--- 0.9390120506286621 seconds ---
# cross_check output:[15, 22, 9, 14, 21, 36, 27] , weight:174.16161616161614
# Cross_check time--- 0.0010840892791748047 seconds ---
# ===================================================
# case:4 ===>
# [8, 24, 22, 9, 14, 25]
# avoiding edges:(14, 25), (9, 14)
# query output:[8, 24, 22, 9, 37, 12, 25] , weight:111.46464646464646
# Query time--- 1.1693096160888672 seconds ---
# cross_check output:[8, 24, 22, 9, 37, 12, 25] , weight:111.46464646464646
# Cross_check time--- 0.0006718635559082031 seconds ---
# ===================================================
# case:5 ===>
# Shortest path for (16, 20) not found in shortest_paths.
# case:6 ===>
# [15, 22, 24, 41]
# avoiding edges:(22, 24), (24, 41)
# query output:[15, 42, 19, 44, 18, 2, 41] , weight:129.59595959595958
# Query time--- 0.7807633876800537 seconds ---
# cross_check output:[15, 42, 19, 44, 18, 2, 41] , weight:129.59595959595958
# Cross_check time--- 0.0008099079132080078 seconds ---
# ===================================================
# case:7 ===>
# [7, 46]
# case:8 ===>
# Shortest path for (11, 15) not found in shortest_paths.
# case:9 ===>
# [9, 22, 24]
# avoiding edges:(22, 24), (9, 22)
# query output:[9, 37, 2, 41, 24] , weight:80.21212121212122
# Query time--- 2.0347702503204346 seconds ---
# cross_check output:[9, 37, 2, 41, 24] , weight:80.21212121212122
# Cross_check time--- 0.0008416175842285156 seconds ---
# ===================================================
# case:10 ===>
# [44, 18, 27, 36]
# avoiding edges:(27, 36), (18, 27)
# query output:[44, 18, 2, 37, 12, 36] , weight:94.6060606060606
# Query time--- 0.620241641998291 seconds ---
# cross_check output:[44, 18, 2, 37, 12, 36] , weight:94.6060606060606
# Cross_check time--- 0.0006489753723144531 seconds ---
# ===================================================
# case:11 ===>
# [9, 22, 24, 8, 3, 31]
# avoiding edges:(22, 24), (8, 3)
# query output:[9, 22, 3, 31] , weight:108.52525252525253
# Query time--- 0.22783899307250977 seconds ---
# cross_check output:[9, 22, 3, 31] , weight:108.52525252525253
# Cross_check time--- 0.0007767677307128906 seconds ---
# ===================================================
# case:12 ===>
# [10, 25, 14, 9, 22]
# avoiding edges:(14, 9), (25, 14)
# query output:[10, 25, 12, 37, 9, 22] , weight:103.83838383838383
# Query time--- 0.6164603233337402 seconds ---
# cross_check output:[10, 25, 12, 37, 9, 22] , weight:103.83838383838383
# Cross_check time--- 0.0007042884826660156 seconds ---
# ===================================================
# case:13 ===>
# Shortest path for (20, 13) not found in shortest_paths.
# case:14 ===>
# [38, 22, 9, 14, 21, 40, 48]
# avoiding edges:(14, 21), (9, 14)
# query output:[38, 22, 24, 46, 48] , weight:157.23232323232324
# Query time--- 2.156622886657715 seconds ---
# cross_check output:[38, 22, 24, 46, 48] , weight:157.23232323232324
# Cross_check time--- 0.0006902217864990234 seconds ---
# ===================================================
# case:15 ===>
# Shortest path for (11, 4) not found in shortest_paths.
# case:16 ===>
# [13, 41, 24, 22, 38]
# avoiding edges:(22, 38), (41, 24)
# query output:[] , weight:0
# Query time--- 0.0716252326965332 seconds ---
# No path exists between nodes 13 and 38 after removing edges (22, 38) and (41, 24).
# cross_check output:[] , weight:0
# Cross_check time--- 0.0007088184356689453 seconds ---
# ===================================================
# case:17 ===>
# [14, 21, 40, 48]
# avoiding edges:(14, 21), (40, 48)
# query output:[14, 9, 48] , weight:92.6060606060606
# Query time--- 1.8051269054412842 seconds ---
# cross_check output:[14, 9, 48] , weight:92.6060606060606
# Cross_check time--- 0.0007026195526123047 seconds ---
# ===================================================
# case:18 ===>
# [22, 7, 4]
# avoiding edges:(7, 4), (22, 7)
# query output:[22, 9, 14, 21, 40, 4] , weight:129.92929292929293
# Query time--- 0.6327037811279297 seconds ---
# cross_check output:[22, 9, 14, 21, 40, 4] , weight:129.92929292929293
# Cross_check time--- 0.0008382797241210938 seconds ---
# ===================================================
# case:19 ===>
# [46, 28]
# case:20 ===>
# [8, 24, 41]
# avoiding edges:(24, 41), (8, 24)
# query output:[8, 3, 22, 9, 37, 2, 41] , weight:147.96969696969697
# Query time--- 0.593498945236206 seconds ---
# cross_check output:[8, 3, 22, 9, 37, 2, 41] , weight:147.96969696969697
# Cross_check time--- 0.0006241798400878906 seconds ---
# ===================================================
# case:21 ===>
# [14, 9, 22, 24]
# avoiding edges:(9, 22), (14, 9)
# query output:[14, 21, 12, 37, 2, 41, 24] , weight:97.28282828282829
# Query time--- 1.0301547050476074 seconds ---
# cross_check output:[14, 21, 12, 37, 2, 41, 24] , weight:97.28282828282829
# Cross_check time--- 0.0006220340728759766 seconds ---
# ===================================================
# case:22 ===>
# [47, 39, 10, 25, 12, 37, 1]
# avoiding edges:(39, 10), (10, 25)
# query output:[47, 39, 23, 36, 12, 37, 1] , weight:172.3131313131313
# Query time--- 1.6853132247924805 seconds ---
# cross_check output:[47, 39, 23, 36, 12, 37, 1] , weight:172.3131313131313
# Cross_check time--- 0.0006792545318603516 seconds ---
# ===================================================
# case:23 ===>
# [6, 13, 41, 24, 8]
# avoiding edges:(24, 8), (13, 41)
# query output:[6, 14, 9, 22, 3, 8] , weight:166.05050505050505
# Query time--- 0.32497167587280273 seconds ---
# cross_check output:[6, 14, 9, 22, 3, 8] , weight:166.05050505050505
# Cross_check time--- 0.0008060932159423828 seconds ---
# ===================================================
# case:24 ===>
# [38, 22]
# case:25 ===>
# [35, 15]
# case:26 ===>
# Shortest path for (44, 30) not found in shortest_paths.
# case:27 ===>
# Shortest path for (31, 11) not found in shortest_paths.
# case:28 ===>
# [7, 22, 9, 14, 35]
# avoiding edges:(14, 35), (22, 9)
# query output:[7, 4, 40, 48, 33, 35] , weight:166.11111111111111
# Query time--- 2.5294721126556396 seconds ---
# cross_check output:[7, 4, 40, 48, 33, 35] , weight:166.11111111111111
# Cross_check time--- 0.0008845329284667969 seconds ---
# ===================================================
# case:29 ===>
# [28, 46]
# case:30 ===>
# [14, 21, 36]
# avoiding edges:(14, 21), (21, 36)
# query output:[14, 9, 37, 12, 36] , weight:80.47474747474747
# Query time--- 0.6665747165679932 seconds ---
# cross_check output:[14, 9, 37, 12, 36] , weight:80.47474747474747
# Cross_check time--- 0.0008988380432128906 seconds ---
# ===================================================
# case:31 ===>
# [44, 18, 2, 41, 24, 8]
# avoiding edges:(24, 8), (41, 24)
# query output:[44, 19, 42, 15, 31, 3, 8] , weight:154.60606060606062
# Query time--- 0.5870330333709717 seconds ---
# cross_check output:[44, 19, 42, 15, 31, 3, 8] , weight:154.60606060606062
# Cross_check time--- 0.0007710456848144531 seconds ---
# ===================================================
# case:32 ===>
# [29, 14, 9, 22, 24, 8, 3, 17]
# avoiding edges:(22, 24), (24, 8)
# query output:[29, 8, 3, 17] , weight:125.4949494949495
# Query time--- 0.546292781829834 seconds ---
# cross_check output:[29, 8, 3, 17] , weight:125.4949494949495
# Cross_check time--- 0.0007636547088623047 seconds ---
# ===================================================
# case:33 ===>
# [23, 21, 14, 9, 22, 38]
# avoiding edges:(22, 38), (21, 14)
# query output:[] , weight:0
# Query time--- 0.019068241119384766 seconds ---
# No path exists between nodes 23 and 38 after removing edges (22, 38) and (21, 14).
# cross_check output:[] , weight:0
# Cross_check time--- 0.0006775856018066406 seconds ---
# ===================================================
# case:34 ===>
# [3, 8, 24, 41, 26]
# avoiding edges:(41, 26), (8, 24)
# query output:[3, 22, 9, 37, 12, 26] , weight:170.56565656565655
# Query time--- 0.47957539558410645 seconds ---
# cross_check output:[3, 22, 9, 37, 12, 26] , weight:170.56565656565655
# Cross_check time--- 0.0007119178771972656 seconds ---
# ===================================================
# case:35 ===>
# Shortest path for (11, 42) not found in shortest_paths.
# case:36 ===>
# [45, 12, 37, 1, 40, 48, 46]
# avoiding edges:(37, 1), (40, 48)
# query output:[45, 12, 37, 28, 46] , weight:129.55555555555554
# Query time--- 1.0238914489746094 seconds ---
# cross_check output:[45, 12, 37, 28, 46] , weight:129.55555555555554
# Cross_check time--- 0.01221323013305664 seconds ---
# ===================================================
# case:37 ===>
# [0, 45, 12, 36, 23]
# avoiding edges:(12, 36), (0, 45)
# query output:[] , weight:0
# Query time--- 0.33445072174072266 seconds ---
# No path exists between nodes 0 and 23 after removing edges (12, 36) and (0, 45).
# cross_check output:[] , weight:0
# Cross_check time--- 0.00021719932556152344 seconds ---
# ===================================================
# case:38 ===>
# [38, 22, 9, 37, 12]
# avoiding edges:(37, 12), (9, 37)
# query output:[38, 22, 9, 14, 21, 12] , weight:123.25252525252525
# Query time--- 3.124112606048584 seconds ---
# cross_check output:[38, 22, 9, 14, 21, 12] , weight:123.25252525252525
# Cross_check time--- 0.0006899833679199219 seconds ---
# ===================================================
# case:39 ===>
# [32, 27, 36, 23, 16]
# avoiding edges:(32, 27), (36, 23)
# query output:[32, 10, 23, 16] , weight:130.29292929292927
# Query time--- 0.3977196216583252 seconds ---
# cross_check output:[32, 10, 23, 16] , weight:130.29292929292927
# Cross_check time--- 0.0007119178771972656 seconds ---
# ===================================================
# case:40 ===>
# Shortest path for (11, 5) not found in shortest_paths.
# case:41 ===>
# [13, 41, 2, 37, 1]
# avoiding edges:(2, 37), (37, 1)
# query output:[13, 48, 40, 1] , weight:109.45454545454545
# Query time--- 1.419187068939209 seconds ---
# cross_check output:[13, 48, 40, 1] , weight:109.45454545454545
# Cross_check time--- 0.0006120204925537109 seconds ---
# ===================================================
# case:42 ===>
# [2, 37, 1, 40, 48, 46]
# avoiding edges:(1, 40), (37, 1)
# query output:[2, 18, 44, 40, 48, 46] , weight:87.62626262626262
# Query time--- 0.9009432792663574 seconds ---
# cross_check output:[2, 18, 44, 40, 48, 46] , weight:87.62626262626262
# Cross_check time--- 0.0007123947143554688 seconds ---
# ===================================================
# case:43 ===>
# [33, 29, 14, 9, 37]
# avoiding edges:(9, 37), (14, 9)
# query output:[33, 29, 14, 21, 12, 37] , weight:102.74747474747474
# Query time--- 0.618274450302124 seconds ---
# cross_check output:[33, 29, 14, 21, 12, 37] , weight:102.74747474747474
# Cross_check time--- 0.0005731582641601562 seconds ---
# ===================================================
# case:44 ===>
# [41, 2, 37, 9, 14, 35]
# avoiding edges:(41, 2), (14, 35)
# query output:[41, 24, 22, 9, 14, 29, 33, 35] , weight:137.37373737373738
# Query time--- 0.9799227714538574 seconds ---
# cross_check output:[41, 24, 22, 9, 14, 29, 33, 35] , weight:137.37373737373738
# Cross_check time--- 0.0008542537689208984 seconds ---
# ===================================================
# case:45 ===>
# Shortest path for (15, 20) not found in shortest_paths.
# case:46 ===>
# [45, 12, 37, 1, 40, 49]
# avoiding edges:(1, 40), (45, 12)
# query output:[45, 6, 44, 19, 49] , weight:138.7171717171717
# Query time--- 0.6407830715179443 seconds ---
# cross_check output:[45, 6, 44, 19, 49] , weight:138.7171717171717
# Cross_check time--- 0.0006272792816162109 seconds ---
# ===================================================
# case:47 ===>
# [22, 24, 41, 2]
# avoiding edges:(24, 41), (22, 24)
# query output:[22, 9, 37, 2] , weight:55.65656565656566
# Query time--- 0.19171810150146484 seconds ---
# cross_check output:[22, 9, 37, 2] , weight:55.65656565656566
# Cross_check time--- 0.0003292560577392578 seconds ---
# ===================================================
# case:48 ===>
# [40, 48, 33]
# avoiding edges:(48, 33), (40, 48)
# query output:[40, 21, 14, 29, 33] , weight:122.54545454545453
# Query time--- 0.28464603424072266 seconds ---
# cross_check output:[40, 21, 14, 29, 33] , weight:122.54545454545453
# Cross_check time--- 0.0007526874542236328 seconds ---
# ===================================================
# case:49 ===>
# [2, 37, 12, 45, 0]
# avoiding edges:(12, 45), (2, 37)
# query output:[2, 18, 44, 6, 45, 0] , weight:118.1010101010101
# Query time--- 2.535620927810669 seconds ---
# cross_check output:[2, 18, 44, 6, 45, 0] , weight:118.1010101010101
# Cross_check time--- 0.0007078647613525391 seconds ---
# ===================================================
# case:50 ===>
# [3, 17, 25, 10, 39]
# avoiding edges:(25, 10), (10, 39)
# query output:[3, 8, 24, 22, 9, 14, 21, 23, 39] , weight:170.6060606060606
# Query time--- 0.6483590602874756 seconds ---
# cross_check output:[3, 8, 24, 22, 9, 14, 21, 23, 39] , weight:170.6060606060606
# Cross_check time--- 0.0008406639099121094 seconds ---
# ===================================================
# case:51 ===>
# [35, 14, 21, 36, 27]
# avoiding edges:(14, 21), (35, 14)
# query output:[35, 33, 32, 27] , weight:161.64646464646464
# Query time--- 1.878589153289795 seconds ---
# cross_check output:[35, 33, 32, 27] , weight:161.64646464646464
# Cross_check time--- 0.0009405612945556641 seconds ---
# ===================================================
# case:52 ===>
# [21, 14, 9, 22, 24, 8, 3]
# avoiding edges:(22, 24), (24, 8)
# query output:[21, 14, 9, 22, 3] , weight:85.23232323232324
# Query time--- 0.21297073364257812 seconds ---
# cross_check output:[21, 14, 9, 22, 3] , weight:85.23232323232324
# Cross_check time--- 0.0007617473602294922 seconds ---
# ===================================================
# case:53 ===>
# Shortest path for (30, 47) not found in shortest_paths.
# case:54 ===>
# [19, 44, 18, 27]
# avoiding edges:(44, 18), (19, 44)
# query output:[19, 37, 2, 18, 27] , weight:118.36363636363637
# Query time--- 1.7244794368743896 seconds ---
# cross_check output:[19, 37, 2, 18, 27] , weight:118.36363636363637
# Cross_check time--- 0.0008387565612792969 seconds ---
# ===================================================
# case:55 ===>
# Shortest path for (47, 11) not found in shortest_paths.
# case:56 ===>
# [36, 12, 37, 1]
# avoiding edges:(12, 37), (36, 12)
# query output:[36, 27, 1] , weight:83.87878787878788
# Query time--- 0.6282262802124023 seconds ---
# cross_check output:[36, 27, 1] , weight:83.87878787878788
# Cross_check time--- 0.0003478527069091797 seconds ---
# ===================================================
# case:57 ===>
# [32, 10, 25, 17]
# avoiding edges:(25, 17), (32, 10)
# query output:[32, 12, 37, 9, 22, 24, 8, 3, 17] , weight:210.66666666666669
# Query time--- 1.625932216644287 seconds ---
# cross_check output:[32, 12, 37, 9, 22, 24, 8, 3, 17] , weight:210.66666666666669
# Cross_check time--- 0.0008673667907714844 seconds ---
# ===================================================
# case:58 ===>
# [4, 40, 1]
# avoiding edges:(40, 1), (4, 40)
# query output:[4, 7, 22, 9, 37, 1] , weight:139.989898989899
# Query time--- 0.6042075157165527 seconds ---
# cross_check output:[4, 7, 22, 9, 37, 1] , weight:139.989898989899
# Cross_check time--- 0.0004775524139404297 seconds ---
# ===================================================
# case:59 ===>
# [26, 41, 24, 8]
# avoiding edges:(24, 8), (41, 24)
# query output:[26, 12, 37, 9, 22, 3, 8] , weight:191.66666666666669
# Query time--- 0.83302903175354 seconds ---
# cross_check output:[26, 12, 37, 9, 22, 3, 8] , weight:191.66666666666669
# Cross_check time--- 0.007027387619018555 seconds ---
# ===================================================
# case:60 ===>
# [19, 37, 12]
# avoiding edges:(37, 12), (19, 37)
# query output:[19, 44, 6, 45, 12] , weight:106.45454545454545
# Query time--- 1.0073187351226807 seconds ---
# cross_check output:[19, 44, 6, 45, 12] , weight:106.45454545454545
# Cross_check time--- 0.0005857944488525391 seconds ---
# ===================================================
# case:61 ===>
# [15, 42, 19, 37, 12, 36]
# avoiding edges:(37, 12), (42, 19)
# query output:[15, 22, 9, 14, 21, 36] , weight:162.3232323232323
# Query time--- 2.427478790283203 seconds ---
# cross_check output:[15, 22, 9, 14, 21, 36] , weight:162.3232323232323
# Cross_check time--- 0.001085519790649414 seconds ---
# ===================================================
# case:62 ===>
# [47, 33, 29]
# avoiding edges:(33, 29), (47, 33)
# query output:[47, 39, 10, 25, 14, 29] , weight:153.68686868686868
# Query time--- 0.6501972675323486 seconds ---
# cross_check output:[47, 39, 10, 25, 14, 29] , weight:153.68686868686868
# Cross_check time--- 0.0006597042083740234 seconds ---
# ===================================================
# case:63 ===>
# [23, 21, 14, 9, 22, 24]
# avoiding edges:(9, 22), (21, 14)
# query output:[23, 36, 12, 37, 2, 41, 24] , weight:125.50505050505052
# Query time--- 0.9069173336029053 seconds ---
# cross_check output:[23, 36, 12, 37, 2, 41, 24] , weight:125.50505050505052
# Cross_check time--- 0.0006744861602783203 seconds ---
# ===================================================
# case:64 ===>
# [13, 41, 2, 37, 12, 25, 10]
# avoiding edges:(13, 41), (25, 10)
# query output:[13, 48, 5, 10] , weight:158.83838383838383
# Query time--- 0.8182864189147949 seconds ---
# cross_check output:[13, 48, 5, 10] , weight:158.83838383838383
# Cross_check time--- 0.0007421970367431641 seconds ---
# ===================================================
# case:65 ===>
# [43, 45, 12, 26]
# avoiding edges:(45, 12), (43, 45)
# query output:[] , weight:0
# Query time--- 0.3057854175567627 seconds ---
# No path exists between nodes 43 and 26 after removing edges (45, 12) and (43, 45).
# cross_check output:[] , weight:0
# Cross_check time--- 0.00016260147094726562 seconds ---
# ===================================================
# case:66 ===>
# [5, 48]
# case:67 ===>
# [40, 21, 14]
# avoiding edges:(40, 21), (21, 14)
# query output:[40, 1, 37, 9, 14] , weight:76.66666666666667
# Query time--- 0.20824766159057617 seconds ---
# cross_check output:[40, 1, 37, 9, 14] , weight:76.66666666666667
# Cross_check time--- 0.00041103363037109375 seconds ---
# ===================================================
# case:68 ===>
# [5, 10, 25, 12, 37, 2, 18]
# avoiding edges:(10, 25), (12, 37)
# query output:[5, 48, 40, 44, 18] , weight:119.74747474747475
# Query time--- 2.2516422271728516 seconds ---
# cross_check output:[5, 48, 40, 44, 18] , weight:119.74747474747475
# Cross_check time--- 0.0009300708770751953 seconds ---
# ===================================================
# case:69 ===>
# [1, 37, 9, 22]
# avoiding edges:(1, 37), (9, 22)
# query output:[1, 40, 48, 46, 24, 22] , weight:134.49494949494948
# Query time--- 3.4493863582611084 seconds ---
# cross_check output:[1, 40, 48, 46, 24, 22] , weight:134.49494949494948
# Cross_check time--- 0.0008699893951416016 seconds ---
# ===================================================
# case:70 ===>
# [26, 12, 25, 10, 32]
# avoiding edges:(12, 25), (10, 32)
# query output:[26, 12, 32] , weight:165.83838383838383
# Query time--- 0.9674737453460693 seconds ---
# cross_check output:[26, 12, 32] , weight:165.83838383838383
# Cross_check time--- 0.000904083251953125 seconds ---
# ===================================================
# case:71 ===>
# [35, 14, 9, 37, 2, 18]
# avoiding edges:(2, 18), (37, 2)
# query output:[35, 33, 48, 40, 44, 18] , weight:160.4040404040404
# Query time--- 0.7522261142730713 seconds ---
# cross_check output:[35, 33, 48, 40, 44, 18] , weight:160.4040404040404
# Cross_check time--- 0.0006122589111328125 seconds ---
# ===================================================
# case:72 ===>
# [26, 12, 36, 23]
# avoiding edges:(36, 23), (26, 12)
# query output:[26, 41, 2, 37, 12, 21, 23] , weight:171.5151515151515
# Query time--- 0.16036462783813477 seconds ---
# cross_check output:[26, 41, 2, 37, 12, 21, 23] , weight:171.5151515151515
# Cross_check time--- 0.0005202293395996094 seconds ---
# ===================================================
# case:73 ===>
# [7, 22]
# case:74 ===>
# [5, 10, 25, 14]
# avoiding edges:(25, 14), (5, 10)
# query output:[5, 48, 40, 21, 14] , weight:115.32323232323232
# Query time--- 0.3667151927947998 seconds ---
# cross_check output:[5, 48, 40, 21, 14] , weight:115.32323232323232
# Cross_check time--- 0.0005245208740234375 seconds ---
# ===================================================
# case:75 ===>
# [8, 24, 41, 13, 6]
# avoiding edges:(13, 6), (41, 13)
# query output:[8, 24, 41, 2, 18, 44, 6] , weight:115.98989898989899
# Query time--- 1.2637157440185547 seconds ---
# cross_check output:[8, 24, 41, 2, 18, 44, 6] , weight:115.98989898989899
# Cross_check time--- 0.02209305763244629 seconds ---
# ===================================================
# case:76 ===>
# [40, 49]
# case:77 ===>
# [34, 24, 22, 7, 4]
# avoiding edges:(24, 22), (34, 24)
# query output:[34, 42, 15, 31, 4] , weight:160.21212121212122
# Query time--- 1.3959028720855713 seconds ---
# cross_check output:[34, 42, 15, 31, 4] , weight:160.21212121212122
# Cross_check time--- 0.0007886886596679688 seconds ---
# ===================================================
# case:78 ===>
# [24, 22, 15]
# avoiding edges:(22, 15), (24, 22)
# query output:[24, 8, 3, 31, 15] , weight:96.03030303030303
# Query time--- 1.1105430126190186 seconds ---
# cross_check output:[24, 8, 3, 31, 15] , weight:96.03030303030303
# Cross_check time--- 0.0008535385131835938 seconds ---
# ===================================================
# case:79 ===>
# [42, 10, 39]
# avoiding edges:(42, 10), (10, 39)
# query output:[42, 19, 37, 12, 36, 23, 39] , weight:202.6060606060606
# Query time--- 0.4860858917236328 seconds ---
# cross_check output:[42, 19, 37, 12, 36, 23, 39] , weight:202.6060606060606
# Cross_check time--- 0.0007696151733398438 seconds ---
# ===================================================
# case:80 ===>
# [41, 2, 37, 12, 25, 10, 39, 47]
# avoiding edges:(25, 10), (39, 47)
# query output:[41, 2, 37, 9, 14, 29, 33, 47] , weight:215.05050505050505
# Query time--- 1.2376093864440918 seconds ---
# cross_check output:[41, 2, 37, 9, 14, 29, 33, 47] , weight:215.05050505050505
# Cross_check time--- 0.0008428096771240234 seconds ---
# ===================================================
# case:81 ===>
# [47, 39, 10, 25, 12, 37, 28]
# avoiding edges:(25, 12), (39, 10)
# query output:[47, 39, 23, 36, 12, 37, 28] , weight:193.16161616161614
# Query time--- 1.9968760013580322 seconds ---
# cross_check output:[47, 39, 23, 36, 12, 37, 28] , weight:193.16161616161614
# Cross_check time--- 0.0006763935089111328 seconds ---
# ===================================================
# case:82 ===>
# [41, 2, 37, 12, 36, 23, 16]
# avoiding edges:(41, 2), (37, 12)
# query output:[41, 24, 22, 9, 14, 21, 23, 16] , weight:156.83838383838383
# Query time--- 3.003286600112915 seconds ---
# cross_check output:[41, 24, 22, 9, 14, 21, 23, 16] , weight:156.83838383838383
# Cross_check time--- 0.0009365081787109375 seconds ---
# ===================================================
# case:83 ===>
# [29, 14, 9, 22, 7, 4]
# avoiding edges:(22, 7), (9, 22)
# query output:[29, 14, 21, 40, 4] , weight:136.82828282828282
# Query time--- 2.3473398685455322 seconds ---
# cross_check output:[29, 14, 21, 40, 4] , weight:136.82828282828282
# Cross_check time--- 0.0006794929504394531 seconds ---
# ===================================================
# case:84 ===>
# Shortest path for (30, 17) not found in shortest_paths.
# case:85 ===>
# [25, 10, 23, 16]
# avoiding edges:(23, 16), (25, 10)
# query output:[25, 40, 48, 46, 16] , weight:141.33333333333331
# Query time--- 0.21803617477416992 seconds ---
# cross_check output:[25, 40, 48, 46, 16] , weight:141.33333333333331
# Cross_check time--- 0.0009875297546386719 seconds ---
# ===================================================
# case:86 ===>
# [26, 49]
# case:87 ===>
# [39, 23, 36, 27]
# avoiding edges:(39, 23), (36, 27)
# query output:[39, 10, 32, 27] , weight:104.56565656565657
# Query time--- 1.4907677173614502 seconds ---
# cross_check output:[39, 10, 32, 27] , weight:104.56565656565657
# Cross_check time--- 0.0005457401275634766 seconds ---
# ===================================================
# case:88 ===>
# Shortest path for (21, 20) not found in shortest_paths.
# case:89 ===>
# [36, 27, 18, 44]
# avoiding edges:(27, 18), (36, 27)
# query output:[36, 12, 37, 2, 18, 44] , weight:94.60606060606061
# Query time--- 0.6068320274353027 seconds ---
# cross_check output:[36, 12, 37, 2, 18, 44] , weight:94.60606060606061
# Cross_check time--- 0.0006737709045410156 seconds ---
# ===================================================
# case:90 ===>
# Shortest path for (30, 5) not found in shortest_paths.
# case:91 ===>
# [13, 41, 24]
# avoiding edges:(13, 41), (41, 24)
# query output:[13, 6, 14, 9, 22, 24] , weight:123.76767676767678
# Query time--- 1.5971343517303467 seconds ---
# cross_check output:[13, 6, 14, 9, 22, 24] , weight:123.76767676767678
# Cross_check time--- 0.000762939453125 seconds ---
# ===================================================
# case:92 ===>
# Shortest path for (0, 50) not found in shortest_paths.
# case:93 ===>
# [37, 9, 22, 7]
# avoiding edges:(9, 22), (22, 7)
# query output:[37, 1, 40, 4, 7] , weight:122.35353535353536
# Query time--- 0.7216434478759766 seconds ---
# cross_check output:[37, 1, 40, 4, 7] , weight:122.35353535353536
# Cross_check time--- 0.0008060932159423828 seconds ---
# ===================================================
# case:94 ===>
# [0, 45, 12, 37, 1, 40, 49]
# avoiding edges:(12, 37), (45, 12)
# query output:[0, 45, 6, 44, 19, 49] , weight:166.72727272727272
# Query time--- 1.4364337921142578 seconds ---
# cross_check output:[0, 45, 6, 44, 19, 49] , weight:166.72727272727272
# Cross_check time--- 0.0008449554443359375 seconds ---
# ===================================================
# case:95 ===>
# [7, 22, 9, 14, 21, 36, 27]
# avoiding edges:(9, 14), (14, 21)
# query output:[7, 22, 24, 41, 2, 18, 27] , weight:149.46464646464648
# Query time--- 0.6757822036743164 seconds ---
# cross_check output:[7, 22, 24, 41, 2, 18, 27] , weight:149.46464646464648
# Cross_check time--- 0.0007464885711669922 seconds ---
# ===================================================
# case:96 ===>
# [5, 10, 25, 12, 37, 2, 41]
# avoiding edges:(5, 10), (2, 41)
# query output:[5, 48, 13, 41] , weight:157.1313131313131
# Query time--- 0.9359273910522461 seconds ---
# cross_check output:[5, 48, 13, 41] , weight:157.1313131313131
# Cross_check time--- 0.0007677078247070312 seconds ---
# ===================================================
# case:97 ===>
# [24, 22, 9, 14, 25, 10, 39, 47]
# avoiding edges:(22, 9), (39, 47)
# query output:[24, 8, 29, 33, 47] , weight:236.3232323232323
# Query time--- 0.975602388381958 seconds ---
# cross_check output:[24, 8, 29, 33, 47] , weight:236.3232323232323
# Cross_check time--- 0.0008029937744140625 seconds ---
# ===================================================
# case:98 ===>
# [17, 3, 31]
# avoiding edges:(17, 3), (3, 31)
# query output:[17, 4, 31] , weight:142.32323232323233
# Query time--- 0.7627444267272949 seconds ---
# cross_check output:[17, 4, 31] , weight:142.32323232323233
# Cross_check time--- 0.0005986690521240234 seconds ---
# ===================================================
# case:99 ===>
# Shortest path for (30, 2) not found in shortest_paths.
# case:100 ===>
# [0, 45, 12, 37, 9, 22, 24]
# avoiding edges:(12, 37), (22, 24)
# query output:[0, 45, 12, 21, 14, 9, 37, 2, 41, 24] , weight:161.84848484848484
# Query time--- 1.6084566116333008 seconds ---
# cross_check output:[0, 45, 12, 21, 14, 9, 37, 2, 41, 24] , weight:161.84848484848484
# Cross_check time--- 0.0008330345153808594 seconds ---
# ===================================================
# case:101 ===>
# [24, 34]
# case:102 ===>
# [49, 33]
# case:103 ===>
# [19, 42, 15, 31, 3, 8]
# avoiding edges:(3, 8), (19, 42)
# query output:[19, 37, 9, 22, 24, 8] , weight:130.1919191919192
# Query time--- 0.41292309761047363 seconds ---
# cross_check output:[19, 37, 9, 22, 24, 8] , weight:130.1919191919192
# Cross_check time--- 0.0007002353668212891 seconds ---
# ===================================================
# case:104 ===>
# [33, 48, 5]
# avoiding edges:(33, 48), (48, 5)
# query output:[33, 32, 10, 5] , weight:142.43434343434342
# Query time--- 1.3276114463806152 seconds ---
# cross_check output:[33, 32, 10, 5] , weight:142.43434343434342
# Cross_check time--- 0.0007824897766113281 seconds ---
# ===================================================
# case:105 ===>
# [32, 10, 25, 40, 48, 46]
# avoiding edges:(10, 25), (32, 10)
# query output:[32, 12, 37, 1, 40, 48, 46] , weight:166.8989898989899
# Query time--- 0.3026714324951172 seconds ---
# cross_check output:[32, 12, 37, 1, 40, 48, 46] , weight:166.8989898989899
# Cross_check time--- 0.0006737709045410156 seconds ---
# ===================================================
# case:106 ===>
# Shortest path for (11, 42) not found in shortest_paths.
# case:107 ===>
# [7, 22, 9, 37, 12]
# avoiding edges:(22, 9), (37, 12)
# query output:[7, 4, 40, 21, 12] , weight:151.3939393939394
# Query time--- 1.6157712936401367 seconds ---
# cross_check output:[7, 4, 40, 21, 12] , weight:151.3939393939394
# Cross_check time--- 0.0008003711700439453 seconds ---
# ===================================================
# case:108 ===>
# Shortest path for (10, 50) not found in shortest_paths.
# case:109 ===>
# [7, 22, 9, 14, 25, 10, 32]
# avoiding edges:(7, 22), (14, 25)
# query output:[7, 4, 40, 25, 10, 32] , weight:153.80808080808083
# Query time--- 0.7736971378326416 seconds ---
# cross_check output:[7, 4, 40, 25, 10, 32] , weight:153.80808080808083
# Cross_check time--- 0.0005459785461425781 seconds ---
# ===================================================
# case:110 ===>
# [1, 37, 19]
# avoiding edges:(37, 19), (1, 37)
# query output:[1, 40, 44, 19] , weight:102.66666666666666
# Query time--- 1.0406670570373535 seconds ---
# cross_check output:[1, 40, 44, 19] , weight:102.66666666666666
# Cross_check time--- 0.0006420612335205078 seconds ---
# ===================================================
# case:111 ===>
# [14, 9, 22, 24, 34]
# avoiding edges:(14, 9), (9, 22)
# query output:[14, 21, 12, 37, 28, 34] , weight:133.0909090909091
# Query time--- 0.5418598651885986 seconds ---
# cross_check output:[14, 21, 12, 37, 28, 34] , weight:133.0909090909091
# Cross_check time--- 0.0008485317230224609 seconds ---
# ===================================================
# case:112 ===>
# [42, 15, 35, 33]
# avoiding edges:(42, 15), (35, 33)
# query output:[42, 46, 48, 33] , weight:130.91919191919192
# Query time--- 0.28636884689331055 seconds ---
# cross_check output:[42, 46, 48, 33] , weight:130.91919191919192
# Cross_check time--- 0.00048732757568359375 seconds ---
# ===================================================
# case:113 ===>
# [47, 39, 10, 25, 12, 45, 0]
# avoiding edges:(12, 45), (39, 10)
# query output:[47, 39, 23, 36, 27, 18, 44, 6, 45, 0] , weight:261.9191919191919
# Query time--- 1.5337159633636475 seconds ---
# cross_check output:[47, 39, 23, 36, 27, 18, 44, 6, 45, 0] , weight:261.9191919191919
# Cross_check time--- 0.0011458396911621094 seconds ---
# ===================================================
# case:114 ===>
# [14, 21, 40, 49]
# avoiding edges:(14, 21), (21, 40)
# query output:[14, 9, 37, 1, 40, 49] , weight:116.63636363636364
# Query time--- 0.5288891792297363 seconds ---
# cross_check output:[14, 9, 37, 1, 40, 49] , weight:116.63636363636364
# Cross_check time--- 0.0007786750793457031 seconds ---
# ===================================================
# case:115 ===>
# [14, 29]
# case:116 ===>
# [34, 28, 37, 12]
# avoiding edges:(34, 28), (37, 12)
# query output:[34, 24, 22, 9, 14, 21, 12] , weight:112.010101010101
# Query time--- 0.805365800857544 seconds ---
# cross_check output:[34, 24, 22, 9, 14, 21, 12] , weight:112.010101010101
# Cross_check time--- 0.0006659030914306641 seconds ---
# ===================================================
# case:117 ===>
# [1, 37]
# case:118 ===>
# [12, 36, 23]
# avoiding edges:(36, 23), (12, 36)
# query output:[12, 21, 23] , weight:76.1010101010101
# Query time--- 0.5606367588043213 seconds ---
# cross_check output:[12, 21, 23] , weight:76.1010101010101
# Cross_check time--- 0.0006315708160400391 seconds ---
# ===================================================
# case:119 ===>
# [18, 27, 36, 23]
# avoiding edges:(36, 23), (27, 36)
# query output:[18, 2, 37, 12, 21, 23] , weight:93.67676767676767
# Query time--- 0.3970460891723633 seconds ---
# cross_check output:[18, 2, 37, 12, 21, 23] , weight:93.67676767676767
# Cross_check time--- 0.0006668567657470703 seconds ---
# ===================================================
# case:120 ===>
# [1, 37, 9, 22, 24]
# avoiding edges:(9, 22), (22, 24)
# query output:[1, 37, 2, 41, 24] , weight:79.92929292929293
# Query time--- 0.6217293739318848 seconds ---
# cross_check output:[1, 37, 2, 41, 24] , weight:79.92929292929293
# Cross_check time--- 0.0006170272827148438 seconds ---
# ===================================================
# case:121 ===>
# [44, 18, 27]
# avoiding edges:(18, 27), (44, 18)
# query output:[44, 6, 45, 12, 36, 27] , weight:139.05050505050505
# Query time--- 1.2619056701660156 seconds ---
# cross_check output:[44, 6, 45, 12, 36, 27] , weight:139.05050505050505
# Cross_check time--- 0.0008006095886230469 seconds ---
# ===================================================
# case:122 ===>
# [14, 9, 37, 12, 45]
# avoiding edges:(12, 45), (37, 12)
# query output:[14, 6, 45] , weight:111.42424242424244
# Query time--- 0.49828672409057617 seconds ---
# cross_check output:[14, 6, 45] , weight:111.42424242424244
# Cross_check time--- 0.0008134841918945312 seconds ---
# ===================================================
# case:123 ===>
# [19, 37, 12, 45, 0]
# avoiding edges:(12, 45), (45, 0)
# query output:[] , weight:0
# Query time--- 0.15355706214904785 seconds ---
# No path exists between nodes 19 and 0 after removing edges (12, 45) and (45, 0).
# cross_check output:[] , weight:0
# Cross_check time--- 0.0010161399841308594 seconds ---
# ===================================================
# case:124 ===>
# [26, 41, 24, 8, 3, 17]
# avoiding edges:(3, 17), (8, 3)
# query output:[26, 12, 25, 17] , weight:183.45454545454544
# Query time--- 0.26521754264831543 seconds ---
# cross_check output:[26, 12, 25, 17] , weight:183.45454545454544
# Cross_check time--- 0.000858306884765625 seconds ---
# ===================================================
# case:125 ===>
# [6, 44, 18, 2, 37, 12, 26]
# avoiding edges:(6, 44), (12, 26)
# query output:[6, 13, 41, 26] , weight:127.52525252525251
# Query time--- 0.8399345874786377 seconds ---
# cross_check output:[6, 13, 41, 26] , weight:127.52525252525251
# Cross_check time--- 0.0007143020629882812 seconds ---
# ===================================================
# case:126 ===>
# Shortest path for (30, 4) not found in shortest_paths.
# case:127 ===>
# [46, 7]
# case:128 ===>
# [22, 24, 41, 13]
# avoiding edges:(41, 13), (24, 41)
# query output:[22, 9, 14, 6, 13] , weight:119.05050505050505
# Query time--- 1.3610496520996094 seconds ---
# cross_check output:[22, 9, 14, 6, 13] , weight:119.05050505050505
# Cross_check time--- 0.0005764961242675781 seconds ---
# ===================================================
# case:129 ===>
# [15, 42, 19, 37]
# avoiding edges:(15, 42), (42, 19)
# query output:[15, 22, 9, 37] , weight:126.12121212121212
# Query time--- 1.265662670135498 seconds ---
# cross_check output:[15, 22, 9, 37] , weight:126.12121212121212
# Cross_check time--- 0.0004975795745849609 seconds ---
# ===================================================
# case:130 ===>
# case:131 ===>
# [27, 36, 21, 14, 9]
# avoiding edges:(14, 9), (21, 14)
# query output:[27, 18, 2, 37, 9] , weight:84.04040404040404
# Query time--- 0.5993449687957764 seconds ---
# cross_check output:[27, 18, 2, 37, 9] , weight:84.04040404040404
# Cross_check time--- 0.0006814002990722656 seconds ---
# ===================================================
# case:132 ===>
# [37, 12, 25]
# avoiding edges:(12, 25), (37, 12)
# query output:[37, 9, 14, 25] , weight:60.131313131313135
# Query time--- 0.3703651428222656 seconds ---
# cross_check output:[37, 9, 14, 25] , weight:60.131313131313135
# Cross_check time--- 0.0004572868347167969 seconds ---
# ===================================================
# case:133 ===>
# [19, 37, 12, 45]
# avoiding edges:(37, 12), (19, 37)
# query output:[19, 44, 6, 45] , weight:92.07070707070707
# Query time--- 0.35719752311706543 seconds ---
# cross_check output:[19, 44, 6, 45] , weight:92.07070707070707
# Cross_check time--- 0.00038123130798339844 seconds ---
# ===================================================
# case:134 ===>
# [1, 37, 12, 25, 10, 39]
# avoiding edges:(10, 39), (1, 37)
# query output:[1, 27, 36, 23, 39] , weight:140.36363636363635
# Query time--- 1.3723907470703125 seconds ---
# cross_check output:[1, 27, 36, 23, 39] , weight:140.36363636363635
# Cross_check time--- 0.0011763572692871094 seconds ---
# ===================================================
# case:135 ===>
# [46, 48]
# case:136 ===>
# [49, 26]
# case:137 ===>
# case:138 ===>
# [27, 36, 21, 14, 9, 22, 24, 8, 3]
# avoiding edges:(24, 8), (21, 14)
# query output:[27, 18, 2, 41, 24, 22, 3] , weight:157.35353535353536
# Query time--- 1.3251111507415771 seconds ---
# cross_check output:[27, 18, 2, 41, 24, 22, 3] , weight:157.35353535353536
# Cross_check time--- 0.000701904296875 seconds ---
# ===================================================
# case:139 ===>
# [46, 42, 15, 31, 3]
# avoiding edges:(31, 3), (46, 42)
# query output:[46, 24, 8, 3] , weight:126.14141414141415
# Query time--- 0.4191761016845703 seconds ---
# cross_check output:[46, 24, 8, 3] , weight:126.14141414141415
# Cross_check time--- 0.0007443428039550781 seconds ---
# ===================================================
# case:140 ===>
# [12, 37, 9]
# avoiding edges:(37, 9), (12, 37)
# query output:[12, 21, 14, 9] , weight:39.24242424242424
# Query time--- 0.7314321994781494 seconds ---
# cross_check output:[12, 21, 14, 9] , weight:39.24242424242424
# Cross_check time--- 0.00032806396484375 seconds ---
# ===================================================
# case:141 ===>
# [48, 46, 24]
# avoiding edges:(46, 24), (48, 46)
# query output:[48, 40, 21, 14, 9, 22, 24] , weight:98.44444444444444
# Query time--- 0.8036997318267822 seconds ---
# cross_check output:[48, 40, 21, 14, 9, 22, 24] , weight:98.44444444444444
# Cross_check time--- 0.0007345676422119141 seconds ---
# ===================================================
# case:142 ===>
# [19, 37, 12, 36, 23]
# avoiding edges:(36, 23), (19, 37)
# query output:[19, 44, 18, 2, 37, 12, 21, 23] , weight:149.94949494949495
# Query time--- 0.41069912910461426 seconds ---
# cross_check output:[19, 44, 18, 2, 37, 12, 21, 23] , weight:149.94949494949495
# Cross_check time--- 0.0008738040924072266 seconds ---
# ===================================================
# case:143 ===>
# case:144 ===>
# [47, 39, 10, 25, 40, 48]
# avoiding edges:(39, 10), (25, 40)
# query output:[47, 33, 48] , weight:171.82828282828282
# Query time--- 0.27823376655578613 seconds ---
# cross_check output:[47, 33, 48] , weight:171.82828282828282
# Cross_check time--- 0.005532979965209961 seconds ---
# ===================================================
# case:145 ===>
# [18, 2, 37, 9]
# avoiding edges:(2, 37), (37, 9)
# query output:[18, 2, 21, 14, 9] , weight:71.96969696969697
# Query time--- 1.4324736595153809 seconds ---
# cross_check output:[18, 2, 21, 14, 9] , weight:71.96969696969697
# Cross_check time--- 0.00041484832763671875 seconds ---
# ===================================================
# case:146 ===>
# [17, 3, 8, 24]
# avoiding edges:(17, 3), (3, 8)
# query output:[17, 4, 7, 22, 24] , weight:142.25252525252526
# Query time--- 0.13565945625305176 seconds ---
# cross_check output:[17, 4, 7, 22, 24] , weight:142.25252525252526
# Cross_check time--- 0.0005192756652832031 seconds ---
# ===================================================
# case:147 ===>
# [28, 37, 12, 36, 23]
# avoiding edges:(37, 12), (36, 23)
# query output:[28, 37, 9, 14, 21, 23] , weight:123.66666666666666
# Query time--- 2.247852325439453 seconds ---
# cross_check output:[28, 37, 9, 14, 21, 23] , weight:123.66666666666666
# Cross_check time--- 0.0007674694061279297 seconds ---
# ===================================================
# case:148 ===>
# [21, 14, 9, 22, 15]
# avoiding edges:(9, 22), (21, 14)
# query output:[21, 40, 48, 46, 42, 15] , weight:132.17171717171715
# Query time--- 0.2958371639251709 seconds ---
# cross_check output:[21, 40, 48, 46, 42, 15] , weight:132.17171717171715
# Cross_check time--- 0.0008876323699951172 seconds ---
# ===================================================
# case:149 ===>
# [9, 37]
# case:150 ===>
# [35, 14, 21, 36]
# avoiding edges:(35, 14), (14, 21)
# query output:[35, 33, 29, 14, 9, 37, 12, 36] , weight:158.77777777777777
# Query time--- 1.7701663970947266 seconds ---
# cross_check output:[35, 33, 29, 14, 9, 37, 12, 36] , weight:158.77777777777777
# Cross_check time--- 0.0008311271667480469 seconds ---
# ===================================================
# case:151 ===>
# [10, 42]
# case:152 ===>
# Shortest path for (18, 20) not found in shortest_paths.
# case:153 ===>
# [36, 21, 14, 9, 22, 38]
# avoiding edges:(14, 9), (22, 38)
# query output:[] , weight:0
# Query time--- 0.7060606479644775 seconds ---
# No path exists between nodes 36 and 38 after removing edges (14, 9) and (22, 38).
# cross_check output:[] , weight:0
# Cross_check time--- 0.0008029937744140625 seconds ---
# ===================================================
# case:154 ===>
# [17, 25, 10]
# avoiding edges:(17, 25), (25, 10)
# query output:[17, 3, 31, 15, 42, 10] , weight:168.66666666666669
# Query time--- 1.798877239227295 seconds ---
# cross_check output:[17, 3, 31, 15, 42, 10] , weight:168.66666666666669
# Cross_check time--- 0.006667375564575195 seconds ---
# ===================================================
# case:155 ===>
# [13, 41, 24, 34]
# avoiding edges:(41, 24), (24, 34)
# query output:[13, 42, 34] , weight:138.42424242424244
# Query time--- 1.2101008892059326 seconds ---
# cross_check output:[13, 42, 34] , weight:138.42424242424244
# Cross_check time--- 0.0007467269897460938 seconds ---
# ===================================================
# case:156 ===>
# [36, 12, 37, 2, 41, 13]
# avoiding edges:(2, 41), (36, 12)
# query output:[36, 27, 18, 44, 6, 13] , weight:122.50505050505052
# Query time--- 0.8716716766357422 seconds ---
# cross_check output:[36, 27, 18, 44, 6, 13] , weight:122.50505050505052
# Cross_check time--- 0.0007464885711669922 seconds ---
# ===================================================
# case:157 ===>
# [46, 48, 40, 44, 6]
# avoiding edges:(44, 6), (48, 40)
# query output:[46, 48, 13, 6] , weight:105.7070707070707
# Query time--- 0.49455857276916504 seconds ---
# cross_check output:[46, 48, 13, 6] , weight:105.7070707070707
# Cross_check time--- 0.0005102157592773438 seconds ---
# ===================================================
# case:158 ===>
# case:159 ===>
# Shortest path for (50, 7) not found in shortest_paths.
# case:160 ===>
# [44, 18, 2, 37, 12, 45]
# avoiding edges:(2, 37), (44, 18)
# query output:[44, 6, 45] , weight:59.41414141414141
# Query time--- 1.3855483531951904 seconds ---
# cross_check output:[44, 6, 45] , weight:59.41414141414141
# Cross_check time--- 0.00035262107849121094 seconds ---
# ===================================================
# case:161 ===>
# [32, 10, 25, 12, 37, 2, 18, 44]
# avoiding edges:(18, 44), (10, 25)
# query output:[32, 10, 5, 48, 40, 44] , weight:150.67676767676767
# Query time--- 1.2053718566894531 seconds ---
# cross_check output:[32, 10, 5, 48, 40, 44] , weight:150.67676767676767
# Cross_check time--- 0.0015285015106201172 seconds ---
# ===================================================
# case:162 ===>
# Shortest path for (50, 21) not found in shortest_paths.
# case:163 ===>
# [37, 12, 36, 23, 16]
# avoiding edges:(23, 16), (12, 36)
# query output:[37, 1, 40, 48, 46, 16] , weight:142.59595959595958
# Query time--- 1.2870314121246338 seconds ---
# cross_check output:[37, 1, 40, 48, 46, 16] , weight:142.59595959595958
# Cross_check time--- 0.0008568763732910156 seconds ---
# ===================================================
# case:164 ===>
# [46, 42, 34]
# avoiding edges:(42, 34), (46, 42)
# query output:[46, 28, 34] , weight:117.7070707070707
# Query time--- 0.4798722267150879 seconds ---
# cross_check output:[46, 28, 34] , weight:117.7070707070707
# Cross_check time--- 0.00110626220703125 seconds ---
# ===================================================
# case:165 ===>
# [41, 2, 37, 12, 25, 10, 39]
# avoiding edges:(37, 12), (2, 37)
# query output:[41, 2, 18, 27, 36, 23, 39] , weight:141.07070707070704
# Query time--- 1.9166274070739746 seconds ---
# cross_check output:[41, 2, 18, 27, 36, 23, 39] , weight:141.07070707070704
# Cross_check time--- 0.0009310245513916016 seconds ---
# ===================================================
# case:166 ===>
# [43, 45, 12, 25, 17]
# avoiding edges:(12, 25), (43, 45)
# query output:[] , weight:0
# Query time--- 1.155500888824463 seconds ---
# No path exists between nodes 43 and 17 after removing edges (12, 25) and (43, 45).
# cross_check output:[] , weight:0
# Cross_check time--- 0.00023245811462402344 seconds ---
# ===================================================
# case:167 ===>
# [2, 37, 9, 14, 29, 33]
# avoiding edges:(2, 37), (9, 14)
# query output:[2, 21, 14, 29, 33] , weight:125.96969696969697
# Query time--- 1.9642138481140137 seconds ---
# cross_check output:[2, 21, 14, 29, 33] , weight:125.96969696969697
# Cross_check time--- 0.0008749961853027344 seconds ---
# ===================================================
# case:168 ===>
# [40, 1, 37, 2]
# avoiding edges:(1, 37), (37, 2)
# query output:[40, 44, 18, 2] , weight:71.65656565656566
# Query time--- 1.1866545677185059 seconds ---
# cross_check output:[40, 44, 18, 2] , weight:71.65656565656566
# Cross_check time--- 0.0005774497985839844 seconds ---
# ===================================================
# case:169 ===>
# [45, 12, 37, 1]
# avoiding edges:(37, 1), (12, 37)
# query output:[45, 12, 21, 40, 1] , weight:124.5050505050505
# Query time--- 0.4689791202545166 seconds ---
# cross_check output:[45, 12, 21, 40, 1] , weight:124.5050505050505
# Cross_check time--- 0.002147197723388672 seconds ---
# ===================================================
# case:170 ===>
# [36, 27, 18, 44, 6]
# avoiding edges:(27, 18), (36, 27)
# query output:[36, 12, 37, 2, 18, 44, 6] , weight:110.81818181818181
# Query time--- 0.9547421932220459 seconds ---
# cross_check output:[36, 12, 37, 2, 18, 44, 6] , weight:110.81818181818181
# Cross_check time--- 0.0006818771362304688 seconds ---
# ===================================================
# case:171 ===>
# [21, 23, 16]
# avoiding edges:(21, 23), (23, 16)
# query output:[21, 40, 48, 46, 16] , weight:142.2121212121212
# Query time--- 0.15021896362304688 seconds ---
# cross_check output:[21, 40, 48, 46, 16] , weight:142.2121212121212
# Cross_check time--- 0.0007567405700683594 seconds ---
# ===================================================
# case:172 ===>
# [15, 42, 10, 39]
# avoiding edges:(42, 10), (10, 39)
# query output:[15, 22, 9, 14, 21, 23, 39] , weight:203.06060606060603
# Query time--- 1.0658044815063477 seconds ---
# cross_check output:[15, 22, 9, 14, 21, 23, 39] , weight:203.06060606060603
# Cross_check time--- 0.0008413791656494141 seconds ---
# ===================================================
# case:173 ===>
# [26, 49, 40, 48]
# avoiding edges:(49, 40), (40, 48)
# query output:[26, 41, 13, 48] , weight:174.75757575757575
# Query time--- 0.4108419418334961 seconds ---
# cross_check output:[26, 41, 13, 48] , weight:174.75757575757575
# Cross_check time--- 0.0007524490356445312 seconds ---
# ===================================================
# case:174 ===>
# [13, 6, 44]
# avoiding edges:(6, 44), (13, 6)
# query output:[13, 41, 2, 18, 44] , weight:88.23232323232324
# Query time--- 0.4667203426361084 seconds ---
# cross_check output:[13, 41, 2, 18, 44] , weight:88.23232323232324
# Cross_check time--- 0.0006303787231445312 seconds ---
# ===================================================
# case:175 ===>
# [36, 12, 45, 43]
# avoiding edges:(12, 45), (36, 12)
# query output:[36, 27, 18, 44, 6, 45, 43] , weight:207.4747474747475
# Query time--- 2.3600170612335205 seconds ---
# cross_check output:[36, 27, 18, 44, 6, 45, 43] , weight:207.4747474747475
# Cross_check time--- 0.0010378360748291016 seconds ---
# ===================================================
# case:176 ===>
# Shortest path for (11, 48) not found in shortest_paths.
# case:177 ===>
# [49, 19, 44, 6]
# avoiding edges:(19, 44), (44, 6)
# query output:[49, 40, 48, 13, 6] , weight:145.62626262626262
# Query time--- 1.1162395477294922 seconds ---
# cross_check output:[49, 40, 48, 13, 6] , weight:145.62626262626262
# ...
# Query time--- 0.4023730754852295 seconds ---
# cross_check output:[16, 23, 21, 14, 9, 22, 7] , weight:166.60606060606062
# Cross_check time--- 0.0007097721099853516 seconds ---
# ===================================================
# case:2945 ===>
# [2, 37, 12, 25, 10]
# avoiding edges:(12, 25), (25, 10)
# query output:[2, 37, 12, 32, 10] , weight:122.31313131313131
# Query time--- 1.2026307582855225 seconds ---
# cross_check output:[2, 37, 12, 32, 10] , weight:122.31313131313131
# Cross_check time--- 0.0007774829864501953 seconds ---
# ===================================================
# case:2946 ===>
# [34, 24, 22, 9, 14, 21, 36, 27]
# avoiding edges:(21, 36), (34, 24)
# query output:[34, 28, 37, 2, 18, 27] , weight:153.45454545454547
# Query time--- 1.0338737964630127 seconds ---
# cross_check output:[34, 28, 37, 2, 18, 27] , weight:153.45454545454547
# Cross_check time--- 0.0007157325744628906 seconds ---
# ===================================================
# case:2947 ===>
# [6, 44, 18, 27, 36]
# avoiding edges:(27, 36), (6, 44)
# query output:[6, 45, 12, 36] , weight:111.0
# Query time--- 0.6308460235595703 seconds ---
# cross_check output:[6, 45, 12, 36] , weight:111.0
# Cross_check time--- 0.0004911422729492188 seconds ---
# ===================================================
# case:2948 ===>
# [34, 42, 15, 35]
# avoiding edges:(42, 15), (15, 35)
# query output:[34, 24, 22, 9, 14, 35] , weight:145.6060606060606
# Query time--- 0.5348513126373291 seconds ---
# cross_check output:[34, 24, 22, 9, 14, 35] , weight:145.6060606060606
# Cross_check time--- 0.007044315338134766 seconds ---
# ===================================================
# case:2949 ===>
# [43, 45, 12, 37, 19]
# avoiding edges:(43, 45), (37, 19)
# query output:[] , weight:0
# Query time--- 0.0032024383544921875 seconds ---
# No path exists between nodes 43 and 19 after removing edges (43, 45) and (37, 19).
# cross_check output:[] , weight:0
# Cross_check time--- 0.00012135505676269531 seconds ---
# ===================================================
# case:2950 ===>
# [25, 12, 26]
# avoiding edges:(25, 12), (12, 26)
# query output:[25, 40, 49, 26] , weight:131.56565656565655
# Query time--- 0.510718822479248 seconds ---
# cross_check output:[25, 40, 49, 26] , weight:131.56565656565655
# Cross_check time--- 0.0007627010345458984 seconds ---
# ===================================================
# case:2951 ===>
# [21, 14, 9, 22, 24, 8, 3, 31]
# avoiding edges:(24, 8), (9, 22)
# query output:[21, 40, 48, 46, 42, 15, 31] , weight:153.7272727272727
# Query time--- 0.747307300567627 seconds ---
# cross_check output:[21, 40, 48, 46, 42, 15, 31] , weight:153.7272727272727
# Cross_check time--- 0.0008566379547119141 seconds ---
# ===================================================
# case:2952 ===>
# [21, 14, 29]
# avoiding edges:(21, 14), (14, 29)
# query output:[21, 40, 48, 33, 29] , weight:161.4242424242424
# Query time--- 0.450885534286499 seconds ---
# cross_check output:[21, 40, 48, 33, 29] , weight:161.4242424242424
# Cross_check time--- 0.00693058967590332 seconds ---
# ===================================================
# case:2953 ===>
# [0, 45, 12, 25]
# avoiding edges:(12, 25), (45, 12)
# query output:[0, 45, 6, 14, 25] , weight:174.94949494949498
# Query time--- 1.7431633472442627 seconds ---
# cross_check output:[0, 45, 6, 14, 25] , weight:174.94949494949498
# Cross_check time--- 0.0007314682006835938 seconds ---
# ===================================================
# case:2954 ===>
# [14, 9, 22, 24, 8, 3, 17]
# avoiding edges:(22, 24), (9, 22)
# query output:[14, 25, 17] , weight:113.11111111111111
# Query time--- 0.3057384490966797 seconds ---
# cross_check output:[14, 25, 17] , weight:113.11111111111111
# Cross_check time--- 0.0006656646728515625 seconds ---
# ===================================================
# case:2955 ===>
# [19, 37, 9, 14, 29]
# avoiding edges:(9, 14), (14, 29)
# query output:[19, 42, 15, 35, 33, 29] , weight:154.55555555555554
# Query time--- 0.5923688411712646 seconds ---
# cross_check output:[19, 42, 15, 35, 33, 29] , weight:154.55555555555554
# Cross_check time--- 0.0007772445678710938 seconds ---
# ===================================================
# case:2956 ===>
# Shortest path for (25, 30) not found in shortest_paths.
# case:2957 ===>
# Shortest path for (23, 11) not found in shortest_paths.
# case:2958 ===>
# Shortest path for (30, 49) not found in shortest_paths.
# case:2959 ===>
# [47, 39, 10, 25, 40, 48, 46]
# avoiding edges:(10, 25), (39, 10)
# query output:[47, 33, 48, 46] , weight:179.83838383838383
# Query time--- 1.681668996810913 seconds ---
# cross_check output:[47, 33, 48, 46] , weight:179.83838383838383
# Cross_check time--- 0.0006990432739257812 seconds ---
# ===================================================
# case:2960 ===>
# Shortest path for (12, 20) not found in shortest_paths.
# case:2961 ===>
# [45, 12, 37, 9, 22, 24, 8]
# avoiding edges:(45, 12), (37, 9)
# query output:[45, 6, 13, 41, 24, 8] , weight:154.92929292929293
# Query time--- 0.6199581623077393 seconds ---
# cross_check output:[45, 6, 13, 41, 24, 8] , weight:154.92929292929293
# Cross_check time--- 0.0007088184356689453 seconds ---
# ===================================================
# case:2962 ===>
# [34, 42, 19, 49]
# avoiding edges:(34, 42), (19, 49)
# query output:[34, 28, 46, 48, 40, 49] , weight:173.64646464646464
# Query time--- 1.0979113578796387 seconds ---
# cross_check output:[34, 28, 46, 48, 40, 49] , weight:173.64646464646464
# Cross_check time--- 0.0008578300476074219 seconds ---
# ===================================================
# case:2963 ===>
# [12, 37, 1, 40, 48]
# avoiding edges:(37, 1), (1, 40)
# query output:[12, 21, 40, 48] , weight:89.05050505050505
# Query time--- 0.398021936416626 seconds ---
# cross_check output:[12, 21, 40, 48] , weight:89.05050505050505
# Cross_check time--- 0.0006804466247558594 seconds ---
# ===================================================
# case:2964 ===>
# [25, 40, 4]
# avoiding edges:(40, 4), (25, 40)
# query output:[25, 14, 9, 22, 7, 4] , weight:130.4949494949495
# Query time--- 0.517827033996582 seconds ---
# cross_check output:[25, 14, 9, 22, 7, 4] , weight:130.4949494949495
# Cross_check time--- 0.0008747577667236328 seconds ---
# ===================================================
# case:2965 ===>
# [47, 39, 10, 25, 12, 37, 19]
# avoiding edges:(39, 10), (12, 37)
# query output:[47, 39, 23, 36, 27, 18, 44, 19] , weight:207.15151515151513
# Query time--- 2.730039358139038 seconds ---
# cross_check output:[47, 39, 23, 36, 27, 18, 44, 19] , weight:207.15151515151513
# Cross_check time--- 0.002395153045654297 seconds ---
# ===================================================
# case:2966 ===>
# [21, 14, 25]
# avoiding edges:(21, 14), (14, 25)
# query output:[21, 12, 25] , weight:65.87878787878788
# Query time--- 0.7493212223052979 seconds ---
# cross_check output:[21, 12, 25] , weight:65.87878787878788
# Cross_check time--- 0.0004725456237792969 seconds ---
# ===================================================
# case:2967 ===>
# [33, 29, 14, 21, 36, 27]
# avoiding edges:(29, 14), (36, 27)
# query output:[33, 32, 27] , weight:145.7171717171717
# Query time--- 0.46097564697265625 seconds ---
# cross_check output:[33, 32, 27] , weight:145.7171717171717
# Cross_check time--- 0.0009660720825195312 seconds ---
# ===================================================
# case:2968 ===>
# [3, 31, 15, 42, 46]
# avoiding edges:(3, 31), (42, 46)
# query output:[3, 8, 24, 46] , weight:126.14141414141413
# Query time--- 0.6975798606872559 seconds ---
# cross_check output:[3, 8, 24, 46] , weight:126.14141414141413
# Cross_check time--- 0.0008087158203125 seconds ---
# ===================================================
# case:2969 ===>
# [23, 21, 40, 4]
# avoiding edges:(40, 4), (23, 21)
# query output:[23, 36, 21, 14, 9, 22, 7, 4] , weight:165.9090909090909
# Query time--- 0.8420441150665283 seconds ---
# cross_check output:[23, 36, 21, 14, 9, 22, 7, 4] , weight:165.9090909090909
# Cross_check time--- 0.0008134841918945312 seconds ---
# ===================================================
# case:2970 ===>
# [28, 37, 2, 18]
# avoiding edges:(2, 18), (28, 37)
# query output:[28, 46, 48, 40, 44, 18] , weight:149.4242424242424
# Query time--- 1.6815900802612305 seconds ---
# cross_check output:[28, 46, 48, 40, 44, 18] , weight:149.4242424242424
# Cross_check time--- 0.0006999969482421875 seconds ---
# ===================================================
# case:2971 ===>
# Shortest path for (21, 11) not found in shortest_paths.
# case:2972 ===>
# [44, 18, 2, 41, 24, 8]
# avoiding edges:(2, 41), (41, 24)
# query output:[44, 18, 2, 37, 9, 22, 24, 8] , weight:111.31313131313132
# Query time--- 1.562561273574829 seconds ---
# cross_check output:[44, 18, 2, 37, 9, 22, 24, 8] , weight:111.31313131313132
# Cross_check time--- 0.0008466243743896484 seconds ---
# ===================================================
# case:2973 ===>
# [34, 24, 41, 2, 18]
# avoiding edges:(41, 2), (34, 24)
# query output:[34, 28, 37, 2, 18] , weight:107.84848484848486
# Query time--- 2.1472177505493164 seconds ---
# cross_check output:[34, 28, 37, 2, 18] , weight:107.84848484848486
# Cross_check time--- 0.0006101131439208984 seconds ---
# ===================================================
# case:2974 ===>
# [48, 40, 1, 37, 12, 45, 43]
# avoiding edges:(12, 45), (48, 40)
# query output:[48, 13, 6, 45, 43] , weight:207.8989898989899
# Query time--- 0.7613155841827393 seconds ---
# cross_check output:[48, 13, 6, 45, 43] , weight:207.8989898989899
# Cross_check time--- 0.0007121562957763672 seconds ---
# ===================================================
# case:2975 ===>
# [9, 37, 12, 26]
# avoiding edges:(37, 12), (12, 26)
# query output:[9, 37, 2, 41, 26] , weight:116.27272727272727
# Query time--- 1.217864990234375 seconds ---
# cross_check output:[9, 37, 2, 41, 26] , weight:116.27272727272727
# Cross_check time--- 0.00080108642578125 seconds ---
# ===================================================
# case:2976 ===>
# Shortest path for (20, 25) not found in shortest_paths.
# case:2977 ===>
# [49, 19, 44, 18]
# avoiding edges:(44, 18), (49, 19)
# query output:[49, 40, 1, 37, 2, 18] , weight:107.15151515151516
# Query time--- 2.6405692100524902 seconds ---
# cross_check output:[49, 40, 1, 37, 2, 18] , weight:107.15151515151516
# Cross_check time--- 0.0005047321319580078 seconds ---
# ===================================================
# case:2978 ===>
# Shortest path for (20, 42) not found in shortest_paths.
# case:2979 ===>
# [49, 40, 1, 27]
# avoiding edges:(49, 40), (1, 27)
# query output:[49, 19, 44, 18, 27] , weight:148.52525252525254
# Query time--- 0.47667765617370605 seconds ---
# cross_check output:[49, 19, 44, 18, 27] , weight:148.52525252525254
# Cross_check time--- 0.0007305145263671875 seconds ---
# ===================================================
# case:2980 ===>
# [36, 21, 14, 9, 22, 24, 8, 3, 17]
# avoiding edges:(3, 17), (9, 22)
# query output:[36, 12, 25, 17] , weight:167.46464646464648
# Query time--- 0.9550487995147705 seconds ---
# cross_check output:[36, 12, 25, 17] , weight:167.46464646464648
# Cross_check time--- 0.0008254051208496094 seconds ---
# ===================================================
# case:2981 ===>
# [14, 21, 36, 27]
# avoiding edges:(36, 27), (14, 21)
# query output:[14, 9, 37, 2, 18, 27] , weight:85.35353535353536
# Query time--- 0.6176493167877197 seconds ---
# cross_check output:[14, 9, 37, 2, 18, 27] , weight:85.35353535353536
# Cross_check time--- 0.0005564689636230469 seconds ---
# ===================================================
# case:2982 ===>
# [10, 25, 40, 4]
# avoiding edges:(25, 40), (40, 4)
# query output:[10, 25, 14, 9, 22, 7, 4] , weight:147.84848484848484
# Query time--- 0.5685470104217529 seconds ---
# cross_check output:[10, 25, 14, 9, 22, 7, 4] , weight:147.84848484848484
# Cross_check time--- 0.0011365413665771484 seconds ---
# ===================================================
# case:2983 ===>
# [37, 19, 42, 15, 31]
# avoiding edges:(37, 19), (42, 15)
# query output:[37, 9, 22, 24, 8, 3, 31] , weight:126.77777777777779
# Query time--- 0.9878146648406982 seconds ---
# cross_check output:[37, 9, 22, 24, 8, 3, 31] , weight:126.77777777777779
# Cross_check time--- 0.0008652210235595703 seconds ---
# ===================================================
# case:2984 ===>
# [32, 33, 35]
# avoiding edges:(32, 33), (33, 35)
# query output:[32, 10, 25, 14, 35] , weight:139.75757575757575
# Query time--- 0.20135068893432617 seconds ---
# cross_check output:[32, 10, 25, 14, 35] , weight:139.75757575757575
# Cross_check time--- 0.0007309913635253906 seconds ---
# ===================================================
# case:2985 ===>
# [17, 25, 12, 45]
# avoiding edges:(25, 12), (17, 25)
# query output:[17, 3, 8, 24, 22, 9, 37, 12, 45] , weight:128.61616161616163
# Query time--- 0.6790854930877686 seconds ---
# cross_check output:[17, 3, 8, 24, 22, 9, 37, 12, 45] , weight:128.61616161616163
# Cross_check time--- 0.0006682872772216797 seconds ---
# ===================================================
# case:2986 ===>
# [38, 22, 9, 37]
# avoiding edges:(22, 9), (9, 37)
# query output:[38, 22, 24, 41, 2, 37] , weight:121.35353535353536
# Query time--- 0.36081886291503906 seconds ---
# cross_check output:[38, 22, 24, 41, 2, 37] , weight:121.35353535353536
# Cross_check time--- 0.0003352165222167969 seconds ---
# ===================================================
# case:2987 ===>
# Shortest path for (20, 29) not found in shortest_paths.
# case:2988 ===>
# [12, 21]
# case:2989 ===>
# [21, 14, 9, 22, 24, 8, 3, 17]
# avoiding edges:(3, 17), (24, 8)
# query output:[21, 14, 25, 17] , weight:121.61616161616162
# Query time--- 0.39079856872558594 seconds ---
# cross_check output:[21, 14, 25, 17] , weight:121.61616161616162
# Cross_check time--- 0.0007674694061279297 seconds ---
# ===================================================
# case:2990 ===>
# [37, 19]
# case:2991 ===>
# [27, 18, 44, 6]
# avoiding edges:(27, 18), (18, 44)
# query output:[27, 36, 12, 45, 6] , weight:122.83838383838383
# Query time--- 1.788527250289917 seconds ---
# cross_check output:[27, 36, 12, 45, 6] , weight:122.83838383838383
# Cross_check time--- 0.0006158351898193359 seconds ---
# ===================================================
# case:2992 ===>
# [47, 39, 10, 25, 12, 45, 0]
# avoiding edges:(25, 12), (12, 45)
# query output:[47, 39, 10, 25, 14, 6, 45, 0] , weight:260.6262626262626
# Query time--- 0.3235952854156494 seconds ---
# cross_check output:[47, 39, 10, 25, 14, 6, 45, 0] , weight:260.6262626262626
# Cross_check time--- 0.0008640289306640625 seconds ---
# ===================================================
# case:2993 ===>
# [6, 44, 19]
# avoiding edges:(44, 19), (6, 44)
# query output:[6, 45, 12, 37, 19] , weight:117.65656565656566
# Query time--- 1.81052565574646 seconds ---
# cross_check output:[6, 45, 12, 37, 19] , weight:117.65656565656566
# Cross_check time--- 0.0007135868072509766 seconds ---
# ===================================================
# case:2994 ===>
# Shortest path for (20, 18) not found in shortest_paths.
# case:2995 ===>
# [22, 24, 41, 26]
# avoiding edges:(24, 41), (41, 26)
# query output:[22, 9, 37, 12, 26] , weight:119.43434343434343
# Query time--- 0.8059709072113037 seconds ---
# cross_check output:[22, 9, 37, 12, 26] , weight:119.43434343434343
# Cross_check time--- 0.0007781982421875 seconds ---
# ===================================================
# case:2996 ===>
# case:2997 ===>
# [3, 8, 24, 22]
# avoiding edges:(3, 8), (8, 24)
# query output:[3, 22] , weight:51.13131313131313
# Query time--- 0.3364980220794678 seconds ---
# cross_check output:[3, 22] , weight:51.13131313131313
# Cross_check time--- 0.00018358230590820312 seconds ---
# ===================================================
# case:2998 ===>
# [14, 9, 22, 38]
# avoiding edges:(22, 38), (9, 22)
# query output:[] , weight:0
# Query time--- 0.002802133560180664 seconds ---
# No path exists between nodes 14 and 38 after removing edges (22, 38) and (9, 22).
# cross_check output:[] , weight:0
# Cross_check time--- 0.000736236572265625 seconds ---
# ===================================================
# case:2999 ===>
# [27, 36, 23, 16]
# avoiding edges:(27, 36), (36, 23)
# query output:[27, 18, 2, 37, 12, 21, 23, 16] , weight:181.8686868686869
# Query time--- 0.6727137565612793 seconds ---
# cross_check output:[27, 18, 2, 37, 12, 21, 23, 16] , weight:181.8686868686869
# Cross_check time--- 0.0011563301086425781 seconds ---
# ===================================================

# %% [markdown]
# *Debugging

# %%
print(f"right:{right}, wrong:{wrong}")
# Out:
# right:2297, wrong:0
