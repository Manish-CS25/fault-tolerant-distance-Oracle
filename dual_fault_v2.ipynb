# %% [markdown]
# \***\*============================GRAPH PREPROCESSING============================**

# %%
import networkx as nx
import matplotlib.pyplot as plt
import pickle
from random import randint
import time
import math
from math import isclose
import plotly.graph_objects as go
from itertools import combinations
from itertools import product

# %% [markdown]
# ### GRAPH PROCESSING

# %%
# # open preprocessing time file
# with open("processing_times.txt", "rb") as f:
#     pptime_file = f.read() 

# G_time = time.time()

# G = nx.Graph()

# # Read the file and create edges with random weights
# file_path = '../small_dataset.txt'  # Replace with the actual file path
# # edges = []
# with open(file_path, 'r') as file:
#     file_contents = file.readlines()
#     num_lines = len(file_contents)
#     print(f"Number of lines: {num_lines}")
#     for i, line in enumerate(file_contents):
#         node1, node2 = map(int, line.split())
#         weight = float(randint(1, 99)) + ((i+1) * (1 / (num_lines -1)))
#         G.add_edge(node1, node2, weight=weight)
        

# with open('graph.pkl', 'wb') as f:
#     pickle.dump(G, f)

# G_process_time = time.time() - G_time  
    


# d_time = time.time()    
# D = dict(nx.all_pairs_dijkstra_path_length(G, weight='weight'))
# with open('D.pkl', 'wb') as f:
#     pickle.dump(D, f)
    
# d_process_time = time.time() - d_time   


# with open('processing_times.txt', 'w') as time_file:
#     time_file.write(f"Graph processing time: {G_process_time:.6f} seconds\n")
#     time_file.write(f"Dijkstra processing time: {d_process_time:.6f} seconds\n")

# def store_shortest_paths(G):
#     # Use NetworkX's built-in function to compute all pairs shortest paths
#     all_pairs_paths = dict(nx.all_pairs_dijkstra_path(G, weight='weight'))
    
#     # Flatten the dictionary to match the desired output format
#     shortest_paths = {}
#     for u, paths in all_pairs_paths.items():
#         for v, path in paths.items():
#             shortest_paths[(u, v)] = path
    
#     return shortest_paths

# # Example usage

# st_time = time.time()   
# shortest_paths = store_shortest_paths(G)


# with open('shortest_paths.pkl', 'wb') as f:
#     pickle.dump(shortest_paths, f)
# st_process_time = time.time() - st_time
# with open('processing_times.txt', 'a') as time_file:
#     time_file.write(f"Shortest paths processing time: {st_process_time:.6f} seconds\n")

# %%
# def create_interactive_graph(G):
#     # Create a spring layout for node positions
#     pos = nx.spring_layout(G)
    
#     # Create edge traces
#     edge_x = []
#     edge_y = []
#     edge_text = []
#     edge_weights = []
    
#     for edge in G.edges():
#         x0, y0 = pos[edge[0]]
#         x1, y1 = pos[edge[1]]
#         edge_x.extend([x0, x1, None])
#         edge_y.extend([y0, y1, None])
#         weight = G.edges[edge]['weight']
#         edge_weights.append(weight)
#         edge_text.append(f"Weight: {int(weight)}")
    
#     edge_trace = go.Scatter(
#         x=edge_x, y=edge_y,
#         line=dict(width=2, color='#888'),
#         hoverinfo='text',
#         text=edge_text,
#         mode='lines+text',
#         textposition='middle center',
#         textfont=dict(size=10)
#     )
    
#     # Add edge weight annotations
#     annotations = []
#     for edge in G.edges():
#         x0, y0 = pos[edge[0]]
#         x1, y1 = pos[edge[1]]
#         weight = G.edges[edge]['weight']
#         annotations.append(dict(
#             x=(x0 + x1) / 2,
#             y=(y0 + y1) / 2,
#             xref='x',
#             yref='y',
#             text=str(int(weight)),
#             showarrow=False,
#             font=dict(size=10)
#         ))
    
#     # Create node traces
#     node_x = []
#     node_y = []
#     node_text = []
    
#     for node in G.nodes():
#         x, y = pos[node]
#         node_x.append(x)
#         node_y.append(y)
#         node_text.append(f"Node: {node}")
    
#     node_trace = go.Scatter(
#         x=node_x, y=node_y,
#         mode='markers+text',
#         hoverinfo='text',
#         text=[str(node) for node in G.nodes()],
#         textposition='middle center',
#         marker=dict(
#             showscale=False,
#             color='yellow',
#             size=40,
#             line_width=2,
#             line=dict(color='black', width=1)
#         ),
#         textfont=dict(size=12)
#     )
    
#     # Create the figure with larger size
#     fig = go.Figure(
#         data=[edge_trace, node_trace],
#         layout=go.Layout(
#             title='Interactive Graph Visualization',
#             showlegend=False,
#             hovermode='closest',
#             margin=dict(b=20, l=20, r=20, t=40),
#             xaxis=dict(showgrid=False, zeroline=False, showticklabels=False),
#             yaxis=dict(showgrid=False, zeroline=False, showticklabels=False),
#             plot_bgcolor='white',
#             width=1200,  # Increased width
#             height=800,  # Increased height
#             annotations=annotations
#         )
#     )
    
#     return fig

# # Create and display the interactive graph
# fig = create_interactive_graph(G)
# fig.show(figsize=(40, 40))

# %% [markdown]
# ### LOAD DATA STRUCTURE

# %%
# Load G , D and shortest_paths from the pickle files
with open('graph.pkl', 'rb') as f:
    G = pickle.load(f)
    
with open('D.pkl', 'rb') as f:
    D = pickle.load(f)
    
with open('shortest_paths.pkl', 'rb') as f:
    shortest_paths = pickle.load(f) 
    
with open('txu_dict.pkl', 'rb') as f:
    txu_dict = pickle.load(f) 

# load maximizer_dict from the local file   
with open('maximizer_dict.pkl', 'rb') as f:
    maximizer_dict = pickle.load(f)

# %% [markdown]
# ---------------------------------POWER_OF_2 FUNCTION--------------------------------

# %%
def floor_power_of_2(x):
    if x <= 0:
        return 0 # Return 1 for non-positive input
    elif math.isinf(x):
        return float("inf")  # Return infinity for infinite input
    else:
        return 2 ** math.floor(math.log2(x))

# %%
from math import isclose

def single_edge_in_path(p, F):
    if not p or len(p) < 2 or not F:
        return False

    s, t = p[0], p[-1]
    p_dist = D[s][t]

    def edge_on_path(u, v):
           
        wt = G[u][v]['weight']

        return (
            isclose(D[s][u] + wt + D[v][t], p_dist) or
            isclose(D[s][v] + wt + D[u][t], p_dist)
        )


    for edge in F:
        u, v = edge
        if edge_on_path(u, v):
            return True

    return False

# %% [markdown]
# --------------------------------FIND_JUMP FUNCTION--------------------------------

# %%
def FINDJUMP(P, F):
    X = []  # Initialie X
    if not P:
        return[]
    x = P[0]
    X.append(x)
    vertices = []
    for edge in F:
        u, v = edge
        vertices.append(u)
        vertices.append(v)
    vertices = list(set(vertices))

    while True:
        u = min(vertices, key=lambda v: floor_power_of_2(D[x][v]))
        
        distance= max(1, floor_power_of_2(D[x][u]))

        y = None
        for vertex in P[P.index(x) + 1:]:
            if D[x][vertex] >= distance:
                y = vertex
                break  
        if y is not None:
            X.append(y)
            x = y
        else:
            break
    return X

# %% [markdown]
# ### ------------------------------MAXIMIZER FUNCTION--------------------------------

# %%
def maximizer(G, x, y, d1, d2):
    G = G.copy()
    max_edges = set()
    edges_set = set()
    max_xy_edge = None
    max_xy_path = None
    max_xy_path_new = None


    if nx.has_path(G, x, y):
        path = shortest_paths[(x, y)]
        for i in range(len(path) - 1):
            u = path[i]
            v = path[i + 1]
            edges_set.add((u, v))

    for u, v in edges_set:
        # if get_distance_cached(x, u) >= d1 and get_distance_cached(y, v) >= d2:
        #     max_edges.add((u, v))
        if (D[x][u] >= d1 and D[y][v] >= d2) :
        
            max_edges.add((u, v))   

    max_xy_distance = float('-inf')
    for u, v in max_edges:
        edge_data = G.get_edge_data(u, v)
        # if G.has_edge(u, v):
        #     G.remove_edge(u, v)
        G.remove_edge(u, v)
        # D = preprocess_graph(G)
        # distance_oracle_new = DistanceOracle(D)
        if nx.has_path(G, x, y):
            xy_path = nx.dijkstra_path(G, x, y, weight='weight')
            max_uv_distance = sum(
                G[xy_path[j]][xy_path[j + 1]]['weight']
                for j in range(len(xy_path) - 1)
            )
            if max_uv_distance > max_xy_distance:
                max_xy_edge = (u, v)
                max_xy_path = xy_path
                max_xy_distance = max_uv_distance
        G.add_edge(u, v, **edge_data)   

    if max_xy_path is None or len(max_xy_path) < 2:
        return max_xy_edge, [max_xy_path] if max_xy_path else []

    s = 0  # Start index of current subpath
    max_xy_path_new = []
    deviation_found = False

    for i in range(len(max_xy_path) - 1):
        u = max_xy_path[s]
        v = max_xy_path[i + 1]
        
        # Direct shortest path distance
        uv_distance = D[u][v]   
        
        # Path distance along max_xy_path from u to v
        uv_path_distance = sum(
            G[max_xy_path[j]][max_xy_path[j + 1]]['weight']
            for j in range(s, i + 1)
        )
   
        
        # Check if path deviates from shortest path
        if uv_distance < uv_path_distance:
            deviation_found = True
            # Define nodes: s (start), a (before deviation), b (deviation), t (end)
            s_node = max_xy_path[0]  # Start node
            a = max_xy_path[i] if i > 0 else max_xy_path[0]  # Node before deviation
            b = v  # Deviation node
            t = max_xy_path[-1]  # End node
            # Construct the output: [[s, a], (a, b), [b, t]]
            s_to_a = [s_node, a]  # Exactly [s, a]
            a_to_b = (a, b)  # Edge from a to b
            b_to_t = [b, t]  # Exactly [b, t]
            max_xy_path_new = [s_to_a, a_to_b, b_to_t]
            break
    
    # If no deviation, return original path wrapped in a list
    if not deviation_found:
        max_xy_path_new = [max_xy_path]
    
    return max_xy_edge, max_xy_path_new

# %% [markdown]
# ### ==========MAXIMIZER Storage================

# %%
def find_max_distance(G, distance_oracle):
    max_distance = float("-inf")
    for key1, value1 in D.items():
        for key2, value2 in value1.items():
            if value2 > max_distance:
                max_distance = value2
    return max_distance

# %%
max_d_value = int(find_max_distance(G, D))
d1_d2_list = [0]
i = floor_power_of_2((max_d_value))


while i >= 1:
    d1_d2_list.append(i)
    i //= 2
# print(max_d_value)

# %% [markdown]
# ### Mximizer storing code

# %%
# import logging
# from tqdm import tqdm

# # Setup logging to file
# logging.basicConfig(filename='maximizer_progress.log', level=logging.INFO, 
#                     format='%(asctime)s %(levelname)s:%(message)s')

# maximizer_time = time.time()
# maximizer_dict = {}
# nodes = list(G.nodes())

# # Calculate total iterations for tqdm
# total = sum(1 for x in nodes for y in nodes if x != y) * len(d1_d2_list) * len(d1_d2_list)

# with tqdm(total=total, desc="Maximizer Progress") as pbar:
#     for x in nodes:
#         for y in nodes:
#             if x != y:
#                 for d1 in d1_d2_list:
#                     for d2 in d1_d2_list:
#                         max_xy_edge, max_xy_path_new = maximizer(G, x, y, d1, d2)
#                         msg = (f"pair: ({x}, {y}), d1: {d1}, d2: {d2}, "
#                                f"max_xy_edge: {max_xy_edge}, max_xy_path_new: {max_xy_path_new}")
#                         print(msg)
#                         logging.info(msg)
#                         maximizer_dict[(x, y, d1, d2)] = (max_xy_edge, max_xy_path_new)
#                         pbar.update(1)

# maximizer_process_time = time.time() - maximizer_time
# print(f"Maximizer processing time: {maximizer_process_time:.6f} seconds")
# logging.info(f"Maximizer processing time: {maximizer_process_time:.6f} seconds")
# with open('processing_times.txt', 'a') as time_file:
#     time_file.write(f"Maximizer processing Time without multiProcessing: {maximizer_process_time:.6f} seconds\n")

# %%
# import networkx as nx
# from concurrent.futures import ThreadPoolExecutor, as_completed
# import tqdm # Import tqdm to display a progress bar


# # Initialize a dictionary to store the maximizer output
# maximizer_dict = {}

# # Store the maximizer function reference directly
# maximizer_function = maximizer  # Replace 'maximizer' with the actual function name

# # Collect errors to print after the loop
# errors = []

# # Define a function to process a single pair of nodes
# def process_pair(G, x, y, d1, d2):
#     try:
#         result = maximizer_function(G, x, y, d1, d2)
#         if result is not None:
#             max_edge, max_path = result
#             return (x, y, d1, d2), (max_edge, max_path)
#     except nx.NetworkXNoPath:
#         return (x, y, d1, d2), None

# # Use ThreadPoolExecutor to parallelize the computation
# nodes = list(G.nodes)

# with ThreadPoolExecutor() as executor:
#     futures = []
#     for x in nodes:
#         for y in nodes:
#             if x != y:
#                 for d1 in d1_d2_list:
#                     for d2 in d1_d2_list:
#                         futures.append(executor.submit(process_pair, G, x, y, d1, d2))

#     for future in tqdm.tqdm(as_completed(futures), total=len(futures)):
#         key, result = future.result()
#         if result is not None:
#             maximizer_dict[key] = result
#         else:
#             errors.append(f"No path between {key[0]} and {key[1]} for d1: {key[2]}, d2: {key[3]}.")

# # Print all errors after the loop
# for error in errors:
#     print(error)

# with open('maximizer_dict.pkl', 'wb') as f:
#     pickle.dump(maximizer_dict, f)

# %% [markdown]
# ===============================MAIN: QUERY FUNCTION====================================

# %% [markdown]
# ### Stable Version

# %%
# from numpy import short


# def is_valid_path(G, path):
#     return all(G.has_edge(path[i], path[i + 1]) for i in range(len(path) - 1)) and (
#         len(path) < 2 or G.has_edge(path[-2], path[-1])
#     )
# def remove_duplicates(lst):
#     seen = set()
#     result = []
#     for item in lst:
#         if item not in seen:
#             seen.add(item)
#             result.append(item)
#     return result
# def QUERY(G, s, t, e):
#     if e == []:
#         try:
#             return shortest_paths[(s, t)]
#         except KeyError:
#             print(f"Shortest path for ({s}, {t}) not found in shortest_paths.")
#             return []
#         # return shortest_paths[(s, t)]
#     # Check if the edge e is in the graph
#     if isinstance(e, list):
#         e.u, e.v = e
#     if not (G.has_edge(e.u, e.v) or G.has_edge(e.v, e.u)):
#         # print("The edge to avoid is not in the graph.")
#         return shortest_paths[(s, t)]

#     # Check if there is a valid path between s and t
#     if shortest_paths[(s, t)] is None and shortest_paths[(t, s)] is None:
#         print("There is no valid path between the source and destination vertices.")
#         return [], float("inf")
#     # print(f"shortest_paths[(s,t)]={shortest_paths[(s, t)]}")
#     JUMP_st = FINDJUMP(shortest_paths[(s, t)], [e.u, e.v])
#     JUMP_ts = FINDJUMP(shortest_paths[(t, s)], [e.u, e.v])
#     # print(f"JUMP_st={JUMP_st}, JUMP_ts={JUMP_ts}")
#     final_shortest_path = []
#     shortest_path_distance = float("inf")
#     for x in JUMP_st:
#         for y in JUMP_ts:
#             if x == y:
#                 continue
#             # print(f"x={x}, y={y}")
#             vertices = [e.u, e.v]

#             d1 = min(nearest_power_of_2(D[x][a]) for a in vertices   )

#             d2 = min(nearest_power_of_2(D[y][a]) for a in vertices) 
#             # print(f"d1={d1}, d2={d2}")
#             e_star, xy_e_star = maximizer_dict[(x, y, d1, d2)]
#             # e_star, xy_e_star = maximizer(G , x, y, d1, d2)
            

#             if xy_e_star is None:
#                 xy_e_star = []
#             elif len(xy_e_star)> 2:
#                 # Flatten the list of lists
#                 xy_e_star = shortest_paths[(xy_e_star[0][0], xy_e_star[0][1])] + [xy_e_star[1][0]] + shortest_paths[(
#                     # print(f"xy_e_star={xy_e_star}")
#                     xy_e_star[2][0], xy_e_star[2][1])]
#             else: 
#                 xy_e_star = xy_e_star[0]
#             sx_path = shortest_paths[(s, x)]
#             yt_path = shortest_paths[(y, t)]
#             # print(f"sx_path={sx_path}, yt_path={yt_path}")
#             # if sx_path is None or yt_path is None:
#             #     continue  # Skip if there is no valid path from s to x or y to t
#             if sx_path is None:
#                 sx_path = [x]
#             if yt_path is None:
#                 yt_path = [y]
            
#             p_distance = float("inf")
#             P = sx_path + xy_e_star[1:-1] + yt_path
#             # P = remove_duplicates(sx_path + xy_e_star + yt_path)
            
#             # if y==s and xy_e_star != []:
#             #     P = xy_e_star[::-1] + shortest_paths[(x, t)]
#             #     if x==t:
#             #         P = xy_e_star[::-1] 
#             # elif xy_e_star != [] and D[s][y] < D[x][s]:
#             #     P = shortest_paths[(s, y)] + xy_e_star[::-1] + shortest_paths[(x, t)]
#             #     if s in xy_e_star and xy_e_star.index(s) > 0:
#             #         s_index  = xy_e_star[::-1].index(s) 
#             #         p1 = xy_e_star[::-1][s_index:]    
#             #         p2 = shortest_paths[(x, t)]
#             #         P = p1 + p2
#             P = remove_duplicates(P)
            
#             # print(f"P={P}")
#             if not is_valid_path(G, P):
#                 continue
            
#             if is_valid_path(G, P):
#                 p_distance = sum(
#                     get_edge_weight(G, P[i], P[i + 1]) for i in range(len(P) - 1)
#                 )

#             p_edges = [(P[i], P[i+1]) for i in range(len(P) - 1)]
#             if ((e.u , e.v) not in p_edges and (e.v , e.u) not in p_edges ) and (p_distance < shortest_path_distance):
#                     final_shortest_path = P
#                     # print(f"shortest_path1={final_shortest_path}")
#                     shortest_path_distance = p_distance
#     return final_shortest_path

# %% [markdown]
# ### BETA Version

# %%
def edge_in_fault_edge(F, e):
    for i in range(len(F)):
        if set((F[i][0], F[i][1])) == set(e):
            return True
    return False

# %%
def is_edge_on_shortest_path(G,  s, t, e):
    u , v = e
    # if not G.has_edge(u, v):
    #     return False
    wt = G[u][v]["weight"] 
    


    dst = D[s][t]

    return (
        isclose(D[s][u] + wt + D[v][t], dst) or
        isclose(D[s][v] + wt + D[u][t], dst)
    )


def QUERY(G, s, t, e):
    if e == []:
        try:
            return shortest_paths[(s, t)], D[s][t]
        except KeyError:
            print(f"Shortest path for ({s}, {t}) not found in shortest_paths.")
            return [], float("inf") 

    # Check if the edge e is in the graph
    # if isinstance(e, list):
    #     e.u, e.v = e
    eu = e[0][0]
    ev = e[0][1]

    # if not (G.has_edge(eu, ev) or G.has_edge(ev, eu)):
    #     return shortest_paths[(s, t)]

    # Check if there is a valid path between s and t
    if shortest_paths[(s, t)] is None :
        print("There is no valid path between the source and destination vertices.")
        return [], float("inf")

    if not is_edge_on_shortest_path(G, s, t , (eu, ev)):
        return shortest_paths[(s, t)], D[s][t]
    
    # print(f"shortest_paths[(s,t)]={shortest_paths[(s, t)]}")
    JUMP_st = FINDJUMP(shortest_paths[(s, t)], e)
    JUMP_ts = FINDJUMP(shortest_paths[(t, s)], e)

    # print(f"JUMP_st={JUMP_st}, JUMP_ts={JUMP_ts}")
    final_shortest_path = []
    shortest_path_distance = float("inf")
    P = []
    p_distance = float("inf")
    processed = set()
    for x in JUMP_st:
        for y in JUMP_ts:
            if x == y or (x, y) in processed:
                continue
            # print(f"x={x}, y={y}")
            # e is list of tuples make vertices list from it
            vertices = [edge[0] for edge in e] + [edge[1] for edge in e]

            d1 = min(floor_power_of_2(D[x][a]) for a in vertices)

            d2 = min(floor_power_of_2(D[y][a]) for a in vertices) 
            
            sx_path = shortest_paths[(s, x)]
            yt_path = shortest_paths[(y, t)]
            
            if single_edge_in_path(sx_path , e) or single_edge_in_path(yt_path , e):
                continue    
            
            
            # print(f"d1={d1}, d2={d2}")
            e_star, xy_e_star = maximizer_dict[(x, y, d1, d2)]
            # e_star, xy_e_star = maximizer(G , x, y, d1, d2)
                        

            if xy_e_star is None or xy_e_star == []:
                xy_e_star = []
            elif len(xy_e_star)> 2 :
                # Flatten the list of lists
                sa = shortest_paths[(xy_e_star[0][0], xy_e_star[0][1])]
                ab = xy_e_star[1]
                bt = shortest_paths[(xy_e_star[2][0], xy_e_star[2][1])] if xy_e_star[2][0] != xy_e_star[2][1] else [xy_e_star[2][0]]
                if edge_in_fault_edge(e, ab) or single_edge_in_path(sa, e) or single_edge_in_path(bt, e):
                    continue
                # print(f"xy_e_star={xy_e_star}")
                xy_e_star_path = sa + bt
                xy_e_star_path_distance = D[sa[0]][sa[-1]] +G[ab[0]][ab[1]]['weight'] + (D[bt[0]][bt[-1]] if bt != [] else 0)
  

            else:
                xy_e_star_path = xy_e_star[0]
                xy_e_star_path_distance = D[0][xy_e_star[-1]]



            
            if xy_e_star != []:
                P = sx_path + xy_e_star_path[1:-1] + yt_path
                p_distance = D[s][x] + xy_e_star_path_distance + D[y][t]

            P = list(dict.fromkeys(P))
            if (p_distance < shortest_path_distance):
                    final_shortest_path = P
                    shortest_path_distance = p_distance
    return final_shortest_path , shortest_path_distance

# %% [markdown]
# ### SINGLE FAULT TESTING

# %%
  
def cross_check(G, s, t, e_u, e_v):
    G_copy = G.copy()
    edge_exists = G_copy.has_edge(e_u, e_v)
    if edge_exists:
        edge_data = G_copy.get_edge_data(e_u, e_v)
        G_copy.remove_edge(e_u, e_v)
        # print(f"Removed edge ({e_u}, {e_v}) from the graph.")
        
    if not nx.has_path(G_copy, s, t):
        # print("No path exists between the source and destination vertices.")
        return [] , float("inf")

    wt_st , st_path   = nx.single_source_dijkstra(G_copy, s, t, weight='weight')


    
    return st_path , wt_st

# %%
import random   
import time
import numpy as np  


    
   
print("=================Single fault Query test=====================") 

test_failed =0
test_passed =0

query_time = []
naive_query_time = []

for i in range(200):
    # print(f"Test {i+1}:")

    s = random.randint(0, 49)
    t = random.randint(0, 49)
    if s == t:
        t = (t + 1) % 50
    if (s, t) not in shortest_paths:
        continue
    p_edges = [(shortest_paths[(s, t)][i], shortest_paths[(s, t)][i + 1]) for i in range(len(shortest_paths[(s, t)]) - 1)]
    
    # select one edge 
    e_u , e_v = random.choice(p_edges)
    
    
    e = [(e_u, e_v)]
    # print(f"Source: {s}, Destination: {t}, Edge to avoid: {e_u}-{e_v}")
    Q_time = time.time()
    
    P1 , wp1 = QUERY(G , s, t, e)

    Q_time = time.time() - Q_time
    
  
    
    C_time = time.time()
    P2 , wp2 = cross_check(G, s, t, e_u, e_v)
    C_time = time.time() - C_time

    # print(P1 , wp1)
    # print(f"QUERY time: {Q_time:.6f} seconds")
    # print(P2 , wp2)
    # print(f"Cross-check time: {C_time:.6f} seconds")
    
    if P1 != P2:
        test_failed +=1
        
        print("Paths dont match.")
        print(f"shortest st path: {shortest_paths[(s, t)]}")    
        print(f"Source: {s}, Destination: {t}, Edge to avoid: {e_u}-{e_v}")
        print(P1 , wp1)
        print(f"QUERY time: {Q_time:.6f} seconds")
        print(P2 , wp2)
        print(f"Cross-check time: {C_time:.6f} seconds")
        print("=========================================================")
    
    else:
         test_passed +=1
    #     print(f"shortest st path: {shortest_paths[(s, t)]}")    
    #     print(f"Source: {s}, Destination: {t}, Edge to avoid: {e_u}-{e_v}")
    #     print(P1 , wp1)
    #     print(f"QUERY time: {Q_time:.6f} seconds")
    #     print(P2 , wp2)
    #     print(f"Cross-check time: {C_time:.6f} seconds")
    #     return print("***********************Paths do not match*****************************.\n")
    query_time.append(Q_time)
    naive_query_time.append(C_time)


print(f"Graph with {len(G.nodes())} Nodes and {len(G.edges())} Edges")
print(f"no. of test-case passed :{test_passed}")
print(f"no. of test-case failed :{test_failed}")

print("=====================================================================")
# Convert seconds to milliseconds
query_time_ms = [t * 1_000 for t in query_time]
naive_query_time_ms = [t * 1_000 for t in naive_query_time]

# Compute statistics
average_query_time = np.mean(query_time_ms)


average_naive_time = np.mean(naive_query_time_ms)
max_query_time = np.max(query_time_ms)
max_naive_time = np.max(naive_query_time_ms)
print(f"Average QUERY time: {average_query_time:.6f} milliseconds")
print(f"Average Cross-check time: {average_naive_time:.6f} milliseconds")
print(f"Maximum QUERY time: {max_query_time:.6f} milliseconds")
print(f"Maximum Cross-check time: {max_naive_time:.6f} milliseconds")
# Out:
# =================Single fault Query test=====================
# Graph with 47 Nodes and 100 Edges
# no. of test-case passed :173
# no. of test-case failed :0
# =====================================================================
# Average QUERY time: 0.236451 milliseconds
# Average Cross-check time: 0.812438 milliseconds
# Maximum QUERY time: 1.390457 milliseconds
# Maximum Cross-check time: 2.541065 milliseconds

# %%
import matplotlib.pyplot as plt
import numpy as np

# # Convert seconds to milliseconds
# query_time_ms = [t * 1_000 for t in query_time]
# naive_query_time_ms = [t * 1_000 for t in naive_query_time]

# # Compute statistics
# average_query_time = np.mean(query_time_ms)
# average_naive_time = np.mean(naive_query_time_ms)
# max_query_time = np.max(query_time_ms)
# max_naive_time = np.max(naive_query_time_ms)

# Create plot with access to axes
fig, ax = plt.subplots(figsize=(16, 9))
ax.plot(query_time_ms, label='QUERY Time (ms)', color='blue', linewidth=2)
ax.plot(naive_query_time_ms, label='Cross-check Time (ms)', color='orange', linewidth=2)
ax.set_xlabel("Test Case Index", fontsize=14)
ax.set_ylabel("Time (milliseconds)", fontsize=14)
ax.set_title("QUERY vs Cross-check (Naive) Time for Shortest Path with Single Edge Fault", fontsize=16)
ax.legend(fontsize=12)
ax.grid(True)

# Add stats text box above the plot
stats_text = (
    f"Graph with {len(G.nodes())} Nodes and {len(G.edges())} Edges | "
    f"Avg QUERY: {average_query_time:.2f} ms | "
    f"Avg Naive: {average_naive_time:.2f} ms | "
    f"Max QUERY: {max_query_time:.2f} ms | "
    f"Max Naive: {max_naive_time:.2f} ms"
)
ax.text(0.5, 1.05, stats_text, transform=ax.transAxes,
        ha='center', va='bottom', fontsize=12,
        bbox=dict(boxstyle="round,pad=0.4", edgecolor='black', facecolor='lightyellow'))

# Adjust layout to fit text
plt.subplots_adjust(top=0.88)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### -----------------2-Fault Distance Oracle----------------

# %% [markdown]
# ### Basic Function

# %%
def intact_from_failure_path(path, F):
    if path is None:
        return True
    if len(path)==1:
        return True

    path_dist = D[path[0]][path[-1]]

    if len(F) == 0:
        return True


    for edge in F:
        u, v = edge[0], edge[1]
        wt = G[u][v]["weight"] 

        if (
            isclose(D[path[0]][u] + wt + D[path[-1]][v], path_dist) or
            isclose(D[path[0]][v] + wt + D[path[-1]][u], path_dist)
        ):
            return False

    return True





def intact_from_failure_tree(T, F):
    # Check if F is empty
    if T is None:
        # print("bfs_tree_of_S_rooted_x returned None")
        return True
    if not F:
        return True


    # Check if any vertex in F is in the tree T
    for edge in F:
        # Unpack edge into u and v
        u, v = edge[0], edge[1]

        if u in T or v in T:
            return False

    return True

# %% [markdown]
# ### Sequential VS Parallel Processing

# %%
# import time
# from multiprocessing import Pool, cpu_count



# # Task function for parallel processing
# def process_combination(args):
#     G, x, y, d1, d2 = args
#     max_xy_edge, max_xy_path_new = maximizer1(G, x, y, d1, d2)
#     msg = (f"pair: ({x}, {y}), d1: {d1}, d2: {d2}, "
#            f"max_xy_edge: {max_xy_edge}, max_xy_path_new: {max_xy_path_new}")
#     return msg

# # Generate first 1000 valid combinations
# def get_combinations(G, nodes, d1_d2_list, max_items=1000):
#     combos = []
#     for x in nodes:
#         for y in nodes:
#             if x != y:
#                 for d1 in d1_d2_list:
#                     for d2 in d1_d2_list:
#                         combos.append((G, x, y, d1, d2))
#                         if len(combos) >= max_items:
#                             return combos
#     return combos

# # Sequential execution
# def run_sequential(combos):
#     start = time.time()
#     for combo in combos:
#         msg = process_combination(combo)
#         # print(msg)
#     end = time.time()
#     return end - start

# # Parallel execution
# def run_parallel(combos, workers=cpu_count()):
#     start = time.time()
#     with Pool(processes=workers) as pool:
#         results = pool.map(process_combination, combos)
#     # for msg in results:
#     #     print(msg)
#     end = time.time()
#     return end - start

# # Entry point
# if __name__ == "__main__":
#     # Simulated graph and data
#     with open('graph.pkl', 'rb') as f:
#         G = pickle.load(f)  
#     # Generate combinations
#     nodes = list(G.nodes()) 
#     combos = get_combinations(G, nodes, d1_d2_list, max_items=1000)

#     print("\nRunning sequentially...")
#     seq_time = run_sequential(combos)
#     print(f"\nSequential time: {seq_time:.2f} seconds")

#     print("\nRunning with multiprocessing...")
#     par_time = run_parallel(combos, workers=64)
#     print(f"\nParallel time: {par_time:.2f} seconds")

#     if par_time > 0:
#         print(f"\nSpeedup: {seq_time / par_time:.2f}x")

# %% [markdown]
# ### Maximizer Functions

# %%
def maximizer1(G, x, y, d1, d2):

    max_xy_edge = None
    max_xy_path = None
    max_xy_distance = float("-inf")
    max_xy_path_new = None

    possible_edges = combinations(G.edges, 2)
    
    for F_star in possible_edges:

        eu , ev = F_star[0]
        eu1 , ev1 = F_star[1]

        if (
            (D[x][eu1] >= d1 and D[x][eu] >= d1 and D[x][ev1] >= d1 and D[x][ev] >= d1)
            and ( D[y][ev1] >= d2 and  D[y][ev] >= d2 and D[y][eu1] >= d2 and D[y][eu] >= d2)
        ):  
            
            edge1_data = G.get_edge_data(eu , ev)
            edge2_data = G.get_edge_data(eu1, ev1)
            G.remove_edge(eu, ev)
            G.remove_edge(eu1, ev1)
            if not nx.has_path(G, x, y):
                G.add_edge(eu1, ev1, **edge2_data)
                G.add_edge(eu , ev , **edge1_data)
                continue
                
            path2_distance , path2 = nx.single_source_dijkstra(G, x, y, weight='weight')

            if path2_distance > max_xy_distance:
                max_xy_edge = [(eu, ev), (eu1, ev1)]
                max_xy_path = path2
                max_xy_distance = path2_distance
            G.add_edge(eu, ev, **edge1_data)
            G.add_edge(eu1, ev1, **edge2_data)


    if max_xy_path is None or len(max_xy_path) < 2:
        return max_xy_edge, []

    s = 0  # Start index of current subpath
    max_xy_path_new = []
    deviations_found = 0  # Counter for deviations

    i = 0
    while i < len(max_xy_path) - 1 and deviations_found < 2:
        u = max_xy_path[s]
        v = max_xy_path[i + 1]
        
        # Direct shortest path distance
        uv_distance = D[u][v]
        
        # Path distance along max_xy_path from u to v
        uv_path_distance = sum(
            G[max_xy_path[j]][max_xy_path[j + 1]]['weight']
            for j in range(s, i + 1)
        )
      
        
        # Check if path deviates from shortest path
        if uv_distance < uv_path_distance:
            deviations_found += 1
            # Define nodes for the deviation
            s_node = max_xy_path[s]  # Start of current subpath
            a = max_xy_path[i] if i > s else s_node  # Node before deviation
            b = v  # Deviation node
            
            if deviations_found == 1:
                # First deviation: store [s, a], (a, b)
                first_s_to_a = [s_node, a]  # Subpath from start to a
                first_a_to_b = (a, b)  # First deviating edge
                # Update start index to b for next subpath
                s = i + 1
            elif deviations_found == 2:
                # Second deviation: store [b_prev, c], (c, d), [d, t]
                # b_prev is the b from the first deviation
                c = a  # Node before second deviation
                d = b  # Second deviation node
                t = max_xy_path[-1]  # End node
                b_to_c = [first_a_to_b[1], c]  # Subpath from first b to c
                c_to_d = (c, d)  # Second deviating edge
                d_to_t = [d, t]  # Subpath from d to t
                # Construct the full output
                max_xy_path_new = [first_s_to_a, first_a_to_b, b_to_c, c_to_d, d_to_t]
                break
        
        i += 1
    
    # If fewer than 2 deviations were found
    if deviations_found < 2:
        if deviations_found == 1:
            # Only one deviation: construct [s, a], (a, b), [b, t]
            t = max_xy_path[-1]
            b_to_t = [first_a_to_b[1], t]
            max_xy_path_new = [first_s_to_a, first_a_to_b, b_to_t]
        else:
            # No deviations: return original path wrapped in a list
            max_xy_path_new = [max_xy_path[0], max_xy_path[-1]] 
    
    return max_xy_edge, max_xy_path_new

# %%
from itertools import combinations

def maximizer21(G, x, y, d1, V):
    G = G.copy()
    max_xy_edge = None
    max_xy_path = None
    max_xy_distance = float("-inf")
    max_xy_path_new = None


    possible_edges = combinations(list(G.edges) , 2)
    for F_star in possible_edges:
        eu , ev = F_star[0];
        eu1 , ev1 = F_star[1]
        if (
            # nx.has_path(G, x, eu1)
            # and nx.has_path(G, y, ev1)
            # and 
            (
                D[x][eu1] >= d1  and D[x][eu] >= d1 and D[x][ev1] >= d1 and D[x][ev] >= d1
            )
            and intact_from_failure_path(shortest_paths[(V, y)], F_star)
            and intact_from_failure_tree(txu_dict[(y, V)], F_star)
        ):
            edge1_data = G.get_edge_data(eu, ev)    
            edge2_data = G.get_edge_data(eu1, ev1)
            
            G.remove_edge(eu, ev)
            G.remove_edge(eu1, ev1) 
            if not nx.has_path(G, x, y):
                G.add_edge(eu, ev, **edge1_data)
                G.add_edge(eu1, ev1, **edge2_data)
                continue

            path2_distance, path2 = nx.single_source_dijkstra(G, x, y, weight='weight') 
            if path2_distance > max_xy_distance:
                max_xy_edge = [(eu, ev), (eu1, ev1)]
                max_xy_path = path2
                max_xy_distance = path2_distance

            G.add_edge(eu1, ev1, **edge2_data)
            G.add_edge(eu, ev, **edge1_data)

    if max_xy_path is None or len(max_xy_path) < 2:
        return max_xy_edge, []

    s = 0  # Start index of current subpath
    max_xy_path_new = []
    deviations_found = 0  # Counter for deviations

    i = 0
    while i < len(max_xy_path) - 1 and deviations_found < 2:
        u = max_xy_path[s]
        v = max_xy_path[i + 1]
        
        # Direct shortest path distance
        uv_distance = D[u][v]   
        
        # Path distance along max_xy_path from u to v
        uv_path_distance = sum(
            G[max_xy_path[j]][max_xy_path[j + 1]]['weight']
            for j in range(s, i + 1)
        )

        
        # Check if path deviates from shortest path
        if uv_distance < uv_path_distance:
            deviations_found += 1
            # Define nodes for the deviation
            s_node = max_xy_path[s]  # Start of current subpath
            a = max_xy_path[i] if i > s else s_node  # Node before deviation
            b = v  # Deviation node
            
            if deviations_found == 1:
                # First deviation: store [s, a], (a, b)
                first_s_to_a = [s_node, a]  # Subpath from start to a
                first_a_to_b = (a, b)  # First deviating edge
                # Update start index to b for next subpath
                s = i + 1
            elif deviations_found == 2:
                # Second deviation: store [b_prev, c], (c, d), [d, t]
                # b_prev is the b from the first deviation
                c = a  # Node before second deviation
                d = b  # Second deviation node
                t = max_xy_path[-1]  # End node
                b_to_c = [first_a_to_b[1], c]  # Subpath from first b to c
                c_to_d = (c, d)  # Second deviating edge
                d_to_t = [d, t]  # Subpath from d to t
                # Construct the full output
                max_xy_path_new = [first_s_to_a, first_a_to_b, b_to_c, c_to_d, d_to_t]
                break
        
        i += 1
    
    # If fewer than 2 deviations were found
    if deviations_found < 2:
        if deviations_found == 1:
            # Only one deviation: construct [s, a], (a, b), [b, t]
            t = max_xy_path[-1]
            b_to_t = [first_a_to_b[1], t]
            max_xy_path_new = [first_s_to_a, first_a_to_b, b_to_t]
        else:
            # No deviations: return original path wrapped in a list
            max_xy_path_new = [max_xy_path[0], max_xy_path[-1]] 
    
    return max_xy_edge, max_xy_path_new

# %%
def maximizer2(G, x, y, V, d2):
    G = G.copy()

    max_xy_edge = None
    max_xy_path = None
    max_xy_distance = float("-inf")
    max_xy_path_new = []


    possible_edges = combinations(list(G.edges) , 2);
    for F_star in possible_edges:
        eu , ev = F_star[0]
        eu1 , ev1 = F_star[1]
 
        Vx_path = shortest_paths[(V, x)]
        txV = txu_dict[(x, V)]  
        if (
            # nx.has_path(G, x, eu1)
            # and nx.has_path(G, y, ev1)
            # and 
            (
                D[y][ev1] >= d2  and D[y][ev] >= d2 and D[y][ev1] >= d2 and D[y][ev] >= d2
            )
            and (intact_from_failure_path(Vx_path, F_star)
            and intact_from_failure_tree(txV, F_star))
        ):  
            edge1_data = G.get_edge_data(eu , ev)
            edge2_data = G.get_edge_data(eu1, ev1)
            G.remove_edge(eu, ev)
            G.remove_edge(eu1, ev1)
            if not nx.has_path(G, x, y):
                G.add_edge(eu1, ev1, **edge2_data)
                G.add_edge(eu, ev, **edge1_data)
                continue

            path2_distance, path2 = nx.single_source_dijkstra(G, x, y, weight='weight')
            if path2_distance > max_xy_distance:
                max_xy_edge = [(eu, ev), (eu1, ev1)]
                max_xy_path = path2
                max_xy_distance = path2_distance

            G.add_edge(eu1, ev1, **edge2_data)

            G.add_edge(eu, ev, **edge1_data)

    if max_xy_path is None or len(max_xy_path) < 2:
        return max_xy_edge, []

    s = 0  # Start index of current subpath
    max_xy_path_new = []
    deviations_found = 0  # Counter for deviations

    i = 0
    while i < len(max_xy_path) - 1 and deviations_found < 2:
        u = max_xy_path[s]
        v = max_xy_path[i + 1]
        
        # Direct shortest path distance
        uv_distance = D[u][v]
        
        # Path distance along max_xy_path from u to v
        uv_path_distance = sum(
            G[max_xy_path[j]][max_xy_path[j + 1]]['weight']
            for j in range(s, i + 1)
        )
 
        
        # Check if path deviates from shortest path
        if uv_distance < uv_path_distance:
            deviations_found += 1
            # Define nodes for the deviation
            s_node = max_xy_path[s]  # Start of current subpath
            a = max_xy_path[i] if i > s else s_node  # Node before deviation
            b = v  # Deviation node
            
            if deviations_found == 1:
                # First deviation: store [s, a], (a, b)
                first_s_to_a = [s_node, a]  # Subpath from start to a
                first_a_to_b = (a, b)  # First deviating edge
                # Update start index to b for next subpath
                s = i + 1
            elif deviations_found == 2:
                # Second deviation: store [b_prev, c], (c, d), [d, t]
                # b_prev is the b from the first deviation
                c = a  # Node before second deviation
                d = b  # Second deviation node
                t = max_xy_path[-1]  # End node
                b_to_c = [first_a_to_b[1], c]  # Subpath from first b to c
                c_to_d = (c, d)  # Second deviating edge
                d_to_t = [d, t]  # Subpath from d to t
                # Construct the full output
                max_xy_path_new = [first_s_to_a, first_a_to_b, b_to_c, c_to_d, d_to_t]
                break
        
        i += 1
    
    # If fewer than 2 deviations were found
    if deviations_found < 2:
        if deviations_found == 1:
            # Only one deviation: construct [s, a], (a, b), [b, t]
            t = max_xy_path[-1]
            b_to_t = [first_a_to_b[1], t]
            max_xy_path_new = [first_s_to_a, first_a_to_b, b_to_t]
        else:
            # No deviations: return original path wrapped in a list
            max_xy_path_new = [max_xy_path[0], max_xy_path[-1]] 
    
    return max_xy_edge, max_xy_path_new

# %%
def maximizer3(G, x, y, U, V):
    G = G.copy()    

    max_xy_edge = None
    max_xy_path = None
    max_xy_distance = float("-inf")
    max_xy_path_new = []
    

    possible_edges = combinations(list(G.edges) , 2)

    for F_star in possible_edges:
        eu , ev = F_star[0]
        eu1 , ev1 = F_star[1]
        xu_path = shortest_paths[(x, U)]
        vy_path = shortest_paths[(V, y)]
        bfsTree_txu = txu_dict[(x, U)]
        bfsTree_tyv = txu_dict[(y, V)]

        
        if (
            # nx.has_path(G, x, eu1)
            # and nx.has_path(G, y, ev1)
            # and
            (intact_from_failure_path(xu_path, F_star)
            and intact_from_failure_tree(bfsTree_txu, F_star))
            and ((intact_from_failure_path(vy_path, F_star)
            and intact_from_failure_tree(bfsTree_tyv, F_star)))
        ):  
            
            edge1_data = G.get_edge_data(eu, ev)
            edge2_data = G.get_edge_data(eu1, ev1)
            G.remove_edge(eu, ev)
            G.remove_edge(eu1, ev1)
            if not nx.has_path(G, x, y):
                G.add_edge(eu, ev, **edge1_data)
                G.add_edge(eu1, ev1, **edge2_data)
                continue
            


            path2_distance, path2 = nx.single_source_dijkstra(G, x, y, weight='weight') 
            if path2_distance > max_xy_distance:
                max_xy_edge = [(eu, ev), (eu1, ev1)]
                max_xy_path = path2
                max_xy_distance = path2_distance
            G.add_edge(eu1, ev1, **edge2_data)
            G.add_edge(eu, ev, **edge1_data)

    if max_xy_path is None or len(max_xy_path) < 2:
        return max_xy_edge, []

    s = 0  # Start index of current subpath
    max_xy_path_new = []
    deviations_found = 0  # Counter for deviations

    i = 0
    while i < len(max_xy_path) - 1 and deviations_found < 2:
        u = max_xy_path[s]
        v = max_xy_path[i + 1]
        
        # Direct shortest path distance
        uv_distance = D[u][v]
        
        # Path distance along max_xy_path from u to v
        uv_path_distance = sum(
            G[max_xy_path[j]][max_xy_path[j + 1]]['weight']
            for j in range(s, i + 1)
        )

        
        # Check if path deviates from shortest path
        if uv_distance < uv_path_distance:
            deviations_found += 1
            # Define nodes for the deviation
            s_node = max_xy_path[s]  # Start of current subpath
            a = max_xy_path[i] if i > s else s_node  # Node before deviation
            b = v  # Deviation node
            
            if deviations_found == 1:
                # First deviation: store [s, a], (a, b)
                first_s_to_a = [s_node, a]  # Subpath from start to a
                first_a_to_b = (a, b)  # First deviating edge
                # Update start index to b for next subpath
                s = i + 1
            elif deviations_found == 2:
                # Second deviation: store [b_prev, c], (c, d), [d, t]
                # b_prev is the b from the first deviation
                c = a  # Node before second deviation
                d = b  # Second deviation node
                t = max_xy_path[-1]  # End node
                b_to_c = [first_a_to_b[1], c]  # Subpath from first b to c
                c_to_d = (c, d)  # Second deviating edge
                d_to_t = [d, t]  # Subpath from d to t
                # Construct the full output
                max_xy_path_new = [first_s_to_a, first_a_to_b, b_to_c, c_to_d, d_to_t]
                break
        
        i += 1
    
    # If fewer than 2 deviations were found
    if deviations_found < 2:
        if deviations_found == 1:
            # Only one deviation: construct [s, a], (a, b), [b, t]
            t = max_xy_path[-1]
            b_to_t = [first_a_to_b[1], t]
            max_xy_path_new = [first_s_to_a, first_a_to_b, b_to_t]
        else:
            # No deviations: return original path wrapped in a list
            max_xy_path_new = [max_xy_path[0], max_xy_path[-1]] 
    
    return max_xy_edge, max_xy_path_new

# %% [markdown]
# ### Load Maximizers from Local files

# %%
# load all maximizer_dict
with open('maximizer_dict1.pkl', 'rb') as f:
    maximizer_dict1 = pickle.load(f)
with open('maximizer_dict21.pkl', 'rb') as f:
    maximizer_dict21 = pickle.load(f)
with open('maximizer_dict2.pkl', 'rb') as f:
    maximizer_dict2 = pickle.load(f)
with open('maximizer_dict3.pkl', 'rb') as f:
    maximizer_dict3 = pickle.load(f)

# %% [markdown]
# =====================================Findpath Function=============================

# %%
def FINDPATHS(G, s, t, F2):
    """
    Optimized version of FINDPATHS to find paths while avoiding specific edges.
    """
    F_prime = []
    P = []
    f = len(F2)

    for i in range(1, f + 1):
        # Determine the path P_i based on F_prime
        if F_prime:
            u, v = F_prime[i - 2][0] , F_prime[i - 2][1]
            P_i, Pi_wt = QUERY(G, s, t, [(u, v)])
        else:
            P_i, Pi_wt = shortest_paths[(s, t)] , D[s][t]

        P.append(P_i)

        # Skip if no valid path is found
        if not P_i:
            continue

        # Calculate the weight of the current path
        weight_p_i = Pi_wt  

        # Update F2 by removing the last edge in F_prime
        if F_prime:

            F2 =  list(set(F2) - set(F_prime))

        # Iterate through edges in F2 to find matching edges
        for e1 in F2:
            # Ensure e1.u is the smaller vertex
            if D[s][e1[0]] > D[s][e1[1]]:
                u, v = (e1[1], e1[0])
            else:
                u, v = (e1[0], e1[1])

            # Query subpaths R1 and R2
            if F_prime:
                R1, weight_R1 = QUERY(G, s, u, [(u, v)])
                R2, weight_R2 = QUERY(G, v, t,  [(u, v)])

            else:
                R1, weight_R1 = shortest_paths[(s, u)], D[s][u]
                R2, weight_R2 = shortest_paths[(v, t)], D[v][t]


            # Calculate weights of R1, R2, and the edge e1
         
            weight_e = G[u][v]['weight']

            # Check if the combined weight matches the path weight
            if isclose(weight_p_i, weight_R1 + weight_R2 + weight_e):
                F_prime.append(e1)
                break
        else:
            # If no matching edge is found, return the paths found so far
            return P

    return P

# %% [markdown]
# ===================================Find Intermediate Functions =================================

# %%
def FIND_INTERMEDIATE3(G, x, y, u, v, F):
    """
    Optimized version of FIND_INTERMEDIATE3 to find the path and intermediate vertices.
    """
    # Retrieve F_star and xy_F_star from the dictionary
    F_star, xy_F_star = maximizer_dict3.get((x, y, u, v), (None, None))
    
    # If no valid F_star, return the shortest path and an empty list
    if not F_star or not xy_F_star or xy_F_star==[]:    
        return ([], 0), []
    # Check if F_star is empty
    # Initialize variables
    direct_path = []
    direct_path_distance = float("inf")
    PATH = []
    INTERMEDIATE = []
    path_distance = float("inf")

    # Check for a direct path
    if any((edge[0] == x and edge[1] == y) or (edge[0] == y and edge[1] == x) for edge in F_star):
        direct_path = [x, y]
        direct_path_distance = G[x][y]["weight"]

        
        
    if len(xy_F_star) == 5:
        xa = shortest_paths[(xy_F_star[0][0], xy_F_star[0][1])] #segment1
        ab = xy_F_star[1]   #intermediate edge1
        bc = shortest_paths[(xy_F_star[2][0], xy_F_star[2][1])] #segment2
        cd = xy_F_star[3]  #intermediate edge2
        dy = shortest_paths[(xy_F_star[4][0], xy_F_star[4][1])] if xy_F_star[4][0]!=xy_F_star[4][1] else [] #segment3
        if not single_edge_in_path(xa, F) and not single_edge_in_path(bc, F) and not single_edge_in_path(dy, F) and not edge_in_fault_edge(F, ab) and  not edge_in_fault_edge(F, cd):
            PATH = xa + [ab[1]] + bc[1:] + [cd[1]] + (dy[1:] if len(dy) > 1 else [])
            path_distance = D[xa[0]][xa[-1]] + G[ab[0]][ab[1]]["weight"] + D[bc[0]][bc[-1]] + G[cd[0]][cd[1]]["weight"] + (D[dy[0]][dy[-1]] if len(dy) > 1 else 0)
    

    elif len(xy_F_star) == 3:
        xa = shortest_paths[(xy_F_star[0][0], xy_F_star[0][1])] 
        ab = xy_F_star[1]
        by = shortest_paths[(xy_F_star[2][0], xy_F_star[2][1])] if xy_F_star[2][0]!=xy_F_star[2][1] else []
        if not single_edge_in_path(xa, F) and not single_edge_in_path(by, F) and not edge_in_fault_edge(F, ab):
            PATH = xa + [ab[1]] + (by[1:] if len(by) > 1 else [])
            path_distance = D[xa[0]][xa[-1]] + G[ab[0]][ab[1]]["weight"] + (D[by[0]][by[-1]] if len(by) > 1 else 0)
        

    else:
        xy = shortest_paths[(xy_F_star[0] , xy_F_star[1])]
        if not single_edge_in_path(xy, F):
            PATH = xy
            path_distance = D[xy[0]][xy[-1]]


    if direct_path and direct_path_distance < path_distance and not single_edge_in_path(direct_path, F):
        PATH = direct_path
        path_distance = direct_path_distance
 
        
   
    # Process vertices in F_star
    F_star_vertices = {vertex for edge in F_star for vertex in edge}
    for z in F_star_vertices:
        # Check if z satisfies the conditions of an intermediate vertex
        xz = shortest_paths[(x, z)]
        zy = shortest_paths[(z, y)]
        if single_edge_in_path(xz, F) and single_edge_in_path(zy, F):
            INTERMEDIATE.append(z)

    # Remove duplicate intermediate vertices
    INTERMEDIATE = list(set(INTERMEDIATE))

    return (PATH, path_distance), INTERMEDIATE

# %%
def FIND_INTERMEDIATE2(G, x, y, u, F):
    """
    Optimized version of FIND_INTERMEDIATE2 to find the path and intermediate vertices.
    """
    # Extract vertices from edges in F
    vertices = {edge[0] for edge in F}.union({edge[1] for edge in F})

    # Calculate d2
    d2 = min(floor_power_of_2(D[y][b]) for b in vertices)

    # Initialize variables
    direct_path = []
    direct_path_distance = float("inf")
    PATH = []
    path_distance = float("inf")
    INTERMEDIATE = []

    # Retrieve F_star and xy_F_star
    F_star, xy_F_star = maximizer_dict2.get((x, y, u, d2), (None, None))
    if not F_star or not xy_F_star or xy_F_star == []:
        return shortest_paths[(x, y)], []

    # Check for direct path
    for edge in F_star:
        if (edge[0] == x and edge[1] == y) or (edge[0] == y and edge[1] == x):
            direct_path = [x, y]
            direct_path_distance = G[x][y]["weight"]


    if len(xy_F_star) == 5:
        xa = shortest_paths[(xy_F_star[0][0], xy_F_star[0][1])] #segment1
        ab = xy_F_star[1]   #intermediate edge1
        bc = shortest_paths[(xy_F_star[2][0], xy_F_star[2][1])] #segment2
        cd = xy_F_star[3]  #intermediate edge2
        dy = shortest_paths[(xy_F_star[4][0], xy_F_star[4][1])] if xy_F_star[4][0]!=xy_F_star[4][1] else [] #segment3
        if not single_edge_in_path(xa, F) and not single_edge_in_path(bc, F) and not single_edge_in_path(dy, F) and not edge_in_fault_edge(F, ab) and  not edge_in_fault_edge(F, cd):
            PATH = xa + [ab[1]] + bc[1:] + [cd[1]] + (dy[1:] if len(dy) > 1 else [])
            path_distance = D[xa[0]][xa[-1]] + G[ab[0]][ab[1]]["weight"] + D[bc[0]][bc[-1]] + G[cd[0]][cd[1]]["weight"] + (D[dy[0]][dy[-1]] if len(dy) > 1 else 0)

    elif len(xy_F_star) == 3:
        xa = shortest_paths[(xy_F_star[0][0], xy_F_star[0][1])] 
        ab = xy_F_star[1]
        by = shortest_paths[(xy_F_star[2][0], xy_F_star[2][1])] if xy_F_star[2][0]!=xy_F_star[2][1] else []
        if not single_edge_in_path(xa, F) and not single_edge_in_path(by, F) and not edge_in_fault_edge(F, ab):
            PATH = xa + [ab[1]] + (by[1:] if len(by) > 1 else [])
            path_distance = D[xa[0]][xa[-1]] + G[ab[0]][ab[1]]["weight"] + (D[by[0]][by[-1]] if len(by) > 1 else 0)


    else:

        xy = shortest_paths[(xy_F_star[0] , xy_F_star[1])]
        if not single_edge_in_path(xy, F):
            PATH = xy
            path_distance = D[xy[0]][xy[-1]]

  


    if direct_path and direct_path_distance < path_distance and not single_edge_in_path(direct_path, F):
        PATH = direct_path
        path_distance = direct_path_distance
  
        
                


    # Process vertices in F_star
    F_star_vertices = {vertex for edge in F_star for vertex in edge}
    for v in F_star_vertices:
        # Check y-clean vertex
        yv = shortest_paths[(y, v)]
        xv = shortest_paths[(x, v)]
        
        bfs_tree_of_y_rooted_v = txu_dict[(y, v)]

        if intact_from_failure_path(yv, F) and intact_from_failure_tree(bfs_tree_of_y_rooted_v, F):
            P, I = FIND_INTERMEDIATE3(G, x, y, u, v, F)
            if P:
                p_distance = P[1]
                if p_distance < path_distance:
                    PATH = P[0]
                    path_distance = p_distance
 
                INTERMEDIATE.extend(I)

        # Check intermediate vertex
        elif single_edge_in_path(xv, F) and single_edge_in_path(yv, F):
            INTERMEDIATE.append(v)

    # Remove duplicate intermediate vertices
    INTERMEDIATE = list(set(INTERMEDIATE))

    return (PATH, path_distance), INTERMEDIATE

# %%
def FIND_INTERMEDIATE21(G, x, y, v, F):
    """
    Optimized version of FIND_INTERMEDIATE21 to find the path and intermediate vertices.
    """
    # Extract vertices from edges in F
    vertices = {edge[0] for edge in F}.union({edge[1] for edge in F})

    # Calculate d1
    d1 = min(floor_power_of_2(D[x][a]) for a in vertices)

    # Initialize variables
    direct_path = []
    direct_path_distance = float("inf")
    PATH = []
    path_distance = float("inf")
    INTERMEDIATE = []

    # Retrieve F_star and xy_F_star
    F_star, xy_F_star = maximizer_dict21.get((x, y, d1, v), (None, None))
    if not F_star:
        return (shortest_paths[(x, y)], D[x][y]), []

    # Check for direct path
    for edge in F_star:
        if (x == edge[0] and y == edge[1]) or (x == edge[1] and y == edge[0]):
            direct_path = [x, y]
            direct_path_distance = G[x][y]["weight"]

    # Construct xy_F_star_path
    if len(xy_F_star) == 5:
        xa = shortest_paths[(xy_F_star[0][0], xy_F_star[0][1])] #segment1
        ab = xy_F_star[1]   #intermediate edge1
        bc = shortest_paths[(xy_F_star[2][0], xy_F_star[2][1])] #segment2
        cd = xy_F_star[3]  #intermediate edge2
        dy = shortest_paths[(xy_F_star[4][0], xy_F_star[4][1])] if xy_F_star[4][0]!=xy_F_star[4][1] else [] #segment3
        if not single_edge_in_path(xa, F) and not single_edge_in_path(bc, F) and not single_edge_in_path(dy, F) and not edge_in_fault_edge(F, ab) and  not edge_in_fault_edge(F, cd):
            PATH = xa + [ab[1]] + bc[1:] + [cd[1]] + (dy[1:] if len(dy) > 1 else [])
            path_distance = D[xa[0]][xa[-1]] + G[ab[0]][ab[1]]["weight"] + D[bc[0]][bc[-1]] + G[cd[0]][cd[1]]["weight"] + (D[dy[0]][dy[-1]] if len(dy) > 1 else 0)

    elif len(xy_F_star) == 3:
        xa = shortest_paths[(xy_F_star[0][0], xy_F_star[0][1])] 
        ab = xy_F_star[1]
        by = shortest_paths[(xy_F_star[2][0], xy_F_star[2][1])] if xy_F_star[2][0]!=xy_F_star[2][1] else []
        if not single_edge_in_path(xa, F) and not single_edge_in_path(by, F) and not edge_in_fault_edge(F, ab):
            PATH = xa + [ab[1]] + (by[1:] if len(by) > 1 else [])
            path_distance = D[xa[0]][xa[-1]] + G[ab[0]][ab[1]]["weight"] + (D[by[0]][by[-1]] if len(by) > 1 else 0)

    else:
        xy = shortest_paths[(xy_F_star[0] , xy_F_star[1])]
        if not single_edge_in_path(xy, F):
            PATH = xy
            path_distance = D[xy[0]][xy[-1]]
  


    if direct_path and direct_path_distance < path_distance and not single_edge_in_path(direct_path, F):
        PATH = direct_path
        path_distance = direct_path_distance
 
        

    # Process vertices in F_star
    F_star_vertices = {vertex for edge in F_star for vertex in edge}
    for u in F_star_vertices:
        # Check x-clean vertex
        xu = shortest_paths[(x, u)]
        yu = shortest_paths[(y, u)]
        bfs_tree_of_x_rooted_u = txu_dict[(x, u)]

        if intact_from_failure_path(xu, F) and intact_from_failure_tree(bfs_tree_of_x_rooted_u, F):
            P, I = FIND_INTERMEDIATE3(G, x, y, u, v, F)
            if P:
                p_distance = P[1]
                # Check if the path distance is less than the current path distance
                if p_distance < path_distance:
                    PATH = P[0]
                    path_distance = p_distance
            INTERMEDIATE.extend(I)

        # Check intermediate vertex
        elif single_edge_in_path(xu, F) and single_edge_in_path(yu, F):
            INTERMEDIATE.append(u)

    # Remove duplicate intermediate vertices
    INTERMEDIATE = list(set(INTERMEDIATE))

    return (PATH, path_distance), INTERMEDIATE

# %%
def FIND_INTERMEDIATE1(G, x, y, r, F):
    """
    Optimized version of FIND_INTERMEDIATE1 to find the path and intermediate vertices.
    """
    # Extract vertices from edges in F
    vertices = {edge[1] for edge in F}.union({edge[0] for edge in F})

    # Calculate d1 and d2
    d1 = min(floor_power_of_2(D[x][a]) for a in vertices)
    d2 = min(floor_power_of_2(D[y][a]) for a in vertices)

    # Initialize variables
    direct_path = []
    direct_path_distance = float("inf")
    PATH = []
    path_distance = float("inf")
    INTERMEDIATE = []
    F_star, xy_F_star = maximizer_dict1.get((x, y, d1, d2), (None, None))

    if not F_star:
        return (shortest_paths[(x, y)] , float("inf")), []

    # Check for direct path
    for edge in F_star:
        if (x == edge[0] and y == edge[1]) or (x == edge[1] and y == edge[0]):
            direct_path = [x, y]
            direct_path_distance = G[x][y]["weight"]


    # Construct xy_F_star_path
    if len(xy_F_star) == 5:
        xa = shortest_paths[(xy_F_star[0][0], xy_F_star[0][1])] #segment1
        ab = xy_F_star[1]   #intermediate edge1
        bc = shortest_paths[(xy_F_star[2][0], xy_F_star[2][1])] #segment2
        cd = xy_F_star[3]  #intermediate edge2
        dy = shortest_paths[(xy_F_star[4][0], xy_F_star[4][1])] if xy_F_star[4][0]!=xy_F_star[4][1] else [xy_F_star[4][0]] #segment3
        if not single_edge_in_path(xa, F) and not single_edge_in_path(bc, F) and not single_edge_in_path(dy, F) and not edge_in_fault_edge(F, ab) and  not edge_in_fault_edge(F, cd):
            PATH = xa + [ab[1]] + bc[1:] + [cd[1]] + (dy[1:] if len(dy) > 1 else [])
            path_distance = D[xa[0]][xa[-1]] + G[ab[0]][ab[1]]["weight"] + D[bc[0]][bc[-1]] + G[cd[0]][cd[1]]["weight"] + (D[dy[0]][dy[-1]] if len(dy) > 1 else 0)

    elif len(xy_F_star) == 3:
        xa = shortest_paths[(xy_F_star[0][0], xy_F_star[0][1])] 
        ab = xy_F_star[1]
        by = shortest_paths[(xy_F_star[2][0], xy_F_star[2][1])] if xy_F_star[2][0]!=xy_F_star[2][1] else [xy_F_star[2][0]]
        by = by if by[0] != by[-1] else []
        if not single_edge_in_path(xa, F) and not single_edge_in_path(by, F) and not edge_in_fault_edge(F, ab):
            PATH = xa + [ab[1]] + (by[1:] if len(by) > 1 else [])
            path_distance = D[xa[0]][xa[-1]] + G[ab[0]][ab[1]]["weight"] + (D[by[0]][by[-1]] if len(by) > 1 else 0)

    else:
        xy = shortest_paths[(xy_F_star[0] , xy_F_star[1])]
        if not single_edge_in_path(xy, F):
            PATH = xy
            path_distance = D[xy[0]][xy[-1]]

  


    if direct_path and direct_path_distance < path_distance and not single_edge_in_path(direct_path, F):
        PATH = direct_path
        path_distance = direct_path_distance
   
    # Process vertices in F_star
    F_star_vertices = list({vertex for edge in F_star for vertex in edge})
    for u in F_star_vertices:
        # Check x-clean vertex
        xu = shortest_paths[(x, u)]
        bfs_tree_of_s_rooted_x = txu_dict[(x, u)]
        yu = shortest_paths[(y, u)]
        bfs_tree_of_s_rooted_y = txu_dict[(y, u)]
        if intact_from_failure_path(xu, F) and intact_from_failure_tree(bfs_tree_of_s_rooted_x, F):
            P1, I1 = FIND_INTERMEDIATE2(G, x, y, u, F)
            if P1:
                p1_distance = P1[1]
                # Check if the path distance is less than the current path distance
                if p1_distance < path_distance:
                    PATH = P1[0]
                    path_distance = p1_distance
            INTERMEDIATE.extend(I1)

        # Check y-clean vertex

        elif intact_from_failure_path(yu, F) and intact_from_failure_tree(bfs_tree_of_s_rooted_y, F):
            P2, I2 = FIND_INTERMEDIATE21(G, x, y, u, F)
            if P2:
                p2_distance = P2[1] 
                if p2_distance < path_distance:
                    PATH = P2[0]
                    path_distance = p2_distance
            INTERMEDIATE.extend(I2)

        # Check intermediate vertex
        elif single_edge_in_path(xu, F) and single_edge_in_path(yu, F):
            INTERMEDIATE.append(u)

    # Remove duplicate intermediate vertices
    INTERMEDIATE = list(set(INTERMEDIATE))

    return (PATH, path_distance), INTERMEDIATE

# %% [markdown]
# ===================================== Main Function ===================================

# %%
def QUERY2(G ,s, t, r, F):

    if r == 0:
        return [] , float("inf")
    P = FINDPATHS(G ,s, t, F[:])
 
    f = len(F)
    
    if len(P)< f:
        return P[0] , D[P[0][0]][P[0][-1]]  if P else float("inf")
    jumps = []
    for i in range(f):
        jump_st = FINDJUMP(P[i], F[:])

        jump_ts = FINDJUMP(P[i][::-1], F[:])

        jumps.append((jump_st, jump_ts))

    PATH = []
    
    path_distance = float("inf")
    processed_pairs = set()
    
    for i in range(f):
        for j in range(f):
            INTERMEDIATE = []  
            for x, y in product(jumps[i][0], jumps[j][1]):
                if(x!=y) and (x, y) not in processed_pairs:
                    # print(f"jumps[i][0]={jumps[i][0]}, jumps[j][1]={jumps[j][1]}")
                    processed_pairs.add((x, y))
                    sx = shortest_paths[(s, x)]     
                    sy = shortest_paths[(s, y)]
                    xt = shortest_paths[(x, t)]
                    yt = shortest_paths[(y, t)]  


                    if single_edge_in_path(sx, F[:]) and single_edge_in_path(xt, F[:]):
                        INTERMEDIATE.append(x)
                    # y satisfies the conditionof an intermediate vertex
                    elif single_edge_in_path(sy, F[:]) and single_edge_in_path(yt, F[:]):
                        INTERMEDIATE.append(y)
                    else:
                        P, I = FIND_INTERMEDIATE1(G, x, y, r, F[:])
                        if single_edge_in_path(sx, F[:]) or single_edge_in_path(yt, F[:]):
                            if I is not None and I != []:
                                INTERMEDIATE.extend(I)
                            continue
                        if P[0] is None or P[0] == []:
                            continue
                        P_prime = []


                        P_prime = sx + P[0][1:-1] + yt

                        
                        # we can do it by distance oracle but need to check distance oracle to fix
                        P_prime_distance = D[s][x] + P[1] + D[y][t]

                        if P_prime_distance < path_distance:
                            PATH = P_prime
                            path_distance = P_prime_distance
                            
                            

                        if I is not None and I != []:
                            INTERMEDIATE.extend(I)


    INTERMEDIATE = list(set(INTERMEDIATE))

    for u in INTERMEDIATE:
        query_path = []
        query_path_distance = float("inf")


        path1 , path1_distance = QUERY2(G, s, u, r - 1, F[:])
        path2 , path2_distance = QUERY2(G, u, t, r - 1, F[:])

        if path1 == [] and path2 == []: 
            query_path = []
        else:
            query_path = path1 + path2[1:] if path2 else path1
            query_path_distance = path1_distance + path2_distance

            
        if query_path != [] and query_path_distance < path_distance:    
                # print(f"Found better path: {query_path} with distance {query_path_distance}")
                PATH = query_path
                path_distance = query_path_distance

    return PATH, path_distance

# %% [markdown]
# #Cross Check Function

# %%
import networkx as nx

def cross_check2(G, s, t, e1, e2):
    G = G.copy()
    e1_u, e1_v = e1
    e2_u, e2_v = e2
    
    if not G.has_node(s) or not G.has_node(t):
        print("Source or target node does not exist in the graph.")  
        return [] , float("inf")    
    
    edge1_exists = False
    edge2_exists = False

    # Check if edges exist before removing them
    if G.has_edge(e1_u, e1_v):
        edge1_exists = True
        edge1_data = G.get_edge_data(e1_u, e1_v)

        G.remove_edge(e1_u, e1_v)
    else:
        print(f"Edge ({e1_u}, {e1_v}) does not exist in the graph.")
    
    if G.has_edge(e2_u, e2_v):
        edge2_exists = True
        edge2_data = G.get_edge_data(e2_u, e2_v)
       # Added debug print
        G.remove_edge(e2_u, e2_v)
    else:
        print(f"Edge ({e2_u}, {e2_v}) does not exist in the graph.")

    # Find the shortest path
    try:
        wt_st , st_path = nx.single_source_dijkstra(G, s, t, weight="weight")  
      # Added debug print
    except nx.NetworkXNoPath:
        st_path = []
        print(f"No path exists between nodes {s} and {t} after removing edges ({e1_u}, {e1_v}) and ({e2_u}, {e2_v}).")
        return st_path , float("inf")
    except nx.NodeNotFound as e:    
        print(f"Node not found: {e}")
        return [], float("inf") 
    # Add the edges back to the graph
    if edge1_exists:
        G.add_edge(e1_u, e1_v, **edge1_data)
     
    if edge2_exists:
        G.add_edge(e2_u, e2_v, **edge2_data)
        

    return st_path, wt_st

# %%
import random
import time

f = 2

query_times = []
cross_check_times = []

right = 0
wrong = 0

for case in range(1, 1000):
    x = random.randint(0, 50)
    y = random.randint(0, 50)
    print(f"case:{case} ===>")
    if x == y:
        continue
    try:
        print(shortest_paths[(x, y)])
    except KeyError:
        print(f"Shortest path for ({x}, {y}) not found in shortest_paths.")
        continue

    path = shortest_paths[(x, y)]

    pedges = []
    for i in range(len(path) - 1):
        pedges.append((path[i], path[i + 1])) 
    if len(pedges) < 2:
        continue
    e1 = random.choice(pedges)
    edges_list = list(G.edges())
    # Filter out edges that are not allowed for e2
    filtered_edges = [
        edge for edge in edges_list
        if not (
            (e1[0] == edge[0] or e1[1] == edge[1] or edge[0] == x or edge[1] == y) or
            (e1[0] == edge[1] or e1[1] == edge[0])  # Also avoid reverse direction
        )
    ]
    if not filtered_edges:  
        continue
    e2 = random.choice(filtered_edges)

    F3 = [(e1[0], e1[1]), (e2[0], e2[1])]   
    

    print(f"avoiding edges:{e1[0], e1[1]}, {e2[0], e2[1]}")
    start_time = time.time()
    query_output , q_weight  = QUERY2(G, x, y, 3, F3)
    query_times.append(time.time() - start_time)
    print("Query time--- %s seconds ---" % (time.time() - start_time))

    print(f"query output:{query_output} , weight:{q_weight}")

    start_time = time.time()
    cross_check_output , c_weight = cross_check2(G, x, y, (e1[0], e1[1]), (e2[0], e2[1]))
    cross_check_times.append(time.time() - start_time)

    print(f"cross_check output:{cross_check_output} , weight:{c_weight}")
    print("Cross_check time--- %s seconds ---" % (time.time() - start_time))
    if query_output != cross_check_output:
        wrong += 1
        print("!!!!!!!!!!!!----SOMETHING WENT WRONG-----!!!!!!!!!!!!!!!!!!")
    else:
        right += 1

    print("===================================================")
# Out:
# case:1 ===>
# [35, 15, 22, 24, 8]
# avoiding edges:(15, 22), (40, 4)
# Query time--- 0.014034509658813477 seconds ---
# query output:[35, 15, 42, 46, 24, 8] , weight:135.14141414141415
# cross_check output:[35, 15, 42, 46, 24, 8] , weight:135.14141414141415
# Cross_check time--- 0.0009965896606445312 seconds ---
# ===================================================
# case:2 ===>
# [10, 5, 48, 9, 37]
# avoiding edges:(10, 5), (40, 21)
# Query time--- 0.01612997055053711 seconds ---
# query output:[10, 23, 21, 37] , weight:116.71717171717172
# cross_check output:[10, 23, 21, 37] , weight:116.71717171717172
# Cross_check time--- 0.0009875297546386719 seconds ---
# ===================================================
# case:3 ===>
# [26, 35, 33, 47]
# avoiding edges:(26, 35), (40, 4)
# Query time--- 0.007506370544433594 seconds ---
# query output:[26, 49, 33, 47] , weight:169.6161616161616
# cross_check output:[26, 49, 33, 47] , weight:169.6161616161616
# Cross_check time--- 0.001999378204345703 seconds ---
# ===================================================
# case:4 ===>
# [1, 37, 19, 42]
# avoiding edges:(19, 42), (48, 33)
# Query time--- 0.009331703186035156 seconds ---
# query output:[1, 28, 46, 42] , weight:135.8989898989899
# cross_check output:[1, 28, 46, 42] , weight:135.8989898989899
# Cross_check time--- 0.001013040542602539 seconds ---
# ===================================================
# case:5 ===>
# Shortest path for (20, 5) not found in shortest_paths.
# case:6 ===>
# [22, 9, 48]
# avoiding edges:(9, 48), (6, 13)
# Query time--- 0.00774693489074707 seconds ---
# query output:[22, 24, 46, 48] , weight:112.50505050505049
# cross_check output:[22, 24, 46, 48] , weight:112.5050505050505
# Cross_check time--- 0.0010428428649902344 seconds ---
# ===================================================
# case:7 ===>
# [18, 2, 37, 22, 3]
# avoiding edges:(2, 37), (45, 6)
# Query time--- 0.00906229019165039 seconds ---
# query output:[18, 2, 41, 24, 8, 3] , weight:176.26262626262627
# cross_check output:[18, 2, 41, 24, 8, 3] , weight:176.26262626262627
# Cross_check time--- 0.0010328292846679688 seconds ---
# ===================================================
# case:8 ===>
# [10, 32]
# case:9 ===>
# Shortest path for (11, 37) not found in shortest_paths.
# case:10 ===>
# [2, 18, 27, 32, 33, 47]
# avoiding edges:(18, 27), (40, 44)
# Query time--- 0.011006593704223633 seconds ---
# query output:[2, 37, 21, 14, 35, 33, 47] , weight:193.63636363636363
# cross_check output:[2, 37, 21, 14, 35, 33, 47] , weight:193.63636363636365
# Cross_check time--- 0.001001119613647461 seconds ---
# ===================================================
# case:11 ===>
# [38, 22]
# case:12 ===>
# [10, 5, 48]
# avoiding edges:(10, 5), (41, 13)
# Query time--- 0.005049467086791992 seconds ---
# query output:[10, 25, 40, 48] , weight:152.1010101010101
# cross_check output:[10, 25, 40, 48] , weight:152.1010101010101
# Cross_check time--- 0.0010004043579101562 seconds ---
# ===================================================
# case:13 ===>
# [46, 48, 5, 10, 32]
# avoiding edges:(48, 5), (14, 25)
# Query time--- 0.011973857879638672 seconds ---
# query output:[46, 28, 1, 27, 32] , weight:172.77777777777777
# cross_check output:[46, 28, 1, 27, 32] , weight:172.77777777777777
# Cross_check time--- 0.001008749008178711 seconds ---
# ===================================================
# case:14 ===>
# [28, 1, 40, 25, 12, 36, 23, 39]
# avoiding edges:(12, 36), (37, 2)
# Query time--- 0.00513768196105957 seconds ---
# query output:[28, 1, 40, 25, 12, 23, 39] , weight:179.46464646464645
# cross_check output:[28, 1, 40, 25, 12, 23, 39] , weight:179.46464646464645
# Cross_check time--- 0.0 seconds ---
# ===================================================
# case:15 ===>
# [34, 42, 10, 39]
# avoiding edges:(42, 10), (48, 33)
# Query time--- 0.012227773666381836 seconds ---
# query output:[34, 42, 46, 48, 5, 10, 39] , weight:222.68686868686868
# cross_check output:[34, 42, 46, 48, 5, 10, 39] , weight:222.6868686868687
# Cross_check time--- 0.0 seconds ---
# ===================================================
# case:16 ===>
# [35, 14, 21, 23]
# avoiding edges:(35, 14), (5, 10)
# Query time--- 0.010596513748168945 seconds ---
# query output:[35, 26, 12, 36, 23] , weight:116.35353535353534
# cross_check output:[35, 26, 12, 36, 23] , weight:116.35353535353536
# Cross_check time--- 0.0009996891021728516 seconds ---
# ===================================================
# case:17 ===>
# [16, 46, 48, 40, 25]
# avoiding edges:(16, 46), (22, 24)
# Query time--- 0.009734392166137695 seconds ---
# query output:[16, 23, 36, 12, 25] , weight:146.1919191919192
# cross_check output:[16, 23, 36, 12, 25] , weight:146.1919191919192
# Cross_check time--- 0.0 seconds ---
# ===================================================
# case:18 ===>
# [45, 6, 44, 18, 2, 41]
# avoiding edges:(18, 2), (10, 42)
# Query time--- 0.006055593490600586 seconds ---
# query output:[45, 6, 13, 41] , weight:127.9090909090909
# cross_check output:[45, 6, 13, 41] , weight:127.9090909090909
# Cross_check time--- 0.0010001659393310547 seconds ---
# ===================================================
# case:19 ===>
# [4, 17, 3, 22, 38]
# avoiding edges:(3, 22), (1, 40)
# Query time--- 0.00820612907409668 seconds ---
# query output:[4, 7, 22, 38] , weight:178.11111111111111
# cross_check output:[4, 7, 22, 38] , weight:178.11111111111111
# Cross_check time--- 0.0010476112365722656 seconds ---
# ===================================================
# case:20 ===>
# [43, 45]
# case:21 ===>
# [40, 25, 12]
# avoiding edges:(40, 25), (6, 14)
# Query time--- 0.0020575523376464844 seconds ---
# query output:[40, 21, 12] , weight:118.0909090909091
# cross_check output:[40, 21, 12] , weight:118.0909090909091
# Cross_check time--- 0.0010004043579101562 seconds ---
# ===================================================
# case:22 ===>
# [3, 22, 9, 48, 5]
# avoiding edges:(22, 9), (1, 28)
# Query time--- 0.010190010070800781 seconds ---
# query output:[3, 8, 24, 46, 48, 5] , weight:144.34343434343435
# cross_check output:[3, 8, 24, 46, 48, 5] , weight:144.34343434343435
# Cross_check time--- 0.0010259151458740234 seconds ---
# ===================================================
# case:23 ===>
# [25, 40, 48, 46, 24, 8]
# avoiding edges:(48, 46), (28, 34)
# Query time--- 0.012382984161376953 seconds ---
# query output:[25, 40, 21, 37, 22, 24, 8] , weight:173.83838383838383
# cross_check output:[25, 40, 21, 37, 22, 24, 8] , weight:173.83838383838383
# Cross_check time--- 0.0009987354278564453 seconds ---
# ===================================================
# case:24 ===>
# [25, 40, 4]
# avoiding edges:(40, 4), (37, 28)
# Query time--- 0.003000497817993164 seconds ---
# query output:[25, 17, 4] , weight:119.74747474747475
# cross_check output:[25, 17, 4] , weight:119.74747474747475
# Cross_check time--- 0.0009970664978027344 seconds ---
# ===================================================
# case:25 ===>
# Shortest path for (13, 11) not found in shortest_paths.
# case:26 ===>
# [24, 46, 48, 5]
# avoiding edges:(24, 46), (45, 43)
# Query time--- 0.0030291080474853516 seconds ---
# query output:[24, 22, 9, 48, 5] , weight:95.48484848484848
# cross_check output:[24, 22, 9, 48, 5] , weight:95.48484848484848
# Cross_check time--- 0.0009930133819580078 seconds ---
# ===================================================
# case:27 ===>
# [40, 21, 37, 22, 38]
# avoiding edges:(40, 21), (42, 34)
# Query time--- 0.007025480270385742 seconds ---
# query output:[40, 48, 9, 22, 38] , weight:109.26262626262624
# cross_check output:[40, 48, 9, 22, 38] , weight:109.26262626262624
# Cross_check time--- 0.001004934310913086 seconds ---
# ===================================================
# case:28 ===>
# [25, 40, 1]
# avoiding edges:(25, 40), (32, 12)
# Query time--- 0.02357339859008789 seconds ---
# query output:[25, 12, 36, 27, 1] , weight:144.74747474747474
# cross_check output:[25, 12, 36, 27, 1] , weight:144.74747474747474
# Cross_check time--- 0.0010004043579101562 seconds ---
# ===================================================
# case:29 ===>
# [12, 37, 22, 38]
# avoiding edges:(12, 37), (39, 47)
# Query time--- 0.0030934810638427734 seconds ---
# query output:[12, 21, 37, 22, 38] , weight:113.55555555555554
# cross_check output:[12, 21, 37, 22, 38] , weight:113.55555555555554
# Cross_check time--- 0.0010035037994384766 seconds ---
# ===================================================
# case:30 ===>
# Shortest path for (9, 30) not found in shortest_paths.
# case:31 ===>
# [43, 45, 12, 25, 40]
# avoiding edges:(25, 40), (48, 46)
# Query time--- 0.005042076110839844 seconds ---
# query output:[43, 45, 6, 44, 40] , weight:153.3939393939394
# cross_check output:[43, 45, 6, 44, 40] , weight:153.3939393939394
# Cross_check time--- 0.0 seconds ---
# ===================================================
# case:32 ===>
# [48, 9]
# case:33 ===>
# Shortest path for (47, 20) not found in shortest_paths.
# case:34 ===>
# [34, 28, 1, 27]
# avoiding edges:(28, 1), (40, 44)
# Query time--- 0.008098602294921875 seconds ---
# query output:[34, 42, 19, 37, 1, 27] , weight:193.26262626262627
# cross_check output:[34, 42, 19, 37, 1, 27] , weight:193.26262626262627
# Cross_check time--- 0.0 seconds ---
# ===================================================
# case:35 ===>
# Shortest path for (19, 50) not found in shortest_paths.
# case:36 ===>
# [49, 40, 25, 12, 36]
# avoiding edges:(40, 25), (32, 33)
# Query time--- 0.004004716873168945 seconds ---
# query output:[49, 26, 12, 36] , weight:139.62626262626262
# cross_check output:[49, 26, 12, 36] , weight:139.62626262626262
# Cross_check time--- 0.0 seconds ---
# ===================================================
# case:37 ===>
# Shortest path for (38, 11) not found in shortest_paths.
# case:38 ===>
# Shortest path for (20, 13) not found in shortest_paths.
# case:39 ===>
# [26, 12, 36, 23, 16]
# avoiding edges:(36, 23), (41, 24)
# Query time--- 0.013170719146728516 seconds ---
# query output:[26, 35, 15, 42, 46, 16] , weight:158.47474747474746
# cross_check output:[26, 35, 15, 42, 46, 16] , weight:158.47474747474746
# Cross_check time--- 0.0010004043579101562 seconds ---
# ===================================================
# case:40 ===>
# [22, 37, 28]
# avoiding edges:(22, 37), (5, 10)
# Query time--- 0.004481792449951172 seconds ---
# query output:[22, 9, 37, 28] , weight:136.45454545454544
# cross_check output:[22, 9, 37, 28] , weight:136.45454545454544
# Cross_check time--- 0.0009982585906982422 seconds ---
# ===================================================
# case:41 ===>
# [40, 25, 12, 45, 43]
# avoiding edges:(25, 12), (14, 9)
# Query time--- 0.0075190067291259766 seconds ---
# query output:[40, 44, 6, 45, 43] , weight:153.39393939393938
# cross_check output:[40, 44, 6, 45, 43] , weight:153.3939393939394
# Cross_check time--- 0.0009975433349609375 seconds ---
# ===================================================
# case:42 ===>
# [6, 14, 21]
# avoiding edges:(14, 21), (10, 23)
# Query time--- 0.004350423812866211 seconds ---
# query output:[6, 45, 12, 21] , weight:98.01010101010101
# cross_check output:[6, 45, 12, 21] , weight:98.01010101010101
# Cross_check time--- 0.0005538463592529297 seconds ---
# ===================================================
# case:43 ===>
# [12, 45, 43]
# avoiding edges:(12, 45), (4, 7)
# Query time--- 0.07570242881774902 seconds ---
# query output:[12, 25, 40, 44, 6, 45, 43] , weight:206.63636363636363
# cross_check output:[12, 25, 40, 44, 6, 45, 43] , weight:206.63636363636365
# Cross_check time--- 0.0 seconds ---
# ===================================================
# case:44 ===>
# Shortest path for (8, 20) not found in shortest_paths.
# case:45 ===>
# [39, 23, 36, 12, 45, 6, 44, 18]
# avoiding edges:(12, 45), (13, 42)
# Query time--- 0.00850367546081543 seconds ---
# query output:[39, 23, 36, 27, 18] , weight:165.9292929292929
# cross_check output:[39, 23, 36, 27, 18] , weight:165.92929292929293
# Cross_check time--- 0.0005331039428710938 seconds ---
# ===================================================
# case:46 ===>
# [36, 21, 37, 22, 3]
# avoiding edges:(21, 37), (48, 46)
# Query time--- 0.00603938102722168 seconds ---
# query output:[36, 12, 37, 22, 3] , weight:155.6969696969697
# cross_check output:[36, 12, 37, 22, 3] , weight:155.6969696969697
# Cross_check time--- 0.0019922256469726562 seconds ---
# ===================================================
# case:47 ===>
# [5, 48, 33, 47]
# avoiding edges:(5, 48), (23, 16)
# Query time--- 0.009570121765136719 seconds ---
# query output:[5, 10, 39, 47] , weight:152.50505050505052
# cross_check output:[5, 10, 39, 47] , weight:152.50505050505052
# Cross_check time--- 0.0010528564453125 seconds ---
# ===================================================
# case:48 ===>
# [4, 40, 1, 27, 32]
# avoiding edges:(27, 32), (3, 31)
# Query time--- 0.0070002079010009766 seconds ---
# query output:[4, 40, 25, 12, 32] , weight:206.83838383838383
# cross_check output:[4, 40, 25, 12, 32] , weight:206.83838383838383
# Cross_check time--- 0.0009999275207519531 seconds ---
# ===================================================
# case:49 ===>
# Shortest path for (11, 18) not found in shortest_paths.
# case:50 ===>
# [18, 44, 6, 45, 12, 36]
# avoiding edges:(18, 44), (46, 42)
# Query time--- 0.007976055145263672 seconds ---
# query output:[18, 27, 36] , weight:107.44444444444444
# cross_check output:[18, 27, 36] , weight:107.44444444444444
# Cross_check time--- 0.0010001659393310547 seconds ---
# ===================================================
# case:51 ===>
# [33, 32, 12, 45, 43]
# avoiding edges:(45, 43), (41, 24)
# Query time--- 0.0021257400512695312 seconds ---
# query output:[] , weight:inf
# No path exists between nodes 33 and 43 after removing edges (45, 43) and (41, 24).
# cross_check output:[] , weight:inf
# Cross_check time--- 0.0 seconds ---
# ===================================================
# case:52 ===>
# [49, 40, 25, 12, 45]
# avoiding edges:(40, 25), (28, 46)
# Query time--- 0.0029997825622558594 seconds ---
# query output:[49, 26, 12, 45] , weight:149.59595959595958
# cross_check output:[49, 26, 12, 45] , weight:149.59595959595958
# Cross_check time--- 0.0 seconds ---
# ===================================================
# case:53 ===>
# [26, 35, 15, 22, 24]
# avoiding edges:(35, 15), (37, 9)
# Query time--- 0.02497100830078125 seconds ---
# query output:[26, 35, 14, 21, 37, 22, 24] , weight:158.94949494949495
# cross_check output:[26, 35, 14, 21, 37, 22, 24] , weight:158.94949494949495
# Cross_check time--- 0.0010097026824951172 seconds ---
# ===================================================
# case:54 ===>
# [10, 23, 36, 12, 45, 6, 44]
# avoiding edges:(6, 44), (23, 16)
# Query time--- 0.00999903678894043 seconds ---
# query output:[10, 25, 40, 44] , weight:164.12121212121212
# cross_check output:[10, 25, 40, 44] , weight:164.12121212121212
# Cross_check time--- 0.0 seconds ---
# ===================================================
# case:55 ===>
# [10, 25, 40, 4]
# avoiding edges:(25, 40), (45, 43)
# Query time--- 0.0035080909729003906 seconds ---
# query output:[10, 5, 48, 40, 4] , weight:185.49494949494948
# cross_check output:[10, 5, 48, 40, 4] , weight:185.49494949494948
# Cross_check time--- 0.0010006427764892578 seconds ---
# ===================================================
# case:56 ===>
# [21, 37, 9, 48, 13]
# avoiding edges:(21, 37), (4, 7)
# Query time--- 0.002999544143676758 seconds ---
# query output:[21, 9, 48, 13] , weight:131.08080808080808
# cross_check output:[21, 9, 48, 13] , weight:131.08080808080808
# Cross_check time--- 0.0010001659393310547 seconds ---
# ===================================================
# case:57 ===>
# [13, 48, 5]
# avoiding edges:(48, 5), (22, 9)
# Query time--- 0.00800633430480957 seconds ---
# query output:[13, 6, 45, 12, 36, 23, 10, 5] , weight:190.49494949494948
# cross_check output:[13, 6, 45, 12, 36, 23, 10, 5] , weight:190.4949494949495
# Cross_check time--- 0.001004934310913086 seconds ---
# ===================================================
# case:58 ===>
# [33, 35, 15, 42]
# avoiding edges:(35, 15), (29, 33)
# Query time--- 0.009990692138671875 seconds ---
# query output:[33, 49, 19, 42] , weight:140.18181818181816
# cross_check output:[33, 49, 19, 42] , weight:140.18181818181816
# Cross_check time--- 0.0010156631469726562 seconds ---
# ===================================================
# case:59 ===>
# Shortest path for (36, 11) not found in shortest_paths.
# case:60 ===>
# [29, 8, 24]
# avoiding edges:(8, 24), (4, 7)
# Query time--- 0.007999420166015625 seconds ---
# query output:[29, 14, 21, 37, 22, 24] , weight:176.12121212121212
# cross_check output:[29, 14, 21, 37, 22, 24] , weight:176.12121212121212
# Cross_check time--- 0.0010006427764892578 seconds ---
# ===================================================
# case:61 ===>
# [12, 26]
# case:62 ===>
# [23, 39]
# case:63 ===>
# [5, 48, 9, 22, 15]
# avoiding edges:(5, 48), (27, 18)
# Query time--- 0.009005308151245117 seconds ---
# query output:[5, 10, 42, 15] , weight:158.06060606060606
# cross_check output:[5, 10, 42, 15] , weight:158.06060606060606
# Cross_check time--- 0.001001119613647461 seconds ---
# ===================================================
# case:64 ===>
# Shortest path for (50, 12) not found in shortest_paths.
# case:65 ===>
# [35, 14, 21, 37, 9, 48, 5]
# avoiding edges:(48, 5), (19, 49)
# Query time--- 0.03316831588745117 seconds ---
# query output:[35, 14, 21, 23, 10, 5] , weight:181.23232323232324
# cross_check output:[35, 14, 21, 23, 10, 5] , weight:181.23232323232324
# Cross_check time--- 0.0025556087493896484 seconds ---
# ===================================================
# case:66 ===>
# [42, 19, 37, 12, 45, 43]
# avoiding edges:(37, 12), (21, 23)
# Query time--- 0.009658336639404297 seconds ---
# query output:[42, 19, 37, 21, 12, 45, 43] , weight:192.76767676767673
# cross_check output:[42, 19, 37, 21, 12, 45, 43] , weight:192.76767676767676
# Cross_check time--- 0.0010001659393310547 seconds ---
# ===================================================
# case:67 ===>
# [9, 37, 21, 36]
# avoiding edges:(9, 37), (35, 15)
# Query time--- 0.0040149688720703125 seconds ---
# query output:[9, 22, 37, 21, 36] , weight:121.37373737373737
# cross_check output:[9, 22, 37, 21, 36] , weight:121.37373737373737
# Cross_check time--- 0.0010235309600830078 seconds ---
# ===================================================
# case:68 ===>
# [6, 13, 48, 46]
# avoiding edges:(13, 48), (1, 27)
# Query time--- 0.011090993881225586 seconds ---
# query output:[6, 45, 12, 36, 23, 16, 46] , weight:165.8989898989899
# cross_check output:[6, 45, 12, 36, 23, 16, 46] , weight:165.8989898989899
# Cross_check time--- 0.0009958744049072266 seconds ---
# ===================================================
# case:69 ===>
# [37, 21, 14, 35, 33, 47]
# avoiding edges:(37, 21), (3, 8)
# Query time--- 0.014665365219116211 seconds ---
# query output:[37, 19, 49, 33, 47] , weight:159.08080808080805
# cross_check output:[37, 19, 49, 33, 47] , weight:159.08080808080805
# Cross_check time--- 0.0 seconds ---
# ===================================================
# case:70 ===>
# [0, 45]
# case:71 ===>
# Shortest path for (24, 50) not found in shortest_paths.
# case:72 ===>
# [38, 22, 37, 12, 45, 6]
# avoiding edges:(12, 45), (14, 25)
# Query time--- 0.06078004837036133 seconds ---
# query output:[38, 22, 37, 21, 14, 6] , weight:139.85858585858585
# cross_check output:[38, 22, 37, 21, 14, 6] , weight:139.85858585858585
# Cross_check time--- 0.0 seconds ---
# ===================================================
# case:73 ===>
# [29, 14, 35, 15]
# avoiding edges:(14, 35), (45, 6)
# Query time--- 0.008246183395385742 seconds ---
# query output:[29, 14, 21, 37, 22, 15] , weight:161.93939393939394
# cross_check output:[29, 14, 21, 37, 22, 15] , weight:161.93939393939394
# Cross_check time--- 0.0015435218811035156 seconds ---
# ===================================================
# case:74 ===>
# [32, 12, 37, 19]
# avoiding edges:(12, 37), (28, 46)
# Query time--- 0.006099700927734375 seconds ---
# query output:[32, 33, 49, 19] , weight:159.43434343434342
# cross_check output:[32, 33, 49, 19] , weight:159.43434343434342
# Cross_check time--- 0.001003265380859375 seconds ---
# ===================================================
# case:75 ===>
# [9, 22]
# case:76 ===>
# Shortest path for (22, 30) not found in shortest_paths.
# case:77 ===>
# [29, 14, 21, 12, 45, 43]
# avoiding edges:(21, 12), (27, 32)
# Query time--- 0.01288294792175293 seconds ---
# query output:[29, 14, 21, 36, 12, 45, 43] , weight:222.48484848484847
# cross_check output:[29, 14, 21, 36, 12, 45, 43] , weight:222.4848484848485
# Cross_check time--- 0.0009872913360595703 seconds ---
# ===================================================
# case:78 ===>
# [5, 48, 9, 37, 21, 14, 35]
# avoiding edges:(48, 9), (18, 44)
# Query time--- 0.010835886001586914 seconds ---
# query output:[5, 48, 46, 42, 15, 35] , weight:144.3030303030303
# cross_check output:[5, 48, 46, 42, 15, 35] , weight:144.3030303030303
# Cross_check time--- 0.0 seconds ---
# ===================================================
# case:79 ===>
# Shortest path for (38, 11) not found in shortest_paths.
# case:80 ===>
# [16, 23, 36, 12, 26]
# avoiding edges:(16, 23), (13, 42)
# Query time--- 0.015275955200195312 seconds ---
# query output:[16, 46, 42, 15, 35, 26] , weight:158.47474747474746
# cross_check output:[16, 46, 42, 15, 35, 26] , weight:158.4747474747475
# Cross_check time--- 0.001003265380859375 seconds ---
# ===================================================
# case:81 ===>
# [12, 25, 40, 4, 31]
# avoiding edges:(25, 40), (6, 44)
# Query time--- 0.0069959163665771484 seconds ---
# query output:[12, 37, 22, 3, 31] , weight:199.39393939393938
# cross_check output:[12, 37, 22, 3, 31] , weight:199.3939393939394
# Cross_check time--- 0.0011196136474609375 seconds ---
# ===================================================
# case:82 ===>
# [17, 25, 12, 45, 6]
# avoiding edges:(25, 12), (42, 19)
# Query time--- 0.005503177642822266 seconds ---
# query output:[17, 25, 40, 44, 6] , weight:194.57575757575756
# cross_check output:[17, 25, 40, 44, 6] , weight:194.5757575757576
# Cross_check time--- 0.0 seconds ---
# ===================================================
# case:83 ===>
# Shortest path for (30, 35) not found in shortest_paths.
# case:84 ===>
# Shortest path for (11, 47) not found in shortest_paths.
# case:85 ===>
# [44, 18, 2, 41, 24]
# avoiding edges:(41, 24), (6, 44)
# Query time--- 0.0038166046142578125 seconds ---
# query output:[44, 18, 2, 37, 22, 24] , weight:179.17171717171715
# cross_check output:[44, 18, 2, 37, 22, 24] , weight:179.17171717171718
# Cross_check time--- 0.001516580581665039 seconds ---
# ===================================================
# case:86 ===>
# [35, 33, 47]
# avoiding edges:(35, 33), (37, 9)
# Query time--- 0.030367374420166016 seconds ---
# query output:[35, 14, 21, 37, 19, 49, 33, 47] , weight:197.80808080808077
# cross_check output:[35, 14, 21, 37, 19, 49, 33, 47] , weight:197.8080808080808
# Cross_check time--- 0.0010256767272949219 seconds ---
# ===================================================
# case:87 ===>
# [6, 45, 12, 32]
# avoiding edges:(45, 12), (37, 21)
# Query time--- 0.023215055465698242 seconds ---
# query output:[6, 44, 18, 27, 32] , weight:135.26262626262627
# cross_check output:[6, 44, 18, 27, 32] , weight:135.26262626262627
# Cross_check time--- 0.0 seconds ---
# ===================================================
# case:88 ===>
# [21, 37, 22, 24]
# avoiding edges:(21, 37), (6, 44)
# Query time--- 0.013622760772705078 seconds ---
# query output:[21, 14, 35, 15, 22, 24] , weight:142.84848484848484
# cross_check output:[21, 14, 35, 15, 22, 24] , weight:142.84848484848484
# Cross_check time--- 0.0010204315185546875 seconds ---
# ===================================================
# case:89 ===>
# [33, 48, 13]
# avoiding edges:(33, 48), (2, 18)
# Query time--- 0.0107421875 seconds ---
# query output:[33, 35, 14, 21, 37, 9, 48, 13] , weight:208.7171717171717
# cross_check output:[33, 35, 14, 21, 37, 9, 48, 13] , weight:208.7171717171717
# Cross_check time--- 0.000993967056274414 seconds ---
# ===================================================
# case:90 ===>
# [23, 36, 12, 26]
# avoiding edges:(23, 36), (28, 46)
# Query time--- 0.0034437179565429688 seconds ---
# query output:[23, 12, 26] , weight:87.79797979797979
# cross_check output:[23, 12, 26] , weight:87.79797979797979
# Cross_check time--- 0.0 seconds ---
# ===================================================
# case:91 ===>
# case:92 ===>
# [44, 6, 13, 48, 9]
# avoiding edges:(48, 9), (6, 14)
# Query time--- 0.01669478416442871 seconds ---
# query output:[44, 18, 2, 37, 9] , weight:141.05050505050505
# cross_check output:[44, 18, 2, 37, 9] , weight:141.05050505050505
# Cross_check time--- 0.000997304916381836 seconds ---
# ===================================================
# case:93 ===>
# [9, 48, 46]
# avoiding edges:(48, 46), (22, 7)
# Query time--- 0.008563518524169922 seconds ---
# query output:[9, 22, 24, 46] , weight:92.77777777777777
# cross_check output:[9, 22, 24, 46] , weight:92.77777777777777
# Cross_check time--- 0.0 seconds ---
# ===================================================
# case:94 ===>
# [10, 23, 36, 12, 45, 0]
# avoiding edges:(10, 23), (48, 33)
# Query time--- 0.00908207893371582 seconds ---
# query output:[10, 39, 23, 36, 12, 45, 0] , weight:167.66666666666666
# cross_check output:[10, 39, 23, 36, 12, 45, 0] , weight:167.66666666666666
# Cross_check time--- 0.001405954360961914 seconds ---
# ===================================================
# case:95 ===>
# Shortest path for (20, 23) not found in shortest_paths.
# case:96 ===>
# case:97 ===>
# [0, 45, 12, 36, 23, 16, 46]
# avoiding edges:(0, 45), (5, 10)
# Query time--- 0.005010366439819336 seconds ---
# query output:[] , weight:inf
# No path exists between nodes 0 and 46 after removing edges (0, 45) and (5, 10).
# cross_check output:[] , weight:inf
# Cross_check time--- 0.0009961128234863281 seconds ---
# ===================================================
# case:98 ===>
# [21, 14, 6]
# avoiding edges:(21, 14), (7, 46)
# Query time--- 0.004982709884643555 seconds ---
# query output:[21, 12, 45, 6] , weight:98.01010101010101
# cross_check output:[21, 12, 45, 6] , weight:98.01010101010101
# Cross_check time--- 0.0019981861114501953 seconds ---
# ===================================================
# case:99 ===>
# [37, 22, 38]
# avoiding edges:(37, 22), (46, 16)
# Query time--- 0.005074977874755859 seconds ---
# query output:[37, 9, 22, 38] , weight:75.31313131313132
# cross_check output:[37, 9, 22, 38] , weight:75.31313131313132
# Cross_check time--- 0.0009911060333251953 seconds ---
# ===================================================
# case:100 ===>
# [23, 10, 42]
# avoiding edges:(23, 10), (32, 33)
# Query time--- 0.0030221939086914062 seconds ---
# query output:[23, 21, 37, 19, 42] , weight:138.63636363636363
# cross_check output:[23, 21, 37, 19, 42] , weight:138.63636363636365
# Cross_check time--- 0.0009999275207519531 seconds ---
# ===================================================
# case:101 ===>
# [38, 22, 37, 19, 49]
# avoiding edges:(37, 19), (3, 31)
# Query time--- 0.010486602783203125 seconds ---
# query output:[38, 22, 15, 42, 19, 49] , weight:155.09090909090907
# cross_check output:[38, 22, 15, 42, 19, 49] , weight:155.09090909090907
# Cross_check time--- 0.0009996891021728516 seconds ---
# ===================================================
# case:102 ===>
# [2, 18, 27, 32]
# avoiding edges:(2, 18), (12, 26)
# Query time--- 0.012011289596557617 seconds ---
# query output:[2, 37, 12, 32] , weight:187.94949494949495
# cross_check output:[2, 37, 12, 32] , weight:187.94949494949495
# Cross_check time--- 0.0009925365447998047 seconds ---
# ===================================================
# case:103 ===>
# [2, 37, 22, 3]
# avoiding edges:(22, 3), (46, 42)
# Query time--- 0.009002447128295898 seconds ---
# query output:[2, 41, 24, 8, 3] , weight:164.2020202020202
# cross_check output:[2, 41, 24, 8, 3] , weight:164.2020202020202
# Cross_check time--- 0.0020020008087158203 seconds ---
# ===================================================
# case:104 ===>
# [2, 18, 27, 32, 33]
# avoiding edges:(32, 33), (28, 34)
# Query time--- 0.010003089904785156 seconds ---
# query output:[2, 37, 21, 14, 35, 33] , weight:165.72727272727275
# cross_check output:[2, 37, 21, 14, 35, 33] , weight:165.72727272727275
# Cross_check time--- 0.0011589527130126953 seconds ---
# ===================================================
# case:105 ===>
# [47, 33, 32, 27, 18, 2]
# avoiding edges:(33, 32), (13, 42)
# Query time--- 0.012827157974243164 seconds ---
# query output:[47, 33, 35, 14, 21, 37, 2] , weight:193.63636363636363
# cross_check output:[47, 33, 35, 14, 21, 37, 2] , weight:193.63636363636363
# Cross_check time--- 0.0010037422180175781 seconds ---
# ===================================================
# case:106 ===>
# [39, 10, 5, 48, 9, 22, 3]
# avoiding edges:(48, 9), (1, 40)
# Query time--- 0.022820472717285156 seconds ---
# query output:[39, 23, 21, 37, 22, 3] , weight:202.95959595959596
# cross_check output:[39, 23, 21, 37, 22, 3] , weight:202.959595959596
# Cross_check time--- 0.0021398067474365234 seconds ---
# ===================================================
# case:107 ===>
# [16, 46, 42, 15]
# avoiding edges:(42, 15), (21, 12)
# Query time--- 0.011622428894042969 seconds ---
# query output:[16, 46, 24, 22, 15] , weight:125.60606060606061
# cross_check output:[16, 46, 24, 22, 15] , weight:125.60606060606061
# Cross_check time--- 0.00113677978515625 seconds ---
# ===================================================
# case:108 ===>
# [31, 15, 35, 26]
# avoiding edges:(31, 15), (40, 4)
# Query time--- 0.011483192443847656 seconds ---
# query output:[31, 3, 22, 15, 35, 26] , weight:213.14141414141415
# cross_check output:[31, 3, 22, 15, 35, 26] , weight:213.14141414141415
# Cross_check time--- 0.0009822845458984375 seconds ---
# ===================================================
# case:109 ===>
# Shortest path for (30, 0) not found in shortest_paths.
# case:110 ===>
# [15, 35, 14, 21]
# avoiding edges:(15, 35), (48, 13)
# Query time--- 0.006515026092529297 seconds ---
# query output:[15, 22, 37, 21] , weight:68.93939393939394
# cross_check output:[15, 22, 37, 21] , weight:68.93939393939394
# Cross_check time--- 0.0020051002502441406 seconds ---
# ===================================================
# case:111 ===>
# [38, 22, 37, 21]
# avoiding edges:(38, 22), (17, 4)
# Query time--- 0.00299072265625 seconds ---
# query output:[] , weight:inf
# No path exists between nodes 38 and 21 after removing edges (38, 22) and (17, 4).
# cross_check output:[] , weight:inf
# Cross_check time--- 0.001001119613647461 seconds ---
# ===================================================
# case:112 ===>
# [0, 45, 12, 37, 19, 42]
# avoiding edges:(12, 37), (7, 46)
# Query time--- 0.011858940124511719 seconds ---
# query output:[0, 45, 12, 21, 37, 19, 42] , weight:193.77777777777774
# cross_check output:[0, 45, 12, 21, 37, 19, 42] , weight:193.77777777777774
# Cross_check time--- 0.0009868144989013672 seconds ---
# ===================================================
# case:113 ===>
# [33, 49, 40]
# avoiding edges:(49, 40), (32, 33)
# Query time--- 0.005878448486328125 seconds ---
# query output:[33, 48, 40] , weight:153.87878787878788
# cross_check output:[33, 48, 40] , weight:153.87878787878788
# Cross_check time--- 0.0010094642639160156 seconds ---
# ===================================================
# case:114 ===>
# [47, 33, 49, 40, 4]
# avoiding edges:(47, 33), (41, 24)
# Query time--- 0.013832807540893555 seconds ---
# query output:[47, 39, 23, 36, 12, 25, 40, 4] , weight:274.25252525252523
# cross_check output:[47, 39, 23, 36, 12, 25, 40, 4] , weight:274.2525252525253
# Cross_check time--- 0.0014426708221435547 seconds ---
# ===================================================
# case:115 ===>
# [15, 31, 4]
# avoiding edges:(31, 4), (42, 19)
# Query time--- 0.008378267288208008 seconds ---
# query output:[15, 42, 46, 7, 4] , weight:164.92929292929293
# cross_check output:[15, 42, 46, 7, 4] , weight:164.92929292929293
# Cross_check time--- 0.0010056495666503906 seconds ---
# ===================================================
# case:116 ===>
# [32, 12, 25, 17]
# avoiding edges:(25, 17), (37, 12)
# Query time--- 0.012086868286132812 seconds ---
# query output:[32, 27, 1, 40, 4, 17] , weight:206.21212121212122
# cross_check output:[32, 27, 1, 40, 4, 17] , weight:206.21212121212122
# Cross_check time--- 0.0011832714080810547 seconds ---
# ===================================================
# case:117 ===>
# [19, 44, 6]
# avoiding edges:(44, 6), (3, 22)
# Query time--- 0.009828329086303711 seconds ---
# query output:[19, 37, 12, 45, 6] , weight:118.65656565656565
# cross_check output:[19, 37, 12, 45, 6] , weight:118.65656565656565
# Cross_check time--- 0.0010018348693847656 seconds ---
# ===================================================
# case:118 ===>
# [47, 33, 32, 27, 1]
# avoiding edges:(32, 27), (40, 49)
# Query time--- 0.00901174545288086 seconds ---
# query output:[47, 33, 48, 40, 1] , weight:201.8181818181818
# cross_check output:[47, 33, 48, 40, 1] , weight:201.8181818181818
# Cross_check time--- 0.0010292530059814453 seconds ---
# ===================================================
# case:119 ===>
# [28, 1, 40, 4, 31]
# avoiding edges:(1, 40), (10, 32)
# Query time--- 0.009054183959960938 seconds ---
# query output:[28, 46, 24, 8, 3, 31] , weight:209.11111111111111
# cross_check output:[28, 46, 24, 8, 3, 31] , weight:209.11111111111111
# Cross_check time--- 0.0010077953338623047 seconds ---
# ===================================================
# case:120 ===>
# [32, 27, 1, 28]
# avoiding edges:(32, 27), (10, 39)
# Query time--- 0.01220393180847168 seconds ---
# query output:[32, 12, 25, 40, 1, 28] , weight:173.75757575757575
# cross_check output:[32, 12, 25, 40, 1, 28] , weight:173.75757575757575
# Cross_check time--- 0.0014500617980957031 seconds ---
# ===================================================
# case:121 ===>
# [34, 42, 10, 23]
# avoiding edges:(10, 23), (21, 36)
# Query time--- 0.010578155517578125 seconds ---
# query output:[34, 42, 19, 37, 21, 23] , weight:192.57575757575756
# cross_check output:[34, 42, 19, 37, 21, 23] , weight:192.57575757575756
# Cross_check time--- 0.0010061264038085938 seconds ---
# ===================================================
# case:122 ===>
# [38, 22, 37, 2, 18, 44]
# avoiding edges:(2, 18), (10, 23)
# Query time--- 0.007993459701538086 seconds ---
# query output:[38, 22, 37, 19, 44] , weight:153.7171717171717
# cross_check output:[38, 22, 37, 19, 44] , weight:153.7171717171717
# Cross_check time--- 0.0010142326354980469 seconds ---
# ===================================================
# case:123 ===>
# [28, 1, 27]
# avoiding edges:(28, 1), (45, 43)
# Query time--- 0.004448890686035156 seconds ---
# query output:[28, 37, 1, 27] , weight:153.92929292929293
# cross_check output:[28, 37, 1, 27] , weight:153.92929292929293
# Cross_check time--- 0.0 seconds ---
# ===================================================
# case:124 ===>
# [1, 40, 25, 12, 26]
# avoiding edges:(1, 40), (23, 39)
# Query time--- 0.00803828239440918 seconds ---
# query output:[1, 37, 21, 14, 35, 26] , weight:146.54545454545456
# cross_check output:[1, 37, 21, 14, 35, 26] , weight:146.54545454545456
# Cross_check time--- 0.0009996891021728516 seconds ---
# ===================================================
# case:125 ===>
# [4, 7]
# case:126 ===>
# [23, 21, 14, 35, 15]
# avoiding edges:(21, 14), (41, 13)
# Query time--- 0.010449647903442383 seconds ---
# query output:[23, 21, 37, 22, 15] , weight:143.6161616161616
# cross_check output:[23, 21, 37, 22, 15] , weight:143.6161616161616
# Cross_check time--- 0.0 seconds ---
# ===================================================
# case:127 ===>
# [16, 46, 24, 22, 38]
# avoiding edges:(22, 38), (46, 24)
# Query time--- 0.002000093460083008 seconds ---
# query output:[] , weight:inf
# No path exists between nodes 16 and 38 after removing edges (22, 38) and (46, 24).
# cross_check output:[] , weight:inf
# Cross_check time--- 0.0 seconds ---
# ===================================================
# case:128 ===>
# Shortest path for (14, 30) not found in shortest_paths.
# case:129 ===>
# [45, 12, 25, 40, 4]
# avoiding edges:(12, 25), (40, 21)
# Query time--- 0.006994724273681641 seconds ---
# query output:[45, 6, 44, 40, 4] , weight:186.55555555555554
# cross_check output:[45, 6, 44, 40, 4] , weight:186.55555555555554
# Cross_check time--- 0.0013065338134765625 seconds ---
# ===================================================
# case:130 ===>
# [10, 5, 48, 9, 37, 21]
# avoiding edges:(9, 37), (35, 33)
# Query time--- 0.010993480682373047 seconds ---
# query output:[10, 23, 21] , weight:111.02020202020202
# cross_check output:[10, 23, 21] , weight:111.02020202020202
# Cross_check time--- 0.0014231204986572266 seconds ---
# ===================================================
# case:131 ===>
# [40, 25, 17]
# avoiding edges:(25, 17), (3, 8)
# Query time--- 0.0031194686889648438 seconds ---
# query output:[40, 4, 17] , weight:110.31313131313132
# cross_check output:[40, 4, 17] , weight:110.31313131313132
# Cross_check time--- 0.0009982585906982422 seconds ---
# ===================================================
# case:132 ===>
# [37, 21, 14, 29]
# avoiding edges:(14, 29), (40, 21)
# Query time--- 0.008999824523925781 seconds ---
# query output:[37, 22, 24, 8, 29] , weight:168.95959595959593
# cross_check output:[37, 22, 24, 8, 29] , weight:168.95959595959596
# Cross_check time--- 0.002031087875366211 seconds ---
# ===================================================
# case:133 ===>
# [7, 46, 48, 33, 47]
# avoiding edges:(33, 47), (48, 9)
# Query time--- 0.11438775062561035 seconds ---
# query output:[7, 46, 48, 5, 10, 39, 47] , weight:229.95959595959596
# cross_check output:[7, 46, 48, 5, 10, 39, 47] , weight:229.959595959596
# Cross_check time--- 0.0009984970092773438 seconds ---
# ===================================================
# case:134 ===>
# [15, 42, 19, 49]
# avoiding edges:(19, 49), (41, 13)
# Query time--- 0.005283355712890625 seconds ---
# query output:[15, 35, 33, 49] , weight:154.39393939393938
# cross_check output:[15, 35, 33, 49] , weight:154.39393939393938
# Cross_check time--- 0.0009982585906982422 seconds ---
# ===================================================
# case:135 ===>
# [48, 13]
# case:136 ===>
# [46, 24, 22]
# avoiding edges:(46, 24), (33, 47)
# Query time--- 0.004000186920166016 seconds ---
# query output:[46, 48, 9, 22] , weight:83.58585858585859
# cross_check output:[46, 48, 9, 22] , weight:83.58585858585859
# Cross_check time--- 0.0 seconds ---
# ===================================================
# case:137 ===>
# [42, 15, 22]
# avoiding edges:(42, 15), (46, 16)
# Query time--- 0.006003141403198242 seconds ---
# query output:[42, 19, 37, 22] , weight:88.96969696969697
# cross_check output:[42, 19, 37, 22] , weight:88.96969696969697
# Cross_check time--- 0.0011670589447021484 seconds ---
# ===================================================
# case:138 ===>
# [17, 3]
# case:139 ===>
# [0, 45, 12, 21]
# avoiding edges:(0, 45), (21, 23)
# Query time--- 0.002424001693725586 seconds ---
# query output:[] , weight:inf
# No path exists between nodes 0 and 21 after removing edges (0, 45) and (21, 23).
# cross_check output:[] , weight:inf
# Cross_check time--- 0.0010266304016113281 seconds ---
# ===================================================
# case:140 ===>
# [0, 45, 12, 36, 23, 16, 46]
# avoiding edges:(12, 36), (17, 25)
# Query time--- 0.015443563461303711 seconds ---
# query output:[0, 45, 6, 13, 48, 46] , weight:206.91919191919192
# cross_check output:[0, 45, 6, 13, 48, 46] , weight:206.91919191919195
# Cross_check time--- 0.0009875297546386719 seconds ---
# ===================================================
# case:141 ===>
# Shortest path for (36, 11) not found in shortest_paths.
# case:142 ===>
# [39, 10, 5, 48, 46, 24, 8]
# avoiding edges:(48, 46), (41, 13)
# Query time--- 0.016070127487182617 seconds ---
# query output:[39, 23, 16, 46, 24, 8] , weight:180.94949494949495
# cross_check output:[39, 23, 16, 46, 24, 8] , weight:180.94949494949495
# Cross_check time--- 0.0009953975677490234 seconds ---
# ===================================================
# case:143 ===>
# Shortest path for (7, 11) not found in shortest_paths.
# case:144 ===>
# [45, 12, 25, 40, 49]
# avoiding edges:(12, 25), (48, 9)
# Query time--- 0.005054473876953125 seconds ---
# query output:[45, 12, 26, 49] , weight:149.59595959595958
# cross_check output:[45, 12, 26, 49] , weight:149.59595959595958
# Cross_check time--- 0.0009942054748535156 seconds ---
# ===================================================
# case:145 ===>
# [40, 1, 27, 32]
# avoiding edges:(1, 27), (35, 15)
# Query time--- 0.00537419319152832 seconds ---
# query output:[40, 25, 12, 32] , weight:125.67676767676767
# cross_check output:[40, 25, 12, 32] , weight:125.67676767676767
# Cross_check time--- 0.001007080078125 seconds ---
# ===================================================
# case:146 ===>
# Shortest path for (32, 20) not found in shortest_paths.
# case:147 ===>
# [37, 12, 45, 0]
# avoiding edges:(37, 12), (22, 38)
# Query time--- 0.004991769790649414 seconds ---
# query output:[37, 21, 12, 45, 0] , weight:135.5151515151515
# cross_check output:[37, 21, 12, 45, 0] , weight:135.5151515151515
# Cross_check time--- 0.0010020732879638672 seconds ---
# ===================================================
# case:148 ===>
# [45, 12, 37, 22, 24]
# avoiding edges:(37, 22), (32, 12)
# Query time--- 0.015467166900634766 seconds ---
# query output:[45, 12, 36, 23, 16, 46, 24] , weight:170.47474747474746
# cross_check output:[45, 12, 36, 23, 16, 46, 24] , weight:170.47474747474746
# Cross_check time--- 0.0010020732879638672 seconds ---
# ===================================================
# case:149 ===>
# [18, 2, 41, 24, 8]
# avoiding edges:(18, 2), (42, 19)
# Query time--- 0.020200729370117188 seconds ---
# query output:[18, 27, 1, 28, 46, 24, 8] , weight:178.59595959595958
# cross_check output:[18, 27, 1, 28, 46, 24, 8] , weight:178.59595959595958
# Cross_check time--- 0.001001119613647461 seconds ---
# ===================================================
# case:150 ===>
# [0, 45, 12, 26, 35]
# avoiding edges:(12, 26), (10, 32)
# Query time--- 0.007998466491699219 seconds ---
# query output:[0, 45, 12, 21, 14, 35] , weight:162.84848484848484
# cross_check output:[0, 45, 12, 21, 14, 35] , weight:162.84848484848487
# Cross_check time--- 0.0 seconds ---
# ===================================================
# case:151 ===>
# Shortest path for (11, 49) not found in shortest_paths.
# case:152 ===>
# [42, 19, 37]
# avoiding edges:(42, 19), (17, 4)
# Query time--- 0.005007266998291016 seconds ---
# query output:[42, 15, 22, 37] , weight:84.78787878787878
# cross_check output:[42, 15, 22, 37] , weight:84.78787878787878
# Cross_check time--- 0.0010013580322265625 seconds ---
# ===================================================
# case:153 ===>
# [32, 12, 36, 23, 16]
# avoiding edges:(12, 36), (46, 42)
# Query time--- 0.005209922790527344 seconds ---
# query output:[32, 10, 23, 16] , weight:185.29292929292927
# cross_check output:[32, 10, 23, 16] , weight:185.29292929292927
# Cross_check time--- 0.0 seconds ---
# ===================================================
# case:154 ===>
# Shortest path for (30, 18) not found in shortest_paths.
# case:155 ===>
# [28, 1, 27, 32, 33, 47]
# avoiding edges:(32, 33), (45, 12)
# Query time--- 0.25161004066467285 seconds ---
# query output:[28, 1, 40, 49, 33, 47] , weight:188.85858585858585
# cross_check output:[28, 1, 40, 49, 33, 47] , weight:188.85858585858585
# Cross_check time--- 0.0012798309326171875 seconds ---
# ===================================================
# case:156 ===>
# [33, 32, 27, 18]
# avoiding edges:(32, 27), (40, 4)
# Query time--- 0.014331340789794922 seconds ---
# query output:[33, 49, 40, 1, 27, 18] , weight:170.54545454545456
# cross_check output:[33, 49, 40, 1, 27, 18] , weight:170.54545454545453
# Cross_check time--- 0.0 seconds ---
# ===================================================
# case:157 ===>
# [48, 46, 42]
# avoiding edges:(46, 42), (22, 38)
# Query time--- 0.01169586181640625 seconds ---
# query output:[48, 9, 22, 15, 42] , weight:93.65656565656566
# cross_check output:[48, 9, 22, 15, 42] , weight:93.65656565656566
# Cross_check time--- 0.0020017623901367188 seconds ---
# ===================================================
# case:158 ===>
# [49, 40, 25, 12, 45]
# avoiding edges:(40, 25), (12, 26)
# Query time--- 0.008645772933959961 seconds ---
# query output:[49, 19, 37, 12, 45] , weight:157.1010101010101
# cross_check output:[49, 19, 37, 12, 45] , weight:157.1010101010101
# Cross_check time--- 0.0014150142669677734 seconds ---
# ===================================================
# case:159 ===>
# [41, 2, 37, 9]
# avoiding edges:(41, 2), (25, 12)
# Query time--- 0.004966259002685547 seconds ---
# query output:[41, 13, 48, 9] , weight:114.23232323232322
# cross_check output:[41, 13, 48, 9] , weight:114.23232323232322
# Cross_check time--- 0.0 seconds ---
# ===================================================
# case:160 ===>
# [9, 48, 33, 47]
# avoiding edges:(33, 47), (10, 32)
# Query time--- 0.01038980484008789 seconds ---
# query output:[9, 48, 5, 10, 39, 47] , weight:176.989898989899
# cross_check output:[9, 48, 5, 10, 39, 47] , weight:176.989898989899
# Cross_check time--- 0.0 seconds ---
# ===================================================
# case:161 ===>
# [33, 32, 27, 1]
# avoiding edges:(33, 32), (6, 14)
# Query time--- 0.00616145133972168 seconds ---
# query output:[33, 49, 40, 1] , weight:132.8989898989899
# cross_check output:[33, 49, 40, 1] , weight:132.8989898989899
# Cross_check time--- 0.0010025501251220703 seconds ---
# ===================================================
# case:162 ===>
# [0, 45, 6]
# avoiding edges:(45, 6), (3, 31)
# Query time--- 0.010787487030029297 seconds ---
# query output:[0, 45, 12, 25, 40, 44, 6] , weight:205.82828282828282
# cross_check output:[0, 45, 12, 25, 40, 44, 6] , weight:205.82828282828282
# Cross_check time--- 0.0009999275207519531 seconds ---
# ===================================================
# case:163 ===>
# [27, 18, 2, 41, 13]
# avoiding edges:(41, 13), (42, 15)
# Query time--- 0.011298179626464844 seconds ---
# query output:[27, 18, 44, 6, 13] , weight:129.66666666666669
# cross_check output:[27, 18, 44, 6, 13] , weight:129.66666666666669
# Cross_check time--- 0.0009982585906982422 seconds ---
# ===================================================
# case:164 ===>
# case:165 ===>
# Shortest path for (12, 20) not found in shortest_paths.
# case:166 ===>
# [41, 13, 48]
# avoiding edges:(41, 13), (48, 46)
# Query time--- 0.010654926300048828 seconds ---
# query output:[41, 2, 37, 9, 48] , weight:126.74747474747475
# cross_check output:[41, 2, 37, 9, 48] , weight:126.74747474747475
# Cross_check time--- 0.0 seconds ---
# ===================================================
# case:167 ===>
# [7, 46, 42, 19, 49]
# avoiding edges:(42, 19), (23, 36)
# Query time--- 0.009798526763916016 seconds ---
# query output:[7, 46, 48, 40, 49] , weight:188.1919191919192
# cross_check output:[7, 46, 48, 40, 49] , weight:188.1919191919192
# Cross_check time--- 0.001001119613647461 seconds ---
# ===================================================
# case:168 ===>
# [34, 28, 1, 40, 25]
# avoiding edges:(28, 1), (22, 7)
# Query time--- 0.008999347686767578 seconds ---
# query output:[34, 42, 19, 37, 21, 40, 25] , weight:186.35353535353534
# cross_check output:[34, 42, 19, 37, 21, 40, 25] , weight:186.35353535353534
# Cross_check time--- 0.0009915828704833984 seconds ---
# ===================================================
# case:169 ===>
# [18, 27, 32, 33, 47]
# avoiding edges:(18, 27), (32, 12)
# Query time--- 0.009998798370361328 seconds ---
# query output:[18, 2, 37, 21, 14, 35, 33, 47] , weight:205.6969696969697
# cross_check output:[18, 2, 37, 21, 14, 35, 33, 47] , weight:205.69696969696972
# Cross_check time--- 0.001003265380859375 seconds ---
# ===================================================
# case:170 ===>
# [47, 33, 48, 46]
# avoiding edges:(48, 46), (35, 15)
# Query time--- 0.008257865905761719 seconds ---
# query output:[47, 33, 49, 19, 42, 46] , weight:207.08080808080805
# cross_check output:[47, 33, 49, 19, 42, 46] , weight:207.08080808080805
# Cross_check time--- 0.0012958049774169922 seconds ---
# ===================================================
# case:171 ===>
# [34, 42, 46, 48]
# avoiding edges:(34, 42), (31, 4)
# Query time--- 0.006848335266113281 seconds ---
# query output:[34, 24, 46, 48] , weight:149.55555555555554
# cross_check output:[34, 24, 46, 48] , weight:149.55555555555554
# Cross_check time--- 0.0010230541229248047 seconds ---
# ===================================================
# case:172 ===>
# [4, 7]
# case:173 ===>
# [15, 35, 26]
# avoiding edges:(35, 26), (46, 16)
# Query time--- 0.005064725875854492 seconds ---
# query output:[15, 22, 37, 12, 26] , weight:168.09090909090907
# cross_check output:[15, 22, 37, 12, 26] , weight:168.09090909090907
# Cross_check time--- 0.0009753704071044922 seconds ---
# ===================================================
# case:174 ===>
# [13, 48, 46, 24, 8]
# avoiding edges:(46, 24), (3, 31)
# Query time--- 0.009980916976928711 seconds ---
# query output:[13, 48, 9, 22, 24, 8] , weight:151.02020202020202
# cross_check output:[13, 48, 9, 22, 24, 8] , weight:151.02020202020202
# Cross_check time--- 0.0014874935150146484 seconds ---
# ===================================================
# case:175 ===>
# [3, 22, 37, 12, 45, 43]
# avoiding edges:(12, 45), (22, 9)
# ...
# query output:[41, 2, 37, 12] , weight:133.59595959595958
# cross_check output:[41, 2, 37, 12] , weight:133.59595959595958
# Cross_check time--- 0.0009999275207519531 seconds ---
# ===================================================
# case:944 ===>
# [27, 36, 23, 39]
# avoiding edges:(23, 39), (37, 21)
# Query time--- 0.010000228881835938 seconds ---
# query output:[27, 32, 10, 39] , weight:169.56565656565655
# cross_check output:[27, 32, 10, 39] , weight:169.56565656565658
# Cross_check time--- 0.0009999275207519531 seconds ---
# ===================================================
# case:945 ===>
# Shortest path for (30, 45) not found in shortest_paths.
# case:946 ===>
# [37, 22, 24, 8]
# avoiding edges:(24, 8), (42, 34)
# Query time--- 0.0030002593994140625 seconds ---
# query output:[37, 22, 3, 8] , weight:135.93939393939394
# cross_check output:[37, 22, 3, 8] , weight:135.93939393939394
# Cross_check time--- 0.0009999275207519531 seconds ---
# ===================================================
# case:947 ===>
# [10, 23, 16]
# avoiding edges:(10, 23), (41, 13)
# Query time--- 0.0070002079010009766 seconds ---
# query output:[10, 5, 48, 46, 16] , weight:114.95959595959596
# cross_check output:[10, 5, 48, 46, 16] , weight:114.95959595959596
# Cross_check time--- 0.0009999275207519531 seconds ---
# ===================================================
# case:948 ===>
# [3, 22, 15, 35]
# avoiding edges:(22, 15), (35, 33)
# Query time--- 0.009999752044677734 seconds ---
# query output:[3, 22, 37, 21, 14, 35] , weight:127.56565656565655
# cross_check output:[3, 22, 37, 21, 14, 35] , weight:127.56565656565657
# Cross_check time--- 0.0009946823120117188 seconds ---
# ===================================================
# case:949 ===>
# [49, 40, 25, 17]
# avoiding edges:(40, 25), (42, 15)
# Query time--- 0.005005598068237305 seconds ---
# query output:[49, 40, 4, 17] , weight:172.2828282828283
# cross_check output:[49, 40, 4, 17] , weight:172.2828282828283
# Cross_check time--- 0.0009996891021728516 seconds ---
# ===================================================
# case:950 ===>
# [26, 41, 2]
# avoiding edges:(41, 2), (44, 19)
# Query time--- 0.006000041961669922 seconds ---
# query output:[26, 35, 14, 21, 37, 2] , weight:135.59595959595958
# cross_check output:[26, 35, 14, 21, 37, 2] , weight:135.59595959595958
# Cross_check time--- 0.0009996891021728516 seconds ---
# ===================================================
# case:951 ===>
# [46, 42, 19, 49]
# avoiding edges:(19, 49), (32, 33)
# Query time--- 0.008041143417358398 seconds ---
# query output:[46, 48, 40, 49] , weight:163.93939393939394
# cross_check output:[46, 48, 40, 49] , weight:163.93939393939394
# Cross_check time--- 0.0009996891021728516 seconds ---
# ===================================================
# case:952 ===>
# [46, 42, 34]
# avoiding edges:(42, 34), (14, 35)
# Query time--- 0.0029997825622558594 seconds ---
# query output:[46, 24, 34] , weight:105.54545454545453
# cross_check output:[46, 24, 34] , weight:105.54545454545453
# Cross_check time--- 0.0009999275207519531 seconds ---
# ===================================================
# case:953 ===>
# [1, 40, 48, 5]
# avoiding edges:(40, 48), (35, 33)
# Query time--- 0.0070002079010009766 seconds ---
# query output:[1, 37, 9, 48, 5] , weight:128.8080808080808
# cross_check output:[1, 37, 9, 48, 5] , weight:128.8080808080808
# Cross_check time--- 0.0009996891021728516 seconds ---
# ===================================================
# case:954 ===>
# case:955 ===>
# [7, 46, 42, 15]
# avoiding edges:(7, 46), (37, 21)
# Query time--- 0.00503993034362793 seconds ---
# query output:[7, 22, 15] , weight:118.77777777777779
# cross_check output:[7, 22, 15] , weight:118.77777777777779
# Cross_check time--- 0.0009999275207519531 seconds ---
# ===================================================
# case:956 ===>
# [23, 36, 12, 25, 40]
# avoiding edges:(25, 40), (27, 32)
# Query time--- 0.004000186920166016 seconds ---
# query output:[23, 21, 40] , weight:127.34343434343435
# cross_check output:[23, 21, 40] , weight:127.34343434343435
# Cross_check time--- 0.0009999275207519531 seconds ---
# ===================================================
# case:957 ===>
# [7, 46, 42, 19, 49]
# avoiding edges:(42, 19), (41, 26)
# Query time--- 0.00700068473815918 seconds ---
# query output:[7, 46, 48, 40, 49] , weight:188.1919191919192
# cross_check output:[7, 46, 48, 40, 49] , weight:188.1919191919192
# Cross_check time--- 0.00099945068359375 seconds ---
# ===================================================
# case:958 ===>
# [28, 1, 40, 25, 12, 45, 43]
# avoiding edges:(12, 45), (10, 23)
# Query time--- 0.03299999237060547 seconds ---
# query output:[28, 1, 27, 18, 44, 6, 45, 43] , weight:184.72727272727275
# cross_check output:[28, 1, 27, 18, 44, 6, 45, 43] , weight:184.72727272727275
# Cross_check time--- 0.0 seconds ---
# ===================================================
# case:959 ===>
# [1, 40, 25, 12, 45, 0]
# avoiding edges:(12, 45), (27, 18)
# Query time--- 0.05461692810058594 seconds ---
# query output:[1, 40, 44, 6, 45, 0] , weight:174.43434343434342
# cross_check output:[1, 40, 44, 6, 45, 0] , weight:174.43434343434345
# Cross_check time--- 0.0009999275207519531 seconds ---
# ===================================================
# case:960 ===>
# Shortest path for (2, 11) not found in shortest_paths.
# case:961 ===>
# [31, 3, 22, 9, 48, 5, 10, 39]
# avoiding edges:(22, 9), (4, 7)
# Query time--- 0.017999887466430664 seconds ---
# query output:[31, 15, 42, 10, 39] , weight:243.8080808080808
# cross_check output:[31, 15, 42, 10, 39] , weight:243.8080808080808
# Cross_check time--- 0.0010001659393310547 seconds ---
# ===================================================
# case:962 ===>
# [39, 23, 21, 14]
# avoiding edges:(39, 23), (17, 25)
# Query time--- 0.007000446319580078 seconds ---
# query output:[39, 10, 5, 48, 9, 37, 21, 14] , weight:158.54545454545453
# cross_check output:[39, 10, 5, 48, 9, 37, 21, 14] , weight:158.54545454545456
# Cross_check time--- 0.0009999275207519531 seconds ---
# ===================================================
# case:963 ===>
# [39, 23, 21]
# avoiding edges:(39, 23), (21, 36)
# Query time--- 0.007999420166015625 seconds ---
# query output:[39, 10, 5, 48, 9, 37, 21] , weight:146.04040404040404
# cross_check output:[39, 10, 5, 48, 9, 37, 21] , weight:146.04040404040404
# Cross_check time--- 0.0009999275207519531 seconds ---
# ===================================================
# case:964 ===>
# [8, 24, 41, 2, 18, 27]
# avoiding edges:(18, 27), (10, 42)
# Query time--- 0.01900005340576172 seconds ---
# query output:[8, 24, 46, 28, 1, 27] , weight:156.989898989899
# cross_check output:[8, 24, 46, 28, 1, 27] , weight:156.989898989899
# Cross_check time--- 0.001094818115234375 seconds ---
# ===================================================
# case:965 ===>
# [0, 45, 12, 26]
# avoiding edges:(45, 12), (1, 37)
# Query time--- 0.03759336471557617 seconds ---
# query output:[0, 45, 6, 14, 35, 26] , weight:208.75757575757575
# cross_check output:[0, 45, 6, 14, 35, 26] , weight:208.75757575757575
# Cross_check time--- 0.0 seconds ---
# ===================================================
# case:966 ===>
# [43, 45, 12, 37, 22]
# avoiding edges:(37, 22), (31, 4)
# Query time--- 0.005002021789550781 seconds ---
# query output:[43, 45, 12, 37, 9, 22] , weight:188.4141414141414
# cross_check output:[43, 45, 12, 37, 9, 22] , weight:188.41414141414143
# Cross_check time--- 0.0010001659393310547 seconds ---
# ===================================================
# case:967 ===>
# [15, 31]
# case:968 ===>
# [33, 35, 26]
# avoiding edges:(35, 26), (42, 34)
# Query time--- 0.003999948501586914 seconds ---
# query output:[33, 49, 26] , weight:141.7070707070707
# cross_check output:[33, 49, 26] , weight:141.7070707070707
# Cross_check time--- 0.0010051727294921875 seconds ---
# ===================================================
# case:969 ===>
# [7, 46, 48, 40]
# avoiding edges:(7, 46), (32, 33)
# Query time--- 0.00800013542175293 seconds ---
# query output:[7, 4, 40] , weight:161.3030303030303
# cross_check output:[7, 4, 40] , weight:161.3030303030303
# Cross_check time--- 0.0 seconds ---
# ===================================================
# case:970 ===>
# [12, 45, 0]
# avoiding edges:(45, 0), (46, 16)
# Query time--- 0.00099945068359375 seconds ---
# query output:[] , weight:inf
# No path exists between nodes 12 and 0 after removing edges (45, 0) and (46, 16).
# cross_check output:[] , weight:inf
# Cross_check time--- 0.0 seconds ---
# ===================================================
# case:971 ===>
# [9, 37, 12, 45, 0]
# avoiding edges:(9, 37), (40, 25)
# Query time--- 0.009999513626098633 seconds ---
# query output:[9, 48, 13, 6, 45, 0] , weight:178.2020202020202
# cross_check output:[9, 48, 13, 6, 45, 0] , weight:178.2020202020202
# Cross_check time--- 0.0010004043579101562 seconds ---
# ===================================================
# case:972 ===>
# [7, 46, 48, 5, 10, 39]
# avoiding edges:(48, 5), (25, 12)
# Query time--- 0.012999773025512695 seconds ---
# query output:[7, 46, 16, 23, 39] , weight:161.16161616161617
# cross_check output:[7, 46, 16, 23, 39] , weight:161.16161616161617
# Cross_check time--- 0.0010001659393310547 seconds ---
# ===================================================
# case:973 ===>
# Shortest path for (4, 50) not found in shortest_paths.
# case:974 ===>
# [39, 10, 5, 48, 9, 22]
# avoiding edges:(10, 5), (28, 34)
# Query time--- 0.01699995994567871 seconds ---
# query output:[39, 23, 21, 37, 22] , weight:144.82828282828282
# cross_check output:[39, 23, 21, 37, 22] , weight:144.82828282828285
# Cross_check time--- 0.0009996891021728516 seconds ---
# ===================================================
# case:975 ===>
# [4, 40, 48]
# avoiding edges:(4, 40), (10, 25)
# Query time--- 0.004000186920166016 seconds ---
# query output:[4, 7, 46, 48] , weight:148.40404040404042
# cross_check output:[4, 7, 46, 48] , weight:148.40404040404042
# Cross_check time--- 0.0009999275207519531 seconds ---
# ===================================================
# case:976 ===>
# [47, 33, 48, 9]
# avoiding edges:(33, 48), (3, 22)
# Query time--- 0.01403951644897461 seconds ---
# query output:[47, 39, 10, 5, 48, 9] , weight:176.989898989899
# cross_check output:[47, 39, 10, 5, 48, 9] , weight:176.98989898989902
# Cross_check time--- 0.0009996891021728516 seconds ---
# ===================================================
# case:977 ===>
# [35, 15, 22, 38]
# avoiding edges:(15, 22), (24, 34)
# Query time--- 0.011553525924682617 seconds ---
# query output:[35, 14, 21, 37, 22, 38] , weight:81.16161616161617
# cross_check output:[35, 14, 21, 37, 22, 38] , weight:81.16161616161617
# Cross_check time--- 0.0 seconds ---
# ===================================================
# case:978 ===>
# [47, 33, 48, 46, 7]
# avoiding edges:(48, 46), (31, 4)
# Query time--- 0.008000373840332031 seconds ---
# query output:[47, 33, 35, 15, 42, 46, 7] , weight:216.1919191919192
# cross_check output:[47, 33, 35, 15, 42, 46, 7] , weight:216.19191919191923
# Cross_check time--- 0.0009999275207519531 seconds ---
# ===================================================
# case:979 ===>
# [6, 45, 12, 32, 33]
# avoiding edges:(32, 33), (22, 38)
# Query time--- 0.006999969482421875 seconds ---
# query output:[6, 14, 35, 33] , weight:172.67676767676767
# cross_check output:[6, 14, 35, 33] , weight:172.67676767676767
# Cross_check time--- 0.0009999275207519531 seconds ---
# ===================================================
# case:980 ===>
# [4, 40, 1, 27]
# avoiding edges:(40, 1), (26, 49)
# Query time--- 0.0060002803802490234 seconds ---
# query output:[4, 40, 44, 18, 27] , weight:208.36363636363635
# cross_check output:[4, 40, 44, 18, 27] , weight:208.36363636363635
# Cross_check time--- 0.0010001659393310547 seconds ---
# ===================================================
# case:981 ===>
# [46, 24, 22]
# avoiding edges:(24, 22), (35, 15)
# Query time--- 0.0039997100830078125 seconds ---
# query output:[46, 48, 9, 22] , weight:83.58585858585859
# cross_check output:[46, 48, 9, 22] , weight:83.58585858585859
# Cross_check time--- 0.0009996891021728516 seconds ---
# ===================================================
# case:982 ===>
# [2, 37, 22, 3, 31]
# avoiding edges:(3, 31), (37, 22)
# Query time--- 0.004000186920166016 seconds ---
# query output:[2, 37, 21, 14, 35, 15, 31] , weight:206.91919191919192
# cross_check output:[2, 37, 21, 14, 35, 15, 31] , weight:206.91919191919192
# Cross_check time--- 0.0009996891021728516 seconds ---
# ===================================================
# case:983 ===>
# [4, 40, 49, 33, 47]
# avoiding edges:(49, 33), (35, 15)
# Query time--- 0.01300048828125 seconds ---
# query output:[4, 40, 1, 27, 32, 33, 47] , weight:257.85858585858585
# cross_check output:[4, 40, 1, 27, 32, 33, 47] , weight:257.85858585858585
# Cross_check time--- 0.0010001659393310547 seconds ---
# ===================================================
# case:984 ===>
# [42, 15, 31]
# avoiding edges:(42, 15), (6, 44)
# Query time--- 0.004999637603759766 seconds ---
# query output:[42, 46, 24, 8, 3, 31] , weight:179.24242424242425
# cross_check output:[42, 46, 24, 8, 3, 31] , weight:179.24242424242425
# Cross_check time--- 0.0009996891021728516 seconds ---
# ===================================================
# case:985 ===>
# [40, 25, 12, 45, 43]
# avoiding edges:(45, 43), (2, 21)
# Query time--- 0.0019998550415039062 seconds ---
# query output:[] , weight:inf
# No path exists between nodes 40 and 43 after removing edges (45, 43) and (2, 21).
# cross_check output:[] , weight:inf
# Cross_check time--- 0.0010001659393310547 seconds ---
# ===================================================
# case:986 ===>
# Shortest path for (4, 50) not found in shortest_paths.
# case:987 ===>
# Shortest path for (3, 20) not found in shortest_paths.
# case:988 ===>
# [32, 10, 5, 48, 9, 22]
# avoiding edges:(32, 10), (27, 18)
# Query time--- 0.006000518798828125 seconds ---
# query output:[32, 12, 37, 22] , weight:164.58585858585857
# cross_check output:[32, 12, 37, 22] , weight:164.58585858585857
# Cross_check time--- 0.0009999275207519531 seconds ---
# ===================================================
# case:989 ===>
# Shortest path for (11, 39) not found in shortest_paths.
# case:990 ===>
# case:991 ===>
# [40, 1, 27, 32]
# avoiding edges:(1, 27), (0, 45)
# Query time--- 0.00899958610534668 seconds ---
# query output:[40, 25, 12, 32] , weight:125.67676767676767
# cross_check output:[40, 25, 12, 32] , weight:125.67676767676767
# Cross_check time--- 0.0009999275207519531 seconds ---
# ===================================================
# case:992 ===>
# case:993 ===>
# [23, 36, 12, 25]
# avoiding edges:(23, 36), (7, 46)
# Query time--- 0.003000020980834961 seconds ---
# query output:[23, 12, 25] , weight:81.84848484848484
# cross_check output:[23, 12, 25] , weight:81.84848484848484
# Cross_check time--- 0.0009996891021728516 seconds ---
# ===================================================
# case:994 ===>
# [21, 12]
# case:995 ===>
# [42, 15, 31]
# avoiding edges:(42, 15), (1, 37)
# Query time--- 0.0050394535064697266 seconds ---
# query output:[42, 46, 24, 8, 3, 31] , weight:179.24242424242425
# cross_check output:[42, 46, 24, 8, 3, 31] , weight:179.24242424242425
# Cross_check time--- 0.0010001659393310547 seconds ---
# ===================================================
# case:996 ===>
# [43, 45, 12, 26, 35]
# avoiding edges:(43, 45), (35, 15)
# Query time--- 0.003999948501586914 seconds ---
# query output:[] , weight:inf
# No path exists between nodes 43 and 35 after removing edges (43, 45) and (35, 15).
# cross_check output:[] , weight:inf
# Cross_check time--- 0.0009999275207519531 seconds ---
# ===================================================
# case:997 ===>
# [23, 36, 12, 25, 40, 49]
# avoiding edges:(36, 12), (37, 2)
# Query time--- 0.004000186920166016 seconds ---
# query output:[23, 12, 25, 40, 49] , weight:159.6060606060606
# cross_check output:[23, 12, 25, 40, 49] , weight:159.6060606060606
# Cross_check time--- 0.0010001659393310547 seconds ---
# ===================================================
# case:998 ===>
# Shortest path for (46, 30) not found in shortest_paths.
# case:999 ===>
# [15, 22, 9, 48, 5]
# avoiding edges:(15, 22), (3, 17)
# Query time--- 0.011835098266601562 seconds ---
# query output:[15, 42, 46, 48, 5] , weight:113.73737373737373
# cross_check output:[15, 42, 46, 48, 5] , weight:113.73737373737374
# Cross_check time--- 0.0009999275207519531 seconds ---
# ===================================================

# %% [markdown]
# *Debugging

# %%
print(f"right={right}, wrong={wrong}")
# Out:
# right=752, wrong=0

# %%
# ...existing code...
import random
import time

f = 2

query_times = []
cross_check_times = []

right = 0
wrong = 0

for case in range(1, 100):
    x = random.randint(0, 50)
    y = random.randint(0, 50)
    print(f"case:{case} ===>")
    if x == y:
        continue
    try:
        print(shortest_paths[(x, y)])
    except KeyError:
        print(f"Shortest path for ({x}, {y}) not found in shortest_paths.")
        continue

    path = shortest_paths[(x, y)]

    pedges = []
    for i in range(len(path) - 1):
        pedges.append((path[i], path[i + 1]))
    if len(pedges) < 1:
        continue
    e1 = random.choice(pedges)
    path2 , path2_distance = QUERY(G, x, y, [(e1[0], e1[1])]) 

    if path2 == []:
        continue
    pedges2 = []
    for i in range(len(path2) - 1):
        pedges2.append((path2[i], path2[i + 1]))
    if len(pedges2) < 1:
        continue
    
    e2 = random.choice(pedges2)
    # print(f"e1={e1}, e2={e2}")
    F3 = [(e1[0], e1[1]), (e2[0], e2[1])]
    print(G.has_edge(e1[0], e1[1]) , G.has_edge(e2[0], e2[1]))   
    print(f"avoiding edges:{e1[0], e1[1]}, {e2[0], e2[1]}")
    start_time = time.time()
    query_output, q_weight = QUERY2(G, x, y, 3, F3)
    query_times.append(time.time() - start_time)
    print("Query time--- %s seconds ---" % (time.time() - start_time))

    print(f"query output:{query_output} , weight:{q_weight}")

    start_time = time.time()
    cross_check_output, c_weight = cross_check2(G, x, y, (e1[0], e1[1]), (e2[0], e2[1]))
    cross_check_times.append(time.time() - start_time)

  

    print(f"cross_check output:{cross_check_output} , weight:{c_weight}")
    print("Cross_check time--- %s seconds ---" % (time.time() - start_time))
    if query_output != cross_check_output:
        wrong += 1
        print("!!!!!!!!!!!!----SOMETHING WENT WRONG-----!!!!!!!!!!!!!!!!!!")
    else:
        right += 1

    print("===================================================")
# Out:
# case:1 ===>
# [12, 36, 23, 10, 5]
# True True
# avoiding edges:(36, 23), (10, 5)
# Query time--- 0.002440214157104492 seconds ---
# query output:[12, 25, 40, 48, 5] , weight:120.3939393939394
# cross_check output:[12, 25, 40, 48, 5] , weight:120.3939393939394
# Cross_check time--- 0.0020034313201904297 seconds ---
# ===================================================
# case:2 ===>
# [42, 15, 35]
# True True
# avoiding edges:(15, 35), (21, 14)
# Query time--- 0.036759138107299805 seconds ---
# query output:[42, 15, 22, 9, 14, 35] , weight:171.2020202020202
# cross_check output:[42, 15, 22, 9, 14, 35] , weight:171.2020202020202
# Cross_check time--- 0.0 seconds ---
# ===================================================
# case:3 ===>
# [31, 15, 42, 34]
# True True
# avoiding edges:(15, 42), (8, 24)
# Query time--- 0.013030052185058594 seconds ---
# query output:[31, 3, 22, 24, 34] , weight:237.72727272727272
# cross_check output:[31, 3, 22, 24, 34] , weight:237.72727272727272
# Cross_check time--- 0.001001119613647461 seconds ---
# ===================================================
# case:4 ===>
# [18, 27, 1, 40, 49]
# True True
# avoiding edges:(18, 27), (18, 2)
# Query time--- 0.04166436195373535 seconds ---
# query output:[18, 44, 40, 49] , weight:167.56565656565658
# cross_check output:[18, 44, 40, 49] , weight:167.56565656565658
# Cross_check time--- 0.0009996891021728516 seconds ---
# ===================================================
# case:5 ===>
# [32, 33, 49]
# True True
# avoiding edges:(32, 33), (32, 27)
# Query time--- 0.01946735382080078 seconds ---
# query output:[32, 12, 25, 40, 49] , weight:187.64646464646464
# cross_check output:[32, 12, 25, 40, 49] , weight:187.64646464646464
# Cross_check time--- 0.00112152099609375 seconds ---
# ===================================================
# case:6 ===>
# Shortest path for (30, 40) not found in shortest_paths.
# case:7 ===>
# [31, 4, 40, 1, 27]
# True True
# avoiding edges:(4, 40), (1, 27)
# Query time--- 0.017766714096069336 seconds ---
# query output:[31, 3, 22, 37, 2, 18, 27] , weight:225.68686868686868
# cross_check output:[31, 3, 22, 37, 2, 18, 27] , weight:225.68686868686868
# Cross_check time--- 0.0009961128234863281 seconds ---
# ===================================================
# case:8 ===>
# [9, 22, 24, 8]
# True True
# avoiding edges:(9, 22), (9, 48)
# Query time--- 0.016761302947998047 seconds ---
# query output:[9, 37, 22, 24, 8] , weight:138.989898989899
# cross_check output:[9, 37, 22, 24, 8] , weight:138.989898989899
# Cross_check time--- 0.0019843578338623047 seconds ---
# ===================================================
# case:9 ===>
# [4, 40, 25, 12, 45, 6]
# True True
# avoiding edges:(40, 25), (4, 40)
# Query time--- 0.0034677982330322266 seconds ---
# query output:[4, 17, 25, 12, 45, 6] , weight:189.7878787878788
# cross_check output:[4, 17, 25, 12, 45, 6] , weight:189.7878787878788
# Cross_check time--- 0.0010464191436767578 seconds ---
# ===================================================
# case:10 ===>
# case:11 ===>
# [47, 33, 32, 27, 18, 2, 41]
# True True
# avoiding edges:(27, 18), (14, 21)
# Query time--- 0.05426192283630371 seconds ---
# query output:[47, 33, 48, 13, 41] , weight:222.76767676767673
# cross_check output:[47, 33, 48, 13, 41] , weight:222.76767676767673
# Cross_check time--- 0.0009794235229492188 seconds ---
# ===================================================
# case:12 ===>
# Shortest path for (2, 20) not found in shortest_paths.
# case:13 ===>
# [36, 21, 37, 22, 24]
# True True
# avoiding edges:(21, 37), (37, 22)
# Query time--- 0.004024505615234375 seconds ---
# query output:[36, 23, 16, 46, 24] , weight:149.6767676767677
# cross_check output:[36, 23, 16, 46, 24] , weight:149.6767676767677
# Cross_check time--- 0.0014431476593017578 seconds ---
# ===================================================
# case:14 ===>
# [36, 12, 26]
# True True
# avoiding edges:(12, 26), (21, 14)
# Query time--- 0.06405854225158691 seconds ---
# query output:[36, 12, 45, 6, 14, 35, 26] , weight:180.54545454545456
# cross_check output:[36, 12, 45, 6, 14, 35, 26] , weight:180.54545454545456
# Cross_check time--- 0.00099945068359375 seconds ---
# ===================================================
# case:15 ===>
# [33, 49, 40, 4]
# True True
# avoiding edges:(40, 4), (7, 4)
# Query time--- 0.012833356857299805 seconds ---
# query output:[33, 49, 40, 25, 17, 4] , weight:248.4040404040404
# cross_check output:[33, 49, 40, 25, 17, 4] , weight:248.4040404040404
# Cross_check time--- 0.0012881755828857422 seconds ---
# ===================================================
# case:16 ===>
# [43, 45, 6, 44, 18, 2]
# True True
# avoiding edges:(45, 6), (43, 45)
# Query time--- 0.008476495742797852 seconds ---
# query output:[] , weight:inf
# No path exists between nodes 43 and 2 after removing edges (45, 6) and (43, 45).
# cross_check output:[] , weight:inf
# Cross_check time--- 0.0005068778991699219 seconds ---
# ===================================================
# case:17 ===>
# [4, 40, 48, 9]
# True True
# avoiding edges:(48, 9), (21, 37)
# Query time--- 0.0060350894927978516 seconds ---
# query output:[4, 17, 3, 22, 9] , weight:182.6868686868687
# cross_check output:[4, 17, 3, 22, 9] , weight:182.6868686868687
# Cross_check time--- 0.0010781288146972656 seconds ---
# ===================================================
# case:18 ===>
# [47, 33, 49]
# True True
# avoiding edges:(33, 49), (21, 37)
# Query time--- 0.034093379974365234 seconds ---
# query output:[47, 33, 35, 26, 49] , weight:234.44444444444443
# cross_check output:[47, 33, 35, 26, 49] , weight:234.44444444444443
# Cross_check time--- 0.0010530948638916016 seconds ---
# ===================================================
# case:19 ===>
# [3, 31]
# True True
# avoiding edges:(3, 31), (17, 4)
# Query time--- 0.0010001659393310547 seconds ---
# query output:[3, 22, 15, 31] , weight:174.22222222222223
# cross_check output:[3, 22, 15, 31] , weight:174.22222222222223
# Cross_check time--- 0.0009822845458984375 seconds ---
# ===================================================
# case:20 ===>
# [5, 48, 40, 1, 27, 18]
# True True
# avoiding edges:(27, 18), (37, 2)
# Query time--- 0.009685277938842773 seconds ---
# query output:[5, 48, 13, 41, 2, 18] , weight:138.27272727272728
# cross_check output:[5, 48, 13, 41, 2, 18] , weight:138.27272727272728
# Cross_check time--- 0.0 seconds ---
# ===================================================
# case:21 ===>
# [37, 9, 48, 5]
# True True
# avoiding edges:(9, 48), (40, 48)
# Query time--- 0.006052494049072266 seconds ---
# query output:[37, 19, 42, 46, 48, 5] , weight:150.45454545454547
# cross_check output:[37, 19, 42, 46, 48, 5] , weight:150.45454545454547
# Cross_check time--- 0.0 seconds ---
# ===================================================
# case:22 ===>
# [0, 45, 12, 37, 22, 38]
# True True
# avoiding edges:(37, 22), (37, 9)
# Query time--- 0.004175424575805664 seconds ---
# query output:[0, 45, 6, 13, 48, 9, 22, 38] , weight:214.21212121212125
# cross_check output:[0, 45, 6, 13, 48, 9, 22, 38] , weight:214.21212121212125
# Cross_check time--- 0.0010528564453125 seconds ---
# ===================================================
# case:23 ===>
# [26, 35, 15]
# True True
# avoiding edges:(35, 15), (21, 37)
# Query time--- 0.03731036186218262 seconds ---
# query output:[26, 12, 37, 22, 15] , weight:168.09090909090907
# cross_check output:[26, 12, 37, 22, 15] , weight:168.09090909090907
# Cross_check time--- 0.0009989738464355469 seconds ---
# ===================================================
# case:24 ===>
# [27, 1, 40, 4]
# True True
# avoiding edges:(1, 40), (44, 40)
# Query time--- 0.012722969055175781 seconds ---
# query output:[27, 1, 28, 46, 7, 4] , weight:217.34343434343435
# cross_check output:[27, 1, 28, 46, 7, 4] , weight:217.34343434343435
# Cross_check time--- 0.0 seconds ---
# ===================================================
# case:25 ===>
# [9, 37, 19]
# True True
# avoiding edges:(9, 37), (37, 19)
# Query time--- 0.0013332366943359375 seconds ---
# query output:[9, 22, 15, 42, 19] , weight:112.0
# cross_check output:[9, 22, 15, 42, 19] , weight:112.0
# Cross_check time--- 0.000993967056274414 seconds ---
# ===================================================
# case:26 ===>
# [48, 9, 22, 3]
# True True
# avoiding edges:(48, 9), (8, 3)
# Query time--- 0.02653646469116211 seconds ---
# query output:[48, 46, 24, 22, 3] , weight:170.63636363636363
# cross_check output:[48, 46, 24, 22, 3] , weight:170.63636363636363
# Cross_check time--- 0.0009791851043701172 seconds ---
# ===================================================
# case:27 ===>
# [29, 14, 21, 37, 2]
# True True
# avoiding edges:(14, 21), (29, 8)
# Query time--- 0.012041091918945312 seconds ---
# query output:[29, 33, 32, 27, 18, 2] , weight:221.26262626262624
# cross_check output:[29, 33, 32, 27, 18, 2] , weight:221.26262626262624
# Cross_check time--- 0.0 seconds ---
# ===================================================
# case:28 ===>
# [17, 25, 40]
# True True
# avoiding edges:(17, 25), (17, 4)
# Query time--- 0.0019989013671875 seconds ---
# query output:[17, 3, 22, 37, 21, 40] , weight:218.3232323232323
# cross_check output:[17, 3, 22, 37, 21, 40] , weight:218.3232323232323
# Cross_check time--- 0.0010006427764892578 seconds ---
# ===================================================
# case:29 ===>
# [26, 35, 15, 22, 3]
# True True
# avoiding edges:(22, 3), (26, 35)
# Query time--- 0.0030052661895751953 seconds ---
# query output:[26, 12, 25, 17, 3] , weight:242.57575757575756
# cross_check output:[26, 12, 25, 17, 3] , weight:242.57575757575756
# Cross_check time--- 0.0014729499816894531 seconds ---
# ===================================================
# case:30 ===>
# [0, 45, 12, 21, 14]
# case:31 ===>
# [49, 19, 42, 46, 16]
# True True
# avoiding edges:(46, 16), (25, 12)
# Query time--- 0.15379977226257324 seconds ---
# query output:[49, 19, 37, 21, 23, 16] , weight:239.23232323232327
# cross_check output:[49, 19, 37, 21, 23, 16] , weight:239.23232323232327
# Cross_check time--- 0.0010178089141845703 seconds ---
# ===================================================
# case:32 ===>
# [2, 37, 22, 3]
# True True
# avoiding edges:(22, 3), (8, 3)
# Query time--- 0.02644181251525879 seconds ---
# query output:[2, 18, 27, 1, 40, 25, 17, 3] , weight:247.24242424242425
# cross_check output:[2, 18, 27, 1, 40, 25, 17, 3] , weight:247.24242424242425
# Cross_check time--- 0.001010894775390625 seconds ---
# ===================================================
# case:33 ===>
# [7, 46, 24, 41, 2]
# True True
# avoiding edges:(46, 24), (1, 27)
# Query time--- 0.038800954818725586 seconds ---
# query output:[7, 22, 37, 2] , weight:171.02020202020202
# cross_check output:[7, 22, 37, 2] , weight:171.02020202020202
# Cross_check time--- 0.0010027885437011719 seconds ---
# ===================================================
# case:34 ===>
# case:35 ===>
# Shortest path for (1, 11) not found in shortest_paths.
# case:36 ===>
# [2, 18, 27, 32, 33]
# True True
# avoiding edges:(18, 27), (21, 14)
# Query time--- 0.040082454681396484 seconds ---
# query output:[2, 37, 19, 49, 33] , weight:185.24242424242422
# cross_check output:[2, 37, 19, 49, 33] , weight:185.24242424242425
# Cross_check time--- 0.0010340213775634766 seconds ---
# ===================================================
# case:37 ===>
# [39, 10, 5, 48, 46, 24]
# True True
# avoiding edges:(39, 10), (39, 23)
# Query time--- 0.008382320404052734 seconds ---
# query output:[39, 47, 33, 48, 46, 24] , weight:265.5656565656566
# cross_check output:[39, 47, 33, 48, 46, 24] , weight:265.5656565656566
# Cross_check time--- 0.0009975433349609375 seconds ---
# ===================================================
# case:38 ===>
# Shortest path for (30, 14) not found in shortest_paths.
# case:39 ===>
# Shortest path for (26, 20) not found in shortest_paths.
# case:40 ===>
# [23, 36, 12, 45, 6]
# True True
# avoiding edges:(12, 45), (21, 14)
# Query time--- 0.03717494010925293 seconds ---
# query output:[23, 36, 12, 25, 40, 44, 6] , weight:171.58585858585857
# cross_check output:[23, 36, 12, 25, 40, 44, 6] , weight:171.58585858585857
# Cross_check time--- 0.001001119613647461 seconds ---
# ===================================================
# case:41 ===>
# [25, 12, 45, 43]
# case:42 ===>
# [31, 3, 8, 24, 41]
# True True
# avoiding edges:(8, 24), (31, 3)
# Query time--- 0.0070230960845947266 seconds ---
# query output:[31, 15, 22, 37, 2, 41] , weight:218.94949494949495
# cross_check output:[31, 15, 22, 37, 2, 41] , weight:218.94949494949495
# Cross_check time--- 0.0009958744049072266 seconds ---
# ===================================================
# case:43 ===>
# [38, 22, 3, 17]
# True True
# avoiding edges:(22, 3), (8, 3)
# Query time--- 0.021633386611938477 seconds ---
# query output:[38, 22, 37, 21, 40, 25, 17] , weight:207.18181818181816
# cross_check output:[38, 22, 37, 21, 40, 25, 17] , weight:207.1818181818182
# Cross_check time--- 0.0010051727294921875 seconds ---
# ===================================================
# case:44 ===>
# [13, 48]
# True True
# avoiding edges:(13, 48), (46, 48)
# Query time--- 0.010996341705322266 seconds ---
# query output:[13, 42, 15, 22, 9, 48] , weight:182.14141414141415
# cross_check output:[13, 42, 15, 22, 9, 48] , weight:182.14141414141417
# Cross_check time--- 0.0 seconds ---
# ===================================================
# case:45 ===>
# Shortest path for (21, 20) not found in shortest_paths.
# case:46 ===>
# [17, 4, 7, 46, 42]
# True True
# avoiding edges:(46, 42), (17, 3)
# Query time--- 0.017339468002319336 seconds ---
# query output:[17, 4, 31, 15, 42] , weight:197.4242424242424
# cross_check output:[17, 4, 31, 15, 42] , weight:197.42424242424244
# Cross_check time--- 0.001065969467163086 seconds ---
# ===================================================
# case:47 ===>
# [6, 45, 12, 25, 40, 49]
# True True
# avoiding edges:(6, 45), (6, 44)
# Query time--- 0.013572454452514648 seconds ---
# query output:[6, 14, 21, 37, 19, 49] , weight:177.6969696969697
# cross_check output:[6, 14, 21, 37, 19, 49] , weight:177.69696969696972
# Cross_check time--- 0.0 seconds ---
# ===================================================
# case:48 ===>
# [27, 1, 37, 21, 14, 29]
# True True
# avoiding edges:(27, 1), (37, 21)
# Query time--- 0.042226552963256836 seconds ---
# query output:[27, 32, 33, 29] , weight:187.59595959595958
# cross_check output:[27, 32, 33, 29] , weight:187.59595959595958
# Cross_check time--- 0.00099945068359375 seconds ---
# ===================================================
# case:49 ===>
# [46, 16, 23, 36]
# True True
# avoiding edges:(23, 36), (16, 23)
# Query time--- 0.006510496139526367 seconds ---
# query output:[46, 48, 40, 25, 12, 36] , weight:160.62626262626262
# cross_check output:[46, 48, 40, 25, 12, 36] , weight:160.62626262626262
# Cross_check time--- 0.0009908676147460938 seconds ---
# ===================================================
# case:50 ===>
# [36, 12, 45]
# True True
# avoiding edges:(12, 45), (6, 45)
# Query time--- 0.10224199295043945 seconds ---
# query output:[] , weight:inf
# No path exists between nodes 36 and 45 after removing edges (12, 45) and (6, 45).
# cross_check output:[] , weight:inf
# Cross_check time--- 0.0 seconds ---
# ===================================================
# case:51 ===>
# [33, 32, 12, 45, 43]
# case:52 ===>
# [42, 19, 37, 21]
# True True
# avoiding edges:(37, 21), (35, 14)
# Query time--- 0.06374526023864746 seconds ---
# query output:[42, 15, 22, 9, 21] , weight:151.6868686868687
# cross_check output:[42, 15, 22, 9, 21] , weight:151.6868686868687
# Cross_check time--- 0.0009946823120117188 seconds ---
# ===================================================
# case:53 ===>
# [49, 40, 48]
# True True
# avoiding edges:(40, 48), (37, 9)
# Query time--- 0.014795303344726562 seconds ---
# query output:[49, 33, 48] , weight:146.8181818181818
# cross_check output:[49, 33, 48] , weight:146.8181818181818
# Cross_check time--- 0.0015180110931396484 seconds ---
# ===================================================
# case:54 ===>
# [28, 1, 40]
# True True
# avoiding edges:(28, 1), (21, 40)
# Query time--- 0.010581016540527344 seconds ---
# query output:[28, 37, 1, 40] , weight:157.91919191919192
# cross_check output:[28, 37, 1, 40] , weight:157.91919191919192
# Cross_check time--- 0.0014772415161132812 seconds ---
# ===================================================
# case:55 ===>
# [44, 6, 45, 0]
# case:56 ===>
# [5, 48, 40, 1]
# True True
# avoiding edges:(5, 48), (25, 40)
# Query time--- 0.022977113723754883 seconds ---
# query output:[5, 10, 32, 27, 1] , weight:183.4141414141414
# cross_check output:[5, 10, 32, 27, 1] , weight:183.4141414141414
# Cross_check time--- 0.0010344982147216797 seconds ---
# ===================================================
# case:57 ===>
# [39, 47, 33, 49]
# True True
# avoiding edges:(33, 49), (12, 25)
# Query time--- 0.0754995346069336 seconds ---
# query output:[39, 23, 21, 37, 19, 49] , weight:194.3939393939394
# cross_check output:[39, 23, 21, 37, 19, 49] , weight:194.3939393939394
# Cross_check time--- 0.0010030269622802734 seconds ---
# ===================================================
# case:58 ===>
# [24, 46, 48, 5, 10, 39]
# True True
# avoiding edges:(10, 39), (46, 16)
# Query time--- 0.012994527816772461 seconds ---
# query output:[24, 46, 48, 5, 10, 23, 39] , weight:182.25252525252523
# cross_check output:[24, 46, 48, 5, 10, 23, 39] , weight:182.25252525252526
# Cross_check time--- 0.0010008811950683594 seconds ---
# ===================================================
# case:59 ===>
# [10, 42, 34]
# True True
# avoiding edges:(42, 34), (5, 48)
# Query time--- 0.029570341110229492 seconds ---
# query output:[10, 25, 40, 1, 28, 34] , weight:233.07070707070707
# cross_check output:[10, 25, 40, 1, 28, 34] , weight:233.07070707070707
# Cross_check time--- 0.0010128021240234375 seconds ---
# ===================================================
# case:60 ===>
# [1, 28, 46, 24, 8]
# True True
# avoiding edges:(24, 8), (37, 22)
# Query time--- 0.022736787796020508 seconds ---
# query output:[1, 40, 48, 9, 22, 3, 8] , weight:222.7979797979798
# cross_check output:[1, 40, 48, 9, 22, 3, 8] , weight:222.7979797979798
# Cross_check time--- 0.0010020732879638672 seconds ---
# ===================================================
# case:61 ===>
# [44, 6, 45]
# True True
# avoiding edges:(6, 45), (40, 25)
# Query time--- 0.059882164001464844 seconds ---
# query output:[44, 18, 27, 36, 12, 45] , weight:163.85858585858585
# cross_check output:[44, 18, 27, 36, 12, 45] , weight:163.85858585858588
# Cross_check time--- 0.0006074905395507812 seconds ---
# ===================================================
# case:62 ===>
# [8, 24, 46, 48, 40, 25]
# True True
# avoiding edges:(48, 40), (24, 22)
# Query time--- 0.0164949893951416 seconds ---
# query output:[8, 24, 46, 28, 1, 40, 25] , weight:176.76767676767676
# cross_check output:[8, 24, 46, 28, 1, 40, 25] , weight:176.76767676767676
# Cross_check time--- 0.0009975433349609375 seconds ---
# ===================================================
# case:63 ===>
# [40, 49, 33]
# True True
# avoiding edges:(49, 33), (1, 27)
# Query time--- 0.0413050651550293 seconds ---
# query output:[40, 48, 33] , weight:153.87878787878788
# cross_check output:[40, 48, 33] , weight:153.87878787878788
# Cross_check time--- 0.0 seconds ---
# ===================================================
# case:64 ===>
# [42, 13]
# True True
# avoiding edges:(42, 13), (48, 13)
# Query time--- 0.0029747486114501953 seconds ---
# query output:[42, 19, 37, 2, 41, 13] , weight:186.88888888888886
# cross_check output:[42, 19, 37, 2, 41, 13] , weight:186.88888888888886
# Cross_check time--- 0.0010216236114501953 seconds ---
# ===================================================
# case:65 ===>
# [38, 22, 37, 12]
# case:66 ===>
# [22, 37, 12]
# True True
# avoiding edges:(22, 37), (9, 37)
# Query time--- 0.0010204315185546875 seconds ---
# query output:[22, 15, 35, 26, 12] , weight:149.3030303030303
# cross_check output:[22, 15, 35, 26, 12] , weight:149.3030303030303
# Cross_check time--- 0.0013797283172607422 seconds ---
# ===================================================
# case:67 ===>
# case:68 ===>
# [24, 46, 7, 4]
# True True
# avoiding edges:(24, 46), (24, 8)
# Query time--- 0.03241300582885742 seconds ---
# query output:[24, 22, 3, 17, 4] , weight:205.12121212121212
# cross_check output:[24, 22, 3, 17, 4] , weight:205.12121212121212
# Cross_check time--- 0.0009963512420654297 seconds ---
# ===================================================
# case:69 ===>
# [37, 12, 45]
# True True
# avoiding edges:(12, 45), (37, 21)
# Query time--- 0.01461648941040039 seconds ---
# query output:[37, 2, 18, 44, 6, 45] , weight:137.16161616161617
# cross_check output:[37, 2, 18, 44, 6, 45] , weight:137.16161616161617
# Cross_check time--- 0.0010008811950683594 seconds ---
# ===================================================
# case:70 ===>
# [24, 46, 16, 23]
# True True
# avoiding edges:(24, 46), (22, 37)
# Query time--- 0.009999275207519531 seconds ---
# query output:[24, 22, 9, 48, 5, 10, 23] , weight:169.010101010101
# cross_check output:[24, 22, 9, 48, 5, 10, 23] , weight:169.010101010101
# Cross_check time--- 0.001003265380859375 seconds ---
# ===================================================
# case:71 ===>
# [32, 12, 45, 0]
# True True
# avoiding edges:(12, 45), (45, 0)
# Query time--- 0.040613651275634766 seconds ---
# query output:[] , weight:inf
# No path exists between nodes 32 and 0 after removing edges (12, 45) and (45, 0).
# cross_check output:[] , weight:inf
# Cross_check time--- 0.0010058879852294922 seconds ---
# ===================================================
# case:72 ===>
# [33, 32, 10]
# True True
# avoiding edges:(33, 32), (5, 10)
# Query time--- 0.0049970149993896484 seconds ---
# query output:[33, 47, 39, 10] , weight:143.23232323232324
# cross_check output:[33, 47, 39, 10] , weight:143.23232323232324
# Cross_check time--- 0.0023794174194335938 seconds ---
# ===================================================
# case:73 ===>
# [21, 37, 19, 42, 46]
# True True
# avoiding edges:(42, 46), (48, 46)
# Query time--- 0.011674165725708008 seconds ---
# query output:[21, 37, 22, 24, 46] , weight:104.8989898989899
# cross_check output:[21, 37, 22, 24, 46] , weight:104.8989898989899
# Cross_check time--- 0.000995635986328125 seconds ---
# ===================================================
# case:74 ===>
# [29, 14, 25]
# True True
# avoiding edges:(29, 14), (49, 40)
# Query time--- 0.008593320846557617 seconds ---
# query output:[29, 8, 24, 46, 48, 40, 25] , weight:231.07070707070704
# cross_check output:[29, 8, 24, 46, 48, 40, 25] , weight:231.07070707070704
# Cross_check time--- 0.0009992122650146484 seconds ---
# ===================================================
# case:75 ===>
# [12, 26, 35, 15]
# True True
# avoiding edges:(35, 15), (37, 22)
# Query time--- 0.0056955814361572266 seconds ---
# query output:[12, 37, 19, 42, 15] , weight:141.25252525252523
# cross_check output:[12, 37, 19, 42, 15] , weight:141.25252525252523
# Cross_check time--- 0.0010561943054199219 seconds ---
# ===================================================
# case:76 ===>
# [35, 15, 22, 3]
# True True
# avoiding edges:(22, 3), (15, 31)
# Query time--- 0.0053136348724365234 seconds ---
# query output:[35, 15, 22, 24, 8, 3] , weight:179.1818181818182
# cross_check output:[35, 15, 22, 24, 8, 3] , weight:179.1818181818182
# Cross_check time--- 0.001009225845336914 seconds ---
# ===================================================
# case:77 ===>
# [42, 10, 32]
# True True
# avoiding edges:(42, 10), (42, 15)
# Query time--- 0.024630069732666016 seconds ---
# query output:[42, 19, 37, 12, 32] , weight:192.14141414141415
# cross_check output:[42, 19, 37, 12, 32] , weight:192.14141414141415
# Cross_check time--- 0.0013446807861328125 seconds ---
# ===================================================
# case:78 ===>
# [47, 33, 35, 15]
# True True
# avoiding edges:(47, 33), (10, 5)
# Query time--- 0.03209376335144043 seconds ---
# query output:[47, 39, 10, 42, 15] , weight:236.20202020202018
# cross_check output:[47, 39, 10, 42, 15] , weight:236.2020202020202
# Cross_check time--- 0.0010042190551757812 seconds ---
# ===================================================
# case:79 ===>
# Shortest path for (8, 30) not found in shortest_paths.
# case:80 ===>
# [2, 18, 27, 32, 33, 47]
# True True
# avoiding edges:(18, 27), (37, 21)
# Query time--- 0.0485532283782959 seconds ---
# query output:[2, 21, 14, 35, 33, 47] , weight:207.95959595959596
# cross_check output:[2, 21, 14, 35, 33, 47] , weight:207.95959595959596
# Cross_check time--- 0.001497507095336914 seconds ---
# ===================================================
# case:81 ===>
# [33, 35, 15, 42]
# True True
# avoiding edges:(33, 35), (33, 49)
# Query time--- 0.007782459259033203 seconds ---
# query output:[33, 48, 46, 42] , weight:178.91919191919192
# cross_check output:[33, 48, 46, 42] , weight:178.91919191919192
# Cross_check time--- 0.0 seconds ---
# ===================================================
# case:82 ===>
# [28, 1, 40, 25, 12, 36]
# True True
# avoiding edges:(40, 25), (27, 36)
# Query time--- 0.007370471954345703 seconds ---
# query output:[28, 37, 21, 36] , weight:139.25252525252526
# cross_check output:[28, 37, 21, 36] , weight:139.25252525252526
# Cross_check time--- 0.0 seconds ---
# ===================================================
# case:83 ===>
# [42, 46, 16]
# True True
# avoiding edges:(46, 16), (42, 10)
# Query time--- 0.0047185420989990234 seconds ---
# query output:[42, 19, 37, 21, 23, 16] , weight:217.22222222222223
# cross_check output:[42, 19, 37, 21, 23, 16] , weight:217.22222222222223
# Cross_check time--- 0.000993967056274414 seconds ---
# ===================================================
# case:84 ===>
# [29, 8, 3, 17]
# True True
# avoiding edges:(3, 17), (46, 7)
# Query time--- 0.026388168334960938 seconds ---
# query output:[29, 14, 25, 17] , weight:249.60606060606062
# cross_check output:[29, 14, 25, 17] , weight:249.60606060606062
# Cross_check time--- 0.001146554946899414 seconds ---
# ===================================================
# case:85 ===>
# Shortest path for (50, 44) not found in shortest_paths.
# case:86 ===>
# [24, 46, 48, 5, 10]
# True True
# avoiding edges:(46, 48), (48, 5)
# Query time--- 0.01018834114074707 seconds ---
# query output:[24, 46, 42, 10] , weight:160.1010101010101
# cross_check output:[24, 46, 42, 10] , weight:160.1010101010101
# Cross_check time--- 0.0 seconds ---
# ===================================================
# case:87 ===>
# [2, 37, 19, 42, 34]
# True True
# avoiding edges:(42, 34), (2, 18)
# Query time--- 0.03397846221923828 seconds ---
# query output:[2, 41, 24, 34] , weight:178.6060606060606
# cross_check output:[2, 41, 24, 34] , weight:178.6060606060606
# Cross_check time--- 0.0009965896606445312 seconds ---
# ===================================================
# case:88 ===>
# [5, 48, 40, 4]
# True True
# avoiding edges:(40, 4), (5, 48)
# Query time--- 0.002008676528930664 seconds ---
# query output:[5, 10, 25, 17, 4] , weight:235.28282828282826
# cross_check output:[5, 10, 25, 17, 4] , weight:235.28282828282826
# Cross_check time--- 0.000989675521850586 seconds ---
# ===================================================
# case:89 ===>
# case:90 ===>
# [40, 1, 27, 32]
# True True
# avoiding edges:(1, 27), (25, 12)
# Query time--- 0.008677482604980469 seconds ---
# query output:[40, 25, 10, 32] , weight:164.5050505050505
# cross_check output:[40, 25, 10, 32] , weight:164.5050505050505
# Cross_check time--- 0.0012259483337402344 seconds ---
# ===================================================
# case:91 ===>
# [38, 22, 37, 19, 49]
# case:92 ===>
# [27, 1, 40, 48, 5]
# True True
# avoiding edges:(1, 40), (37, 9)
# Query time--- 0.007603168487548828 seconds ---
# query output:[27, 18, 2, 41, 13, 48, 5] , weight:159.87878787878788
# cross_check output:[27, 18, 2, 41, 13, 48, 5] , weight:159.87878787878788
# Cross_check time--- 0.0011835098266601562 seconds ---
# ===================================================
# case:93 ===>
# [46, 24, 22]
# True True
# avoiding edges:(24, 22), (46, 48)
# Query time--- 0.002981901168823242 seconds ---
# query output:[46, 42, 15, 22] , weight:93.07070707070707
# cross_check output:[46, 42, 15, 22] , weight:93.07070707070707
# Cross_check time--- 0.0014760494232177734 seconds ---
# ===================================================
# case:94 ===>
# [0, 45, 6, 44]
# True True
# avoiding edges:(45, 6), (0, 45)
# Query time--- 0.04296517372131348 seconds ---
# query output:[] , weight:inf
# No path exists between nodes 0 and 44 after removing edges (45, 6) and (0, 45).
# cross_check output:[] , weight:inf
# Cross_check time--- 0.0010006427764892578 seconds ---
# ===================================================
# case:95 ===>
# [37, 19, 42]
# True True
# avoiding edges:(19, 42), (22, 15)
# Query time--- 0.0032858848571777344 seconds ---
# query output:[37, 21, 14, 35, 15, 42] , weight:90.83838383838385
# cross_check output:[37, 21, 14, 35, 15, 42] , weight:90.83838383838385
# Cross_check time--- 0.0012733936309814453 seconds ---
# ===================================================
# case:96 ===>
# case:97 ===>
# [25, 40, 48, 46, 7]
# True True
# avoiding edges:(46, 7), (4, 7)
# Query time--- 0.007882118225097656 seconds ---
# query output:[25, 40, 21, 37, 22, 7] , weight:191.1010101010101
# cross_check output:[25, 40, 21, 37, 22, 7] , weight:191.1010101010101
# Cross_check time--- 0.0 seconds ---
# ===================================================
# case:98 ===>
# [23, 36, 12, 45, 6, 44, 18]
# True True
# avoiding edges:(12, 45), (36, 27)
# Query time--- 0.009179830551147461 seconds ---
# query output:[23, 36, 12, 25, 40, 1, 27, 18] , weight:141.07070707070707
# cross_check output:[23, 36, 12, 25, 40, 1, 27, 18] , weight:141.07070707070707
# Cross_check time--- 0.0010044574737548828 seconds ---
# ===================================================
# case:99 ===>
# [28, 1, 40, 25]
# True True
# avoiding edges:(1, 40), (21, 40)
# Query time--- 0.0164945125579834 seconds ---
# query output:[28, 37, 21, 14, 25] , weight:169.58585858585857
# cross_check output:[28, 37, 21, 14, 25] , weight:169.5858585858586
# Cross_check time--- 0.000997781753540039 seconds ---
# ===================================================

# %%
# import cProfile
# # case:556 ===>
# # [34, 42, 19, 49]
# # True True
# # avoiding edges:(34, 42), (1, 40)
# # Query time--- 0.5906648635864258 seconds ---
# # query output:[34, 24, 46, 42, 19, 49] , weight:233.81818181818178
# # cross_check output:[34, 24, 46, 42, 19, 49] , weight:233.81818181818178
# # Cross_check time--- 0.0009906291961669922 seconds ---
# e = [(34, 42), (1, 40)] 
# cProfile.run('QUERY2(G, 34, 49, 3, e)')

# %%
import matplotlib.pyplot as plt
import numpy as np

print(f"right={right}, wrong={wrong}")

# Convert seconds to milliseconds
query_time_ms = [t * 1_000 for t in query_times]
naive_query_time_ms = [t * 1_000 for t in cross_check_times]    

# Compute statistics
average_query_time = np.mean(query_time_ms)
average_naive_time = np.mean(naive_query_time_ms)
max_query_time = np.max(query_time_ms)
max_naive_time = np.max(naive_query_time_ms)

# Create plot with access to axes
fig, ax = plt.subplots(figsize=(16, 9))
ax.plot(query_time_ms, label='QUERY Time (ms)', color='blue', linewidth=2)
ax.plot(naive_query_time_ms, label='Cross-check Time (ms)', color='orange', linewidth=2)
ax.set_xlabel("Test Case Index", fontsize=14)
ax.set_ylabel("Time (milliseconds)", fontsize=14)
ax.set_title("QUERY vs Cross-check (Naive) Time for Shortest Path with Dual Edge Fault", fontsize=16)
ax.legend(fontsize=12)
ax.grid(True)

# Add stats text box above the plot
stats_text = (
    f"Graph with {len(G.nodes())} Nodes and {len(G.edges())} Edges | "
    f"Avg QUERY: {average_query_time:.2f} ms | "
    f"Avg Naive: {average_naive_time:.2f} ms | "
    f"Max QUERY: {max_query_time:.2f} ms | "
    f"Max Naive: {max_naive_time:.2f} ms"
)
ax.text(0.5, 1.05, stats_text, transform=ax.transAxes,
        ha='center', va='bottom', fontsize=12,
        bbox=dict(boxstyle="round,pad=0.4", edgecolor='black', facecolor='lightyellow'))

# Adjust layout to fit text
plt.subplots_adjust(top=0.88)
plt.tight_layout()
plt.show()
# Out:
# right=80, wrong=0
